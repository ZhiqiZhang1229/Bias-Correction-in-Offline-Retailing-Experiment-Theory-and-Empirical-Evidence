# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import MinMaxScaler,StandardScaler
import torch
from sklearn.model_selection import train_test_split
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
# Out:
# c:\Users\zhang\anaconda3\envs\tensorflow\lib\site-packages\scipy\__init__.py:155: UserWarning: A NumPy version >=1.18.5 and <1.26.0 is required for this version of SciPy (detected version 1.26.4
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %% [markdown]
# # Pre-processing Stage

# %%
no = pd.read_csv('no_discount.csv')
all = pd.read_csv('all_discount.csv')
half = pd.read_csv('half_discount.csv')
prod = pd.read_csv('product.csv')

# %% [markdown]
# ## Data Preparation

# %%
# Map user features to number
dataframes = {'all': all, 'half': half, 'no': no}
feature_cols = ['user_feature_1', 'user_feature_2', 'user_feature_3']
category_maps = {}

# 1. Build mapping for each feature across all dataframes
for col in feature_cols:
    # Collect unique values from all dataframes for this column
    unique_vals = pd.concat([df[col] for df in dataframes.values()]).unique()
    cat_map = {cat: i+1 for i, cat in enumerate(sorted(unique_vals))}
    category_maps[col] = cat_map

# 2. Apply the mapping to each dataframe
for df in dataframes.values():
    for col in feature_cols:
        df[col + '_num'] = df[col].map(category_maps[col])

# 3. Show mapping for each feature
for col in feature_cols:
    print(f"\nMapping for {col}:")
    for cat, idx in category_maps[col].items():
        print(f"{idx}: {cat}")
# Out:
# Mapping for user_feature_1:
# 1: Female
# 2: Male
# 3: Non-binary / third gender
# 4: Prefer not to say
#
# Mapping for user_feature_2:
# 1: 1-2 years ago
# 2: 2-3 years ago
# 3: 3-4 yeas ago
# 4: Currently, I don't have a phone
# 5: Less than 1 year ago
# 6: More than 4 years ago
#
# Mapping for user_feature_3:
# 1: Brand reputation
# 2: Design and appearance
# 3: Good price
# 4: Product quality

# %%
# Map choice to number (no discount)
# Define the mapping for 'choice'
choice_map = {
    "Do not purchase; save the $30 or use it for other expenses ($30 is roughly enough to cover two meals at a fast-food restaurant in the U.S.)": 0,
    "Color: Black; Style: Solid color; Weight: 2.66 pounds; Price: $24 (MSRP: $24)": 1,
    "Color: Black; Style: Gradient color; Weight: 2.66 pounds; Price: $26 (MSRP: $26)": 2,
    "Color: Dark blue; Style: Solid color; Weight: 2.61 pounds; Price: $25 (MSRP: $25)": 3,
    "Color: Dark blue; Style: Gradient color; Weight: 2.64 pounds; Price: $25 (MSRP: $25)": 4,
    "Color: Light blue; Style: Gradient color; Weight: 2.68 pounds; Price: $26 (MSRP: $26)": 5,
    "Color: White; Style: Solid color; Weight: 2.68 pounds; Price: $27 (MSRP: $27)": 6
}

# Apply the mapping
no['choice_num'] = no['choice'].map(choice_map)

# %%
# Map choice to number (all discount)
# Define the mapping for 'choice'
choice_map = {
    "Do not purchase; save the $30 or use it for other expenses ($30 is roughly enough to cover two meals at a fast-food restaurant in the U.S.)": 0,
    "Color: Black; Style: Solid color; Weight: 2.66 pounds; Price: $4.8 (MSRP: $24)": 1,
    "Color: Black; Style: Gradient color; Weight: 2.66 pounds; Price: $5.2 (MSRP: $26)": 2,
    "Color: Dark blue; Style: Solid color; Weight: 2.61 pounds; Price: $5 (MSRP: $25)": 3,
    "Color: Dark blue; Style: Gradient color; Weight: 2.64 pounds; Price: $5 (MSRP: $25)": 4,
    "Color: Light blue; Style: Gradient color; Weight: 2.68 pounds; Price: $5.2 (MSRP: $26)": 5,
    "Color: White; Style: Solid color; Weight: 2.68 pounds; Price: $5.4 (MSRP: $27)": 6
}

# Apply the mapping
all['choice_num'] = all['choice'].map(choice_map)

# %%
# Map choice to number (half discount)
# Define the mapping for 'choice'
choice_map = {
    "Do not purchase; save the $30 or use it for other expenses ($30 is roughly enough to cover two meals at a fast-food restaurant in the U.S.)": 0,
    "Color: Black; Style: Solid color; Weight: 2.66 pounds; Price: $4.8 (MSRP: $24)": 1,
    "Color: Black; Style: Gradient color; Weight: 2.66 pounds; Price: $26 (MSRP: $26)": 2,
    "Color: Dark blue; Style: Solid color; Weight: 2.61 pounds; Price: $25 (MSRP: $25)": 3,
    "Color: Dark blue; Style: Gradient color; Weight: 2.64 pounds; Price: $25 (MSRP: $25)": 4,
    "Color: Light blue; Style: Gradient color; Weight: 2.68 pounds; Price: $5.2 (MSRP: $26)": 5,
    "Color: White; Style: Solid color; Weight: 2.68 pounds; Price: $5.4 (MSRP: $27)": 6
}

# Apply the mapping
half['choice_num'] = half['choice'].map(choice_map)

# %%
# Normalization:  price
# Define the columns to scale
columns_to_scale = [
    'price'
]

# Initialize the scaler
scaler = MinMaxScaler()

# Fit and transform the selected columns
prod[columns_to_scale] = scaler.fit_transform(prod[columns_to_scale])

# %%
# Set parameters
discount_percentage = 0.2
num_product = 6

# %%
# Check the number of valid data
num_row_no = len(no)
num_row_all = len(all)
num_row_half = len(half)
print(num_row_no)
print(num_row_all)
print(num_row_half)
# Out:
# 291
# 278
# 266

# %% [markdown]
# # Analysis Stage

# %% [markdown]
# ## True GTE

# %%
# All products are control (no discount)
# Merge the purchasing data with the product data
merged_no = no.merge(prod, left_on='choice_num', right_on='product_id', how='left')

# Calculate the total revenue
revenue_control = 0
revenue_control = merged_no['price'].sum() * 300/291

# All products are treated (all discount)
# Merge the purchasing data with the product data
merged_all = all.merge(prod, left_on='choice_num', right_on='product_id', how='left')

# Calculate the total revenue
revenue_treated = 0
revenue_treated = merged_all['price'].sum() * discount_percentage * 300/278

# Calculate the GTE
true = revenue_treated - revenue_control
print(true)
# Out:
# -68.6551789496238

# %% [markdown]
# ## DIM Estimator

# %%
# Define the function to calculate the revenue
def calculate_total_revenue(df):
    revenue_treated = 0.0
    revenue_control = 0.0
    df['adjusted_price'] = df.apply(
        lambda row: row['price'] * discount_percentage if row['if_treated'] == 1 else row['price'], axis=1
    )
    for _, row in df.iterrows():
        if row['if_treated'] == 0:
            revenue_control += row['adjusted_price']
        elif row['if_treated'] == 1:
            revenue_treated += row['adjusted_price']
    return revenue_control, revenue_treated

# Merge the purchasing data with the product data
merged_half = half.merge(prod, left_on='choice_num', right_on='product_id', how='left')

# Calculate the revenue difference
revenue_control, revenue_treated = calculate_total_revenue(merged_half)

# Calculate the GTE
naive = (revenue_treated - revenue_control) * 600/266
naive
naive_pe = abs((naive - true)/true)
print(naive_pe)
# Out:
# 0.11024849998145407

# %%
feature_cols = ['product_feature_1', 'product_feature_2', 'product_feature_3']
encoded_features = pd.get_dummies(prod[feature_cols], dtype=float)
X_product = torch.tensor(encoded_features.iloc[1:].to_numpy(), dtype=torch.float)

user_num_cols = ['user_feature_1_num', 'user_feature_2_num', 'user_feature_3_num']
encoded_features = pd.get_dummies(merged_half[user_num_cols], dtype=float)
X_user = torch.tensor(encoded_features.to_numpy(), dtype=torch.float)

# %% [markdown]
# ## MNL Estimator

# %%
# # Product features (skip the first row)
# feature_cols = ['product_feature_1', 'product_feature_2', 'product_feature_3']
# X_product = torch.tensor(prod[feature_cols].iloc[1:].to_numpy(), dtype=torch.float)

# Price (skip first row)
price = torch.tensor(prod['price'].iloc[1:].to_numpy(), dtype=torch.float)

# Product randomization (skip first row)
prod_randomization = torch.tensor(prod['if_treated'].iloc[1:].to_numpy(), dtype=torch.bool)

# User features
user_num_cols = ['user_feature_1_num', 'user_feature_2_num', 'user_feature_3_num']
X_user = torch.tensor(merged_half[user_num_cols].to_numpy(),dtype=torch.float)

# User choice
choice = torch.tensor(
    merged_half['choice_num'].to_numpy(),
    dtype=torch.long
)

# %%
# Split the training and test set
X_user_train, X_user_test, choice_train, choice_test = train_test_split(
    X_user, choice, test_size=0.5, random_state=42
)

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

X_user_train = X_user_train.to(device)
X_user_test  = X_user_test.to(device)
X_product    = X_product.to(device)
price        = price.to(device)
prod_randomization = prod_randomization.to(device)

choice_train = choice_train.to(device)
choice_test  = choice_test.to(device)

# Validation set
X_user_train1, X_user_val, choice_train1, choice_val = train_test_split(X_user_train, choice_train,test_size=0.1,random_state=34)

# %% [markdown]
# ### No features

# %%
class LinearMNLModel_No(nn.Module):
    def __init__(self):
        super(LinearMNLModel_No, self).__init__()
        # v is the same constant value for all products.
        self.v = nn.Parameter(torch.tensor(1.0))
        # gamma is the price sensitivity parameter.
        self.gamma = nn.Parameter(torch.tensor(1.0))

    def forward(self, x_user, X_product, price, prod_randomization):
        N = x_user.shape[0]
        # Adjust prices for treated products (discounted)
        adjusted_price = torch.where(
            prod_randomization,
            price * discount_percentage,
            price
        )
        # Compute utilities: shape [M]
        utility = self.v + self.gamma * adjusted_price
        # Expand to shape [N, M]
        utility = utility.expand(N, -1)
        # Add outside option (utility = 0)
        zero_utilities = torch.zeros(N, 1, device=utility.device)
        utilities_with_outside = torch.cat((zero_utilities, utility), dim=1)
        return utilities_with_outside

# %%
model = LinearMNLModel_No().to(device)
optimizer = optim.Adam(model.parameters(), lr=0.1) 

num_epochs = 1000
l2_lambda = 0
best_val_loss = float('inf')
patience = 10
patience_counter = 0

for epoch in range(num_epochs):
    # Set model to training mode
    model.train()
    optimizer.zero_grad()

    # Forward pass (Training)
    utilities = model(X_user_train1, X_product, price, prod_randomization)
    
    choice_probabilities = F.log_softmax(utilities, dim=1)
    loss = -torch.mean(choice_probabilities[torch.arange(choice_probabilities.shape[0]), choice_train1])

    # L2 Regularization
    l2_norm = sum(param.pow(2.0).sum() for param in model.parameters())
    loss = loss + l2_lambda * l2_norm

    # Backward pass
    loss.backward()
    optimizer.step()
    model.eval()  # Set model to evaluation mode
    with torch.no_grad():
        val_utilities = model(X_user_val, X_product, price, prod_randomization)
        
        # val_utilities = val_utilities - val_utilities.max(dim=1, keepdim=True).values
        
        val_choice_probabilities = F.log_softmax(val_utilities, dim=1)
        val_loss = -torch.mean(val_choice_probabilities[torch.arange(val_choice_probabilities.shape[0]), choice_val])

    if epoch % 100 == 0: 
        print(f"Epoch {epoch+1}, Training Loss: {loss.item()}, Validation Loss: {val_loss.item()}")

    if (val_loss < best_val_loss) | (val_loss < loss):
        best_val_loss = val_loss
        patience_counter = 0  # Reset counter
        # torch.save(model.state_dict(), 'best_model_linear_mnl.pth')  # Save best model
    else:
        patience_counter += 1  

    if patience_counter >= patience:
        print(f"Early stopping triggered at epoch {epoch}")
        break
# Out:
# Epoch 1, Training Loss: 2.959160566329956, Validation Loss: 2.8459665775299072
# Epoch 101, Training Loss: 1.2196589708328247, Validation Loss: 1.1565020084381104
# Epoch 201, Training Loss: 1.2172282934188843, Validation Loss: 1.133847713470459
# Epoch 301, Training Loss: 1.2172260284423828, Validation Loss: 1.1332342624664307
# Epoch 401, Training Loss: 1.2172260284423828, Validation Loss: 1.1332358121871948
# Epoch 501, Training Loss: 1.2172260284423828, Validation Loss: 1.1332358121871948
# Epoch 601, Training Loss: 1.2172260284423828, Validation Loss: 1.1332358121871948
# Epoch 701, Training Loss: 1.2172260284423828, Validation Loss: 1.1332358121871948
# Epoch 801, Training Loss: 1.2172260284423828, Validation Loss: 1.1332358121871948
# Epoch 901, Training Loss: 1.2172260284423828, Validation Loss: 1.1332358121871948

# %%
# All control and all treated in test set
all_product_control = np.random.choice([0,1], num_product, p=[1, 0])
all_product_treated = np.random.choice([0,1], num_product, p=[0, 1])
all_product_control = torch.from_numpy(all_product_control).to(X_user_train.device).bool()
all_product_treated = torch.from_numpy(all_product_treated).to(X_user_train.device).bool()
X_user_test, X_product, price = X_user_test.to(device), X_product.to(device), price.to(device)

# Calculate expected revenue if all control
utilities = model(X_user_test, X_product, price, all_product_control)
probabilities = F.softmax(utilities, dim=1)  # Convert utilities to probabilities
price_with_outside = torch.cat((torch.zeros(1, device=price.device),price), dim=0)
expected_revenue = torch.sum(probabilities * price_with_outside.unsqueeze(0).expand_as(probabilities), dim=0).sum()
print(f"Expected Revenue: ${expected_revenue.item():.2f}")

# Calculate expected revenue if all treated
utilities = model(X_user_test, X_product, price, all_product_treated)
probabilities = F.softmax(utilities, dim=1)  # Convert utilities to probabilities
price_with_outside = torch.cat((torch.zeros(1, device=price.device),price), dim=0)
expected_revenue_treated = torch.sum(probabilities * price_with_outside.unsqueeze(0).expand_as(probabilities), dim=0).sum() * discount_percentage
print(f"Expected Revenue: ${expected_revenue_treated.item():.2f}")

# Calculate GTE
linear = (expected_revenue_treated-expected_revenue).cpu().detach().numpy()
linear = linear * 600 / 266 # For comparison purpose
print(linear)
linear_no = abs((linear - true)/true)
print(linear_no)
# Out:
# Expected Revenue: $37.51
# Expected Revenue: $8.90
# -64.52994669290413
# 0.06008625015378063

# %% [markdown]
# ### Only user features

# %%
class LinearMNLModel_UserOnly(nn.Module):
    def __init__(self, user_feature_dim):
        super(LinearMNLModel_UserOnly, self).__init__()
        self.beta_user = nn.Parameter(torch.randn(user_feature_dim))
        self.beta_price = nn.Parameter(torch.tensor(-1.0))

    def forward(self, x_user, X_product, price, prod_randomization):
        N, M = x_user.shape[0], X_product.shape[0]

        # Expand user features
        x_user_expanded = x_user.unsqueeze(1).expand(-1, M, -1).detach()
        utility_user = torch.sum(x_user_expanded * self.beta_user, dim=2)

        # Price adjustment
        adjusted_price = torch.where(
            prod_randomization.unsqueeze(0),
            price * discount_percentage,
            price
        )
        utility_price = adjusted_price * self.beta_price
        utility_price = utility_price.expand(N, M)

        total_utility = utility_user + utility_price

        # Outside option
        zero_utilities = torch.zeros(N, 1, device=total_utility.device)
        utilities_with_outside = torch.cat((zero_utilities,total_utility), dim=1)
        return utilities_with_outside

# %%
# Model training
model = LinearMNLModel_UserOnly(user_feature_dim=X_user.shape[1]).to(device)
def init_weights(m):
    if isinstance(m, nn.Linear):
        nn.init.xavier_uniform_(m.weight)
        if m.bias is not None:
            m.bias.data.fill_(0.01)
model.apply(init_weights)
optimizer = optim.Adam(model.parameters(), lr=0.01) 
scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size=2500, gamma=0.5)

num_epochs = 1000
l2_lambda = 0
best_val_loss = float('inf')
patience = 10
patience_counter = 0

for epoch in range(num_epochs):
    # Set model to training mode
    model.train()
    optimizer.zero_grad()

    # Forward pass (Training)
    utilities = model(X_user_train1, X_product, price, prod_randomization)
    
    choice_probabilities = F.log_softmax(utilities, dim=1)
    loss = -torch.mean(choice_probabilities[torch.arange(choice_probabilities.shape[0]), choice_train1])

    # L2 Regularization
    l2_norm = sum(param.pow(2.0).sum() for param in model.parameters())
    loss = loss + l2_lambda * l2_norm

    # Backward pass
    loss.backward()
    optimizer.step()
    scheduler.step()

    # --- 4. Validation phase (验证阶段) ---
    model.eval()  # Set model to evaluation mode
    with torch.no_grad():
        val_utilities = model(X_user_val, X_product, price, prod_randomization)
        
        val_utilities = val_utilities - val_utilities.max(dim=1, keepdim=True).values
        
        val_choice_probabilities = F.log_softmax(val_utilities, dim=1)
        val_loss = -torch.mean(val_choice_probabilities[torch.arange(val_choice_probabilities.shape[0]), choice_val])

    if epoch % 100 == 0: 
        print(f"Epoch {epoch+1}, Training Loss: {loss.item()}, Validation Loss: {val_loss.item()}")

    if (val_loss < best_val_loss) | (val_loss < loss):
        best_val_loss = val_loss
        patience_counter = 0  # Reset counter
        torch.save(model.state_dict(), 'best_model_linear_mnl.pth')  # Save best model
    else:
        patience_counter += 1  

    if patience_counter >= patience:
        print(f"Early stopping triggered at epoch {epoch}")
        break
# Out:
# Epoch 1, Training Loss: 5.740757465362549, Validation Loss: 6.385035037994385
# Epoch 101, Training Loss: 1.5111818313598633, Validation Loss: 1.6648344993591309
# Epoch 201, Training Loss: 1.3114057779312134, Validation Loss: 1.4550843238830566
# Epoch 301, Training Loss: 1.260339379310608, Validation Loss: 1.3194432258605957
# Epoch 401, Training Loss: 1.226991057395935, Validation Loss: 1.213325023651123
# Epoch 501, Training Loss: 1.2106239795684814, Validation Loss: 1.1434248685836792
# Epoch 601, Training Loss: 1.2042226791381836, Validation Loss: 1.1021337509155273
# Epoch 701, Training Loss: 1.2020015716552734, Validation Loss: 1.0792975425720215
# Epoch 801, Training Loss: 1.2012255191802979, Validation Loss: 1.067275047302246
# Epoch 901, Training Loss: 1.2009180784225464, Validation Loss: 1.0612200498580933

# %%
# All control and all treated in test set
all_product_control = np.random.choice([0,1], num_product, p=[1, 0])
all_product_treated = np.random.choice([0,1], num_product, p=[0, 1])
all_product_control = torch.from_numpy(all_product_control).to(X_user_train.device).bool()
all_product_treated = torch.from_numpy(all_product_treated).to(X_user_train.device).bool()
X_user_test, X_product, price = X_user_test.to(device), X_product.to(device), price.to(device)

# Calculate expected revenue if all control
utilities = model(X_user_test, X_product, price, all_product_control)
probabilities = F.softmax(utilities, dim=1)  # Convert utilities to probabilities
price_with_outside = torch.cat((torch.zeros(1, device=price.device),price), dim=0)
expected_revenue = torch.sum(probabilities * price_with_outside.unsqueeze(0).expand_as(probabilities), dim=0).sum()
print(f"Expected Revenue: ${expected_revenue.item():.2f}")

# Calculate expected revenue if all treated
utilities = model(X_user_test, X_product, price, all_product_treated)
probabilities = F.softmax(utilities, dim=1)  # Convert utilities to probabilities
price_with_outside = torch.cat((torch.zeros(1, device=price.device),price), dim=0)
expected_revenue_treated = torch.sum(probabilities * price_with_outside.unsqueeze(0).expand_as(probabilities), dim=0).sum() * discount_percentage
print(f"Expected Revenue: ${expected_revenue_treated.item():.2f}")

# Calculate GTE
linear = (expected_revenue_treated-expected_revenue).cpu().detach().numpy()
linear = linear * 600 / 266
print(linear)
linear_user_only = abs((linear - true)/true)
print(linear_user_only)
# Out:
# Expected Revenue: $36.43
# Expected Revenue: $8.95
# -61.987276005565676
# 0.09712163082337526

# %% [markdown]
# ### Only product features

# %%
class LinearMNLModel_ProductOnly(nn.Module):
    def __init__(self, product_feature_dim):
        super(LinearMNLModel_ProductOnly, self).__init__()
        self.beta_product = nn.Parameter(torch.randn(product_feature_dim))
        self.beta_price = nn.Parameter(torch.tensor(-1.0))

    def forward(self, x_user, X_product, price, prod_randomization):
        N, M = x_user.shape[0], X_product.shape[0]

        # Expand product features
        X_product_expanded = X_product.unsqueeze(0).expand(N, -1, -1).detach()
        utility_product = torch.sum(X_product_expanded * self.beta_product, dim=2)

        # Price adjustment
        adjusted_price = torch.where(
            prod_randomization.unsqueeze(0),
            price * discount_percentage,
            price
        )
        utility_price = adjusted_price * self.beta_price
        utility_price = utility_price.expand(N, M)

        total_utility = utility_product + utility_price

        # Outside option
        zero_utilities = torch.zeros(N, 1, device=total_utility.device)
        utilities_with_outside = torch.cat((zero_utilities,total_utility), dim=1)
        return utilities_with_outside

# %%
# Model training
model = LinearMNLModel_ProductOnly(product_feature_dim=X_product.shape[1]).to(device)
def init_weights(m):
    if isinstance(m, nn.Linear):
        nn.init.xavier_uniform_(m.weight)
        if m.bias is not None:
            m.bias.data.fill_(0.01)
model.apply(init_weights)
optimizer = optim.Adam(model.parameters(), lr=0.01) 


num_epochs = 1000
l2_lambda = 0
best_val_loss = float('inf')
patience = 20
patience_counter = 0

for epoch in range(num_epochs):
    # Set model to training mode
    model.train()
    optimizer.zero_grad()

    # Forward pass (Training)
    utilities = model(X_user_train1, X_product, price, prod_randomization)
    
    choice_probabilities = F.log_softmax(utilities, dim=1)
    loss = -torch.mean(choice_probabilities[torch.arange(choice_probabilities.shape[0]), choice_train1])

    # L2 Regularization
    l2_norm = sum(param.pow(2.0).sum() for param in model.parameters())
    loss = loss + l2_lambda * l2_norm

    # Backward pass
    loss.backward()
    optimizer.step()


    model.eval()  # Set model to evaluation mode
    with torch.no_grad():
        val_utilities = model(X_user_val, X_product, price, prod_randomization)
        
        # val_utilities = val_utilities - val_utilities.max(dim=1, keepdim=True).values
        
        val_choice_probabilities = F.log_softmax(val_utilities, dim=1)
        val_loss = -torch.mean(val_choice_probabilities[torch.arange(val_choice_probabilities.shape[0]), choice_val])

    if epoch % 100 == 0: 
        print(f"Epoch {epoch+1}, Training Loss: {loss.item()}, Validation Loss: {val_loss.item()}")

    if (val_loss < best_val_loss) | (val_loss < loss):
        best_val_loss = val_loss
        patience_counter = 0  # Reset counter
        torch.save(model.state_dict(), 'best_model_linear_mnl.pth')  # Save best model
    else:
        patience_counter += 1  

    if patience_counter >= patience:
        print(f"Early stopping triggered at epoch {epoch}")
        break
# Out:
# Epoch 1, Training Loss: 1.4182103872299194, Validation Loss: 1.4443371295928955
# Epoch 101, Training Loss: 1.1987248659133911, Validation Loss: 1.1952967643737793
# Early stopping triggered at epoch 130

# %%
# All control and all treated in test set
all_product_control = np.random.choice([0,1], num_product, p=[1, 0])
all_product_treated = np.random.choice([0,1], num_product, p=[0, 1])
all_product_control = torch.from_numpy(all_product_control).to(X_user_train.device).bool()
all_product_treated = torch.from_numpy(all_product_treated).to(X_user_train.device).bool()
X_user_test, X_product, price = X_user_test.to(device), X_product.to(device), price.to(device)

# Calculate expected revenue if all control
utilities = model(X_user_test, X_product, price, all_product_control)
probabilities = F.softmax(utilities, dim=1)  # Convert utilities to probabilities
price_with_outside = torch.cat((torch.zeros(1, device=price.device),price), dim=0)
expected_revenue = torch.sum(probabilities * price_with_outside.unsqueeze(0).expand_as(probabilities), dim=0).sum()
print(f"Expected Revenue: ${expected_revenue.item():.2f}")

# Calculate expected revenue if all treated
utilities = model(X_user_test, X_product, price, all_product_treated)
probabilities = F.softmax(utilities, dim=1)  # Convert utilities to probabilities
price_with_outside = torch.cat((torch.zeros(1, device=price.device),price), dim=0)
expected_revenue_treated = torch.sum(probabilities * price_with_outside.unsqueeze(0).expand_as(probabilities), dim=0).sum() * discount_percentage
print(f"Expected Revenue: ${expected_revenue_treated.item():.2f}")

# Calculate GTE
linear = (expected_revenue_treated-expected_revenue).cpu().detach().numpy()
linear = linear * 600 / 266
print(linear)
linear_product_only = abs((linear - true)/true)
print(linear_product_only)
# Out:
# Expected Revenue: $30.96
# Expected Revenue: $11.51
# -43.865646993307244
# 0.3610730076824364

# %% [markdown]
# ### All features

# %%
# MNL choice model
class LinearMNLModel(nn.Module):
    def __init__(self, user_feature_dim, product_feature_dim):
        super(LinearMNLModel, self).__init__()
        # Initialize parameters for user and product features
        self.beta_user = nn.Parameter(torch.randn(user_feature_dim))
        self.beta_product = nn.Parameter(torch.randn(product_feature_dim))
        self.beta_price = nn.Parameter(torch.tensor(-1.0))
    def forward(self, x_user, X_product, price, prod_randomization):
        N, M = x_user.shape[0], X_product.shape[0]

        # Expand user and product features to create a [N, M, F] shaped tensor for each
        x_user_expanded = x_user.unsqueeze(1).expand(-1, M, -1).detach()
        X_product_expanded = X_product.unsqueeze(0).expand(N, -1, -1).detach()

        # Calculate linear utility from features
        utility_user = torch.sum(x_user_expanded * self.beta_user, dim=2)
        utility_product = torch.sum(X_product_expanded * self.beta_product, dim=2)

        # Adjust prices based on randomization
        adjusted_price = torch.where(
            prod_randomization.unsqueeze(0),
            price * discount_percentage,
            price
        )

        # Calculate utility from price, properly expanding its dimension
        utility_price = adjusted_price * self.beta_price  # [M]
        utility_price = utility_price.expand(N, M)  # [N, M]

        # Total utility including features and price
        total_utility = utility_user + utility_product + utility_price

        # Incorporate the outside option with utility 0
        zero_utilities = torch.zeros(N, 1, device=total_utility.device)
        utilities_with_outside = torch.cat((zero_utilities,total_utility), dim=1)

        return utilities_with_outside

# %%
# Model training
model = LinearMNLModel(
    user_feature_dim=X_user.shape[1],
    product_feature_dim=X_product.shape[1]
).to(device)
def init_weights(m):
    if isinstance(m, nn.Linear):
        nn.init.xavier_uniform_(m.weight)
        if m.bias is not None:
            m.bias.data.fill_(0.01)
model.apply(init_weights)
optimizer = optim.Adam(model.parameters(), lr=0.01) 
scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size=2500, gamma=0.5)

num_epochs = 5000
l2_lambda = 0
best_val_loss = float('inf')
patience = 20
patience_counter = 0

for epoch in range(num_epochs):
    # Set model to training mode
    model.train()
    optimizer.zero_grad()

    # Forward pass (Training)
    utilities = model(X_user_train1, X_product, price, prod_randomization)
    
    choice_probabilities = F.log_softmax(utilities, dim=1)
    loss = -torch.mean(choice_probabilities[torch.arange(choice_probabilities.shape[0]), choice_train1])

    # L2 Regularization
    l2_norm = sum(param.pow(2.0).sum() for param in model.parameters())
    loss = loss + l2_lambda * l2_norm

    # Backward pass
    loss.backward()
    optimizer.step()
    scheduler.step()

    # --- 4. Validation phase (验证阶段) ---
    model.eval()  # Set model to evaluation mode
    with torch.no_grad():
        val_utilities = model(X_user_val, X_product, price, prod_randomization)
        
        # val_utilities = val_utilities - val_utilities.max(dim=1, keepdim=True).values
        
        val_choice_probabilities = F.log_softmax(val_utilities, dim=1)
        val_loss = -torch.mean(val_choice_probabilities[torch.arange(val_choice_probabilities.shape[0]), choice_val])

    if epoch % 100 == 0: 
        print(f"Epoch {epoch+1}, Training Loss: {loss.item()}, Validation Loss: {val_loss.item()}")

    if (val_loss < best_val_loss) | (val_loss < loss):
        best_val_loss = val_loss
        patience_counter = 0  # Reset counter
        torch.save(model.state_dict(), 'best_model_linear_mnl.pth')  # Save best model
    else:
        patience_counter += 1  

    if patience_counter >= patience:
        print(f"Early stopping triggered at epoch {epoch}")
        break
# Out:
# Epoch 1, Training Loss: 4.151847839355469, Validation Loss: 3.3779635429382324
# Epoch 101, Training Loss: 1.607783317565918, Validation Loss: 1.4097914695739746
# Epoch 201, Training Loss: 1.3611581325531006, Validation Loss: 1.1588371992111206
# Epoch 301, Training Loss: 1.2767632007598877, Validation Loss: 1.0957163572311401
# Epoch 401, Training Loss: 1.2256914377212524, Validation Loss: 1.079655408859253
# Epoch 501, Training Loss: 1.194152593612671, Validation Loss: 1.08278226852417
# Epoch 601, Training Loss: 1.1777933835983276, Validation Loss: 1.096991777420044
# Epoch 701, Training Loss: 1.1700944900512695, Validation Loss: 1.1149234771728516
# Epoch 801, Training Loss: 1.1663105487823486, Validation Loss: 1.1321467161178589
# Epoch 901, Training Loss: 1.1641597747802734, Validation Loss: 1.147223711013794
# Epoch 1001, Training Loss: 1.1627538204193115, Validation Loss: 1.160097360610962
# Early stopping triggered at epoch 1040

# %%
# All control and all treated in test set
all_product_control = np.random.choice([0,1], num_product, p=[1, 0])
all_product_treated = np.random.choice([0,1], num_product, p=[0, 1])
all_product_control = torch.from_numpy(all_product_control).to(X_user_train.device).bool()
all_product_treated = torch.from_numpy(all_product_treated).to(X_user_train.device).bool()
X_user_test, X_product, price = X_user_test.to(device), X_product.to(device), price.to(device)

# Calculate expected revenue if all control
utilities = model(X_user_test, X_product, price, all_product_control)
probabilities = F.softmax(utilities, dim=1)  # Convert utilities to probabilities
price_with_outside = torch.cat((torch.zeros(1, device=price.device),price), dim=0)
expected_revenue = torch.sum(probabilities * price_with_outside.unsqueeze(0).expand_as(probabilities), dim=0).sum()
print(f"Expected Revenue: ${expected_revenue.item():.2f}")

# Calculate expected revenue if all treated
utilities = model(X_user_test, X_product, price, all_product_treated)
probabilities = F.softmax(utilities, dim=1)  # Convert utilities to probabilities
price_with_outside = torch.cat((torch.zeros(1, device=price.device),price), dim=0)
expected_revenue_treated = torch.sum(probabilities * price_with_outside.unsqueeze(0).expand_as(probabilities), dim=0).sum() * discount_percentage
print(f"Expected Revenue: ${expected_revenue_treated.item():.2f}")

# Calculate GTE
linear = (expected_revenue_treated-expected_revenue).cpu().detach().numpy()
linear = linear * 600 / 266
print(linear)
linear_all = abs((linear - true)/true)
print(linear_all)
# Out:
# Expected Revenue: $30.40
# Expected Revenue: $10.51
# -44.87579460430862
# 0.34635965864663265

# %% [markdown]
# ## PDL Estimator

# %%
# Prepare data
def prepare_data(user_features, product_features, prices):
    num_products = product_features.shape[0]
    all_x_other_products = []
    all_other_prices = []
    for i in range(num_products):
        indices = [j for j in range(num_products) if j != i]
        other_products = product_features[indices].reshape(-1)
        other_product_prices = prices[indices]
        all_x_other_products.append(other_products)
        all_other_prices.append(other_product_prices)
    # Convert lists to tensor
    all_x_other_products = torch.stack(all_x_other_products, dim=0)
    all_other_prices = torch.stack(all_other_prices, dim=0)
    return user_features, product_features, prices, all_x_other_products, all_other_prices

# %% [markdown]
# ### No features

# %%
class DeepMNLModel_No(nn.Module):
    """
    Price-only Deep MNL:
    u_ij = theta(p_j)
    Outside option utility = 0.
    """
    def __init__(self, num_product, hidden=5):
        super(DeepMNLModel_No, self).__init__()

        # theta(p_j):
        # Input:  [1]
        # Output: scalar utility
        self.theta = nn.Sequential(
        nn.Linear(1, hidden),
        nn.ReLU(),
        nn.Linear(hidden, 1)

)

    def forward(self, x_user, X_product, X_other_products, x_other_prices, price, prod_randomization):
        """
        Inputs used:
        - price: [M]  own price p_j
        - prod_randomization: [M]  treatment indicator
        """
        device = price.device
        N, M = x_user.shape[0], price.shape[0]

        # Apply treatment discount to own prices
        adjusted_price = torch.where(
            prod_randomization.to(device).bool(),
            price * discount_percentage,
            price
        )  # [M]

        # Prepare input for theta: [M, 1]
        pj_input = adjusted_price.unsqueeze(1)

        # Expand to all users: [N, M, 1]
        theta_input_exp = pj_input.unsqueeze(0).expand(N, -1, -1)

        # u_ij = theta(p_j): [N, M]
        utilities = self.theta(theta_input_exp).squeeze(-1)

        # Outside option utility = 0
        zero_utilities = torch.zeros(N, 1, device=device)
        utilities_with_outside = torch.cat([zero_utilities, utilities], dim=1)

        return utilities_with_outside

# %%
# Apply the model
pdlmodel = DeepMNLModel_No(
    num_product=X_product.shape[0],
    hidden=5
).to(device)

# Weight initialization
def init_weights(m):
    if isinstance(m, nn.Linear):
        nn.init.xavier_uniform_(m.weight)
        if m.bias is not None:
            m.bias.data.fill_(0.01)

pdlmodel.apply(init_weights)
# Out:
# DeepMNLModel_No(
#   (theta): Sequential(
#     (0): Linear(in_features=1, out_features=5, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=5, out_features=1, bias=True)
#   )
# )

# %%
prepared_data = prepare_data(X_user_train1, X_product,  price * (1 - (1-discount_percentage) * prod_randomization))
user_features, product_features, prices, all_x_other_products, all_other_prices = prepared_data
all_x_other_products = all_x_other_products.to(device)
all_other_prices = all_other_prices.to(device)

# %%
# ----- Prepare validation data -----
prepared_val = prepare_data(
    X_user_val,
    X_product,
    price * (1 - (1 - discount_percentage) * prod_randomization)
)
user_features_val, product_features_val, _, all_x_other_products_val, all_other_prices_val = prepared_val

user_features_val = user_features_val.to(device)
product_features_val = product_features_val.to(device)
all_x_other_products_val = all_x_other_products_val.to(device)
all_other_prices_val = all_other_prices_val.to(device)
choice_val = choice_val.to(device)

# ----- Optimizer and scheduler -----
optimizer = optim.Adam(pdlmodel.parameters(), lr=0.01)
scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size=2500, gamma=0.5)
l2_lambda = 0  # L2 regularization coefficient

# Early stopping setup
best_val_loss = float('inf')
patience = 10
patience_counter = 0

# ----- Training loop -----
for epoch in range(5000):
    pdlmodel.train()
    optimizer.zero_grad()

    # Forward pass (train): use prepared prices and other-prices matrix
    outputs = pdlmodel(
        user_features,         # x_user (not used inside DeepMNLModel_No, but kept for interface)
        product_features,      # X_product (not used)
        all_x_other_products,  # X_other_products (not used in No model)
        all_other_prices,      # x_other_prices: p_-j
        prices,                # price: experimental p_j (after discount)
        prod_randomization     # can be ignored inside No model
    )
    choice_probabilities = F.log_softmax(outputs, dim=1)

    # Training loss
    loss = -torch.mean(
        choice_probabilities[
            torch.arange(choice_probabilities.shape[0], device=device),
            choice_train1
        ]
    )

    # L2 regularization
    l2_norm = sum(param.pow(2.0).sum() for param in pdlmodel.parameters())
    loss = loss + l2_lambda * l2_norm

    # Backward
    loss.backward()
    optimizer.step()

    # ----- Validation -----
    pdlmodel.eval()
    with torch.no_grad():
        val_outputs = pdlmodel(
            user_features_val,
            product_features_val,
            all_x_other_products_val,
            all_other_prices_val,
            prices,              # same product prices for validation
            prod_randomization
        )
        val_choice_probabilities = F.log_softmax(val_outputs, dim=1)
        val_loss = -torch.mean(
            val_choice_probabilities[
                torch.arange(val_choice_probabilities.shape[0], device=device),
                choice_val
            ]
        )

    print(
        f"Epoch {epoch+1}, "
        f"Training Loss: {loss.item():.4f}, "
        f"Validation Loss: {val_loss.item():.4f}"
    )

    # Early stopping logic
    if val_loss < best_val_loss:
        best_val_loss = val_loss
        patience_counter = 0
        torch.save(pdlmodel.state_dict(), 'best_model.pth')
    else:
        patience_counter += 1

    if patience_counter >= patience:
        print("Early stopping triggered")
        break

    scheduler.step()
# Out:
# Epoch 1, Training Loss: 1.7769, Validation Loss: 1.8092
# Epoch 2, Training Loss: 1.7590, Validation Loss: 1.7921
# Epoch 3, Training Loss: 1.7412, Validation Loss: 1.7752
# Epoch 4, Training Loss: 1.7235, Validation Loss: 1.7583
# Epoch 5, Training Loss: 1.7059, Validation Loss: 1.7416
# Epoch 6, Training Loss: 1.6885, Validation Loss: 1.7251
# Epoch 7, Training Loss: 1.6712, Validation Loss: 1.7088
# Epoch 8, Training Loss: 1.6541, Validation Loss: 1.6927
# Epoch 9, Training Loss: 1.6372, Validation Loss: 1.6769
# Epoch 10, Training Loss: 1.6206, Validation Loss: 1.6613
# Epoch 11, Training Loss: 1.6043, Validation Loss: 1.6460
# Epoch 12, Training Loss: 1.5882, Validation Loss: 1.6310
# Epoch 13, Training Loss: 1.5725, Validation Loss: 1.6164
# Epoch 14, Training Loss: 1.5572, Validation Loss: 1.6022
# Epoch 15, Training Loss: 1.5423, Validation Loss: 1.5883
# Epoch 16, Training Loss: 1.5278, Validation Loss: 1.5748
# Epoch 17, Training Loss: 1.5137, Validation Loss: 1.5617
# Epoch 18, Training Loss: 1.5000, Validation Loss: 1.5489
# Epoch 19, Training Loss: 1.4868, Validation Loss: 1.5366
# Epoch 20, Training Loss: 1.4741, Validation Loss: 1.5247
# Epoch 21, Training Loss: 1.4619, Validation Loss: 1.5132
# Epoch 22, Training Loss: 1.4501, Validation Loss: 1.5020
# Epoch 23, Training Loss: 1.4388, Validation Loss: 1.4912
# Epoch 24, Training Loss: 1.4280, Validation Loss: 1.4808
# Epoch 25, Training Loss: 1.4177, Validation Loss: 1.4707
# Epoch 26, Training Loss: 1.4079, Validation Loss: 1.4609
# Epoch 27, Training Loss: 1.3985, Validation Loss: 1.4514
# Epoch 28, Training Loss: 1.3895, Validation Loss: 1.4421
# Epoch 29, Training Loss: 1.3810, Validation Loss: 1.4332
# Epoch 30, Training Loss: 1.3729, Validation Loss: 1.4244
# Epoch 31, Training Loss: 1.3651, Validation Loss: 1.4159
# Epoch 32, Training Loss: 1.3578, Validation Loss: 1.4075
# Epoch 33, Training Loss: 1.3508, Validation Loss: 1.3994
# Epoch 34, Training Loss: 1.3441, Validation Loss: 1.3914
# Epoch 35, Training Loss: 1.3378, Validation Loss: 1.3836
# Epoch 36, Training Loss: 1.3317, Validation Loss: 1.3760
# Epoch 37, Training Loss: 1.3260, Validation Loss: 1.3685
# Epoch 38, Training Loss: 1.3205, Validation Loss: 1.3611
# Epoch 39, Training Loss: 1.3153, Validation Loss: 1.3539
# Epoch 40, Training Loss: 1.3103, Validation Loss: 1.3468
# Epoch 41, Training Loss: 1.3056, Validation Loss: 1.3399
# Epoch 42, Training Loss: 1.3010, Validation Loss: 1.3331
# Epoch 43, Training Loss: 1.2967, Validation Loss: 1.3263
# Epoch 44, Training Loss: 1.2926, Validation Loss: 1.3198
# Epoch 45, Training Loss: 1.2886, Validation Loss: 1.3133
# Epoch 46, Training Loss: 1.2848, Validation Loss: 1.3069
# Epoch 47, Training Loss: 1.2812, Validation Loss: 1.3007
# Epoch 48, Training Loss: 1.2777, Validation Loss: 1.2946
# Epoch 49, Training Loss: 1.2744, Validation Loss: 1.2886
# Epoch 50, Training Loss: 1.2712, Validation Loss: 1.2827
# Epoch 51, Training Loss: 1.2681, Validation Loss: 1.2769
# Epoch 52, Training Loss: 1.2651, Validation Loss: 1.2712
# Epoch 53, Training Loss: 1.2623, Validation Loss: 1.2657
# Epoch 54, Training Loss: 1.2595, Validation Loss: 1.2603
# Epoch 55, Training Loss: 1.2569, Validation Loss: 1.2550
# Epoch 56, Training Loss: 1.2544, Validation Loss: 1.2499
# Epoch 57, Training Loss: 1.2520, Validation Loss: 1.2449
# Epoch 58, Training Loss: 1.2497, Validation Loss: 1.2400
# Epoch 59, Training Loss: 1.2475, Validation Loss: 1.2353
# Epoch 60, Training Loss: 1.2455, Validation Loss: 1.2307
# Epoch 61, Training Loss: 1.2435, Validation Loss: 1.2262
# Epoch 62, Training Loss: 1.2416, Validation Loss: 1.2219
# Epoch 63, Training Loss: 1.2399, Validation Loss: 1.2178
# Epoch 64, Training Loss: 1.2382, Validation Loss: 1.2138
# Epoch 65, Training Loss: 1.2366, Validation Loss: 1.2099
# Epoch 66, Training Loss: 1.2351, Validation Loss: 1.2062
# Epoch 67, Training Loss: 1.2338, Validation Loss: 1.2026
# Epoch 68, Training Loss: 1.2325, Validation Loss: 1.1992
# Epoch 69, Training Loss: 1.2312, Validation Loss: 1.1959
# Epoch 70, Training Loss: 1.2301, Validation Loss: 1.1927
# Epoch 71, Training Loss: 1.2291, Validation Loss: 1.1897
# Epoch 72, Training Loss: 1.2281, Validation Loss: 1.1867
# Epoch 73, Training Loss: 1.2272, Validation Loss: 1.1839
# Epoch 74, Training Loss: 1.2263, Validation Loss: 1.1813
# Epoch 75, Training Loss: 1.2255, Validation Loss: 1.1787
# Epoch 76, Training Loss: 1.2248, Validation Loss: 1.1762
# Epoch 77, Training Loss: 1.2241, Validation Loss: 1.1739
# Epoch 78, Training Loss: 1.2235, Validation Loss: 1.1716
# Epoch 79, Training Loss: 1.2229, Validation Loss: 1.1694
# Epoch 80, Training Loss: 1.2224, Validation Loss: 1.1674
# Epoch 81, Training Loss: 1.2219, Validation Loss: 1.1654
# Epoch 82, Training Loss: 1.2215, Validation Loss: 1.1635
# Epoch 83, Training Loss: 1.2210, Validation Loss: 1.1617
# Epoch 84, Training Loss: 1.2206, Validation Loss: 1.1600
# Epoch 85, Training Loss: 1.2203, Validation Loss: 1.1583
# Epoch 86, Training Loss: 1.2200, Validation Loss: 1.1568
# Epoch 87, Training Loss: 1.2197, Validation Loss: 1.1553
# Epoch 88, Training Loss: 1.2194, Validation Loss: 1.1539
# Epoch 89, Training Loss: 1.2191, Validation Loss: 1.1525
# Epoch 90, Training Loss: 1.2189, Validation Loss: 1.1512
# Epoch 91, Training Loss: 1.2187, Validation Loss: 1.1500
# Epoch 92, Training Loss: 1.2185, Validation Loss: 1.1488
# Epoch 93, Training Loss: 1.2184, Validation Loss: 1.1477
# Epoch 94, Training Loss: 1.2182, Validation Loss: 1.1467
# Epoch 95, Training Loss: 1.2181, Validation Loss: 1.1457
# Epoch 96, Training Loss: 1.2180, Validation Loss: 1.1448
# Epoch 97, Training Loss: 1.2179, Validation Loss: 1.1439
# Epoch 98, Training Loss: 1.2178, Validation Loss: 1.1430
# Epoch 99, Training Loss: 1.2177, Validation Loss: 1.1422
# Epoch 100, Training Loss: 1.2176, Validation Loss: 1.1415
# Epoch 101, Training Loss: 1.2176, Validation Loss: 1.1408
# Epoch 102, Training Loss: 1.2175, Validation Loss: 1.1401
# Epoch 103, Training Loss: 1.2175, Validation Loss: 1.1395
# Epoch 104, Training Loss: 1.2174, Validation Loss: 1.1389
# Epoch 105, Training Loss: 1.2174, Validation Loss: 1.1383
# Epoch 106, Training Loss: 1.2174, Validation Loss: 1.1378
# Epoch 107, Training Loss: 1.2174, Validation Loss: 1.1373
# Epoch 108, Training Loss: 1.2173, Validation Loss: 1.1368
# Epoch 109, Training Loss: 1.2173, Validation Loss: 1.1364
# Epoch 110, Training Loss: 1.2173, Validation Loss: 1.1360
# Epoch 111, Training Loss: 1.2173, Validation Loss: 1.1356
# Epoch 112, Training Loss: 1.2173, Validation Loss: 1.1353
# Epoch 113, Training Loss: 1.2173, Validation Loss: 1.1349
# Epoch 114, Training Loss: 1.2173, Validation Loss: 1.1346
# Epoch 115, Training Loss: 1.2173, Validation Loss: 1.1343
# Epoch 116, Training Loss: 1.2173, Validation Loss: 1.1341
# Epoch 117, Training Loss: 1.2173, Validation Loss: 1.1339
# Epoch 118, Training Loss: 1.2173, Validation Loss: 1.1336
# Epoch 119, Training Loss: 1.2173, Validation Loss: 1.1334
# Epoch 120, Training Loss: 1.2173, Validation Loss: 1.1333
# Epoch 121, Training Loss: 1.2173, Validation Loss: 1.1331
# Epoch 122, Training Loss: 1.2173, Validation Loss: 1.1330
# Epoch 123, Training Loss: 1.2173, Validation Loss: 1.1328
# Epoch 124, Training Loss: 1.2173, Validation Loss: 1.1327
# Epoch 125, Training Loss: 1.2173, Validation Loss: 1.1326
# Epoch 126, Training Loss: 1.2173, Validation Loss: 1.1326
# Epoch 127, Training Loss: 1.2173, Validation Loss: 1.1325
# Epoch 128, Training Loss: 1.2173, Validation Loss: 1.1324
# Epoch 129, Training Loss: 1.2173, Validation Loss: 1.1324
# Epoch 130, Training Loss: 1.2173, Validation Loss: 1.1323
# Epoch 131, Training Loss: 1.2173, Validation Loss: 1.1323
# Epoch 132, Training Loss: 1.2173, Validation Loss: 1.1323
# Epoch 133, Training Loss: 1.2173, Validation Loss: 1.1323
# Epoch 134, Training Loss: 1.2173, Validation Loss: 1.1323
# Epoch 135, Training Loss: 1.2173, Validation Loss: 1.1323
# Epoch 136, Training Loss: 1.2173, Validation Loss: 1.1323
# Epoch 137, Training Loss: 1.2173, Validation Loss: 1.1323
# Epoch 138, Training Loss: 1.2173, Validation Loss: 1.1323
# Epoch 139, Training Loss: 1.2173, Validation Loss: 1.1324
# Epoch 140, Training Loss: 1.2173, Validation Loss: 1.1324
# Epoch 141, Training Loss: 1.2173, Validation Loss: 1.1324
# Epoch 142, Training Loss: 1.2173, Validation Loss: 1.1324
# Epoch 143, Training Loss: 1.2173, Validation Loss: 1.1325
# Epoch 144, Training Loss: 1.2173, Validation Loss: 1.1325
# Early stopping triggered

# %%
# All-control and all-treated for test set
num_product = X_product.shape[0]

# All control: product_randomization = 0
all_product_control = torch.zeros(num_product, device=device).bool()

# All treated: product_randomization = 1
all_product_treated = torch.ones(num_product, device=device).bool()

# Move base price and test users/products to device
X_user_test = X_user_test.to(device)
X_product = X_product.to(device)
price = price.to(device)

# --------- Expected revenue: all control ----------
# Control prices = base prices (no discount)
price_control = price.clone()

# Prepare test data under all-control prices
user_test_ctrl, product_test_ctrl, prices_ctrl, x_other_products_ctrl, other_prices_ctrl = prepare_data(
    X_user_test,
    X_product,
    price_control
)

utilities_ctrl = pdlmodel(
    user_test_ctrl,
    product_test_ctrl,
    x_other_products_ctrl,
    other_prices_ctrl,
    prices_ctrl,          # control prices
    all_product_control   # all False
)

probabilities_ctrl = F.softmax(utilities_ctrl, dim=1)

price_with_outside_ctrl = torch.cat(
    (torch.zeros(1, device=price.device), prices_ctrl), dim=0
)  # [M+1]

expected_revenue_ctrl = torch.sum(
    probabilities_ctrl * price_with_outside_ctrl.unsqueeze(0).expand_as(probabilities_ctrl),
    dim=1
).sum()

print(f"Expected Revenue (all control): ${expected_revenue_ctrl.item():.2f}")

# --------- Expected revenue: all treated ----------
# Treated prices = discounted prices
price_treated = price * discount_percentage

user_test_trt, product_test_trt, prices_trt, x_other_products_trt, other_prices_trt = prepare_data(
    X_user_test,
    X_product,
    price_treated
)

utilities_trt = pdlmodel(
    user_test_trt,
    product_test_trt,
    x_other_products_trt,
    other_prices_trt,
    prices_trt,          # treated prices
    all_product_treated  # all True
)

probabilities_trt = F.softmax(utilities_trt, dim=1)

price_with_outside_trt = torch.cat(
    (torch.zeros(1, device=price.device), prices_trt), dim=0
)

expected_revenue_trt = torch.sum(
    probabilities_trt * price_with_outside_trt.unsqueeze(0).expand_as(probabilities_trt),
    dim=1
).sum()

print(f"Expected Revenue (all treated): ${expected_revenue_trt.item():.2f}")

# --------- GTE ----------
pdl = (expected_revenue_trt - expected_revenue_ctrl).cpu().detach().numpy() * 600 / 266
print(pdl)

pdl_no = abs((pdl - true) / true)
print(pdl_no)
# Out:
# Expected Revenue (all control): $37.61
# Expected Revenue (all treated): $8.85
# -64.87762336444138
# 0.055022150447735826

# %% [markdown]
# ### Only user features

# %%
class DeepMNLModel_UserOnly(nn.Module):
    """
    Deep MNL (user + own price only):
    u_ij = theta(x_i, p_j)
    Outside option utility = 0.
    """
    def __init__(self, user_dim, num_product, hidden=5):
        super(DeepMNLModel_UserOnly, self).__init__()

        # theta(x_i, p_j)
        # Input per (i,j): [user_dim + 1]
        self.theta = nn.Sequential(
            nn.Linear(user_dim + 1, hidden),
            nn.ReLU(),
            nn.Linear(hidden, hidden),
            nn.ReLU(),
            nn.Linear(hidden, 1)
        )

    def forward(self, x_user, X_product, X_other_products,
                x_other_prices, price, prod_randomization):

        device = price.device
        N, M = x_user.shape[0], price.shape[0]

        # p_j: [M, 1]
        pj_feat = price.unsqueeze(1)          # [M, 1]

        pj_feat_exp = pj_feat.unsqueeze(0).expand(N, -1, -1)

        x_user_exp = x_user.unsqueeze(1).expand(-1, M, -1)

        theta_input = torch.cat([x_user_exp, pj_feat_exp], dim=2)

        theta_input_flat = theta_input.reshape(N * M, -1)

        # u_ij: [N*M, 1] -> [N, M]
        utilities = self.theta(theta_input_flat).view(N, M)

        # outside option utility = 0
        zero_utilities = torch.zeros(N, 1, device=device)
        utilities_with_outside = torch.cat([zero_utilities, utilities], dim=1)

        return utilities_with_outside

# %%
# Apply the model
pdlmodel = DeepMNLModel_UserOnly(
    user_dim=X_user.shape[1],
    num_product=X_product.shape[0],
    hidden=5
).to(device)

# # Weight initialization
# def init_weights(m):
#     if isinstance(m, nn.Linear):
#         nn.init.xavier_uniform_(m.weight)
#         if m.bias is not None:
#             m.bias.data.fill_(0.01)

pdlmodel.apply(init_weights)
# Out:
# DeepMNLModel_UserOnly(
#   (theta): Sequential(
#     (0): Linear(in_features=4, out_features=5, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=5, out_features=5, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=5, out_features=1, bias=True)
#   )
# )

# %%
prepared_data = prepare_data(X_user_train1, X_product,  price * (1 - (1-discount_percentage) * prod_randomization))
user_features, product_features, prices, all_x_other_products, all_other_prices = prepared_data
all_x_other_products = all_x_other_products.to(device)
all_other_prices = all_other_prices.to(device)

# %%
# ----- Prepare validation data -----
prepared_val = prepare_data(
    X_user_val,
    X_product,
    price * (1 - (1 - discount_percentage) * prod_randomization)
)
user_features_val, product_features_val, _, all_x_other_products_val, all_other_prices_val = prepared_val

user_features_val = user_features_val.to(device)
product_features_val = product_features_val.to(device)
all_x_other_products_val = all_x_other_products_val.to(device)
all_other_prices_val = all_other_prices_val.to(device)
choice_val = choice_val.to(device)

# ----- Optimizer and scheduler -----
optimizer = optim.Adam(pdlmodel.parameters(), lr=0.01)
scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size=2500, gamma=0.5)
l2_lambda = 0  # L2 regularization coefficient

# Early stopping setup
best_val_loss = float('inf')
patience = 20
patience_counter = 0

# ----- Training loop -----
for epoch in range(5000):
    pdlmodel.train()
    optimizer.zero_grad()

    # Forward pass (train): use prepared prices and other-prices matrix
    outputs = pdlmodel(
        user_features,         # x_user (not used inside DeepMNLModel_No, but kept for interface)
        product_features,      # X_product (not used)
        all_x_other_products,  # X_other_products (not used in No model)
        all_other_prices,      # x_other_prices: p_-j
        prices,                # price: experimental p_j (after discount)
        prod_randomization     # can be ignored inside No model
    )
    choice_probabilities = F.log_softmax(outputs, dim=1)

    # Training loss
    loss = -torch.mean(
        choice_probabilities[
            torch.arange(choice_probabilities.shape[0], device=device),
            choice_train1
        ]
    )

    # L2 regularization
    l2_norm = sum(param.pow(2.0).sum() for param in pdlmodel.parameters())
    loss = loss + l2_lambda * l2_norm

    # Backward
    loss.backward()
    optimizer.step()

    # ----- Validation -----
    pdlmodel.eval()
    with torch.no_grad():
        val_outputs = pdlmodel(
            user_features_val,
            product_features_val,
            all_x_other_products_val,
            all_other_prices_val,
            prices,              # same product prices for validation
            prod_randomization
        )
        val_choice_probabilities = F.log_softmax(val_outputs, dim=1)
        val_loss = -torch.mean(
            val_choice_probabilities[
                torch.arange(val_choice_probabilities.shape[0], device=device),
                choice_val
            ]
        )

    print(
        f"Epoch {epoch+1}, "
        f"Training Loss: {loss.item():.4f}, "
        f"Validation Loss: {val_loss.item():.4f}"
    )

    # Early stopping logic
    if val_loss < best_val_loss:
        best_val_loss = val_loss
        patience_counter = 0
        # torch.save(pdlmodel.state_dict(), 'best_model.pth')
    else:
        patience_counter += 1

    if patience_counter >= patience:
        print("Early stopping triggered")
        break

    scheduler.step()
# Out:
# Epoch 1, Training Loss: 2.4532, Validation Loss: 2.4765
# Epoch 2, Training Loss: 2.3600, Validation Loss: 2.3780
# Epoch 3, Training Loss: 2.2770, Validation Loss: 2.2878
# Epoch 4, Training Loss: 2.2045, Validation Loss: 2.2105
# Epoch 5, Training Loss: 2.1416, Validation Loss: 2.1461
# Epoch 6, Training Loss: 2.0868, Validation Loss: 2.0929
# Epoch 7, Training Loss: 2.0415, Validation Loss: 2.0495
# Epoch 8, Training Loss: 2.0049, Validation Loss: 2.0114
# Epoch 9, Training Loss: 1.9759, Validation Loss: 1.9793
# Epoch 10, Training Loss: 1.9515, Validation Loss: 1.9517
# Epoch 11, Training Loss: 1.9321, Validation Loss: 1.9275
# Epoch 12, Training Loss: 1.9151, Validation Loss: 1.9070
# Epoch 13, Training Loss: 1.9026, Validation Loss: 1.8916
# Epoch 14, Training Loss: 1.8930, Validation Loss: 1.8814
# Epoch 15, Training Loss: 1.8852, Validation Loss: 1.8737
# Epoch 16, Training Loss: 1.8784, Validation Loss: 1.8663
# Epoch 17, Training Loss: 1.8718, Validation Loss: 1.8592
# Epoch 18, Training Loss: 1.8655, Validation Loss: 1.8523
# Epoch 19, Training Loss: 1.8594, Validation Loss: 1.8458
# Epoch 20, Training Loss: 1.8535, Validation Loss: 1.8395
# Epoch 21, Training Loss: 1.8478, Validation Loss: 1.8335
# Epoch 22, Training Loss: 1.8423, Validation Loss: 1.8275
# Epoch 23, Training Loss: 1.8369, Validation Loss: 1.8218
# Epoch 24, Training Loss: 1.8316, Validation Loss: 1.8160
# Epoch 25, Training Loss: 1.8263, Validation Loss: 1.8103
# Epoch 26, Training Loss: 1.8210, Validation Loss: 1.8045
# Epoch 27, Training Loss: 1.8156, Validation Loss: 1.7986
# Epoch 28, Training Loss: 1.8102, Validation Loss: 1.7925
# Epoch 29, Training Loss: 1.8046, Validation Loss: 1.7862
# Epoch 30, Training Loss: 1.7988, Validation Loss: 1.7796
# Epoch 31, Training Loss: 1.7928, Validation Loss: 1.7728
# Epoch 32, Training Loss: 1.7866, Validation Loss: 1.7655
# Epoch 33, Training Loss: 1.7800, Validation Loss: 1.7579
# Epoch 34, Training Loss: 1.7730, Validation Loss: 1.7498
# Epoch 35, Training Loss: 1.7656, Validation Loss: 1.7412
# Epoch 36, Training Loss: 1.7578, Validation Loss: 1.7318
# Epoch 37, Training Loss: 1.7493, Validation Loss: 1.7218
# Epoch 38, Training Loss: 1.7403, Validation Loss: 1.7110
# Epoch 39, Training Loss: 1.7305, Validation Loss: 1.6990
# Epoch 40, Training Loss: 1.7198, Validation Loss: 1.6851
# Epoch 41, Training Loss: 1.7080, Validation Loss: 1.6698
# Epoch 42, Training Loss: 1.6948, Validation Loss: 1.6528
# Epoch 43, Training Loss: 1.6803, Validation Loss: 1.6344
# Epoch 44, Training Loss: 1.6648, Validation Loss: 1.6142
# Epoch 45, Training Loss: 1.6477, Validation Loss: 1.5923
# Epoch 46, Training Loss: 1.6293, Validation Loss: 1.5687
# Epoch 47, Training Loss: 1.6093, Validation Loss: 1.5435
# Epoch 48, Training Loss: 1.5878, Validation Loss: 1.5165
# Epoch 49, Training Loss: 1.5649, Validation Loss: 1.4877
# Epoch 50, Training Loss: 1.5407, Validation Loss: 1.4576
# Epoch 51, Training Loss: 1.5152, Validation Loss: 1.4261
# Epoch 52, Training Loss: 1.4884, Validation Loss: 1.3938
# Epoch 53, Training Loss: 1.4606, Validation Loss: 1.3618
# Epoch 54, Training Loss: 1.4325, Validation Loss: 1.3295
# Epoch 55, Training Loss: 1.4040, Validation Loss: 1.2972
# Epoch 56, Training Loss: 1.3754, Validation Loss: 1.2658
# Epoch 57, Training Loss: 1.3473, Validation Loss: 1.2356
# Epoch 58, Training Loss: 1.3202, Validation Loss: 1.2073
# Epoch 59, Training Loss: 1.2947, Validation Loss: 1.1815
# Epoch 60, Training Loss: 1.2713, Validation Loss: 1.1589
# Epoch 61, Training Loss: 1.2505, Validation Loss: 1.1402
# Epoch 62, Training Loss: 1.2328, Validation Loss: 1.1256
# Epoch 63, Training Loss: 1.2187, Validation Loss: 1.1152
# Epoch 64, Training Loss: 1.2084, Validation Loss: 1.1091
# Epoch 65, Training Loss: 1.2018, Validation Loss: 1.1068
# Epoch 66, Training Loss: 1.1987, Validation Loss: 1.1077
# Epoch 67, Training Loss: 1.1988, Validation Loss: 1.1111
# Epoch 68, Training Loss: 1.2012, Validation Loss: 1.1160
# Epoch 69, Training Loss: 1.2053, Validation Loss: 1.1215
# Epoch 70, Training Loss: 1.2101, Validation Loss: 1.1267
# Epoch 71, Training Loss: 1.2148, Validation Loss: 1.1311
# Epoch 72, Training Loss: 1.2188, Validation Loss: 1.1342
# Epoch 73, Training Loss: 1.2216, Validation Loss: 1.1357
# Epoch 74, Training Loss: 1.2230, Validation Loss: 1.1356
# Epoch 75, Training Loss: 1.2230, Validation Loss: 1.1342
# Epoch 76, Training Loss: 1.2217, Validation Loss: 1.1317
# Epoch 77, Training Loss: 1.2194, Validation Loss: 1.1285
# Epoch 78, Training Loss: 1.2165, Validation Loss: 1.1249
# Epoch 79, Training Loss: 1.2131, Validation Loss: 1.1211
# Epoch 80, Training Loss: 1.2097, Validation Loss: 1.1176
# Epoch 81, Training Loss: 1.2065, Validation Loss: 1.1144
# Epoch 82, Training Loss: 1.2037, Validation Loss: 1.1118
# Epoch 83, Training Loss: 1.2014, Validation Loss: 1.1098
# Epoch 84, Training Loss: 1.1997, Validation Loss: 1.1084
# Epoch 85, Training Loss: 1.1986, Validation Loss: 1.1076
# Early stopping triggered

# %%
# All-control and all-treated for test set
num_product = X_product.shape[0]

# All control: product_randomization = 0
all_product_control = torch.zeros(num_product, device=device).bool()

# All treated: product_randomization = 1
all_product_treated = torch.ones(num_product, device=device).bool()

# Move base price and test users/products to device
X_user_test = X_user_test.to(device)
X_product = X_product.to(device)
price = price.to(device)

# --------- Expected revenue: all control ----------
# Control prices = base prices (no discount)
price_control = price.clone()

# Prepare test data under all-control prices
user_test_ctrl, product_test_ctrl, prices_ctrl, x_other_products_ctrl, other_prices_ctrl = prepare_data(
    X_user_test,
    X_product,
    price_control
)

utilities_ctrl = pdlmodel(
    user_test_ctrl,
    product_test_ctrl,
    x_other_products_ctrl,
    other_prices_ctrl,
    prices_ctrl,          # control prices
    all_product_control   # all False
)

probabilities_ctrl = F.softmax(utilities_ctrl, dim=1)

price_with_outside_ctrl = torch.cat(
    (torch.zeros(1, device=price.device), prices_ctrl), dim=0
)  # [M+1]

expected_revenue_ctrl = torch.sum(
    probabilities_ctrl * price_with_outside_ctrl.unsqueeze(0).expand_as(probabilities_ctrl),
    dim=1
).sum()

print(f"Expected Revenue (all control): ${expected_revenue_ctrl.item():.2f}")

# --------- Expected revenue: all treated ----------
# Treated prices = discounted prices
price_treated = price * discount_percentage

user_test_trt, product_test_trt, prices_trt, x_other_products_trt, other_prices_trt = prepare_data(
    X_user_test,
    X_product,
    price_treated
)

utilities_trt = pdlmodel(
    user_test_trt,
    product_test_trt,
    x_other_products_trt,
    other_prices_trt,
    prices_trt,          # treated prices
    all_product_treated  # all True
)

probabilities_trt = F.softmax(utilities_trt, dim=1)

price_with_outside_trt = torch.cat(
    (torch.zeros(1, device=price.device), prices_trt), dim=0
)

expected_revenue_trt = torch.sum(
    probabilities_trt * price_with_outside_trt.unsqueeze(0).expand_as(probabilities_trt),
    dim=1
).sum()

print(f"Expected Revenue (all treated): ${expected_revenue_trt.item():.2f}")

# --------- GTE ----------
pdl = (expected_revenue_trt - expected_revenue_ctrl).cpu().detach().numpy() * 600 / 266
print(pdl)

pdl_user = abs((pdl - true) / true)
print(pdl_user)
# Out:
# Expected Revenue (all control): $37.05
# Expected Revenue (all treated): $8.46
# -64.49294269533085
# 0.060625233492538386

# %% [markdown]
# ### Only product features

# %%
class DeepMNLModel_ProductOnly(nn.Module):
    """
    Deep MNL (product-only):
    u_ij = theta(z_j, z_-j, p_j)
    Outside option utility = 0.
    """
    def __init__(self, product_dim, num_product, hidden=5):
        super(DeepMNLModel_ProductOnly, self).__init__()

        # Aggregate other products' features z_-j:
        # Input:  [M, (M-1)*F_p]
        # Output: [M, hidden]
        self.other_product_features_layers = nn.Sequential(
            nn.Linear(product_dim * (num_product - 1), hidden),
            nn.ReLU(),
            nn.Linear(hidden, hidden),
            nn.ReLU()
        )

        # theta(z_j, z_-j, p_j)
        # Input per (i,j): [F_p + hidden (z_-j) + 1 (p_j)]
        in_dim = product_dim + hidden + 1

        self.theta = nn.Sequential(
            nn.Linear(in_dim, hidden),
            nn.ReLU(),
            nn.Linear(hidden, hidden),
            nn.ReLU(),
            nn.Linear(hidden, 1)
        )

    def forward(self, x_user, X_product, X_other_products,
                x_other_prices, price, prod_randomization):
        """
        X_product:        [M, F_p]          product features z_j
        X_other_products: [M, (M-1)*F_p]    other products' features z_-j
        price:            [M]               own price p_j (already discounted)
        """
        device = price.device
        # N users, M products
        N, M = x_user.shape[0], X_product.shape[0]

        # z_-j features: [M, hidden]
        zminus_feat = self.other_product_features_layers(X_other_products)

        # p_j scalar: [M, 1]
        pj_feat = price.unsqueeze(1)

        # Combine product-side info: [M, F_p + hidden + 1]
        product_feat = torch.cat(
            [X_product, zminus_feat, pj_feat],
            dim=1
        )

        # Expand to all users: [N, M, in_dim]
        product_feat_exp = product_feat.unsqueeze(0).expand(N, -1, -1)

        # Flatten to [N*M, in_dim]
        theta_input_flat = product_feat_exp.reshape(N * M, -1)

        # Utilities: [N*M, 1] -> [N, M]
        utilities = self.theta(theta_input_flat).view(N, M)

        # Outside option = 0
        zero_utilities = torch.zeros(N, 1, device=device)
        utilities_with_outside = torch.cat([zero_utilities, utilities], dim=1)

        return utilities_with_outside

# %%
# Apply the model
pdlmodel = DeepMNLModel_ProductOnly(
    product_dim=X_product.shape[1],
    num_product=X_product.shape[0],
    hidden=5
).to(device)

# # Weight initialization
# def init_weights(m):
#     if isinstance(m, nn.Linear):
#         nn.init.xavier_uniform_(m.weight)
#         if m.bias is not None:
#             m.bias.data.fill_(0.01)

pdlmodel.apply(init_weights)
# Out:
# DeepMNLModel_ProductOnly(
#   (other_product_features_layers): Sequential(
#     (0): Linear(in_features=15, out_features=5, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=5, out_features=5, bias=True)
#     (3): ReLU()
#   )
#   (theta): Sequential(
#     (0): Linear(in_features=9, out_features=5, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=5, out_features=5, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=5, out_features=1, bias=True)
#   )
# )

# %%
prepared_data = prepare_data(X_user_train1, X_product,  price * (1 - (1-discount_percentage) * prod_randomization))
user_features, product_features, prices, all_x_other_products, all_other_prices = prepared_data
all_x_other_products = all_x_other_products.to(device)
all_other_prices = all_other_prices.to(device)

# %%
# ----- Prepare validation data -----
prepared_val = prepare_data(
    X_user_val,
    X_product,
    price * (1 - (1 - discount_percentage) * prod_randomization)
)
user_features_val, product_features_val, _, all_x_other_products_val, all_other_prices_val = prepared_val

user_features_val = user_features_val.to(device)
product_features_val = product_features_val.to(device)
all_x_other_products_val = all_x_other_products_val.to(device)
all_other_prices_val = all_other_prices_val.to(device)
choice_val = choice_val.to(device)

# ----- Optimizer and scheduler -----
optimizer = optim.Adam(pdlmodel.parameters(), lr=0.01)
scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size=2500, gamma=0.5)
l2_lambda = 0  # L2 regularization coefficient

# Early stopping setup
best_val_loss = float('inf')
patience = 20
patience_counter = 0

# ----- Training loop -----
for epoch in range(1000):
    pdlmodel.train()
    optimizer.zero_grad()

    # Forward pass (train): use prepared prices and other-prices matrix
    outputs = pdlmodel(
        user_features,         # x_user (not used inside DeepMNLModel_No, but kept for interface)
        product_features,      # X_product (not used)
        all_x_other_products,  # X_other_products (not used in No model)
        all_other_prices,      # x_other_prices: p_-j
        prices,                # price: experimental p_j (after discount)
        prod_randomization     # can be ignored inside No model
    )

    choice_probabilities = F.log_softmax(outputs, dim=1)

    # Training loss
    loss = -torch.mean(
        choice_probabilities[
            torch.arange(choice_probabilities.shape[0], device=device),
            choice_train1
        ]
    )

    # L2 regularization
    l2_norm = sum(param.pow(2.0).sum() for param in pdlmodel.parameters())
    loss = loss + l2_lambda * l2_norm

    # Backward
    loss.backward()
    optimizer.step()

    # ----- Validation -----
    pdlmodel.eval()
    with torch.no_grad():
        val_outputs = pdlmodel(
            user_features_val,
            product_features_val,
            all_x_other_products_val,
            all_other_prices_val,
            prices,              # same product prices for validation
            prod_randomization
        )
        val_choice_probabilities = F.log_softmax(val_outputs, dim=1)
        val_loss = -torch.mean(
            val_choice_probabilities[
                torch.arange(val_choice_probabilities.shape[0], device=device),
                choice_val
            ]
        )

    print(
        f"Epoch {epoch+1}, "
        f"Training Loss: {loss.item():.4f}, "
        f"Validation Loss: {val_loss.item():.4f}"
    )

    # Early stopping logic
    if val_loss < best_val_loss:
        best_val_loss = val_loss
        patience_counter = 0
        torch.save(pdlmodel.state_dict(), 'best_model.pth')
    else:
        patience_counter += 1

    if patience_counter >= patience:
        print("Early stopping triggered")
        break

    scheduler.step()
# Out:
# Epoch 1, Training Loss: 1.2698, Validation Loss: 1.0990
# Epoch 2, Training Loss: 1.2440, Validation Loss: 1.0921
# Epoch 3, Training Loss: 1.2440, Validation Loss: 1.0903
# Epoch 4, Training Loss: 1.2458, Validation Loss: 1.0870
# Epoch 5, Training Loss: 1.2398, Validation Loss: 1.0790
# Epoch 6, Training Loss: 1.2374, Validation Loss: 1.0775
# Epoch 7, Training Loss: 1.2350, Validation Loss: 1.0806
# Epoch 8, Training Loss: 1.2323, Validation Loss: 1.0849
# Epoch 9, Training Loss: 1.2306, Validation Loss: 1.0893
# Epoch 10, Training Loss: 1.2303, Validation Loss: 1.0932
# Epoch 11, Training Loss: 1.2303, Validation Loss: 1.0960
# Epoch 12, Training Loss: 1.2300, Validation Loss: 1.0973
# Epoch 13, Training Loss: 1.2292, Validation Loss: 1.0969
# Epoch 14, Training Loss: 1.2277, Validation Loss: 1.0954
# Epoch 15, Training Loss: 1.2257, Validation Loss: 1.0932
# Epoch 16, Training Loss: 1.2235, Validation Loss: 1.0908
# Epoch 17, Training Loss: 1.2215, Validation Loss: 1.0887
# Epoch 18, Training Loss: 1.2197, Validation Loss: 1.0898
# Epoch 19, Training Loss: 1.2176, Validation Loss: 1.0933
# Epoch 20, Training Loss: 1.2166, Validation Loss: 1.0946
# Epoch 21, Training Loss: 1.2171, Validation Loss: 1.0954
# Epoch 22, Training Loss: 1.2163, Validation Loss: 1.0956
# Epoch 23, Training Loss: 1.2144, Validation Loss: 1.0955
# Epoch 24, Training Loss: 1.2118, Validation Loss: 1.0933
# Epoch 25, Training Loss: 1.2110, Validation Loss: 1.0931
# Epoch 26, Training Loss: 1.2107, Validation Loss: 1.0959
# Early stopping triggered

# %%
# All-control and all-treated for test set
num_product = X_product.shape[0]

# All control: product_randomization = 0
all_product_control = torch.zeros(num_product, device=device).bool()

# All treated: product_randomization = 1
all_product_treated = torch.ones(num_product, device=device).bool()

# Move base price and test users/products to device
X_user_test = X_user_test.to(device)
X_product = X_product.to(device)
price = price.to(device)

# --------- Expected revenue: all control ----------
# Control prices = base prices (no discount)
price_control = price.clone()

# Prepare test data under all-control prices
user_test_ctrl, product_test_ctrl, prices_ctrl, x_other_products_ctrl, other_prices_ctrl = prepare_data(
    X_user_test,
    X_product,
    price_control
)

utilities_ctrl = pdlmodel(
    user_test_ctrl,
    product_test_ctrl,
    x_other_products_ctrl,
    other_prices_ctrl,
    prices_ctrl,          # control prices
    all_product_control   # all False
)

probabilities_ctrl = F.softmax(utilities_ctrl, dim=1)

price_with_outside_ctrl = torch.cat(
    (torch.zeros(1, device=price.device), prices_ctrl), dim=0
)  # [M+1]

expected_revenue_ctrl = torch.sum(
    probabilities_ctrl * price_with_outside_ctrl.unsqueeze(0).expand_as(probabilities_ctrl),
    dim=1
).sum()

print(f"Expected Revenue (all control): ${expected_revenue_ctrl.item():.2f}")

# --------- Expected revenue: all treated ----------
# Treated prices = discounted prices
price_treated = price * discount_percentage

user_test_trt, product_test_trt, prices_trt, x_other_products_trt, other_prices_trt = prepare_data(
    X_user_test,
    X_product,
    price_treated
)

utilities_trt = pdlmodel(
    user_test_trt,
    product_test_trt,
    x_other_products_trt,
    other_prices_trt,
    prices_trt,          # treated prices
    all_product_treated  # all True
)

probabilities_trt = F.softmax(utilities_trt, dim=1)

price_with_outside_trt = torch.cat(
    (torch.zeros(1, device=price.device), prices_trt), dim=0
)

expected_revenue_trt = torch.sum(
    probabilities_trt * price_with_outside_trt.unsqueeze(0).expand_as(probabilities_trt),
    dim=1
).sum()

print(f"Expected Revenue (all treated): ${expected_revenue_trt.item():.2f}")

# --------- GTE ----------
pdl = (expected_revenue_trt - expected_revenue_ctrl).cpu().detach().numpy() * 600 / 266
print(pdl)

pdl_product = abs((pdl - true) / true)
print(pdl_product)
# Out:
# Expected Revenue (all control): $37.91
# Expected Revenue (all treated): $9.36
# -64.3806271086958
# 0.0622611710627756

# %% [markdown]
# ### All features

# %%
# PDL choice model
class DeepMNLModel_UserProduct(nn.Module):
    """
    Deep MNL:
    u_ij = theta(x_i, z_j, z_-j, p_j)
    Outside option utility = 0.
    """
    def __init__(self, user_dim, product_dim, num_product, hidden=5):
        super(DeepMNLModel_UserProduct, self).__init__()

        # Aggregate other products' features z_-j:
        # Input:  [M, (M-1)*F_p]
        # Output: [M, hidden]
        self.other_product_features_layers = nn.Sequential(
            nn.Linear(product_dim * (num_product - 1), hidden),
            nn.ReLU(),
            nn.Linear(hidden, hidden),
            nn.ReLU()
        )

        # theta(x_i, z_j, z_-j, p_j)
        # Input per (i,j):
        #   user_dim (x_i)
        # + product_dim (z_j)
        # + hidden (z_-j)
        # + 1 (p_j)
        in_dim = user_dim + product_dim + hidden + 1

        self.theta = nn.Sequential(
            nn.Linear(in_dim, hidden),
            nn.ReLU(),
            nn.Linear(hidden, hidden),
            nn.ReLU(),
            nn.Linear(hidden, 1)
        )

    def forward(self, x_user, X_product, X_other_products,
                x_other_prices, price, prod_randomization):
        """
        x_user:          [N, F_u]          user features x_i
        X_product:       [M, F_p]          product features z_j
        X_other_products:[M, (M-1)*F_p]    other products' features z_-j
        price:           [M]               own price p_j (already discounted)

        x_other_prices, prod_randomization are not used here.
        """
        device = price.device
        N, M = x_user.shape[0], X_product.shape[0]

        # z_-j features: [M, hidden]
        zminus_feat = self.other_product_features_layers(X_other_products)

        # p_j: [M, 1]
        pj_feat = price.unsqueeze(1)

        # Product-side block: [M, F_p + hidden + 1]
        product_block = torch.cat(
            [X_product, zminus_feat, pj_feat],
            dim=1
        )

        # Expand product block for all users: [N, M, *]
        product_block_exp = product_block.unsqueeze(0).expand(N, -1, -1)

        # Expand user features: [N, 1, F_u] -> [N, M, F_u]
        x_user_exp = x_user.unsqueeze(1).expand(-1, M, -1)

        # Final theta input: [N, M, in_dim]
        theta_input = torch.cat([x_user_exp, product_block_exp], dim=2)

        # Flatten to [N*M, in_dim]
        theta_input_flat = theta_input.reshape(N * M, -1)

        # Utilities: [N*M, 1] -> [N, M]
        utilities = self.theta(theta_input_flat).view(N, M)

        # Outside option = 0
        zero_utilities = torch.zeros(N, 1, device=device)
        utilities_with_outside = torch.cat([zero_utilities, utilities], dim=1)

        return utilities_with_outside

# %%
# Apply the model
pdlmodel = DeepMNLModel_UserProduct(
    user_dim=X_user.shape[1],
    product_dim=X_product.shape[1],
    num_product=X_product.shape[0],
    hidden=5
).to(device)

# # Weight initialization
# def init_weights(m):
#     if isinstance(m, nn.Linear):
#         nn.init.xavier_uniform_(m.weight)
#         if m.bias is not None:
#             m.bias.data.fill_(0.01)

pdlmodel.apply(init_weights)
# Out:
# DeepMNLModel_UserProduct(
#   (other_product_features_layers): Sequential(
#     (0): Linear(in_features=15, out_features=5, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=5, out_features=5, bias=True)
#     (3): ReLU()
#   )
#   (theta): Sequential(
#     (0): Linear(in_features=12, out_features=5, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=5, out_features=5, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=5, out_features=1, bias=True)
#   )
# )

# %%
prepared_data = prepare_data(X_user_train1, X_product,  price * (1 - (1-discount_percentage) * prod_randomization))
user_features, product_features, prices, all_x_other_products, all_other_prices = prepared_data
all_x_other_products = all_x_other_products.to(device)
all_other_prices = all_other_prices.to(device)

# %%
# ----- Prepare validation data -----
prepared_val = prepare_data(
    X_user_val,
    X_product,
    price * (1 - (1 - discount_percentage) * prod_randomization)
)
user_features_val, product_features_val, _, all_x_other_products_val, all_other_prices_val = prepared_val

user_features_val = user_features_val.to(device)
product_features_val = product_features_val.to(device)
all_x_other_products_val = all_x_other_products_val.to(device)
all_other_prices_val = all_other_prices_val.to(device)
choice_val = choice_val.to(device)

# ----- Optimizer and scheduler -----
optimizer = optim.Adam(pdlmodel.parameters(), lr=0.01)
scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size=2500, gamma=0.5)
l2_lambda = 0 # L2 regularization coefficient

# Early stopping setup
best_val_loss = float('inf')
patience = 50
patience_counter = 0

# ----- Training loop -----
for epoch in range(5000):
    pdlmodel.train()
    optimizer.zero_grad()

    # Forward pass (train): use prepared prices and other-prices matrix
    outputs = pdlmodel(
        user_features,         # x_user (not used inside DeepMNLModel_No, but kept for interface)
        product_features,      # X_product (not used)
        all_x_other_products,  # X_other_products (not used in No model)
        all_other_prices,      # x_other_prices: p_-j
        prices,                # price: experimental p_j (after discount)
        prod_randomization     # can be ignored inside No model
    )

    choice_probabilities = F.log_softmax(outputs, dim=1)

    # Training loss
    loss = -torch.mean(
        choice_probabilities[
            torch.arange(choice_probabilities.shape[0], device=device),
            choice_train1
        ]
    )

    # L2 regularization
    l2_norm = sum(param.pow(2.0).sum() for param in pdlmodel.parameters())
    loss = loss + l2_lambda * l2_norm

    # Backward
    loss.backward()
    optimizer.step()

    # ----- Validation -----
    pdlmodel.eval()
    with torch.no_grad():
        val_outputs = pdlmodel(
            user_features_val,
            product_features_val,
            all_x_other_products_val,
            all_other_prices_val,
            prices,              # same product prices for validation
            prod_randomization
        )
        val_choice_probabilities = F.log_softmax(val_outputs, dim=1)
        val_loss = -torch.mean(
            val_choice_probabilities[
                torch.arange(val_choice_probabilities.shape[0], device=device),
                choice_val
            ]
        )

    print(
        f"Epoch {epoch+1}, "
        f"Training Loss: {loss.item():.4f}, "
        f"Validation Loss: {val_loss.item():.4f}"
    )

    # Early stopping logic
    if val_loss < best_val_loss:
        best_val_loss = val_loss
        patience_counter = 0
        torch.save(pdlmodel.state_dict(), 'best_model.pth')
    else:
        patience_counter += 1

    if patience_counter >= patience:
        print("Early stopping triggered")
        break

    scheduler.step()
# Out:
# Epoch 1, Training Loss: 1.7447, Validation Loss: 1.6316
# Epoch 2, Training Loss: 1.6764, Validation Loss: 1.5406
# Epoch 3, Training Loss: 1.5972, Validation Loss: 1.4349
# Epoch 4, Training Loss: 1.5091, Validation Loss: 1.3334
# Epoch 5, Training Loss: 1.4239, Validation Loss: 1.2394
# Epoch 6, Training Loss: 1.3548, Validation Loss: 1.1501
# Epoch 7, Training Loss: 1.3074, Validation Loss: 1.0815
# Epoch 8, Training Loss: 1.2951, Validation Loss: 1.0496
# Epoch 9, Training Loss: 1.3129, Validation Loss: 1.0517
# Epoch 10, Training Loss: 1.3388, Validation Loss: 1.0574
# Epoch 11, Training Loss: 1.3526, Validation Loss: 1.0569
# Epoch 12, Training Loss: 1.3482, Validation Loss: 1.0511
# Epoch 13, Training Loss: 1.3300, Validation Loss: 1.0445
# Epoch 14, Training Loss: 1.3063, Validation Loss: 1.0415
# Epoch 15, Training Loss: 1.2857, Validation Loss: 1.0438
# Epoch 16, Training Loss: 1.2727, Validation Loss: 1.0515
# Epoch 17, Training Loss: 1.2661, Validation Loss: 1.0625
# Epoch 18, Training Loss: 1.2652, Validation Loss: 1.0761
# Epoch 19, Training Loss: 1.2671, Validation Loss: 1.0874
# Epoch 20, Training Loss: 1.2696, Validation Loss: 1.0945
# Epoch 21, Training Loss: 1.2713, Validation Loss: 1.0975
# Epoch 22, Training Loss: 1.2711, Validation Loss: 1.0953
# Epoch 23, Training Loss: 1.2688, Validation Loss: 1.0884
# Epoch 24, Training Loss: 1.2645, Validation Loss: 1.0786
# Epoch 25, Training Loss: 1.2589, Validation Loss: 1.0687
# Epoch 26, Training Loss: 1.2529, Validation Loss: 1.0585
# Epoch 27, Training Loss: 1.2472, Validation Loss: 1.0491
# Epoch 28, Training Loss: 1.2427, Validation Loss: 1.0415
# Epoch 29, Training Loss: 1.2397, Validation Loss: 1.0358
# Epoch 30, Training Loss: 1.2380, Validation Loss: 1.0323
# Epoch 31, Training Loss: 1.2373, Validation Loss: 1.0304
# Epoch 32, Training Loss: 1.2371, Validation Loss: 1.0297
# Epoch 33, Training Loss: 1.2367, Validation Loss: 1.0297
# Epoch 34, Training Loss: 1.2357, Validation Loss: 1.0303
# Epoch 35, Training Loss: 1.2338, Validation Loss: 1.0311
# Epoch 36, Training Loss: 1.2314, Validation Loss: 1.0325
# Epoch 37, Training Loss: 1.2287, Validation Loss: 1.0344
# Epoch 38, Training Loss: 1.2261, Validation Loss: 1.0367
# Epoch 39, Training Loss: 1.2240, Validation Loss: 1.0396
# Epoch 40, Training Loss: 1.2225, Validation Loss: 1.0429
# Epoch 41, Training Loss: 1.2214, Validation Loss: 1.0461
# Epoch 42, Training Loss: 1.2207, Validation Loss: 1.0489
# Epoch 43, Training Loss: 1.2201, Validation Loss: 1.0510
# Epoch 44, Training Loss: 1.2194, Validation Loss: 1.0524
# Epoch 45, Training Loss: 1.2186, Validation Loss: 1.0531
# Epoch 46, Training Loss: 1.2175, Validation Loss: 1.0527
# Epoch 47, Training Loss: 1.2163, Validation Loss: 1.0517
# Epoch 48, Training Loss: 1.2149, Validation Loss: 1.0502
# Epoch 49, Training Loss: 1.2136, Validation Loss: 1.0485
# Epoch 50, Training Loss: 1.2125, Validation Loss: 1.0472
# Epoch 51, Training Loss: 1.2116, Validation Loss: 1.0464
# Epoch 52, Training Loss: 1.2109, Validation Loss: 1.0462
# Epoch 53, Training Loss: 1.2102, Validation Loss: 1.0466
# Epoch 54, Training Loss: 1.2097, Validation Loss: 1.0468
# Epoch 55, Training Loss: 1.2091, Validation Loss: 1.0468
# Epoch 56, Training Loss: 1.2084, Validation Loss: 1.0474
# Epoch 57, Training Loss: 1.2077, Validation Loss: 1.0484
# Epoch 58, Training Loss: 1.2068, Validation Loss: 1.0498
# Epoch 59, Training Loss: 1.2060, Validation Loss: 1.0512
# Epoch 60, Training Loss: 1.2053, Validation Loss: 1.0524
# Epoch 61, Training Loss: 1.2046, Validation Loss: 1.0533
# Epoch 62, Training Loss: 1.2039, Validation Loss: 1.0542
# Epoch 63, Training Loss: 1.2034, Validation Loss: 1.0549
# Epoch 64, Training Loss: 1.2029, Validation Loss: 1.0556
# Epoch 65, Training Loss: 1.2023, Validation Loss: 1.0562
# Epoch 66, Training Loss: 1.2018, Validation Loss: 1.0566
# Epoch 67, Training Loss: 1.2012, Validation Loss: 1.0568
# Epoch 68, Training Loss: 1.2006, Validation Loss: 1.0569
# Epoch 69, Training Loss: 1.1999, Validation Loss: 1.0569
# Epoch 70, Training Loss: 1.1993, Validation Loss: 1.0569
# Epoch 71, Training Loss: 1.1988, Validation Loss: 1.0566
# Epoch 72, Training Loss: 1.1982, Validation Loss: 1.0564
# Epoch 73, Training Loss: 1.1977, Validation Loss: 1.0564
# Epoch 74, Training Loss: 1.1972, Validation Loss: 1.0568
# Epoch 75, Training Loss: 1.1967, Validation Loss: 1.0574
# Epoch 76, Training Loss: 1.1962, Validation Loss: 1.0580
# Epoch 77, Training Loss: 1.1956, Validation Loss: 1.0590
# Epoch 78, Training Loss: 1.1951, Validation Loss: 1.0597
# Epoch 79, Training Loss: 1.1945, Validation Loss: 1.0601
# Epoch 80, Training Loss: 1.1940, Validation Loss: 1.0609
# Epoch 81, Training Loss: 1.1935, Validation Loss: 1.0616
# Epoch 82, Training Loss: 1.1929, Validation Loss: 1.0623
# Early stopping triggered

# %%
# All-control and all-treated for test set
num_product = X_product.shape[0]

# All control: product_randomization = 0
all_product_control = torch.zeros(num_product, device=device).bool()

# All treated: product_randomization = 1
all_product_treated = torch.ones(num_product, device=device).bool()

# Move base price and test users/products to device
X_user_test = X_user_test.to(device)
X_product = X_product.to(device)
price = price.to(device)

# --------- Expected revenue: all control ----------
# Control prices = base prices (no discount)
price_control = price.clone()

# Prepare test data under all-control prices
user_test_ctrl, product_test_ctrl, prices_ctrl, x_other_products_ctrl, other_prices_ctrl = prepare_data(
    X_user_test,
    X_product,
    price_control
)

utilities_ctrl = pdlmodel(
    user_test_ctrl,
    product_test_ctrl,
    x_other_products_ctrl,
    other_prices_ctrl,
    prices_ctrl,          # control prices
    all_product_control   # all False
)

probabilities_ctrl = F.softmax(utilities_ctrl, dim=1)

price_with_outside_ctrl = torch.cat(
    (torch.zeros(1, device=price.device), prices_ctrl), dim=0
)  # [M+1]

expected_revenue_ctrl = torch.sum(
    probabilities_ctrl * price_with_outside_ctrl.unsqueeze(0).expand_as(probabilities_ctrl),
    dim=1
).sum()

print(f"Expected Revenue (all control): ${expected_revenue_ctrl.item():.2f}")

# --------- Expected revenue: all treated ----------
# Treated prices = discounted prices
price_treated = price * discount_percentage

user_test_trt, product_test_trt, prices_trt, x_other_products_trt, other_prices_trt = prepare_data(
    X_user_test,
    X_product,
    price_treated
)

utilities_trt = pdlmodel(
    user_test_trt,
    product_test_trt,
    x_other_products_trt,
    other_prices_trt,
    prices_trt,          # treated prices
    all_product_treated  # all True
)

probabilities_trt = F.softmax(utilities_trt, dim=1)

price_with_outside_trt = torch.cat(
    (torch.zeros(1, device=price.device), prices_trt), dim=0
)

expected_revenue_trt = torch.sum(
    probabilities_trt * price_with_outside_trt.unsqueeze(0).expand_as(probabilities_trt),
    dim=1
).sum()

print(f"Expected Revenue (all treated): ${expected_revenue_trt.item():.2f}")

# --------- GTE ----------
pdl = (expected_revenue_trt - expected_revenue_ctrl).cpu().detach().numpy() * 600 / 266
print(pdl)

pdl_all = abs((pdl - true) / true)
print(pdl_all)
# Out:
# Expected Revenue (all control): $37.59
# Expected Revenue (all treated): $8.76
# -65.0320411624765
# 0.05277297128313949

# %% [markdown]
# ## DML Estimator

# %%
def H_theta(theta0_output,theta1_output,all_treated_price,price):
    N = theta0_output.shape[0]
    M = num_product
    expand_price = price.unsqueeze(0).expand(N, M)
    expand_all_treated_price = all_treated_price.unsqueeze(0).expand(N, M)
    all_treated_uti = theta0_output + theta1_output * expand_all_treated_price
    all_control_uti =  theta0_output + theta1_output * expand_price

    zero_utilities = torch.zeros(N, 1, device=all_treated_uti.device)
    all_treated_uti = torch.cat((zero_utilities,all_treated_uti), dim=1)
    all_control_uti = torch.cat((zero_utilities,all_control_uti), dim=1)

    all_treated_probabilities = F.softmax(all_treated_uti, dim=1)
    all_control_probabilities = F.softmax(all_control_uti, dim=1)

    price_with_outside = torch.cat((torch.zeros(1, device=price.device), price), dim=0)
    treated_price_with_outside = torch.cat((torch.zeros(1, device=all_treated_price.device), all_treated_price), dim=0)

    H = torch.sum(all_treated_probabilities * treated_price_with_outside - all_control_probabilities * price_with_outside,dim=1)
    expsum_treated = torch.sum(torch.exp(all_treated_uti),dim=1)
    expsum_control = torch.sum(torch.exp(all_control_uti),dim=1)

    expsum_treated_expanded = expsum_treated.unsqueeze(1).expand(-1, all_treated_uti.shape[1])
    expsum_control_expanded = expsum_control.unsqueeze(1).expand(-1, all_control_uti.shape[1])

    H_theta0 = torch.sum((torch.exp(all_treated_uti)*(1-torch.exp(all_treated_uti))/expsum_treated_expanded/expsum_treated_expanded) * treated_price_with_outside-
                          (torch.exp(all_control_uti)*(1-torch.exp(all_control_uti))/expsum_control_expanded/expsum_control_expanded) * price_with_outside,dim=1)
    H_theta1 = torch.sum((torch.exp(all_treated_uti)*(1-torch.exp(all_treated_uti))/expsum_treated_expanded/expsum_treated_expanded) * treated_price_with_outside * treated_price_with_outside-
                          (torch.exp(all_control_uti)*(1-torch.exp(all_control_uti))/expsum_control_expanded/expsum_control_expanded) * price_with_outside * price_with_outside,dim=1)

    return H,H_theta0,H_theta1

# %%
# l_theta
def l_theta(theta0_output, theta1_output, adjusted_price, decision_test, l2_lambda=1e-4):
    N = theta0_output.shape[0]
    M = theta0_output.shape[1]

    expand_adjusted_price = adjusted_price.unsqueeze(0).expand(N, M)
    uti = theta0_output + theta1_output * expand_adjusted_price

    zero_utilities = torch.zeros(N, 1, device=uti.device)
    uti_with_outside = torch.cat((zero_utilities, uti), dim=1)

    probabilities = F.softmax(uti_with_outside, dim=1)

    prod_indices = torch.ones(M, device=uti.device)
    prod_indices = torch.cat([torch.zeros(1, device=uti.device), prod_indices])

    adjusted_price_with_outside = torch.cat([torch.zeros(1, device=adjusted_price.device), adjusted_price])

    ltheta0 = probabilities[torch.arange(decision_test.size(0)), decision_test] - prod_indices[decision_test]

    ltheta1 = (probabilities[torch.arange(decision_test.size(0)), decision_test] * adjusted_price_with_outside[decision_test]) - \
              (adjusted_price_with_outside[decision_test] * prod_indices[decision_test])

    is_inside = (decision_test > 0)

    inside_indices = (decision_test - 1).clamp(min=0)

    theta0_chosen = theta0_output.gather(1, inside_indices.unsqueeze(1)).squeeze(1)
    theta1_chosen = theta1_output.gather(1, inside_indices.unsqueeze(1)).squeeze(1)

    reg_grad0 = 2 * l2_lambda * theta0_chosen
    reg_grad1 = 2 * l2_lambda * theta1_chosen

    ltheta0 = ltheta0 + (reg_grad0 * is_inside.float())
    ltheta1 = ltheta1 + (reg_grad1 * is_inside.float())

    return ltheta0, ltheta1

# %%
# l_inv
def lambdainv(theta0_output, theta1_output, price, decision_test, epsilon=1e-6, l2_lambda=1e-4):

    N = theta0_output.shape[0]
    M = num_product

    expand_price = price.unsqueeze(0).expand(N, M)
    expand_all_treated_price = discount_percentage * price.unsqueeze(0).expand(N, M)

    all_treated_uti = theta0_output + theta1_output * expand_all_treated_price
    all_control_uti = theta0_output + theta1_output * expand_price

    zero_utilities = torch.zeros(N, 1, device=all_control_uti.device)
    all_treated_uti = torch.cat((zero_utilities, all_treated_uti), dim=1)
    all_control_uti = torch.cat((zero_utilities, all_control_uti), dim=1)

    probabilities_control = F.softmax(all_control_uti, dim=1)
    probabilities_treated = F.softmax(all_treated_uti, dim=1)

    chosen_prob_control = probabilities_control[torch.arange(N), decision_test]
    chosen_prob_treated = probabilities_treated[torch.arange(N), decision_test]

    price_with_outside = torch.cat((torch.zeros(1, device=price.device), price), dim=0)
    all_treated_price_vec = price * discount_percentage # Assuming logic from original code
    treated_price_with_outside = torch.cat((torch.zeros(1, device=price.device), all_treated_price_vec), dim=0)

    expand_price_ext = price_with_outside.unsqueeze(0).expand(N, M+1)

    chosen_price = expand_price_ext[torch.arange(N), decision_test]

    ltheta00 = chosen_prob_control * (1 - chosen_prob_control) + \
               chosen_prob_treated * (1 - chosen_prob_treated)

    ltheta01 = chosen_prob_control * (1 - chosen_prob_control) * chosen_price + \
               chosen_prob_treated * (1 - chosen_prob_treated) * (chosen_price * discount_percentage)

    ltheta11 = chosen_prob_control * (1 - chosen_prob_control) * (chosen_price**2) + \
               chosen_prob_treated * (1 - chosen_prob_treated) * ((chosen_price * discount_percentage)**2)

    ltheta00 = ltheta00 / 2
    ltheta01 = ltheta01 / 2
    ltheta11 = ltheta11 / 2

    ltheta00 = ltheta00.unsqueeze(1).unsqueeze(2)
    ltheta01 = ltheta01.unsqueeze(1).unsqueeze(2)
    ltheta11 = ltheta11.unsqueeze(1).unsqueeze(2)

    top_row = torch.cat((ltheta00, ltheta01), dim=2)
    bottom_row = torch.cat((ltheta01, ltheta11), dim=2)

    L_matrix = torch.cat((top_row, bottom_row), dim=1) # [N, 2, 2]

    reg_hessian_value = 2 * l2_lambda
    identity_matrix = torch.eye(2, dtype=L_matrix.dtype, device=L_matrix.device)
    reg_matrix = identity_matrix.unsqueeze(0).expand(N, 2, 2) * reg_hessian_value

    L_total = L_matrix + reg_matrix + (identity_matrix.unsqueeze(0) * epsilon)

    L_inv = torch.linalg.inv(L_total)

    return L_inv

# %% [markdown]
# ### No features

# %%
class UtilityEstimator_No(nn.Module):
    def __init__(self, num_product): 
        super(UtilityEstimator_No, self).__init__()
        self.num_product = num_product

        self.theta0 = nn.Parameter(torch.tensor(1.0)) 
        self.theta1 = nn.Parameter(torch.tensor(-1.0)) 

    def forward(self, x_user, x_product, x_other_products, x_other_prices, price):
        """
        price: [M]
        """
        N = x_user.shape[0]
        M = self.num_product

        u_product = self.theta0 + self.theta1 * price 
        
        utilities = u_product.unsqueeze(0).expand(N, -1)
        zero_utilities = torch.zeros(N, 1, device=price.device)
        utilities_with_outside = torch.cat([zero_utilities, utilities], dim=1)


        theta0_expanded = self.theta0.view(1, 1).expand(N, M)
        theta1_expanded = self.theta1.view(1, 1).expand(N, M)

        return utilities_with_outside, theta0_expanded, theta1_expanded

# %%
# Apply the model
dml_model = UtilityEstimator_No(
    num_product=X_product.shape[0]
).to(device)


# Initialize weight
def init_weights(m):
    if isinstance(m, nn.Linear):
        nn.init.xavier_uniform_(m.weight)
        if m.bias is not None:
            m.bias.data.fill_(0.01)
dml_model.apply(init_weights)
# Out:
# UtilityEstimator_No()

# %%
prepared_data = prepare_data(X_user_train1, X_product,  price * (1 - (1-discount_percentage) * prod_randomization))
user_features, product_features, prices, all_x_other_products, all_other_prices = prepared_data
all_x_other_products = all_x_other_products.to(device)
all_other_prices = all_other_prices.to(device)

# %%
# Train the model
optimizer = torch.optim.Adam(dml_model.parameters(), lr=0.01)
scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size=2500, gamma=0.5)
l2_lambda = 0
best_val_loss = float('inf')
patience = 10
patience_counter = 0

for epoch in range(1000):
    dml_model.train()  # Set model to training mode
    optimizer.zero_grad()

    outputs = dml_model(user_features, product_features, all_x_other_products, all_other_prices,prices)[0]
    choice_probabilities = torch.nn.functional.log_softmax(outputs, dim=1)
    loss = -torch.mean(choice_probabilities[torch.arange(choice_probabilities.shape[0]), choice_train1])
    l2_norm = sum(param.pow(2.0).sum() for param in dml_model.parameters())
    loss = loss + l2_lambda * l2_norm
    loss.backward()
    optimizer.step()
    scheduler.step()

    # Validation phase
    dml_model.eval()  # Set model to evaluation mode
    with torch.no_grad():
        val_outputs = dml_model(X_user_val, product_features, all_x_other_products, all_other_prices,prices)[0]
        val_choice_probabilities = F.log_softmax(val_outputs, dim=1)
        val_loss = -torch.mean(val_choice_probabilities[torch.arange(val_choice_probabilities.shape[0]), choice_val])
    print(f"Epoch {epoch+1}, Training Loss: {loss.item()}, Validation Loss: {val_loss.item()}")
    # Check if validation loss improved
    if (val_loss < best_val_loss)|(val_loss<loss):
        best_val_loss = val_loss
        patience_counter = 0  # Reset counter on improvement
        torch.save(dml_model.state_dict(), 'best_model.pth')  # Save the best model
    else:
        patience_counter += 1  # Increment counter if no improvement

    # Early stopping condition
    if patience_counter >= patience:
        print("Early stopping triggered")
        break
# Out:
# Epoch 1, Training Loss: 2.2338318824768066, Validation Loss: 2.309324026107788
# Epoch 2, Training Loss: 2.225825071334839, Validation Loss: 2.3013405799865723
# Epoch 3, Training Loss: 2.217846393585205, Validation Loss: 2.2933857440948486
# Epoch 4, Training Loss: 2.209897518157959, Validation Loss: 2.28546142578125
# Epoch 5, Training Loss: 2.2019786834716797, Validation Loss: 2.2775678634643555
# Epoch 6, Training Loss: 2.1940906047821045, Validation Loss: 2.2697055339813232
# Epoch 7, Training Loss: 2.186234474182129, Validation Loss: 2.2618749141693115
# Epoch 8, Training Loss: 2.178410053253174, Validation Loss: 2.2540762424468994
# Epoch 9, Training Loss: 2.1706180572509766, Validation Loss: 2.2463104724884033
# Epoch 10, Training Loss: 2.1628592014312744, Validation Loss: 2.2385780811309814
# Epoch 11, Training Loss: 2.1551339626312256, Validation Loss: 2.230879545211792
# Epoch 12, Training Loss: 2.1474430561065674, Validation Loss: 2.2232155799865723
# Epoch 13, Training Loss: 2.139787197113037, Validation Loss: 2.2155861854553223
# Epoch 14, Training Loss: 2.1321663856506348, Validation Loss: 2.2079918384552
# Epoch 15, Training Loss: 2.1245813369750977, Validation Loss: 2.2004334926605225
# Epoch 16, Training Loss: 2.117032527923584, Validation Loss: 2.192911148071289
# Epoch 17, Training Loss: 2.109520435333252, Validation Loss: 2.1854255199432373
# Epoch 18, Training Loss: 2.102045774459839, Validation Loss: 2.177976608276367
# Epoch 19, Training Loss: 2.0946085453033447, Validation Loss: 2.170565366744995
# Epoch 20, Training Loss: 2.087209701538086, Validation Loss: 2.163191795349121
# Epoch 21, Training Loss: 2.0798490047454834, Validation Loss: 2.1558566093444824
# Epoch 22, Training Loss: 2.0725274085998535, Validation Loss: 2.148559331893921
# Epoch 23, Training Loss: 2.065244674682617, Validation Loss: 2.141301155090332
# Epoch 24, Training Loss: 2.058001756668091, Validation Loss: 2.134082078933716
# Epoch 25, Training Loss: 2.0507986545562744, Validation Loss: 2.1269023418426514
# Epoch 26, Training Loss: 2.043635845184326, Validation Loss: 2.1197621822357178
# Epoch 27, Training Loss: 2.0365138053894043, Validation Loss: 2.112661838531494
# Epoch 28, Training Loss: 2.0294322967529297, Validation Loss: 2.1056020259857178
# Epoch 29, Training Loss: 2.0223920345306396, Validation Loss: 2.0985822677612305
# Epoch 30, Training Loss: 2.015392780303955, Validation Loss: 2.0916035175323486
# Epoch 31, Training Loss: 2.0084357261657715, Validation Loss: 2.084665298461914
# Epoch 32, Training Loss: 2.0015201568603516, Validation Loss: 2.077768325805664
# Epoch 33, Training Loss: 1.9946465492248535, Validation Loss: 2.0709128379821777
# Epoch 34, Training Loss: 1.9878156185150146, Validation Loss: 2.0640981197357178
# Epoch 35, Training Loss: 1.9810266494750977, Validation Loss: 2.0573253631591797
# Epoch 36, Training Loss: 1.9742804765701294, Validation Loss: 2.0505943298339844
# Epoch 37, Training Loss: 1.9675770998001099, Validation Loss: 2.043905019760132
# Epoch 38, Training Loss: 1.9609167575836182, Validation Loss: 2.0372579097747803
# Epoch 39, Training Loss: 1.9542990922927856, Validation Loss: 2.0306522846221924
# Epoch 40, Training Loss: 1.94772469997406, Validation Loss: 2.0240893363952637
# Epoch 41, Training Loss: 1.9411934614181519, Validation Loss: 2.017568349838257
# Epoch 42, Training Loss: 1.9347058534622192, Validation Loss: 2.011090040206909
# Epoch 43, Training Loss: 1.9282617568969727, Validation Loss: 2.0046539306640625
# Epoch 44, Training Loss: 1.9218610525131226, Validation Loss: 1.9982599020004272
# Epoch 45, Training Loss: 1.9155036211013794, Validation Loss: 1.991909146308899
# Epoch 46, Training Loss: 1.90919029712677, Validation Loss: 1.9856007099151611
# Epoch 47, Training Loss: 1.9029208421707153, Validation Loss: 1.9793344736099243
# Epoch 48, Training Loss: 1.8966947793960571, Validation Loss: 1.9731111526489258
# Epoch 49, Training Loss: 1.8905128240585327, Validation Loss: 1.9669307470321655
# Epoch 50, Training Loss: 1.8843746185302734, Validation Loss: 1.960792899131775
# Epoch 51, Training Loss: 1.8782802820205688, Validation Loss: 1.954697608947754
# Epoch 52, Training Loss: 1.872229814529419, Validation Loss: 1.948644995689392
# Epoch 53, Training Loss: 1.8662230968475342, Validation Loss: 1.942635178565979
# Epoch 54, Training Loss: 1.8602603673934937, Validation Loss: 1.9366683959960938
# Epoch 55, Training Loss: 1.854341745376587, Validation Loss: 1.930743932723999
# Epoch 56, Training Loss: 1.8484667539596558, Validation Loss: 1.924862027168274
# Epoch 57, Training Loss: 1.8426355123519897, Validation Loss: 1.919023036956787
# Epoch 58, Training Loss: 1.836848497390747, Validation Loss: 1.9132263660430908
# Epoch 59, Training Loss: 1.8311048746109009, Validation Loss: 1.9074723720550537
# Epoch 60, Training Loss: 1.825405240058899, Validation Loss: 1.9017611742019653
# Epoch 61, Training Loss: 1.8197494745254517, Validation Loss: 1.8960920572280884
# Epoch 62, Training Loss: 1.8141372203826904, Validation Loss: 1.8904658555984497
# Epoch 63, Training Loss: 1.8085687160491943, Validation Loss: 1.8848814964294434
# Epoch 64, Training Loss: 1.8030437231063843, Validation Loss: 1.8793398141860962
# Epoch 65, Training Loss: 1.7975622415542603, Validation Loss: 1.87384033203125
# Epoch 66, Training Loss: 1.7921243906021118, Validation Loss: 1.8683830499649048
# Epoch 67, Training Loss: 1.7867299318313599, Validation Loss: 1.8629677295684814
# Epoch 68, Training Loss: 1.7813787460327148, Validation Loss: 1.8575948476791382
# Epoch 69, Training Loss: 1.7760708332061768, Validation Loss: 1.8522636890411377
# Epoch 70, Training Loss: 1.7708061933517456, Validation Loss: 1.8469741344451904
# Epoch 71, Training Loss: 1.7655844688415527, Validation Loss: 1.8417267799377441
# Epoch 72, Training Loss: 1.7604057788848877, Validation Loss: 1.8365209102630615
# Epoch 73, Training Loss: 1.7552701234817505, Validation Loss: 1.8313567638397217
# Epoch 74, Training Loss: 1.750177264213562, Validation Loss: 1.8262341022491455
# Epoch 75, Training Loss: 1.7451273202896118, Validation Loss: 1.8211530447006226
# Epoch 76, Training Loss: 1.7401198148727417, Validation Loss: 1.8161128759384155
# Epoch 77, Training Loss: 1.7351547479629517, Validation Loss: 1.811113953590393
# Epoch 78, Training Loss: 1.7302321195602417, Validation Loss: 1.8061565160751343
# Epoch 79, Training Loss: 1.7253519296646118, Validation Loss: 1.8012396097183228
# Epoch 80, Training Loss: 1.7205137014389038, Validation Loss: 1.7963639497756958
# Epoch 81, Training Loss: 1.7157177925109863, Validation Loss: 1.7915284633636475
# Epoch 82, Training Loss: 1.7109633684158325, Validation Loss: 1.7867339849472046
# Epoch 83, Training Loss: 1.7062511444091797, Validation Loss: 1.7819796800613403
# Epoch 84, Training Loss: 1.7015804052352905, Validation Loss: 1.7772659063339233
# Epoch 85, Training Loss: 1.6969512701034546, Validation Loss: 1.7725921869277954
# Epoch 86, Training Loss: 1.6923633813858032, Validation Loss: 1.7679582834243774
# Epoch 87, Training Loss: 1.687816858291626, Validation Loss: 1.763364553451538
# Epoch 88, Training Loss: 1.6833114624023438, Validation Loss: 1.7588106393814087
# Epoch 89, Training Loss: 1.678846836090088, Validation Loss: 1.7542963027954102
# Epoch 90, Training Loss: 1.674423336982727, Validation Loss: 1.7498210668563843
# Epoch 91, Training Loss: 1.6700401306152344, Validation Loss: 1.7453854084014893
# Epoch 92, Training Loss: 1.665697455406189, Validation Loss: 1.7409887313842773
# Epoch 93, Training Loss: 1.6613951921463013, Validation Loss: 1.736630916595459
# Epoch 94, Training Loss: 1.6571331024169922, Validation Loss: 1.7323122024536133
# Epoch 95, Training Loss: 1.6529110670089722, Validation Loss: 1.728032112121582
# Epoch 96, Training Loss: 1.648728609085083, Validation Loss: 1.723790168762207
# Epoch 97, Training Loss: 1.6445860862731934, Validation Loss: 1.7195866107940674
# Epoch 98, Training Loss: 1.6404829025268555, Validation Loss: 1.7154209613800049
# Epoch 99, Training Loss: 1.6364190578460693, Validation Loss: 1.7112934589385986
# Epoch 100, Training Loss: 1.6323940753936768, Validation Loss: 1.7072036266326904
# Epoch 101, Training Loss: 1.6284081935882568, Validation Loss: 1.7031512260437012
# Epoch 102, Training Loss: 1.6244611740112305, Validation Loss: 1.6991362571716309
# Epoch 103, Training Loss: 1.62055242061615, Validation Loss: 1.6951583623886108
# Epoch 104, Training Loss: 1.6166822910308838, Validation Loss: 1.691217303276062
# Epoch 105, Training Loss: 1.6128499507904053, Validation Loss: 1.687313437461853
# Epoch 106, Training Loss: 1.6090556383132935, Validation Loss: 1.683445692062378
# Epoch 107, Training Loss: 1.6052993535995483, Validation Loss: 1.679614543914795
# Epoch 108, Training Loss: 1.601580262184143, Validation Loss: 1.6758192777633667
# Epoch 109, Training Loss: 1.5978987216949463, Validation Loss: 1.6720601320266724
# Epoch 110, Training Loss: 1.5942541360855103, Validation Loss: 1.6683366298675537
# Epoch 111, Training Loss: 1.590646505355835, Validation Loss: 1.6646486520767212
# Epoch 112, Training Loss: 1.5870754718780518, Validation Loss: 1.6609960794448853
# Epoch 113, Training Loss: 1.5835410356521606, Validation Loss: 1.6573784351348877
# Epoch 114, Training Loss: 1.580042839050293, Validation Loss: 1.653795838356018
# Epoch 115, Training Loss: 1.5765807628631592, Validation Loss: 1.6502474546432495
# Epoch 116, Training Loss: 1.573154091835022, Validation Loss: 1.6467338800430298
# Epoch 117, Training Loss: 1.5697635412216187, Validation Loss: 1.6432545185089111
# Epoch 118, Training Loss: 1.5664079189300537, Validation Loss: 1.639809012413025
# Epoch 119, Training Loss: 1.5630875825881958, Validation Loss: 1.6363970041275024
# Epoch 120, Training Loss: 1.5598021745681763, Validation Loss: 1.6330186128616333
# Epoch 121, Training Loss: 1.556551456451416, Validation Loss: 1.6296736001968384
# Epoch 122, Training Loss: 1.5533350706100464, Validation Loss: 1.626361608505249
# Epoch 123, Training Loss: 1.5501527786254883, Validation Loss: 1.6230822801589966
# Epoch 124, Training Loss: 1.5470044612884521, Validation Loss: 1.619835615158081
# Epoch 125, Training Loss: 1.5438899993896484, Validation Loss: 1.6166211366653442
# Epoch 126, Training Loss: 1.5408087968826294, Validation Loss: 1.6134387254714966
# Epoch 127, Training Loss: 1.5377610921859741, Validation Loss: 1.610288143157959
# Epoch 128, Training Loss: 1.5347460508346558, Validation Loss: 1.607169270515442
# Epoch 129, Training Loss: 1.5317639112472534, Validation Loss: 1.6040815114974976
# Epoch 130, Training Loss: 1.5288140773773193, Validation Loss: 1.6010249853134155
# Epoch 131, Training Loss: 1.525896668434143, Validation Loss: 1.5979993343353271
# Epoch 132, Training Loss: 1.5230110883712769, Validation Loss: 1.5950042009353638
# Epoch 133, Training Loss: 1.5201573371887207, Validation Loss: 1.5920394659042358
# Epoch 134, Training Loss: 1.517335057258606, Validation Loss: 1.5891045331954956
# Epoch 135, Training Loss: 1.514543890953064, Validation Loss: 1.5861999988555908
# Epoch 136, Training Loss: 1.5117839574813843, Validation Loss: 1.5833245515823364
# Epoch 137, Training Loss: 1.5090543031692505, Validation Loss: 1.580478310585022
# Epoch 138, Training Loss: 1.5063551664352417, Validation Loss: 1.577661395072937
# Epoch 139, Training Loss: 1.5036863088607788, Validation Loss: 1.5748733282089233
# Epoch 140, Training Loss: 1.5010477304458618, Validation Loss: 1.5721138715744019
# Epoch 141, Training Loss: 1.4984385967254639, Validation Loss: 1.5693825483322144
# Epoch 142, Training Loss: 1.4958586692810059, Validation Loss: 1.5666794776916504
# Epoch 143, Training Loss: 1.4933079481124878, Validation Loss: 1.5640040636062622
# Epoch 144, Training Loss: 1.4907863140106201, Validation Loss: 1.5613560676574707
# Epoch 145, Training Loss: 1.488293170928955, Validation Loss: 1.5587354898452759
# Epoch 146, Training Loss: 1.4858283996582031, Validation Loss: 1.55614173412323
# Epoch 147, Training Loss: 1.4833918809890747, Validation Loss: 1.5535749197006226
# Epoch 148, Training Loss: 1.480983018875122, Validation Loss: 1.5510345697402954
# Epoch 149, Training Loss: 1.4786018133163452, Validation Loss: 1.5485204458236694
# Epoch 150, Training Loss: 1.476248025894165, Validation Loss: 1.5460323095321655
# Epoch 151, Training Loss: 1.473921298980713, Validation Loss: 1.5435699224472046
# Epoch 152, Training Loss: 1.4716213941574097, Validation Loss: 1.5411328077316284
# Epoch 153, Training Loss: 1.469347596168518, Validation Loss: 1.5387212038040161
# Epoch 154, Training Loss: 1.4671006202697754, Validation Loss: 1.5363342761993408
# Epoch 155, Training Loss: 1.4648793935775757, Validation Loss: 1.533972144126892
# Epoch 156, Training Loss: 1.4626840353012085, Validation Loss: 1.5316344499588013
# Epoch 157, Training Loss: 1.4605141878128052, Validation Loss: 1.5293209552764893
# Epoch 158, Training Loss: 1.458369493484497, Validation Loss: 1.5270311832427979
# Epoch 159, Training Loss: 1.4562499523162842, Validation Loss: 1.524765133857727
# Epoch 160, Training Loss: 1.4541547298431396, Validation Loss: 1.5225225687026978
# Epoch 161, Training Loss: 1.4520844221115112, Validation Loss: 1.5203032493591309
# Epoch 162, Training Loss: 1.450038194656372, Validation Loss: 1.5181068181991577
# Epoch 163, Training Loss: 1.448015809059143, Validation Loss: 1.5159326791763306
# Epoch 164, Training Loss: 1.4460171461105347, Validation Loss: 1.513781189918518
# Epoch 165, Training Loss: 1.4440418481826782, Validation Loss: 1.5116521120071411
# Epoch 166, Training Loss: 1.4420900344848633, Validation Loss: 1.5095446109771729
# Epoch 167, Training Loss: 1.4401607513427734, Validation Loss: 1.5074588060379028
# Epoch 168, Training Loss: 1.4382542371749878, Validation Loss: 1.5053942203521729
# Epoch 169, Training Loss: 1.4363703727722168, Validation Loss: 1.5033509731292725
# Epoch 170, Training Loss: 1.4345084428787231, Validation Loss: 1.501328706741333
# Epoch 171, Training Loss: 1.4326685667037964, Validation Loss: 1.4993268251419067
# Epoch 172, Training Loss: 1.4308502674102783, Validation Loss: 1.4973454475402832
# Epoch 173, Training Loss: 1.4290531873703003, Validation Loss: 1.4953843355178833
# Epoch 174, Training Loss: 1.427277684211731, Validation Loss: 1.4934428930282593
# Epoch 175, Training Loss: 1.425522804260254, Validation Loss: 1.4915213584899902
# Epoch 176, Training Loss: 1.4237886667251587, Validation Loss: 1.4896193742752075
# Epoch 177, Training Loss: 1.4220751523971558, Validation Loss: 1.4877363443374634
# Epoch 178, Training Loss: 1.4203815460205078, Validation Loss: 1.4858723878860474
# Epoch 179, Training Loss: 1.418708086013794, Validation Loss: 1.4840271472930908
# Epoch 180, Training Loss: 1.4170541763305664, Validation Loss: 1.4822005033493042
# Epoch 181, Training Loss: 1.4154199361801147, Validation Loss: 1.4803920984268188
# Epoch 182, Training Loss: 1.4138048887252808, Validation Loss: 1.4786015748977661
# Epoch 183, Training Loss: 1.4122087955474854, Validation Loss: 1.476828932762146
# Epoch 184, Training Loss: 1.410631537437439, Validation Loss: 1.4750739336013794
# Epoch 185, Training Loss: 1.4090725183486938, Validation Loss: 1.473336100578308
# Epoch 186, Training Loss: 1.4075322151184082, Validation Loss: 1.4716154336929321
# Epoch 187, Training Loss: 1.4060097932815552, Validation Loss: 1.469911813735962
# Epoch 188, Training Loss: 1.4045051336288452, Validation Loss: 1.4682248830795288
# Epoch 189, Training Loss: 1.4030182361602783, Validation Loss: 1.4665542840957642
# Epoch 190, Training Loss: 1.4015486240386963, Validation Loss: 1.4649001359939575
# Epoch 191, Training Loss: 1.4000962972640991, Validation Loss: 1.4632618427276611
# Epoch 192, Training Loss: 1.3986608982086182, Validation Loss: 1.4616395235061646
# Epoch 193, Training Loss: 1.3972423076629639, Validation Loss: 1.460032343864441
# Epoch 194, Training Loss: 1.3958401679992676, Validation Loss: 1.458440899848938
# Epoch 195, Training Loss: 1.3944541215896606, Validation Loss: 1.4568647146224976
# Epoch 196, Training Loss: 1.3930844068527222, Validation Loss: 1.4553035497665405
# Epoch 197, Training Loss: 1.3917306661605835, Validation Loss: 1.4537569284439087
# Epoch 198, Training Loss: 1.3903923034667969, Validation Loss: 1.4522250890731812
# Epoch 199, Training Loss: 1.389069676399231, Validation Loss: 1.4507075548171997
# Epoch 200, Training Loss: 1.387762188911438, Validation Loss: 1.4492040872573853
# Epoch 201, Training Loss: 1.3864697217941284, Validation Loss: 1.4477145671844482
# Epoch 202, Training Loss: 1.3851921558380127, Validation Loss: 1.4462388753890991
# Epoch 203, Training Loss: 1.3839290142059326, Validation Loss: 1.4447768926620483
# Epoch 204, Training Loss: 1.3826806545257568, Validation Loss: 1.4433280229568481
# Epoch 205, Training Loss: 1.381446361541748, Validation Loss: 1.4418925046920776
# Epoch 206, Training Loss: 1.3802260160446167, Validation Loss: 1.4404700994491577
# Epoch 207, Training Loss: 1.3790196180343628, Validation Loss: 1.4390605688095093
# Epoch 208, Training Loss: 1.3778271675109863, Validation Loss: 1.4376635551452637
# Epoch 209, Training Loss: 1.376647710800171, Validation Loss: 1.4362788200378418
# Epoch 210, Training Loss: 1.3754818439483643, Validation Loss: 1.4349064826965332
# Epoch 211, Training Loss: 1.3743289709091187, Validation Loss: 1.4335464239120483
# Epoch 212, Training Loss: 1.373189091682434, Validation Loss: 1.43219792842865
# Epoch 213, Training Loss: 1.372061848640442, Validation Loss: 1.4308615922927856
# Epoch 214, Training Loss: 1.3709471225738525, Validation Loss: 1.4295365810394287
# Epoch 215, Training Loss: 1.3698451519012451, Validation Loss: 1.4282231330871582
# Epoch 216, Training Loss: 1.3687549829483032, Validation Loss: 1.426920771598816
# Epoch 217, Training Loss: 1.367677092552185, Validation Loss: 1.4256294965744019
# Epoch 218, Training Loss: 1.3666107654571533, Validation Loss: 1.424349308013916
# Epoch 219, Training Loss: 1.3655565977096558, Validation Loss: 1.4230797290802002
# Epoch 220, Training Loss: 1.3645133972167969, Validation Loss: 1.4218205213546753
# Epoch 221, Training Loss: 1.363481879234314, Validation Loss: 1.42057204246521
# Epoch 222, Training Loss: 1.3624614477157593, Validation Loss: 1.419333815574646
# Epoch 223, Training Loss: 1.3614521026611328, Validation Loss: 1.4181056022644043
# Epoch 224, Training Loss: 1.360453724861145, Validation Loss: 1.4168874025344849
# Epoch 225, Training Loss: 1.3594657182693481, Validation Loss: 1.4156790971755981
# Epoch 226, Training Loss: 1.3584885597229004, Validation Loss: 1.4144803285598755
# Epoch 227, Training Loss: 1.357521653175354, Validation Loss: 1.413291096687317
# Epoch 228, Training Loss: 1.3565651178359985, Validation Loss: 1.4121114015579224
# Epoch 229, Training Loss: 1.3556185960769653, Validation Loss: 1.4109406471252441
# Epoch 230, Training Loss: 1.3546820878982544, Validation Loss: 1.4097789525985718
# Epoch 231, Training Loss: 1.353755235671997, Validation Loss: 1.408626675605774
# Epoch 232, Training Loss: 1.352838158607483, Validation Loss: 1.4074827432632446
# Epoch 233, Training Loss: 1.3519306182861328, Validation Loss: 1.4063477516174316
# Epoch 234, Training Loss: 1.3510323762893677, Validation Loss: 1.4052212238311768
# Epoch 235, Training Loss: 1.3501434326171875, Validation Loss: 1.4041030406951904
# Epoch 236, Training Loss: 1.349263310432434, Validation Loss: 1.4029934406280518
# Epoch 237, Training Loss: 1.3483926057815552, Validation Loss: 1.4018914699554443
# Epoch 238, Training Loss: 1.3475303649902344, Validation Loss: 1.4007980823516846
# Epoch 239, Training Loss: 1.3466768264770508, Validation Loss: 1.399712085723877
# Epoch 240, Training Loss: 1.3458319902420044, Validation Loss: 1.3986343145370483
# Epoch 241, Training Loss: 1.3449954986572266, Validation Loss: 1.3975640535354614
# Epoch 242, Training Loss: 1.3441673517227173, Validation Loss: 1.3965013027191162
# Epoch 243, Training Loss: 1.343347430229187, Validation Loss: 1.395445704460144
# Epoch 244, Training Loss: 1.3425352573394775, Validation Loss: 1.3943978548049927
# Epoch 245, Training Loss: 1.341731309890747, Validation Loss: 1.3933573961257935
# Epoch 246, Training Loss: 1.340935230255127, Validation Loss: 1.39232337474823
# Epoch 247, Training Loss: 1.3401466608047485, Validation Loss: 1.391296625137329
# Epoch 248, Training Loss: 1.339365839958191, Validation Loss: 1.3902767896652222
# Epoch 249, Training Loss: 1.338592290878296, Validation Loss: 1.3892638683319092
# Epoch 250, Training Loss: 1.3378263711929321, Validation Loss: 1.388257384300232
# Epoch 251, Training Loss: 1.3370673656463623, Validation Loss: 1.38725745677948
# Epoch 252, Training Loss: 1.3363157510757446, Validation Loss: 1.3862640857696533
# Epoch 253, Training Loss: 1.3355709314346313, Validation Loss: 1.3852771520614624
# Epoch 254, Training Loss: 1.3348332643508911, Validation Loss: 1.3842960596084595
# Epoch 255, Training Loss: 1.3341021537780762, Validation Loss: 1.3833215236663818
# Epoch 256, Training Loss: 1.3333779573440552, Validation Loss: 1.3823531866073608
# Epoch 257, Training Loss: 1.3326603174209595, Validation Loss: 1.3813903331756592
# Epoch 258, Training Loss: 1.33194899559021, Validation Loss: 1.3804335594177246
# Epoch 259, Training Loss: 1.3312442302703857, Validation Loss: 1.379482626914978
# Epoch 260, Training Loss: 1.3305456638336182, Validation Loss: 1.3785374164581299
# Epoch 261, Training Loss: 1.3298535346984863, Validation Loss: 1.3775979280471802
# Epoch 262, Training Loss: 1.3291674852371216, Validation Loss: 1.3766636848449707
# Epoch 263, Training Loss: 1.3284872770309448, Validation Loss: 1.3757349252700806
# Epoch 264, Training Loss: 1.3278131484985352, Validation Loss: 1.3748116493225098
# Epoch 265, Training Loss: 1.3271448612213135, Validation Loss: 1.3738936185836792
# Epoch 266, Training Loss: 1.3264825344085693, Validation Loss: 1.3729809522628784
# Epoch 267, Training Loss: 1.3258256912231445, Validation Loss: 1.3720730543136597
# Epoch 268, Training Loss: 1.32517409324646, Validation Loss: 1.3711704015731812
# Epoch 269, Training Loss: 1.3245283365249634, Validation Loss: 1.3702728748321533
# Epoch 270, Training Loss: 1.3238881826400757, Validation Loss: 1.3693801164627075
# Epoch 271, Training Loss: 1.3232531547546387, Validation Loss: 1.3684918880462646
# Epoch 272, Training Loss: 1.3226231336593628, Validation Loss: 1.367608666419983
# Epoch 273, Training Loss: 1.3219984769821167, Validation Loss: 1.3667302131652832
# Epoch 274, Training Loss: 1.32137930393219, Validation Loss: 1.3658562898635864
# Epoch 275, Training Loss: 1.3207646608352661, Validation Loss: 1.3649868965148926
# Epoch 276, Training Loss: 1.320155382156372, Validation Loss: 1.3641217947006226
# Epoch 277, Training Loss: 1.319550633430481, Validation Loss: 1.3632614612579346
# Epoch 278, Training Loss: 1.318950891494751, Validation Loss: 1.3624050617218018
# Epoch 279, Training Loss: 1.3183557987213135, Validation Loss: 1.3615530729293823
# Epoch 280, Training Loss: 1.317765235900879, Validation Loss: 1.3607052564620972
# Epoch 281, Training Loss: 1.317179560661316, Validation Loss: 1.359861969947815
# Epoch 282, Training Loss: 1.3165984153747559, Validation Loss: 1.3590224981307983
# Epoch 283, Training Loss: 1.3160215616226196, Validation Loss: 1.358186960220337
# Epoch 284, Training Loss: 1.3154489994049072, Validation Loss: 1.3573555946350098
# Epoch 285, Training Loss: 1.3148810863494873, Validation Loss: 1.3565279245376587
# Epoch 286, Training Loss: 1.3143171072006226, Validation Loss: 1.3557041883468628
# Epoch 287, Training Loss: 1.3137574195861816, Validation Loss: 1.3548846244812012
# Epoch 288, Training Loss: 1.3132022619247437, Validation Loss: 1.354068398475647
# Epoch 289, Training Loss: 1.3126509189605713, Validation Loss: 1.353256106376648
# Epoch 290, Training Loss: 1.3121036291122437, Validation Loss: 1.352447271347046
# Epoch 291, Training Loss: 1.3115601539611816, Validation Loss: 1.3516422510147095
# Epoch 292, Training Loss: 1.311020851135254, Validation Loss: 1.3508408069610596
# Epoch 293, Training Loss: 1.3104852437973022, Validation Loss: 1.3500429391860962
# Epoch 294, Training Loss: 1.3099536895751953, Validation Loss: 1.3492484092712402
# Epoch 295, Training Loss: 1.309425711631775, Validation Loss: 1.3484570980072021
# Epoch 296, Training Loss: 1.3089014291763306, Validation Loss: 1.3476693630218506
# Epoch 297, Training Loss: 1.3083807229995728, Validation Loss: 1.346885085105896
# Epoch 298, Training Loss: 1.307863712310791, Validation Loss: 1.3461039066314697
# Epoch 299, Training Loss: 1.3073502779006958, Validation Loss: 1.3453260660171509
# Epoch 300, Training Loss: 1.306840419769287, Validation Loss: 1.3445513248443604
# Epoch 301, Training Loss: 1.3063340187072754, Validation Loss: 1.3437799215316772
# Epoch 302, Training Loss: 1.3058308362960815, Validation Loss: 1.343011498451233
# Epoch 303, Training Loss: 1.3053311109542847, Validation Loss: 1.3422462940216064
# Epoch 304, Training Loss: 1.3048347234725952, Validation Loss: 1.3414841890335083
# Epoch 305, Training Loss: 1.3043419122695923, Validation Loss: 1.340725064277649
# Epoch 306, Training Loss: 1.3038520812988281, Validation Loss: 1.3399685621261597
# Epoch 307, Training Loss: 1.3033653497695923, Validation Loss: 1.3392151594161987
# Epoch 308, Training Loss: 1.3028815984725952, Validation Loss: 1.3384649753570557
# Epoch 309, Training Loss: 1.3024013042449951, Validation Loss: 1.3377175331115723
# Epoch 310, Training Loss: 1.3019241094589233, Validation Loss: 1.3369728326797485
# Epoch 311, Training Loss: 1.3014497756958008, Validation Loss: 1.3362308740615845
# Epoch 312, Training Loss: 1.300978422164917, Validation Loss: 1.3354917764663696
# Epoch 313, Training Loss: 1.300510048866272, Validation Loss: 1.334755539894104
# Epoch 314, Training Loss: 1.3000447750091553, Validation Loss: 1.334022045135498
# Epoch 315, Training Loss: 1.2995821237564087, Validation Loss: 1.3332910537719727
# Epoch 316, Training Loss: 1.2991225719451904, Validation Loss: 1.3325629234313965
# Epoch 317, Training Loss: 1.2986657619476318, Validation Loss: 1.3318371772766113
# Epoch 318, Training Loss: 1.298211693763733, Validation Loss: 1.3311142921447754
# Epoch 319, Training Loss: 1.2977603673934937, Validation Loss: 1.3303937911987305
# Epoch 320, Training Loss: 1.2973116636276245, Validation Loss: 1.3296760320663452
# Epoch 321, Training Loss: 1.296865701675415, Validation Loss: 1.3289607763290405
# Epoch 322, Training Loss: 1.2964224815368652, Validation Loss: 1.3282476663589478
# Epoch 323, Training Loss: 1.2959816455841064, Validation Loss: 1.3275372982025146
# Epoch 324, Training Loss: 1.2955435514450073, Validation Loss: 1.326829433441162
# Epoch 325, Training Loss: 1.2951080799102783, Validation Loss: 1.326123833656311
# Epoch 326, Training Loss: 1.2946751117706299, Validation Loss: 1.3254207372665405
# Epoch 327, Training Loss: 1.294244408607483, Validation Loss: 1.3247201442718506
# Epoch 328, Training Loss: 1.293816328048706, Validation Loss: 1.324021816253662
# Epoch 329, Training Loss: 1.2933909893035889, Validation Loss: 1.3233256340026855
# Epoch 330, Training Loss: 1.292967677116394, Validation Loss: 1.322632074356079
# Epoch 331, Training Loss: 1.2925469875335693, Validation Loss: 1.3219406604766846
# Epoch 332, Training Loss: 1.2921284437179565, Validation Loss: 1.3212515115737915
# Epoch 333, Training Loss: 1.2917125225067139, Validation Loss: 1.3205646276474
# Epoch 334, Training Loss: 1.2912986278533936, Validation Loss: 1.3198801279067993
# Epoch 335, Training Loss: 1.2908872365951538, Validation Loss: 1.319197654724121
# Epoch 336, Training Loss: 1.2904778718948364, Validation Loss: 1.3185174465179443
# Epoch 337, Training Loss: 1.2900710105895996, Validation Loss: 1.317839503288269
# Epoch 338, Training Loss: 1.2896662950515747, Validation Loss: 1.3171637058258057
# Epoch 339, Training Loss: 1.2892637252807617, Validation Loss: 1.3164901733398438
# Epoch 340, Training Loss: 1.2888635396957397, Validation Loss: 1.3158187866210938
# Epoch 341, Training Loss: 1.2884653806686401, Validation Loss: 1.3151493072509766
# Epoch 342, Training Loss: 1.2880693674087524, Validation Loss: 1.3144820928573608
# Epoch 343, Training Loss: 1.2876752614974976, Validation Loss: 1.3138169050216675
# Epoch 344, Training Loss: 1.2872835397720337, Validation Loss: 1.3131539821624756
# Epoch 345, Training Loss: 1.2868937253952026, Validation Loss: 1.312492847442627
# Epoch 346, Training Loss: 1.2865060567855835, Validation Loss: 1.3118338584899902
# Epoch 347, Training Loss: 1.2861204147338867, Validation Loss: 1.311177134513855
# Epoch 348, Training Loss: 1.2857369184494019, Validation Loss: 1.3105220794677734
# Epoch 349, Training Loss: 1.2853550910949707, Validation Loss: 1.3098692893981934
# Epoch 350, Training Loss: 1.284975528717041, Validation Loss: 1.3092186450958252
# Epoch 351, Training Loss: 1.2845978736877441, Validation Loss: 1.3085695505142212
# Epoch 352, Training Loss: 1.28422212600708, Validation Loss: 1.3079228401184082
# Epoch 353, Training Loss: 1.2838482856750488, Validation Loss: 1.3072779178619385
# Epoch 354, Training Loss: 1.2834763526916504, Validation Loss: 1.3066349029541016
# Epoch 355, Training Loss: 1.2831062078475952, Validation Loss: 1.305993914604187
# Epoch 356, Training Loss: 1.2827383279800415, Validation Loss: 1.3053548336029053
# Epoch 357, Training Loss: 1.282371997833252, Validation Loss: 1.304717779159546
# Epoch 358, Training Loss: 1.2820075750350952, Validation Loss: 1.3040826320648193
# Epoch 359, Training Loss: 1.2816452980041504, Validation Loss: 1.303449273109436
# Epoch 360, Training Loss: 1.2812844514846802, Validation Loss: 1.3028180599212646
# Epoch 361, Training Loss: 1.2809256315231323, Validation Loss: 1.302188515663147
# Epoch 362, Training Loss: 1.2805683612823486, Validation Loss: 1.301560878753662
# Epoch 363, Training Loss: 1.2802131175994873, Validation Loss: 1.3009352684020996
# Epoch 364, Training Loss: 1.2798595428466797, Validation Loss: 1.3003113269805908
# Epoch 365, Training Loss: 1.2795078754425049, Validation Loss: 1.2996892929077148
# Epoch 366, Training Loss: 1.2791576385498047, Validation Loss: 1.2990690469741821
# Epoch 367, Training Loss: 1.2788094282150269, Validation Loss: 1.2984508275985718
# Epoch 368, Training Loss: 1.2784630060195923, Validation Loss: 1.2978342771530151
# Epoch 369, Training Loss: 1.2781178951263428, Validation Loss: 1.2972197532653809
# Epoch 370, Training Loss: 1.2777748107910156, Validation Loss: 1.2966068983078003
# Epoch 371, Training Loss: 1.2774332761764526, Validation Loss: 1.295996069908142
# Epoch 372, Training Loss: 1.277093529701233, Validation Loss: 1.295386791229248
# Epoch 373, Training Loss: 1.2767553329467773, Validation Loss: 1.2947794198989868
# Epoch 374, Training Loss: 1.2764188051223755, Validation Loss: 1.2941738367080688
# Epoch 375, Training Loss: 1.2760841846466064, Validation Loss: 1.2935700416564941
# Epoch 376, Training Loss: 1.2757508754730225, Validation Loss: 1.2929680347442627
# Epoch 377, Training Loss: 1.2754191160202026, Validation Loss: 1.2923678159713745
# Epoch 378, Training Loss: 1.275089144706726, Validation Loss: 1.2917693853378296
# Epoch 379, Training Loss: 1.2747608423233032, Validation Loss: 1.2911726236343384
# Epoch 380, Training Loss: 1.2744338512420654, Validation Loss: 1.29057776927948
# Epoch 381, Training Loss: 1.274108648300171, Validation Loss: 1.2899845838546753
# Epoch 382, Training Loss: 1.2737852334976196, Validation Loss: 1.2893933057785034
# Epoch 383, Training Loss: 1.273463249206543, Validation Loss: 1.2888036966323853
# Epoch 384, Training Loss: 1.273142695426941, Validation Loss: 1.2882155179977417
# Epoch 385, Training Loss: 1.2728235721588135, Validation Loss: 1.28762948513031
# Epoch 386, Training Loss: 1.2725061178207397, Validation Loss: 1.2870451211929321
# Epoch 387, Training Loss: 1.2721902132034302, Validation Loss: 1.286462426185608
# Epoch 388, Training Loss: 1.2718758583068848, Validation Loss: 1.285881519317627
# Epoch 389, Training Loss: 1.2715630531311035, Validation Loss: 1.2853021621704102
# Epoch 390, Training Loss: 1.2712515592575073, Validation Loss: 1.2847247123718262
# Epoch 391, Training Loss: 1.2709417343139648, Validation Loss: 1.284148931503296
# Epoch 392, Training Loss: 1.270633339881897, Validation Loss: 1.2835747003555298
# Epoch 393, Training Loss: 1.2703262567520142, Validation Loss: 1.283002495765686
# Epoch 394, Training Loss: 1.2700209617614746, Validation Loss: 1.2824318408966064
# Epoch 395, Training Loss: 1.2697169780731201, Validation Loss: 1.2818628549575806
# Epoch 396, Training Loss: 1.2694145441055298, Validation Loss: 1.2812955379486084
# Epoch 397, Training Loss: 1.269113540649414, Validation Loss: 1.2807300090789795
# Epoch 398, Training Loss: 1.2688138484954834, Validation Loss: 1.2801661491394043
# Epoch 399, Training Loss: 1.2685158252716064, Validation Loss: 1.2796038389205933
# Epoch 400, Training Loss: 1.2682188749313354, Validation Loss: 1.279043436050415
# Epoch 401, Training Loss: 1.2679235935211182, Validation Loss: 1.278484582901001
# Epoch 402, Training Loss: 1.2676297426223755, Validation Loss: 1.2779273986816406
# Epoch 403, Training Loss: 1.2673370838165283, Validation Loss: 1.2773720026016235
# Epoch 404, Training Loss: 1.2670462131500244, Validation Loss: 1.2768181562423706
# Epoch 405, Training Loss: 1.266756534576416, Validation Loss: 1.2762659788131714
# Epoch 406, Training Loss: 1.2664680480957031, Validation Loss: 1.2757154703140259
# Epoch 407, Training Loss: 1.2661809921264648, Validation Loss: 1.2751667499542236
# Epoch 408, Training Loss: 1.2658956050872803, Validation Loss: 1.2746198177337646
# Epoch 409, Training Loss: 1.2656115293502808, Validation Loss: 1.2740743160247803
# Epoch 410, Training Loss: 1.2653287649154663, Validation Loss: 1.2735304832458496
# Epoch 411, Training Loss: 1.265047311782837, Validation Loss: 1.272988200187683
# Epoch 412, Training Loss: 1.2647672891616821, Validation Loss: 1.272447943687439
# Epoch 413, Training Loss: 1.2644884586334229, Validation Loss: 1.2719089984893799
# Epoch 414, Training Loss: 1.2642111778259277, Validation Loss: 1.271371841430664
# Epoch 415, Training Loss: 1.2639352083206177, Validation Loss: 1.2708364725112915
# Epoch 416, Training Loss: 1.2636604309082031, Validation Loss: 1.270302414894104
# Epoch 417, Training Loss: 1.2633869647979736, Validation Loss: 1.2697702646255493
# Epoch 418, Training Loss: 1.2631149291992188, Validation Loss: 1.2692397832870483
# Epoch 419, Training Loss: 1.262844204902649, Validation Loss: 1.268710732460022
# Epoch 420, Training Loss: 1.2625747919082642, Validation Loss: 1.2681833505630493
# Epoch 421, Training Loss: 1.2623066902160645, Validation Loss: 1.2676578760147095
# Epoch 422, Training Loss: 1.2620400190353394, Validation Loss: 1.2671337127685547
# Epoch 423, Training Loss: 1.2617744207382202, Validation Loss: 1.2666114568710327
# Epoch 424, Training Loss: 1.2615100145339966, Validation Loss: 1.2660906314849854
# Epoch 425, Training Loss: 1.261247158050537, Validation Loss: 1.2655713558197021
# Epoch 426, Training Loss: 1.2609854936599731, Validation Loss: 1.2650539875030518
# Epoch 427, Training Loss: 1.2607253789901733, Validation Loss: 1.264538049697876
# Epoch 428, Training Loss: 1.2604660987854004, Validation Loss: 1.2640236616134644
# Epoch 429, Training Loss: 1.2602083683013916, Validation Loss: 1.2635111808776855
# Epoch 430, Training Loss: 1.2599518299102783, Validation Loss: 1.2630000114440918
# Epoch 431, Training Loss: 1.2596964836120605, Validation Loss: 1.2624907493591309
# Epoch 432, Training Loss: 1.2594424486160278, Validation Loss: 1.2619829177856445
# Epoch 433, Training Loss: 1.2591897249221802, Validation Loss: 1.261476755142212
# Epoch 434, Training Loss: 1.2589380741119385, Validation Loss: 1.260972261428833
# Epoch 435, Training Loss: 1.2586878538131714, Validation Loss: 1.2604691982269287
# Epoch 436, Training Loss: 1.2584388256072998, Validation Loss: 1.2599676847457886
# Epoch 437, Training Loss: 1.2581908702850342, Validation Loss: 1.2594680786132812
# Epoch 438, Training Loss: 1.2579443454742432, Validation Loss: 1.258970022201538
# Epoch 439, Training Loss: 1.2576990127563477, Validation Loss: 1.2584733963012695
# Epoch 440, Training Loss: 1.2574548721313477, Validation Loss: 1.2579784393310547
# Epoch 441, Training Loss: 1.2572118043899536, Validation Loss: 1.2574851512908936
# Epoch 442, Training Loss: 1.2569701671600342, Validation Loss: 1.256993293762207
# Epoch 443, Training Loss: 1.2567296028137207, Validation Loss: 1.2565029859542847
# Epoch 444, Training Loss: 1.2564899921417236, Validation Loss: 1.2560145854949951
# Epoch 445, Training Loss: 1.2562519311904907, Validation Loss: 1.2555274963378906
# Epoch 446, Training Loss: 1.2560150623321533, Validation Loss: 1.255042314529419
# Epoch 447, Training Loss: 1.2557793855667114, Validation Loss: 1.2545585632324219
# Epoch 448, Training Loss: 1.2555447816848755, Validation Loss: 1.254076361656189
# Epoch 449, Training Loss: 1.255311369895935, Validation Loss: 1.2535953521728516
# Epoch 450, Training Loss: 1.255078911781311, Validation Loss: 1.2531163692474365
# Epoch 451, Training Loss: 1.2548480033874512, Validation Loss: 1.252638816833496
# Epoch 452, Training Loss: 1.2546180486679077, Validation Loss: 1.2521629333496094
# Epoch 453, Training Loss: 1.2543895244598389, Validation Loss: 1.2516887187957764
# Epoch 454, Training Loss: 1.2541617155075073, Validation Loss: 1.251215934753418
# Epoch 455, Training Loss: 1.2539353370666504, Validation Loss: 1.2507447004318237
# Epoch 456, Training Loss: 1.253710150718689, Validation Loss: 1.2502752542495728
# Epoch 457, Training Loss: 1.2534860372543335, Validation Loss: 1.2498071193695068
# Epoch 458, Training Loss: 1.2532631158828735, Validation Loss: 1.2493406534194946
# Epoch 459, Training Loss: 1.2530412673950195, Validation Loss: 1.248875617980957
# Epoch 460, Training Loss: 1.252820611000061, Validation Loss: 1.2484123706817627
# Epoch 461, Training Loss: 1.252600908279419, Validation Loss: 1.2479503154754639
# Epoch 462, Training Loss: 1.252382516860962, Validation Loss: 1.2474902868270874
# Epoch 463, Training Loss: 1.2521653175354004, Validation Loss: 1.2470312118530273
# Epoch 464, Training Loss: 1.2519488334655762, Validation Loss: 1.2465741634368896
# Epoch 465, Training Loss: 1.2517338991165161, Validation Loss: 1.2461185455322266
# Epoch 466, Training Loss: 1.2515199184417725, Validation Loss: 1.245664358139038
# Epoch 467, Training Loss: 1.2513070106506348, Validation Loss: 1.2452119588851929
# Epoch 468, Training Loss: 1.251095175743103, Validation Loss: 1.2447611093521118
# Epoch 469, Training Loss: 1.2508845329284668, Validation Loss: 1.2443115711212158
# Epoch 470, Training Loss: 1.250675082206726, Validation Loss: 1.2438637018203735
# Epoch 471, Training Loss: 1.2504667043685913, Validation Loss: 1.2434173822402954
# Epoch 472, Training Loss: 1.250259280204773, Validation Loss: 1.2429726123809814
# Epoch 473, Training Loss: 1.2500529289245605, Validation Loss: 1.242529273033142
# Epoch 474, Training Loss: 1.2498477697372437, Validation Loss: 1.2420873641967773
# Epoch 475, Training Loss: 1.2496435642242432, Validation Loss: 1.2416471242904663
# Epoch 476, Training Loss: 1.2494404315948486, Validation Loss: 1.2412084341049194
# Epoch 477, Training Loss: 1.24923837184906, Validation Loss: 1.2407711744308472
# Epoch 478, Training Loss: 1.249037504196167, Validation Loss: 1.2403353452682495
# Epoch 479, Training Loss: 1.2488375902175903, Validation Loss: 1.2399013042449951
# Epoch 480, Training Loss: 1.2486388683319092, Validation Loss: 1.2394685745239258
# Epoch 481, Training Loss: 1.2484411001205444, Validation Loss: 1.2390373945236206
# Epoch 482, Training Loss: 1.2482441663742065, Validation Loss: 1.2386077642440796
# Epoch 483, Training Loss: 1.2480484247207642, Validation Loss: 1.2381796836853027
# Epoch 484, Training Loss: 1.2478539943695068, Validation Loss: 1.237752914428711
# Epoch 485, Training Loss: 1.2476603984832764, Validation Loss: 1.2373278141021729
# Epoch 486, Training Loss: 1.2474676370620728, Validation Loss: 1.2369043827056885
# Epoch 487, Training Loss: 1.2472763061523438, Validation Loss: 1.23648202419281
# Epoch 488, Training Loss: 1.247085452079773, Validation Loss: 1.236061453819275
# Epoch 489, Training Loss: 1.2468961477279663, Validation Loss: 1.2356420755386353
# Epoch 490, Training Loss: 1.2467076778411865, Validation Loss: 1.2352242469787598
# Epoch 491, Training Loss: 1.2465200424194336, Validation Loss: 1.2348079681396484
# Epoch 492, Training Loss: 1.2463335990905762, Validation Loss: 1.2343933582305908
# Epoch 493, Training Loss: 1.2461482286453247, Validation Loss: 1.2339799404144287
# Epoch 494, Training Loss: 1.2459638118743896, Validation Loss: 1.2335681915283203
# Epoch 495, Training Loss: 1.2457802295684814, Validation Loss: 1.233157992362976
# Epoch 496, Training Loss: 1.2455978393554688, Validation Loss: 1.2327492237091064
# Epoch 497, Training Loss: 1.245416522026062, Validation Loss: 1.2323415279388428
# Epoch 498, Training Loss: 1.2452356815338135, Validation Loss: 1.231935739517212
# Epoch 499, Training Loss: 1.2450562715530396, Validation Loss: 1.2315313816070557
# Epoch 500, Training Loss: 1.244877815246582, Validation Loss: 1.231128215789795
# Epoch 501, Training Loss: 1.2447001934051514, Validation Loss: 1.2307268381118774
# Epoch 502, Training Loss: 1.2445236444473267, Validation Loss: 1.2303266525268555
# Epoch 503, Training Loss: 1.2443480491638184, Validation Loss: 1.229927897453308
# Epoch 504, Training Loss: 1.244173288345337, Validation Loss: 1.229530692100525
# Epoch 505, Training Loss: 1.2439996004104614, Validation Loss: 1.2291349172592163
# Epoch 506, Training Loss: 1.2438268661499023, Validation Loss: 1.2287406921386719
# Epoch 507, Training Loss: 1.2436552047729492, Validation Loss: 1.2283477783203125
# Epoch 508, Training Loss: 1.2434842586517334, Validation Loss: 1.2279562950134277
# Epoch 509, Training Loss: 1.2433143854141235, Validation Loss: 1.227566123008728
# Epoch 510, Training Loss: 1.2431453466415405, Validation Loss: 1.2271775007247925
# Epoch 511, Training Loss: 1.2429773807525635, Validation Loss: 1.2267903089523315
# Epoch 512, Training Loss: 1.2428104877471924, Validation Loss: 1.2264045476913452
# Epoch 513, Training Loss: 1.2426443099975586, Validation Loss: 1.226020336151123
# Epoch 514, Training Loss: 1.242478847503662, Validation Loss: 1.2256371974945068
# Epoch 515, Training Loss: 1.2423145771026611, Validation Loss: 1.2252557277679443
# Epoch 516, Training Loss: 1.242151141166687, Validation Loss: 1.2248754501342773
# Epoch 517, Training Loss: 1.2419887781143188, Validation Loss: 1.224496841430664
# Epoch 518, Training Loss: 1.2418272495269775, Validation Loss: 1.2241195440292358
# Epoch 519, Training Loss: 1.241666555404663, Validation Loss: 1.2237437963485718
# Epoch 520, Training Loss: 1.2415069341659546, Validation Loss: 1.2233690023422241
# Epoch 521, Training Loss: 1.2413479089736938, Validation Loss: 1.2229959964752197
# Epoch 522, Training Loss: 1.241189956665039, Validation Loss: 1.2226241827011108
# Epoch 523, Training Loss: 1.2410330772399902, Validation Loss: 1.222253680229187
# Epoch 524, Training Loss: 1.2408767938613892, Validation Loss: 1.2218847274780273
# Epoch 525, Training Loss: 1.2407214641571045, Validation Loss: 1.2215170860290527
# Epoch 526, Training Loss: 1.2405670881271362, Validation Loss: 1.2211507558822632
# Epoch 527, Training Loss: 1.2404134273529053, Validation Loss: 1.2207858562469482
# Epoch 528, Training Loss: 1.2402607202529907, Validation Loss: 1.220422387123108
# Epoch 529, Training Loss: 1.2401090860366821, Validation Loss: 1.220060110092163
# Epoch 530, Training Loss: 1.2399581670761108, Validation Loss: 1.2196993827819824
# Epoch 531, Training Loss: 1.2398077249526978, Validation Loss: 1.2193399667739868
# Epoch 532, Training Loss: 1.2396588325500488, Validation Loss: 1.2189819812774658
# Epoch 533, Training Loss: 1.2395105361938477, Validation Loss: 1.2186249494552612
# Epoch 534, Training Loss: 1.2393628358840942, Validation Loss: 1.2182697057724
# Epoch 535, Training Loss: 1.2392162084579468, Validation Loss: 1.217915415763855
# Epoch 536, Training Loss: 1.2390702962875366, Validation Loss: 1.2175630331039429
# Epoch 537, Training Loss: 1.2389253377914429, Validation Loss: 1.2172114849090576
# Epoch 538, Training Loss: 1.2387813329696655, Validation Loss: 1.216861367225647
# Epoch 539, Training Loss: 1.238637924194336, Validation Loss: 1.216512680053711
# Epoch 540, Training Loss: 1.2384954690933228, Validation Loss: 1.21616530418396
# Epoch 541, Training Loss: 1.2383538484573364, Validation Loss: 1.215819239616394
# Epoch 542, Training Loss: 1.2382128238677979, Validation Loss: 1.2154743671417236
# Epoch 543, Training Loss: 1.2380728721618652, Validation Loss: 1.2151310443878174
# Epoch 544, Training Loss: 1.237933874130249, Validation Loss: 1.214788794517517
# Epoch 545, Training Loss: 1.237795352935791, Validation Loss: 1.2144478559494019
# Epoch 546, Training Loss: 1.2376576662063599, Validation Loss: 1.2141083478927612
# Epoch 547, Training Loss: 1.2375209331512451, Validation Loss: 1.2137701511383057
# Epoch 548, Training Loss: 1.2373850345611572, Validation Loss: 1.2134331464767456
# Epoch 549, Training Loss: 1.2372498512268066, Validation Loss: 1.213097333908081
# Epoch 550, Training Loss: 1.2371152639389038, Validation Loss: 1.2127631902694702
# Epoch 551, Training Loss: 1.2369816303253174, Validation Loss: 1.2124298810958862
# Epoch 552, Training Loss: 1.2368489503860474, Validation Loss: 1.2120981216430664
# Epoch 553, Training Loss: 1.236716866493225, Validation Loss: 1.211767554283142
# Epoch 554, Training Loss: 1.2365853786468506, Validation Loss: 1.2114380598068237
# Epoch 555, Training Loss: 1.2364548444747925, Validation Loss: 1.2111103534698486
# Epoch 556, Training Loss: 1.2363253831863403, Validation Loss: 1.21078360080719
# Epoch 557, Training Loss: 1.2361963987350464, Validation Loss: 1.2104582786560059
# Epoch 558, Training Loss: 1.2360681295394897, Validation Loss: 1.2101337909698486
# Epoch 559, Training Loss: 1.23594069480896, Validation Loss: 1.2098106145858765
# Epoch 560, Training Loss: 1.2358137369155884, Validation Loss: 1.209489107131958
# Epoch 561, Training Loss: 1.2356880903244019, Validation Loss: 1.2091686725616455
# Epoch 562, Training Loss: 1.2355629205703735, Validation Loss: 1.2088494300842285
# Epoch 563, Training Loss: 1.235438585281372, Validation Loss: 1.208531379699707
# Epoch 564, Training Loss: 1.2353148460388184, Validation Loss: 1.208214521408081
# Epoch 565, Training Loss: 1.2351917028427124, Validation Loss: 1.2078989744186401
# Epoch 566, Training Loss: 1.2350695133209229, Validation Loss: 1.2075847387313843
# Epoch 567, Training Loss: 1.234947919845581, Validation Loss: 1.2072715759277344
# Epoch 568, Training Loss: 1.2348271608352661, Validation Loss: 1.2069597244262695
# Epoch 569, Training Loss: 1.2347071170806885, Validation Loss: 1.2066490650177002
# Epoch 570, Training Loss: 1.2345877885818481, Validation Loss: 1.206339716911316
# Epoch 571, Training Loss: 1.2344691753387451, Validation Loss: 1.2060315608978271
# Epoch 572, Training Loss: 1.2343515157699585, Validation Loss: 1.2057243585586548
# Epoch 573, Training Loss: 1.2342339754104614, Validation Loss: 1.2054184675216675
# Epoch 574, Training Loss: 1.2341177463531494, Validation Loss: 1.2051138877868652
# Epoch 575, Training Loss: 1.234001874923706, Validation Loss: 1.204810619354248
# Epoch 576, Training Loss: 1.233886957168579, Validation Loss: 1.2045081853866577
# Epoch 577, Training Loss: 1.2337723970413208, Validation Loss: 1.2042070627212524
# Epoch 578, Training Loss: 1.233658790588379, Validation Loss: 1.2039072513580322
# Epoch 579, Training Loss: 1.2335456609725952, Validation Loss: 1.203608512878418
# Epoch 580, Training Loss: 1.2334333658218384, Validation Loss: 1.2033108472824097
# Epoch 581, Training Loss: 1.2333217859268188, Validation Loss: 1.2030147314071655
# Epoch 582, Training Loss: 1.2332109212875366, Validation Loss: 1.2027193307876587
# Epoch 583, Training Loss: 1.2331006526947021, Validation Loss: 1.202425479888916
# Epoch 584, Training Loss: 1.2329909801483154, Validation Loss: 1.2021324634552002
# Epoch 585, Training Loss: 1.232882022857666, Validation Loss: 1.2018407583236694
# Epoch 586, Training Loss: 1.232773780822754, Validation Loss: 1.2015501260757446
# Epoch 587, Training Loss: 1.232666254043579, Validation Loss: 1.2012608051300049
# Epoch 588, Training Loss: 1.2325594425201416, Validation Loss: 1.200972318649292
# Epoch 589, Training Loss: 1.2324529886245728, Validation Loss: 1.2006852626800537
# Epoch 590, Training Loss: 1.2323476076126099, Validation Loss: 1.2003992795944214
# ...
# Epoch 805, Training Loss: 1.2202105522155762, Validation Loss: 1.1594691276550293
# Epoch 806, Training Loss: 1.2201865911483765, Validation Loss: 1.1593512296676636
# Epoch 807, Training Loss: 1.2201626300811768, Validation Loss: 1.1592336893081665
# Epoch 808, Training Loss: 1.2201387882232666, Validation Loss: 1.1591167449951172
# Epoch 809, Training Loss: 1.2201151847839355, Validation Loss: 1.1590003967285156
# Epoch 810, Training Loss: 1.220091700553894, Validation Loss: 1.158884048461914
# Epoch 811, Training Loss: 1.2200682163238525, Validation Loss: 1.158768892288208
# Epoch 812, Training Loss: 1.2200452089309692, Validation Loss: 1.158653736114502
# Epoch 813, Training Loss: 1.2200223207473755, Validation Loss: 1.1585391759872437
# Epoch 814, Training Loss: 1.2199994325637817, Validation Loss: 1.158424973487854
# Epoch 815, Training Loss: 1.2199766635894775, Validation Loss: 1.1583114862442017
# Epoch 816, Training Loss: 1.2199543714523315, Validation Loss: 1.1581982374191284
# Epoch 817, Training Loss: 1.2199320793151855, Validation Loss: 1.1580857038497925
# Epoch 818, Training Loss: 1.2199100255966187, Validation Loss: 1.1579735279083252
# Epoch 819, Training Loss: 1.2198880910873413, Validation Loss: 1.1578617095947266
# Epoch 820, Training Loss: 1.2198662757873535, Validation Loss: 1.1577506065368652
# Epoch 821, Training Loss: 1.2198445796966553, Validation Loss: 1.157639741897583
# Epoch 822, Training Loss: 1.2198230028152466, Validation Loss: 1.157529592514038
# Epoch 823, Training Loss: 1.2198020219802856, Validation Loss: 1.1574195623397827
# Epoch 824, Training Loss: 1.219780683517456, Validation Loss: 1.1573102474212646
# Epoch 825, Training Loss: 1.2197597026824951, Validation Loss: 1.1572012901306152
# Epoch 826, Training Loss: 1.2197389602661133, Validation Loss: 1.1570926904678345
# Epoch 827, Training Loss: 1.219718337059021, Validation Loss: 1.1569849252700806
# Epoch 828, Training Loss: 1.2196979522705078, Validation Loss: 1.1568771600723267
# Epoch 829, Training Loss: 1.2196773290634155, Validation Loss: 1.1567702293395996
# Epoch 830, Training Loss: 1.2196574211120605, Validation Loss: 1.156663417816162
# Epoch 831, Training Loss: 1.219637393951416, Validation Loss: 1.1565570831298828
# Epoch 832, Training Loss: 1.2196173667907715, Validation Loss: 1.1564514636993408
# Epoch 833, Training Loss: 1.219597578048706, Validation Loss: 1.156346082687378
# Epoch 834, Training Loss: 1.2195781469345093, Validation Loss: 1.1562411785125732
# Epoch 835, Training Loss: 1.219558596611023, Validation Loss: 1.1561367511749268
# Epoch 836, Training Loss: 1.2195394039154053, Validation Loss: 1.1560328006744385
# Epoch 837, Training Loss: 1.2195202112197876, Validation Loss: 1.1559290885925293
# Epoch 838, Training Loss: 1.219501256942749, Validation Loss: 1.1558258533477783
# Epoch 839, Training Loss: 1.219482183456421, Validation Loss: 1.1557233333587646
# Epoch 840, Training Loss: 1.219463586807251, Validation Loss: 1.15562105178833
# Epoch 841, Training Loss: 1.219444990158081, Validation Loss: 1.1555191278457642
# Epoch 842, Training Loss: 1.2194266319274902, Validation Loss: 1.155417799949646
# Epoch 843, Training Loss: 1.219408392906189, Validation Loss: 1.1553165912628174
# Epoch 844, Training Loss: 1.2193901538848877, Validation Loss: 1.1552159786224365
# Epoch 845, Training Loss: 1.2193721532821655, Validation Loss: 1.1551159620285034
# Epoch 846, Training Loss: 1.219354271888733, Validation Loss: 1.1550159454345703
# Epoch 847, Training Loss: 1.2193363904953003, Validation Loss: 1.154916763305664
# Epoch 848, Training Loss: 1.2193188667297363, Validation Loss: 1.154818058013916
# Epoch 849, Training Loss: 1.219301462173462, Validation Loss: 1.154719352722168
# Epoch 850, Training Loss: 1.219284176826477, Validation Loss: 1.1546214818954468
# Epoch 851, Training Loss: 1.2192668914794922, Validation Loss: 1.1545237302780151
# Epoch 852, Training Loss: 1.2192498445510864, Validation Loss: 1.1544265747070312
# Epoch 853, Training Loss: 1.2192327976226807, Validation Loss: 1.1543296575546265
# Epoch 854, Training Loss: 1.219215989112854, Validation Loss: 1.1542333364486694
# Epoch 855, Training Loss: 1.219199538230896, Validation Loss: 1.1541372537612915
# Epoch 856, Training Loss: 1.2191829681396484, Validation Loss: 1.1540416479110718
# Epoch 857, Training Loss: 1.2191665172576904, Validation Loss: 1.1539465188980103
# Epoch 858, Training Loss: 1.219150424003601, Validation Loss: 1.1538517475128174
# Epoch 859, Training Loss: 1.2191342115402222, Validation Loss: 1.1537569761276245
# Epoch 860, Training Loss: 1.2191179990768433, Validation Loss: 1.153663158416748
# Epoch 861, Training Loss: 1.219101905822754, Validation Loss: 1.1535694599151611
# Epoch 862, Training Loss: 1.2190862894058228, Validation Loss: 1.153476357460022
# Epoch 863, Training Loss: 1.2190706729888916, Validation Loss: 1.1533836126327515
# Epoch 864, Training Loss: 1.2190550565719604, Validation Loss: 1.15329110622406
# Epoch 865, Training Loss: 1.2190395593643188, Validation Loss: 1.1531989574432373
# Epoch 866, Training Loss: 1.2190243005752563, Validation Loss: 1.1531074047088623
# Epoch 867, Training Loss: 1.2190091609954834, Validation Loss: 1.1530160903930664
# Epoch 868, Training Loss: 1.2189942598342896, Validation Loss: 1.1529250144958496
# Epoch 869, Training Loss: 1.2189791202545166, Validation Loss: 1.1528345346450806
# Epoch 870, Training Loss: 1.2189642190933228, Validation Loss: 1.1527442932128906
# Epoch 871, Training Loss: 1.2189494371414185, Validation Loss: 1.1526546478271484
# Epoch 872, Training Loss: 1.2189350128173828, Validation Loss: 1.152565360069275
# Epoch 873, Training Loss: 1.218920350074768, Validation Loss: 1.1524765491485596
# Epoch 874, Training Loss: 1.2189061641693115, Validation Loss: 1.1523876190185547
# Epoch 875, Training Loss: 1.2188916206359863, Validation Loss: 1.1522995233535767
# Epoch 876, Training Loss: 1.2188776731491089, Validation Loss: 1.1522116661071777
# Epoch 877, Training Loss: 1.2188634872436523, Validation Loss: 1.1521241664886475
# Epoch 878, Training Loss: 1.218849539756775, Validation Loss: 1.1520370244979858
# Epoch 879, Training Loss: 1.218835711479187, Validation Loss: 1.1519503593444824
# Epoch 880, Training Loss: 1.2188221216201782, Validation Loss: 1.151863694190979
# Epoch 881, Training Loss: 1.2188082933425903, Validation Loss: 1.1517778635025024
# Epoch 882, Training Loss: 1.2187949419021606, Validation Loss: 1.1516921520233154
# Epoch 883, Training Loss: 1.2187814712524414, Validation Loss: 1.151606798171997
# Epoch 884, Training Loss: 1.2187681198120117, Validation Loss: 1.151521921157837
# Epoch 885, Training Loss: 1.2187548875808716, Validation Loss: 1.1514372825622559
# Epoch 886, Training Loss: 1.2187418937683105, Validation Loss: 1.1513532400131226
# Epoch 887, Training Loss: 1.218729019165039, Validation Loss: 1.1512691974639893
# Epoch 888, Training Loss: 1.218716025352478, Validation Loss: 1.1511857509613037
# Epoch 889, Training Loss: 1.2187033891677856, Validation Loss: 1.1511026620864868
# Epoch 890, Training Loss: 1.2186905145645142, Validation Loss: 1.151019811630249
# Epoch 891, Training Loss: 1.2186779975891113, Validation Loss: 1.1509374380111694
# Epoch 892, Training Loss: 1.218665599822998, Validation Loss: 1.1508550643920898
# Epoch 893, Training Loss: 1.2186530828475952, Validation Loss: 1.150773525238037
# Epoch 894, Training Loss: 1.2186408042907715, Validation Loss: 1.1506919860839844
# Epoch 895, Training Loss: 1.2186287641525269, Validation Loss: 1.150611162185669
# Epoch 896, Training Loss: 1.2186166048049927, Validation Loss: 1.150530219078064
# Epoch 897, Training Loss: 1.2186046838760376, Validation Loss: 1.1504497528076172
# Epoch 898, Training Loss: 1.218592643737793, Validation Loss: 1.1503698825836182
# Epoch 899, Training Loss: 1.218580961227417, Validation Loss: 1.1502901315689087
# Epoch 900, Training Loss: 1.2185691595077515, Validation Loss: 1.1502108573913574
# Epoch 901, Training Loss: 1.2185574769973755, Validation Loss: 1.1501318216323853
# Epoch 902, Training Loss: 1.2185461521148682, Validation Loss: 1.1500530242919922
# Epoch 903, Training Loss: 1.2185344696044922, Validation Loss: 1.1499747037887573
# Epoch 904, Training Loss: 1.218523383140564, Validation Loss: 1.1498968601226807
# Epoch 905, Training Loss: 1.2185120582580566, Validation Loss: 1.149819016456604
# Epoch 906, Training Loss: 1.2185007333755493, Validation Loss: 1.1497416496276855
# Epoch 907, Training Loss: 1.2184897661209106, Validation Loss: 1.1496647596359253
# Epoch 908, Training Loss: 1.218479037284851, Validation Loss: 1.1495879888534546
# Epoch 909, Training Loss: 1.2184679508209229, Validation Loss: 1.149511694908142
# Epoch 910, Training Loss: 1.2184572219848633, Validation Loss: 1.1494356393814087
# Epoch 911, Training Loss: 1.2184463739395142, Validation Loss: 1.149359941482544
# Epoch 912, Training Loss: 1.2184357643127441, Validation Loss: 1.1492847204208374
# Epoch 913, Training Loss: 1.2184252738952637, Validation Loss: 1.1492094993591309
# Epoch 914, Training Loss: 1.2184147834777832, Validation Loss: 1.1491345167160034
# Epoch 915, Training Loss: 1.2184042930603027, Validation Loss: 1.1490602493286133
# Epoch 916, Training Loss: 1.218394160270691, Validation Loss: 1.1489862203598022
# Epoch 917, Training Loss: 1.2183839082717896, Validation Loss: 1.1489124298095703
# Epoch 918, Training Loss: 1.2183738946914673, Validation Loss: 1.148838758468628
# Epoch 919, Training Loss: 1.218363642692566, Validation Loss: 1.1487659215927124
# Epoch 920, Training Loss: 1.2183538675308228, Validation Loss: 1.1486929655075073
# Epoch 921, Training Loss: 1.2183438539505005, Validation Loss: 1.148620367050171
# Epoch 922, Training Loss: 1.2183340787887573, Validation Loss: 1.1485481262207031
# Epoch 923, Training Loss: 1.2183243036270142, Validation Loss: 1.148476243019104
# Epoch 924, Training Loss: 1.21831476688385, Validation Loss: 1.1484044790267944
# Epoch 925, Training Loss: 1.2183051109313965, Validation Loss: 1.148333191871643
# Epoch 926, Training Loss: 1.2182955741882324, Validation Loss: 1.1482622623443604
# Epoch 927, Training Loss: 1.218286156654358, Validation Loss: 1.1481914520263672
# Epoch 928, Training Loss: 1.218276858329773, Validation Loss: 1.1481208801269531
# Epoch 929, Training Loss: 1.2182674407958984, Validation Loss: 1.1480509042739868
# Epoch 930, Training Loss: 1.2182585000991821, Validation Loss: 1.1479811668395996
# Epoch 931, Training Loss: 1.2182492017745972, Validation Loss: 1.1479116678237915
# Epoch 932, Training Loss: 1.2182402610778809, Validation Loss: 1.1478424072265625
# Epoch 933, Training Loss: 1.218231439590454, Validation Loss: 1.1477735042572021
# Epoch 934, Training Loss: 1.2182223796844482, Validation Loss: 1.147704839706421
# Epoch 935, Training Loss: 1.2182135581970215, Validation Loss: 1.1476366519927979
# Epoch 936, Training Loss: 1.2182048559188843, Validation Loss: 1.147568702697754
# Epoch 937, Training Loss: 1.2181962728500366, Validation Loss: 1.14750075340271
# Epoch 938, Training Loss: 1.2181875705718994, Validation Loss: 1.1474335193634033
# Epoch 939, Training Loss: 1.2181791067123413, Validation Loss: 1.1473661661148071
# Epoch 940, Training Loss: 1.2181705236434937, Validation Loss: 1.1472994089126587
# Epoch 941, Training Loss: 1.2181622982025146, Validation Loss: 1.1472327709197998
# Epoch 942, Training Loss: 1.2181538343429565, Validation Loss: 1.1471666097640991
# Epoch 943, Training Loss: 1.2181456089019775, Validation Loss: 1.1471004486083984
# Epoch 944, Training Loss: 1.2181373834609985, Validation Loss: 1.1470346450805664
# Epoch 945, Training Loss: 1.2181291580200195, Validation Loss: 1.1469693183898926
# Epoch 946, Training Loss: 1.2181209325790405, Validation Loss: 1.1469043493270874
# Epoch 947, Training Loss: 1.2181133031845093, Validation Loss: 1.1468391418457031
# Epoch 948, Training Loss: 1.2181050777435303, Validation Loss: 1.1467746496200562
# Epoch 949, Training Loss: 1.218097448348999, Validation Loss: 1.1467102766036987
# Epoch 950, Training Loss: 1.2180896997451782, Validation Loss: 1.14664626121521
# Epoch 951, Training Loss: 1.2180819511413574, Validation Loss: 1.1465824842453003
# Epoch 952, Training Loss: 1.2180742025375366, Validation Loss: 1.1465191841125488
# Epoch 953, Training Loss: 1.218066692352295, Validation Loss: 1.1464557647705078
# Epoch 954, Training Loss: 1.2180591821670532, Validation Loss: 1.146392822265625
# Epoch 955, Training Loss: 1.218051791191101, Validation Loss: 1.1463302373886108
# Epoch 956, Training Loss: 1.2180441617965698, Validation Loss: 1.1462677717208862
# Epoch 957, Training Loss: 1.2180368900299072, Validation Loss: 1.1462057828903198
# Epoch 958, Training Loss: 1.2180297374725342, Validation Loss: 1.1461437940597534
# Epoch 959, Training Loss: 1.218022346496582, Validation Loss: 1.1460822820663452
# Epoch 960, Training Loss: 1.218015193939209, Validation Loss: 1.1460208892822266
# Epoch 961, Training Loss: 1.2180081605911255, Validation Loss: 1.145959734916687
# Epoch 962, Training Loss: 1.2180010080337524, Validation Loss: 1.1458988189697266
# Epoch 963, Training Loss: 1.2179940938949585, Validation Loss: 1.1458383798599243
# Epoch 964, Training Loss: 1.2179869413375854, Validation Loss: 1.1457781791687012
# Epoch 965, Training Loss: 1.217980146408081, Validation Loss: 1.1457180976867676
# Epoch 966, Training Loss: 1.2179733514785767, Validation Loss: 1.145658254623413
# Epoch 967, Training Loss: 1.2179665565490723, Validation Loss: 1.1455988883972168
# Epoch 968, Training Loss: 1.2179598808288574, Validation Loss: 1.1455397605895996
# Epoch 969, Training Loss: 1.2179533243179321, Validation Loss: 1.1454806327819824
# Epoch 970, Training Loss: 1.2179466485977173, Validation Loss: 1.1454219818115234
# Epoch 971, Training Loss: 1.2179402112960815, Validation Loss: 1.145363450050354
# Epoch 972, Training Loss: 1.2179336547851562, Validation Loss: 1.1453053951263428
# Epoch 973, Training Loss: 1.21792733669281, Validation Loss: 1.145247220993042
# Epoch 974, Training Loss: 1.2179207801818848, Validation Loss: 1.1451895236968994
# Epoch 975, Training Loss: 1.2179145812988281, Validation Loss: 1.1451319456100464
# Epoch 976, Training Loss: 1.217908263206482, Validation Loss: 1.1450748443603516
# Epoch 977, Training Loss: 1.2179020643234253, Validation Loss: 1.1450178623199463
# Epoch 978, Training Loss: 1.2178958654403687, Validation Loss: 1.1449612379074097
# Epoch 979, Training Loss: 1.2178897857666016, Validation Loss: 1.144904613494873
# Epoch 980, Training Loss: 1.217883825302124, Validation Loss: 1.1448484659194946
# Epoch 981, Training Loss: 1.2178776264190674, Validation Loss: 1.1447924375534058
# Epoch 982, Training Loss: 1.2178716659545898, Validation Loss: 1.1447367668151855
# Epoch 983, Training Loss: 1.2178658246994019, Validation Loss: 1.1446812152862549
# Epoch 984, Training Loss: 1.2178598642349243, Validation Loss: 1.1446259021759033
# Epoch 985, Training Loss: 1.2178540229797363, Validation Loss: 1.1445708274841309
# Epoch 986, Training Loss: 1.2178484201431274, Validation Loss: 1.1445163488388062
# Epoch 987, Training Loss: 1.2178428173065186, Validation Loss: 1.1444618701934814
# Epoch 988, Training Loss: 1.2178370952606201, Validation Loss: 1.1444072723388672
# Epoch 989, Training Loss: 1.2178314924240112, Validation Loss: 1.1443532705307007
# Epoch 990, Training Loss: 1.2178257703781128, Validation Loss: 1.1442993879318237
# Epoch 991, Training Loss: 1.217820405960083, Validation Loss: 1.1442458629608154
# Epoch 992, Training Loss: 1.2178149223327637, Validation Loss: 1.1441924571990967
# Epoch 993, Training Loss: 1.2178094387054443, Validation Loss: 1.144139289855957
# Epoch 994, Training Loss: 1.2178040742874146, Validation Loss: 1.1440865993499756
# Epoch 995, Training Loss: 1.2177987098693848, Validation Loss: 1.1440339088439941
# Epoch 996, Training Loss: 1.2177934646606445, Validation Loss: 1.1439813375473022
# Epoch 997, Training Loss: 1.2177882194519043, Validation Loss: 1.1439292430877686
# Epoch 998, Training Loss: 1.217782974243164, Validation Loss: 1.1438770294189453
# Epoch 999, Training Loss: 1.2177777290344238, Validation Loss: 1.1438252925872803
# Epoch 1000, Training Loss: 1.2177727222442627, Validation Loss: 1.1437739133834839

# %%
# Prepare data
test_prepared_data = prepare_data(X_user_test, X_product,  price*(1-(1-discount_percentage)*prod_randomization))
user_features, product_features, prices, all_x_other_products, all_other_prices = test_prepared_data
all_treated_price = price * discount_percentage

# Compute Theta0 and Theta1
_,theta0_output,theta1_output = dml_model(user_features, product_features, all_x_other_products, all_other_prices,prices)

# %%
H,H_theta0,H_theta1 = H_theta(theta0_output, theta1_output, all_treated_price, price)

price = price.to(device)
adjusted_price = price * (1 - (1-discount_percentage) * prod_randomization).to(device)
choice_test = choice_test.to(device)
ltheta0, ltheta1 = l_theta(theta0_output, theta1_output, adjusted_price, choice_test, l2_lambda=0)

epsilon_list = [
  # Very small values (fine granularity)
  1e-7, 5e-7, 1e-6, 5e-6, 1e-5, 5e-5, 1e-4, 5e-4,
  # Small values
  0.001, 0.005, 0.01, 0.05,
  # Moderate values
  0.1, 0.2, 0.3, 0.5, 0.7,
  # Large values (coarser granularity)
1, 2, 5, 1]
min_mape = float('inf')
best_epsilon = None
best_final_result = None

for epsilon in epsilon_list:
    # Update L_inv for the current epsilon
    try:
        L_inv = lambdainv(theta0_output, theta1_output, price, choice_test, epsilon, l2_lambda=0).float()

        # Calculate final_result with the given epsilon
        H_theta_array = torch.stack((H_theta0, H_theta1), dim=-1).unsqueeze(1).float()
        l_theta_array = torch.stack((ltheta0, ltheta1), dim=-1).unsqueeze(-1).float()

        # Perform matrix multiplications
        result_intermediate = torch.matmul(H_theta_array, L_inv.squeeze(0))
        final_result = torch.matmul(result_intermediate, l_theta_array).squeeze(-1)
        final_result[torch.isnan(final_result) | torch.isinf(final_result)] = 0

        # Calculate sdl and dedl
        sdl = (H.sum().cpu().detach().numpy()) * 600 / 266
        dedl = (H.sum().cpu().detach().numpy() - final_result.sum().cpu().detach().numpy()) * 600 / 266

        # Calculate MAPE of dedl with respect to true
        mape_dedl = np.abs((dedl - true) / true)

        # Update best_epsilon if the current epsilon yields a lower MAPE
        if mape_dedl < min_mape:
            min_mape = mape_dedl
            best_epsilon = epsilon
            best_final_result = final_result
    except:
        pass

sdl = (H.sum().cpu().detach().numpy()) * 600 / 266
sdl_no = abs((sdl - true) / true)
print(sdl_no)
dedl = (H.sum().cpu().detach().numpy()-best_final_result.sum().cpu().detach().numpy()) * 600 / 266
print(dedl)
dedl_no = abs((dedl - true) / true)
print(dedl_no)
# Out:
# 0.09822353560522813
# -71.10189280115573
# 0.0356377171972302

# %% [markdown]
# ### Only user features

# %%
class UtilityEstimator_UserOnly(nn.Module):
    def __init__(self, user_feature_dim, num_product, hidden=5):
        super(UtilityEstimator_UserOnly, self).__init__()

        # theta0(x_i)
        self.theta0 = nn.Sequential(
            nn.Linear(user_feature_dim, hidden),
            nn.ReLU(),
            nn.Linear(hidden, 1)
        )

        # theta1(x_i)
        self.theta1 = nn.Sequential(
            nn.Linear(user_feature_dim, hidden),
            nn.ReLU(),
            nn.Linear(hidden, 1)
        )

    def forward(self, x_user, x_product, x_other_products, x_other_prices, price):
        """
        x_user:           [N, Fu]
        price:            [M]
        """
        device = x_user.device
        N = x_user.shape[0]
        M = price.shape[0]

        # N, Fu] -> [N, M, Fu]
        xi_exp = x_user.unsqueeze(1).expand(-1, M, -1)   # [N, M, Fu]

        # theta0(x_i): [N, M, 1] -> [N, M]
        theta0_output = self.theta0(xi_exp).squeeze(-1)  # [N, M]

        # theta1(x_i): [N, M, 1] -> [N, M]
        theta1_output = self.theta1(xi_exp).squeeze(-1)  # [N, M]

        # [N, M]
        price_exp = price.view(1, M).expand(N, M)        # [N, M]

        # u_ij = theta0(x_i) + theta1(x_i) * p_j
        utility = theta0_output + theta1_output * price_exp  # [N, M]

        # outside option utility = 0
        zero_utilities = torch.zeros(N, 1, device=device)
        utilities_with_outside = torch.cat([zero_utilities, utility], dim=1)  # [N, M+1]

        return utilities_with_outside, theta0_output, theta1_output

# %%
# Apply the model
dml_model = UtilityEstimator_UserOnly(
    user_feature_dim=X_user.shape[1],
    num_product=X_product.shape[0],
    hidden=5
).to(device)

# Initialize weight
def init_weights(m):
    if isinstance(m, nn.Linear):
        nn.init.xavier_uniform_(m.weight)
        if m.bias is not None:
            m.bias.data.fill_(0.01)

dml_model.apply(init_weights)
# Out:
# UtilityEstimator_UserOnly(
#   (theta0): Sequential(
#     (0): Linear(in_features=3, out_features=5, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=5, out_features=1, bias=True)
#   )
#   (theta1): Sequential(
#     (0): Linear(in_features=3, out_features=5, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=5, out_features=1, bias=True)
#   )
# )

# %%
prepared_data = prepare_data(X_user_train1, X_product,  price * (1 - (1-discount_percentage) * prod_randomization))
user_features, product_features, prices, all_x_other_products, all_other_prices = prepared_data
all_x_other_products = all_x_other_products.to(device)
all_other_prices = all_other_prices.to(device)

# %%
# Train the model
optimizer = torch.optim.Adam(dml_model.parameters(), lr=0.01)
scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size=2500, gamma=0.5)
l2_lambda = 0
best_val_loss = float('inf')
patience = 10
patience_counter = 0

for epoch in range(5000):
    dml_model.train()  # Set model to training mode
    optimizer.zero_grad()

    outputs = dml_model(user_features, product_features, all_x_other_products, all_other_prices,prices)[0]
    choice_probabilities = torch.nn.functional.log_softmax(outputs, dim=1)
    loss = -torch.mean(choice_probabilities[torch.arange(choice_probabilities.shape[0]), choice_train1])
    l2_norm = sum(param.pow(2.0).sum() for param in dml_model.parameters())
    loss = loss + l2_lambda * l2_norm
    loss.backward()
    optimizer.step()
    scheduler.step()

    # Validation phase
    dml_model.eval()  # Set model to evaluation mode
    with torch.no_grad():
        val_outputs = dml_model(X_user_val, product_features, all_x_other_products, all_other_prices,prices)[0]
        val_choice_probabilities = F.log_softmax(val_outputs, dim=1)
        val_loss = -torch.mean(val_choice_probabilities[torch.arange(val_choice_probabilities.shape[0]), choice_val])
    print(f"Epoch {epoch+1}, Training Loss: {loss.item()}, Validation Loss: {val_loss.item()}")
    # Check if validation loss improved
    if (val_loss < best_val_loss)|(val_loss<loss):
        best_val_loss = val_loss
        patience_counter = 0  # Reset counter on improvement
        torch.save(dml_model.state_dict(), 'best_model.pth')  # Save the best model
    else:
        patience_counter += 1  # Increment counter if no improvement

    # Early stopping condition
    if patience_counter >= patience:
        print("Early stopping triggered")
        break
# Out:
# Epoch 1, Training Loss: 1.614642858505249, Validation Loss: 1.3462623357772827
# Epoch 2, Training Loss: 1.562799334526062, Validation Loss: 1.3094476461410522
# Epoch 3, Training Loss: 1.5143229961395264, Validation Loss: 1.2756067514419556
# Epoch 4, Training Loss: 1.470048189163208, Validation Loss: 1.2456281185150146
# Epoch 5, Training Loss: 1.4301544427871704, Validation Loss: 1.218544363975525
# Epoch 6, Training Loss: 1.3938353061676025, Validation Loss: 1.1942564249038696
# Epoch 7, Training Loss: 1.3617098331451416, Validation Loss: 1.1730124950408936
# Epoch 8, Training Loss: 1.3338265419006348, Validation Loss: 1.153957724571228
# Epoch 9, Training Loss: 1.3099641799926758, Validation Loss: 1.1368231773376465
# Epoch 10, Training Loss: 1.2899805307388306, Validation Loss: 1.1220753192901611
# Epoch 11, Training Loss: 1.273714303970337, Validation Loss: 1.1097302436828613
# Epoch 12, Training Loss: 1.2607635259628296, Validation Loss: 1.0997651815414429
# Epoch 13, Training Loss: 1.2508301734924316, Validation Loss: 1.0920560359954834
# Epoch 14, Training Loss: 1.2434937953948975, Validation Loss: 1.0863882303237915
# Epoch 15, Training Loss: 1.238397479057312, Validation Loss: 1.0824857950210571
# Epoch 16, Training Loss: 1.235248327255249, Validation Loss: 1.080033302307129
# Epoch 17, Training Loss: 1.2334754467010498, Validation Loss: 1.078685998916626
# Epoch 18, Training Loss: 1.232783317565918, Validation Loss: 1.078092098236084
# Epoch 19, Training Loss: 1.2328212261199951, Validation Loss: 1.0779117345809937
# Epoch 20, Training Loss: 1.2332792282104492, Validation Loss: 1.077831745147705
# Epoch 21, Training Loss: 1.2338961362838745, Validation Loss: 1.0775871276855469
# Epoch 22, Training Loss: 1.2344530820846558, Validation Loss: 1.0769003629684448
# Epoch 23, Training Loss: 1.2347561120986938, Validation Loss: 1.075566053390503
# Epoch 24, Training Loss: 1.2346254587173462, Validation Loss: 1.073781967163086
# Epoch 25, Training Loss: 1.2341735363006592, Validation Loss: 1.0717098712921143
# Epoch 26, Training Loss: 1.233391284942627, Validation Loss: 1.0695717334747314
# Epoch 27, Training Loss: 1.2321665287017822, Validation Loss: 1.0671628713607788
# Epoch 28, Training Loss: 1.2305036783218384, Validation Loss: 1.0645548105239868
# Epoch 29, Training Loss: 1.2285329103469849, Validation Loss: 1.0618423223495483
# Epoch 30, Training Loss: 1.2263489961624146, Validation Loss: 1.0590996742248535
# Epoch 31, Training Loss: 1.2240257263183594, Validation Loss: 1.0563522577285767
# Epoch 32, Training Loss: 1.2218214273452759, Validation Loss: 1.054660677909851
# Epoch 33, Training Loss: 1.2196714878082275, Validation Loss: 1.0529464483261108
# Epoch 34, Training Loss: 1.217685580253601, Validation Loss: 1.051120638847351
# Epoch 35, Training Loss: 1.215788722038269, Validation Loss: 1.0492987632751465
# Epoch 36, Training Loss: 1.2139642238616943, Validation Loss: 1.0474213361740112
# Epoch 37, Training Loss: 1.2122490406036377, Validation Loss: 1.0456109046936035
# Epoch 38, Training Loss: 1.2106436491012573, Validation Loss: 1.0439059734344482
# Epoch 39, Training Loss: 1.2091741561889648, Validation Loss: 1.0423333644866943
# Epoch 40, Training Loss: 1.207829475402832, Validation Loss: 1.0408978462219238
# Epoch 41, Training Loss: 1.2066066265106201, Validation Loss: 1.0394940376281738
# Epoch 42, Training Loss: 1.2055436372756958, Validation Loss: 1.038274884223938
# Epoch 43, Training Loss: 1.2046072483062744, Validation Loss: 1.0372415781021118
# Epoch 44, Training Loss: 1.2038068771362305, Validation Loss: 1.036381483078003
# Epoch 45, Training Loss: 1.2030953168869019, Validation Loss: 1.035675287246704
# Epoch 46, Training Loss: 1.2024528980255127, Validation Loss: 1.0350993871688843
# Epoch 47, Training Loss: 1.2018595933914185, Validation Loss: 1.0346293449401855
# Epoch 48, Training Loss: 1.2012970447540283, Validation Loss: 1.0342435836791992
# Epoch 49, Training Loss: 1.2007700204849243, Validation Loss: 1.0338938236236572
# Epoch 50, Training Loss: 1.2002480030059814, Validation Loss: 1.0335924625396729
# Epoch 51, Training Loss: 1.1997135877609253, Validation Loss: 1.0333367586135864
# Epoch 52, Training Loss: 1.1991621255874634, Validation Loss: 1.0331214666366577
# Epoch 53, Training Loss: 1.1985878944396973, Validation Loss: 1.0329391956329346
# Epoch 54, Training Loss: 1.19798743724823, Validation Loss: 1.0327847003936768
# Epoch 55, Training Loss: 1.1973631381988525, Validation Loss: 1.0326505899429321
# Epoch 56, Training Loss: 1.1967158317565918, Validation Loss: 1.0325355529785156
# Epoch 57, Training Loss: 1.1960489749908447, Validation Loss: 1.0325007438659668
# Epoch 58, Training Loss: 1.195364236831665, Validation Loss: 1.0324506759643555
# Epoch 59, Training Loss: 1.1946676969528198, Validation Loss: 1.0323717594146729
# Epoch 60, Training Loss: 1.1939888000488281, Validation Loss: 1.0326992273330688
# Epoch 61, Training Loss: 1.1932897567749023, Validation Loss: 1.0329267978668213
# Epoch 62, Training Loss: 1.1926239728927612, Validation Loss: 1.0330374240875244
# Epoch 63, Training Loss: 1.1919625997543335, Validation Loss: 1.0330181121826172
# Epoch 64, Training Loss: 1.1913129091262817, Validation Loss: 1.0328600406646729
# Epoch 65, Training Loss: 1.1906918287277222, Validation Loss: 1.0325267314910889
# Epoch 66, Training Loss: 1.1900519132614136, Validation Loss: 1.0320088863372803
# Epoch 67, Training Loss: 1.1894439458847046, Validation Loss: 1.0318543910980225
# Epoch 68, Training Loss: 1.1888023614883423, Validation Loss: 1.0320106744766235
# Epoch 69, Training Loss: 1.1881978511810303, Validation Loss: 1.0318692922592163
# Epoch 70, Training Loss: 1.187587022781372, Validation Loss: 1.031428337097168
# Epoch 71, Training Loss: 1.1869648694992065, Validation Loss: 1.0306938886642456
# Epoch 72, Training Loss: 1.1863282918930054, Validation Loss: 1.0296789407730103
# Epoch 73, Training Loss: 1.1856766939163208, Validation Loss: 1.0284035205841064
# Epoch 74, Training Loss: 1.185130000114441, Validation Loss: 1.027456521987915
# Epoch 75, Training Loss: 1.184533953666687, Validation Loss: 1.026802897453308
# Epoch 76, Training Loss: 1.183883547782898, Validation Loss: 1.0264075994491577
# Epoch 77, Training Loss: 1.1832032203674316, Validation Loss: 1.0256364345550537
# Epoch 78, Training Loss: 1.182625412940979, Validation Loss: 1.0245146751403809
# Epoch 79, Training Loss: 1.1820149421691895, Validation Loss: 1.0232770442962646
# Epoch 80, Training Loss: 1.1814393997192383, Validation Loss: 1.022754192352295
# Epoch 81, Training Loss: 1.180855393409729, Validation Loss: 1.0222070217132568
# Epoch 82, Training Loss: 1.1802222728729248, Validation Loss: 1.0216426849365234
# Epoch 83, Training Loss: 1.1796116828918457, Validation Loss: 1.0210325717926025
# Epoch 84, Training Loss: 1.1790227890014648, Validation Loss: 1.020358920097351
# Epoch 85, Training Loss: 1.178369402885437, Validation Loss: 1.019587516784668
# Epoch 86, Training Loss: 1.1777684688568115, Validation Loss: 1.018831491470337
# Epoch 87, Training Loss: 1.1772587299346924, Validation Loss: 1.0181570053100586
# Epoch 88, Training Loss: 1.1768040657043457, Validation Loss: 1.0175669193267822
# Epoch 89, Training Loss: 1.176455020904541, Validation Loss: 1.0170902013778687
# Epoch 90, Training Loss: 1.1760890483856201, Validation Loss: 1.0167698860168457
# Epoch 91, Training Loss: 1.1756607294082642, Validation Loss: 1.0165668725967407
# Epoch 92, Training Loss: 1.1753640174865723, Validation Loss: 1.0164728164672852
# Epoch 93, Training Loss: 1.1750437021255493, Validation Loss: 1.0164191722869873
# Epoch 94, Training Loss: 1.1746714115142822, Validation Loss: 1.0167384147644043
# Epoch 95, Training Loss: 1.1742841005325317, Validation Loss: 1.0171558856964111
# Epoch 96, Training Loss: 1.1738702058792114, Validation Loss: 1.0176408290863037
# Epoch 97, Training Loss: 1.1735953092575073, Validation Loss: 1.0181740522384644
# Epoch 98, Training Loss: 1.1732836961746216, Validation Loss: 1.0187121629714966
# Epoch 99, Training Loss: 1.1728811264038086, Validation Loss: 1.0192302465438843
# Epoch 100, Training Loss: 1.1724613904953003, Validation Loss: 1.0197067260742188
# Epoch 101, Training Loss: 1.1721596717834473, Validation Loss: 1.020129680633545
# Epoch 102, Training Loss: 1.171822190284729, Validation Loss: 1.0205004215240479
# Epoch 103, Training Loss: 1.1714529991149902, Validation Loss: 1.0208308696746826
# Epoch 104, Training Loss: 1.171091079711914, Validation Loss: 1.0211355686187744
# Epoch 105, Training Loss: 1.1707669496536255, Validation Loss: 1.0213871002197266
# Epoch 106, Training Loss: 1.170499324798584, Validation Loss: 1.0215427875518799
# Epoch 107, Training Loss: 1.170229434967041, Validation Loss: 1.0216560363769531
# Epoch 108, Training Loss: 1.1699367761611938, Validation Loss: 1.021799087524414
# Epoch 109, Training Loss: 1.1696144342422485, Validation Loss: 1.0219448804855347
# Epoch 110, Training Loss: 1.1693284511566162, Validation Loss: 1.0220844745635986
# Epoch 111, Training Loss: 1.1690224409103394, Validation Loss: 1.0222053527832031
# Epoch 112, Training Loss: 1.1687328815460205, Validation Loss: 1.0222939252853394
# Epoch 113, Training Loss: 1.1684565544128418, Validation Loss: 1.0223451852798462
# Epoch 114, Training Loss: 1.1681450605392456, Validation Loss: 1.0223608016967773
# Epoch 115, Training Loss: 1.1678022146224976, Validation Loss: 1.0223495960235596
# Epoch 116, Training Loss: 1.1674928665161133, Validation Loss: 1.0223227739334106
# Epoch 117, Training Loss: 1.1671606302261353, Validation Loss: 1.0222854614257812
# Epoch 118, Training Loss: 1.1668916940689087, Validation Loss: 1.022104263305664
# Epoch 119, Training Loss: 1.1666172742843628, Validation Loss: 1.0218652486801147
# Epoch 120, Training Loss: 1.1663057804107666, Validation Loss: 1.0216058492660522
# Epoch 121, Training Loss: 1.1659632921218872, Validation Loss: 1.021306037902832
# Epoch 122, Training Loss: 1.1656421422958374, Validation Loss: 1.0209691524505615
# Epoch 123, Training Loss: 1.1653265953063965, Validation Loss: 1.0206457376480103
# Epoch 124, Training Loss: 1.1650454998016357, Validation Loss: 1.0202950239181519
# Epoch 125, Training Loss: 1.164764642715454, Validation Loss: 1.0199179649353027
# Epoch 126, Training Loss: 1.1644459962844849, Validation Loss: 1.0195300579071045
# Epoch 127, Training Loss: 1.16409432888031, Validation Loss: 1.0191502571105957
# Epoch 128, Training Loss: 1.1638635396957397, Validation Loss: 1.0187954902648926
# Epoch 129, Training Loss: 1.1635606288909912, Validation Loss: 1.0184704065322876
# Epoch 130, Training Loss: 1.1631659269332886, Validation Loss: 1.0181673765182495
# Epoch 131, Training Loss: 1.1628843545913696, Validation Loss: 1.017879605293274
# Epoch 132, Training Loss: 1.1625651121139526, Validation Loss: 1.0176032781600952
# Epoch 133, Training Loss: 1.1622893810272217, Validation Loss: 1.0173391103744507
# Epoch 134, Training Loss: 1.1619455814361572, Validation Loss: 1.0171153545379639
# Epoch 135, Training Loss: 1.1617056131362915, Validation Loss: 1.0169243812561035
# Epoch 136, Training Loss: 1.16143798828125, Validation Loss: 1.0167425870895386
# Epoch 137, Training Loss: 1.161121129989624, Validation Loss: 1.0165824890136719
# Epoch 138, Training Loss: 1.1607600450515747, Validation Loss: 1.0164576768875122
# Epoch 139, Training Loss: 1.1604464054107666, Validation Loss: 1.0163768529891968
# Epoch 140, Training Loss: 1.1601532697677612, Validation Loss: 1.0163344144821167
# Epoch 141, Training Loss: 1.1597926616668701, Validation Loss: 1.0163105726242065
# Epoch 142, Training Loss: 1.1594948768615723, Validation Loss: 1.016289234161377
# Epoch 143, Training Loss: 1.1591531038284302, Validation Loss: 1.0162601470947266
# Epoch 144, Training Loss: 1.158951759338379, Validation Loss: 1.0162228345870972
# Epoch 145, Training Loss: 1.1586265563964844, Validation Loss: 1.01617431640625
# Epoch 146, Training Loss: 1.15823233127594, Validation Loss: 1.016122579574585
# Epoch 147, Training Loss: 1.1579475402832031, Validation Loss: 1.01604425907135
# Epoch 148, Training Loss: 1.1576071977615356, Validation Loss: 1.0159553289413452
# Epoch 149, Training Loss: 1.157335877418518, Validation Loss: 1.0158779621124268
# Epoch 150, Training Loss: 1.1569913625717163, Validation Loss: 1.0158158540725708
# Epoch 151, Training Loss: 1.1566566228866577, Validation Loss: 1.0157617330551147
# Epoch 152, Training Loss: 1.1563522815704346, Validation Loss: 1.015709400177002
# Epoch 153, Training Loss: 1.1559890508651733, Validation Loss: 1.0156538486480713
# Epoch 154, Training Loss: 1.155648946762085, Validation Loss: 1.0155924558639526
# Epoch 155, Training Loss: 1.1553056240081787, Validation Loss: 1.0155298709869385
# Epoch 156, Training Loss: 1.1549756526947021, Validation Loss: 1.0154445171356201
# Epoch 157, Training Loss: 1.1546491384506226, Validation Loss: 1.0153344869613647
# Epoch 158, Training Loss: 1.154260516166687, Validation Loss: 1.0152086019515991
# Epoch 159, Training Loss: 1.1540042161941528, Validation Loss: 1.0150803327560425
# Epoch 160, Training Loss: 1.153705358505249, Validation Loss: 1.0149495601654053
# Epoch 161, Training Loss: 1.1532998085021973, Validation Loss: 1.014796257019043
# Epoch 162, Training Loss: 1.1530591249465942, Validation Loss: 1.0145901441574097
# Epoch 163, Training Loss: 1.1527886390686035, Validation Loss: 1.014312982559204
# Epoch 164, Training Loss: 1.1524269580841064, Validation Loss: 1.013970136642456
# Epoch 165, Training Loss: 1.151987910270691, Validation Loss: 1.0135891437530518
# Epoch 166, Training Loss: 1.1516540050506592, Validation Loss: 1.0132054090499878
# Epoch 167, Training Loss: 1.1513934135437012, Validation Loss: 1.0128633975982666
# Epoch 168, Training Loss: 1.1510149240493774, Validation Loss: 1.0125800371170044
# Epoch 169, Training Loss: 1.1506621837615967, Validation Loss: 1.0123567581176758
# Epoch 170, Training Loss: 1.1503753662109375, Validation Loss: 1.0121933221817017
# Epoch 171, Training Loss: 1.1500149965286255, Validation Loss: 1.0120909214019775
# Epoch 172, Training Loss: 1.1495941877365112, Validation Loss: 1.0120381116867065
# Epoch 173, Training Loss: 1.1494261026382446, Validation Loss: 1.0120058059692383
# Epoch 174, Training Loss: 1.1491401195526123, Validation Loss: 1.0119454860687256
# Epoch 175, Training Loss: 1.148740291595459, Validation Loss: 1.0117956399917603
# Epoch 176, Training Loss: 1.1483068466186523, Validation Loss: 1.0115554332733154
# Epoch 177, Training Loss: 1.1480859518051147, Validation Loss: 1.0112950801849365
# Epoch 178, Training Loss: 1.1476404666900635, Validation Loss: 1.0110752582550049
# Epoch 179, Training Loss: 1.1473240852355957, Validation Loss: 1.010925054550171
# Epoch 180, Training Loss: 1.1470555067062378, Validation Loss: 1.01083242893219
# Epoch 181, Training Loss: 1.1466927528381348, Validation Loss: 1.0107858180999756
# Epoch 182, Training Loss: 1.1463600397109985, Validation Loss: 1.0107671022415161
# Epoch 183, Training Loss: 1.1461459398269653, Validation Loss: 1.0107600688934326
# Epoch 184, Training Loss: 1.145713448524475, Validation Loss: 1.010739803314209
# Epoch 185, Training Loss: 1.1455141305923462, Validation Loss: 1.010709524154663
# Epoch 186, Training Loss: 1.145207405090332, Validation Loss: 1.0106432437896729
# Epoch 187, Training Loss: 1.1447951793670654, Validation Loss: 1.010514736175537
# Epoch 188, Training Loss: 1.1445866823196411, Validation Loss: 1.0103496313095093
# Epoch 189, Training Loss: 1.144223928451538, Validation Loss: 1.0102229118347168
# Epoch 190, Training Loss: 1.1438268423080444, Validation Loss: 1.0101566314697266
# Epoch 191, Training Loss: 1.1435670852661133, Validation Loss: 1.0101408958435059
# Epoch 192, Training Loss: 1.1431806087493896, Validation Loss: 1.0101613998413086
# Epoch 193, Training Loss: 1.1428520679473877, Validation Loss: 1.01015043258667
# Epoch 194, Training Loss: 1.1424955129623413, Validation Loss: 1.010083556175232
# Epoch 195, Training Loss: 1.1421804428100586, Validation Loss: 1.0099786520004272
# Epoch 196, Training Loss: 1.141838788986206, Validation Loss: 1.0098451375961304
# Epoch 197, Training Loss: 1.1415473222732544, Validation Loss: 1.009682059288025
# Epoch 198, Training Loss: 1.1412858963012695, Validation Loss: 1.0095001459121704
# Epoch 199, Training Loss: 1.1408902406692505, Validation Loss: 1.0093096494674683
# Epoch 200, Training Loss: 1.1406059265136719, Validation Loss: 1.0091221332550049
# Epoch 201, Training Loss: 1.1402482986450195, Validation Loss: 1.00894296169281
# Epoch 202, Training Loss: 1.1399487257003784, Validation Loss: 1.0087316036224365
# Epoch 203, Training Loss: 1.1397042274475098, Validation Loss: 1.008492350578308
# Epoch 204, Training Loss: 1.139388084411621, Validation Loss: 1.0081719160079956
# Epoch 205, Training Loss: 1.1392343044281006, Validation Loss: 1.007756233215332
# Epoch 206, Training Loss: 1.1388709545135498, Validation Loss: 1.007257103919983
# Epoch 207, Training Loss: 1.1385911703109741, Validation Loss: 1.006723165512085
# Epoch 208, Training Loss: 1.1383198499679565, Validation Loss: 1.0062087774276733
# Epoch 209, Training Loss: 1.137986660003662, Validation Loss: 1.005741834640503
# Epoch 210, Training Loss: 1.1377288103103638, Validation Loss: 1.0053540468215942
# Epoch 211, Training Loss: 1.1374633312225342, Validation Loss: 1.0050591230392456
# Epoch 212, Training Loss: 1.1372299194335938, Validation Loss: 1.0048573017120361
# Epoch 213, Training Loss: 1.1369519233703613, Validation Loss: 1.004727840423584
# Epoch 214, Training Loss: 1.1367084980010986, Validation Loss: 1.0046504735946655
# Epoch 215, Training Loss: 1.1364028453826904, Validation Loss: 1.004611849784851
# Epoch 216, Training Loss: 1.1363489627838135, Validation Loss: 1.0045974254608154
# Epoch 217, Training Loss: 1.136029601097107, Validation Loss: 1.0045987367630005
# Epoch 218, Training Loss: 1.1357792615890503, Validation Loss: 1.0046067237854004
# Epoch 219, Training Loss: 1.1356370449066162, Validation Loss: 1.004601240158081
# Epoch 220, Training Loss: 1.1353329420089722, Validation Loss: 1.004575252532959
# Epoch 221, Training Loss: 1.1349635124206543, Validation Loss: 1.0045591592788696
# Epoch 222, Training Loss: 1.134722352027893, Validation Loss: 1.0045950412750244
# Epoch 223, Training Loss: 1.1344913244247437, Validation Loss: 1.0046757459640503
# Epoch 224, Training Loss: 1.1343969106674194, Validation Loss: 1.0047591924667358
# Epoch 225, Training Loss: 1.1340863704681396, Validation Loss: 1.004831075668335
# Epoch 226, Training Loss: 1.1340408325195312, Validation Loss: 1.0048905611038208
# Epoch 227, Training Loss: 1.1338967084884644, Validation Loss: 1.0049432516098022
# Epoch 228, Training Loss: 1.1335996389389038, Validation Loss: 1.004992961883545
# Epoch 229, Training Loss: 1.1332285404205322, Validation Loss: 1.0050290822982788
# Epoch 230, Training Loss: 1.1330525875091553, Validation Loss: 1.0050535202026367
# Epoch 231, Training Loss: 1.1328625679016113, Validation Loss: 1.0050461292266846
# Epoch 232, Training Loss: 1.1326487064361572, Validation Loss: 1.0049891471862793
# Epoch 233, Training Loss: 1.1324671506881714, Validation Loss: 1.0048682689666748
# Epoch 234, Training Loss: 1.132236361503601, Validation Loss: 1.004710078239441
# Epoch 235, Training Loss: 1.1321406364440918, Validation Loss: 1.0045967102050781
# Epoch 236, Training Loss: 1.1319905519485474, Validation Loss: 1.0045552253723145
# Epoch 237, Training Loss: 1.1316543817520142, Validation Loss: 1.0045912265777588
# Epoch 238, Training Loss: 1.1317099332809448, Validation Loss: 1.0046592950820923
# Epoch 239, Training Loss: 1.1316184997558594, Validation Loss: 1.0047056674957275
# Epoch 240, Training Loss: 1.1313008069992065, Validation Loss: 1.0046887397766113
# Epoch 241, Training Loss: 1.1309399604797363, Validation Loss: 1.0046117305755615
# Epoch 242, Training Loss: 1.1308608055114746, Validation Loss: 1.0044883489608765
# Epoch 243, Training Loss: 1.130590558052063, Validation Loss: 1.004325270652771
# Epoch 244, Training Loss: 1.1305581331253052, Validation Loss: 1.0041370391845703
# Epoch 245, Training Loss: 1.1304411888122559, Validation Loss: 1.0039467811584473
# Epoch 246, Training Loss: 1.1301344633102417, Validation Loss: 1.0037806034088135
# Epoch 247, Training Loss: 1.1300731897354126, Validation Loss: 1.003707766532898
# Epoch 248, Training Loss: 1.1299865245819092, Validation Loss: 1.0037339925765991
# Epoch 249, Training Loss: 1.129688024520874, Validation Loss: 1.003851056098938
# Epoch 250, Training Loss: 1.1295653581619263, Validation Loss: 1.003970980644226
# Epoch 251, Training Loss: 1.1295192241668701, Validation Loss: 1.0040591955184937
# Epoch 252, Training Loss: 1.1292871236801147, Validation Loss: 1.0040473937988281
# Epoch 253, Training Loss: 1.1290217638015747, Validation Loss: 1.003965139389038
# Epoch 254, Training Loss: 1.1289217472076416, Validation Loss: 1.0038467645645142
# Epoch 255, Training Loss: 1.1287363767623901, Validation Loss: 1.0037198066711426
# Epoch 256, Training Loss: 1.1286898851394653, Validation Loss: 1.003623127937317
# Epoch 257, Training Loss: 1.128495216369629, Validation Loss: 1.00360906124115
# Epoch 258, Training Loss: 1.1283984184265137, Validation Loss: 1.0036593675613403
# Epoch 259, Training Loss: 1.1282659769058228, Validation Loss: 1.0037455558776855
# Epoch 260, Training Loss: 1.128083348274231, Validation Loss: 1.0038185119628906
# Epoch 261, Training Loss: 1.1279752254486084, Validation Loss: 1.0038578510284424
# Epoch 262, Training Loss: 1.1278074979782104, Validation Loss: 1.0038765668869019
# Epoch 263, Training Loss: 1.1276826858520508, Validation Loss: 1.003867506980896
# Epoch 264, Training Loss: 1.1275851726531982, Validation Loss: 1.0038018226623535
# Epoch 265, Training Loss: 1.1274402141571045, Validation Loss: 1.0037034749984741
# Epoch 266, Training Loss: 1.1273372173309326, Validation Loss: 1.0035934448242188
# Epoch 267, Training Loss: 1.1271867752075195, Validation Loss: 1.003499984741211
# Epoch 268, Training Loss: 1.1271517276763916, Validation Loss: 1.0034065246582031
# Epoch 269, Training Loss: 1.1269949674606323, Validation Loss: 1.0033296346664429
# Epoch 270, Training Loss: 1.1268644332885742, Validation Loss: 1.0032293796539307
# Epoch 271, Training Loss: 1.1268951892852783, Validation Loss: 1.0030856132507324
# Epoch 272, Training Loss: 1.126725196838379, Validation Loss: 1.0028774738311768
# Epoch 273, Training Loss: 1.1266653537750244, Validation Loss: 1.0026500225067139
# Epoch 274, Training Loss: 1.1266266107559204, Validation Loss: 1.0024540424346924
# Epoch 275, Training Loss: 1.1264474391937256, Validation Loss: 1.0022995471954346
# Epoch 276, Training Loss: 1.1263127326965332, Validation Loss: 1.0022021532058716
# Epoch 277, Training Loss: 1.1262084245681763, Validation Loss: 1.0021424293518066
# Epoch 278, Training Loss: 1.1261425018310547, Validation Loss: 1.0021162033081055
# Epoch 279, Training Loss: 1.1260840892791748, Validation Loss: 1.0021239519119263
# Epoch 280, Training Loss: 1.1258822679519653, Validation Loss: 1.002148151397705
# Epoch 281, Training Loss: 1.125949740409851, Validation Loss: 1.0022163391113281
# Epoch 282, Training Loss: 1.1258506774902344, Validation Loss: 1.0023077726364136
# Epoch 283, Training Loss: 1.1255693435668945, Validation Loss: 1.0023999214172363
# Epoch 284, Training Loss: 1.125522494316101, Validation Loss: 1.0024545192718506
# Epoch 285, Training Loss: 1.1253995895385742, Validation Loss: 1.0024206638336182
# Epoch 286, Training Loss: 1.125314712524414, Validation Loss: 1.0023300647735596
# Epoch 287, Training Loss: 1.1252024173736572, Validation Loss: 1.0021928548812866
# Epoch 288, Training Loss: 1.125136137008667, Validation Loss: 1.0019991397857666
# Epoch 289, Training Loss: 1.1250447034835815, Validation Loss: 1.0017917156219482
# Epoch 290, Training Loss: 1.1250160932540894, Validation Loss: 1.00154447555542
# Epoch 291, Training Loss: 1.1249582767486572, Validation Loss: 1.0012775659561157
# Epoch 292, Training Loss: 1.124781847000122, Validation Loss: 1.0010020732879639
# Epoch 293, Training Loss: 1.1248139142990112, Validation Loss: 1.0007154941558838
# Epoch 294, Training Loss: 1.1247150897979736, Validation Loss: 1.000400424003601
# Epoch 295, Training Loss: 1.1245172023773193, Validation Loss: 1.000009536743164
# Epoch 296, Training Loss: 1.1244862079620361, Validation Loss: 0.9995859861373901
# Epoch 297, Training Loss: 1.1243301630020142, Validation Loss: 0.9992125630378723
# Epoch 298, Training Loss: 1.124399185180664, Validation Loss: 0.9989433884620667
# Epoch 299, Training Loss: 1.1242915391921997, Validation Loss: 0.9987301826477051
# Epoch 300, Training Loss: 1.12411367893219, Validation Loss: 0.9985188245773315
# Epoch 301, Training Loss: 1.1240943670272827, Validation Loss: 0.9982416033744812
# Epoch 302, Training Loss: 1.1239559650421143, Validation Loss: 0.9979124069213867
# Epoch 303, Training Loss: 1.1239365339279175, Validation Loss: 0.9975849390029907
# Epoch 304, Training Loss: 1.123840093612671, Validation Loss: 0.9973507523536682
# Epoch 305, Training Loss: 1.1237475872039795, Validation Loss: 0.9972035884857178
# Epoch 306, Training Loss: 1.123720407485962, Validation Loss: 0.997134268283844
# Epoch 307, Training Loss: 1.1235716342926025, Validation Loss: 0.9970402717590332
# Epoch 308, Training Loss: 1.1235520839691162, Validation Loss: 0.9969034790992737
# Epoch 309, Training Loss: 1.1234644651412964, Validation Loss: 0.9966984391212463
# Epoch 310, Training Loss: 1.12336003780365, Validation Loss: 0.9964130520820618
# Epoch 311, Training Loss: 1.1233328580856323, Validation Loss: 0.996115505695343
# Epoch 312, Training Loss: 1.123179316520691, Validation Loss: 0.9959018230438232
# Epoch 313, Training Loss: 1.1232328414916992, Validation Loss: 0.9957881569862366
# Epoch 314, Training Loss: 1.1231448650360107, Validation Loss: 0.9956708550453186
# Epoch 315, Training Loss: 1.1229820251464844, Validation Loss: 0.9954813718795776
# Epoch 316, Training Loss: 1.1229549646377563, Validation Loss: 0.9952187538146973
# Epoch 317, Training Loss: 1.1228166818618774, Validation Loss: 0.9950004816055298
# Epoch 318, Training Loss: 1.1229220628738403, Validation Loss: 0.9948763847351074
# Epoch 319, Training Loss: 1.122835397720337, Validation Loss: 0.9947627186775208
# Epoch 320, Training Loss: 1.122636079788208, Validation Loss: 0.9945710301399231
# Epoch 321, Training Loss: 1.1226242780685425, Validation Loss: 0.9942464828491211
# Epoch 322, Training Loss: 1.1224861145019531, Validation Loss: 0.993902862071991
# Epoch 323, Training Loss: 1.1225948333740234, Validation Loss: 0.9936424493789673
# Epoch 324, Training Loss: 1.1225168704986572, Validation Loss: 0.9934394955635071
# Epoch 325, Training Loss: 1.1223024129867554, Validation Loss: 0.9932526350021362
# Epoch 326, Training Loss: 1.1222947835922241, Validation Loss: 0.9930470585823059
# Epoch 327, Training Loss: 1.1221622228622437, Validation Loss: 0.9928350448608398
# Epoch 328, Training Loss: 1.1222801208496094, Validation Loss: 0.992709755897522
# Epoch 329, Training Loss: 1.122202754020691, Validation Loss: 0.9926684498786926
# Epoch 330, Training Loss: 1.1219968795776367, Validation Loss: 0.9925991296768188
# Epoch 331, Training Loss: 1.1219887733459473, Validation Loss: 0.9924553036689758
# Epoch 332, Training Loss: 1.121859073638916, Validation Loss: 0.9922409653663635
# Epoch 333, Training Loss: 1.1219826936721802, Validation Loss: 0.992057204246521
# Epoch 334, Training Loss: 1.1219065189361572, Validation Loss: 0.9919503927230835
# Epoch 335, Training Loss: 1.121698260307312, Validation Loss: 0.9918427467346191
# Epoch 336, Training Loss: 1.121690034866333, Validation Loss: 0.9917209148406982
# Epoch 337, Training Loss: 1.1215773820877075, Validation Loss: 0.991588294506073
# Epoch 338, Training Loss: 1.1215579509735107, Validation Loss: 0.9914201498031616
# Epoch 339, Training Loss: 1.1214687824249268, Validation Loss: 0.9912717938423157
# Epoch 340, Training Loss: 1.1214072704315186, Validation Loss: 0.9911513328552246
# Epoch 341, Training Loss: 1.121354579925537, Validation Loss: 0.9910679459571838
# Epoch 342, Training Loss: 1.1213476657867432, Validation Loss: 0.9909509420394897
# Epoch 343, Training Loss: 1.1212971210479736, Validation Loss: 0.9908176064491272
# Epoch 344, Training Loss: 1.1211817264556885, Validation Loss: 0.9906827211380005
# Epoch 345, Training Loss: 1.121124267578125, Validation Loss: 0.9905259609222412
# Epoch 346, Training Loss: 1.1210689544677734, Validation Loss: 0.9903300404548645
# Epoch 347, Training Loss: 1.1210660934448242, Validation Loss: 0.9901130795478821
# Epoch 348, Training Loss: 1.1209968328475952, Validation Loss: 0.9898573160171509
# Epoch 349, Training Loss: 1.1209720373153687, Validation Loss: 0.9896079897880554
# Epoch 350, Training Loss: 1.1208600997924805, Validation Loss: 0.9893879890441895
# Epoch 351, Training Loss: 1.12082839012146, Validation Loss: 0.9891942143440247
# Epoch 352, Training Loss: 1.1207871437072754, Validation Loss: 0.9889621734619141
# Epoch 353, Training Loss: 1.120737075805664, Validation Loss: 0.9886375665664673
# Epoch 354, Training Loss: 1.1207212209701538, Validation Loss: 0.988198459148407
# Epoch 355, Training Loss: 1.1207317113876343, Validation Loss: 0.9877685308456421
# Epoch 356, Training Loss: 1.1206985712051392, Validation Loss: 0.9875099062919617
# Epoch 357, Training Loss: 1.1205748319625854, Validation Loss: 0.9875389337539673
# Epoch 358, Training Loss: 1.1206905841827393, Validation Loss: 0.9877849817276001
# Epoch 359, Training Loss: 1.1205447912216187, Validation Loss: 0.9880692362785339
# Epoch 360, Training Loss: 1.1206305027008057, Validation Loss: 0.9882541298866272
# Epoch 361, Training Loss: 1.1206845045089722, Validation Loss: 0.9883497357368469
# Epoch 362, Training Loss: 1.1206016540527344, Validation Loss: 0.9884402751922607
# Epoch 363, Training Loss: 1.1204091310501099, Validation Loss: 0.9885731339454651
# Epoch 364, Training Loss: 1.120524525642395, Validation Loss: 0.9887499809265137
# Epoch 365, Training Loss: 1.1205542087554932, Validation Loss: 0.9889235496520996
# Epoch 366, Training Loss: 1.120300531387329, Validation Loss: 0.989006757736206
# Epoch 367, Training Loss: 1.120424509048462, Validation Loss: 0.9890390634536743
# Epoch 368, Training Loss: 1.120535969734192, Validation Loss: 0.9890853762626648
# Epoch 369, Training Loss: 1.1205294132232666, Validation Loss: 0.989233672618866
# Epoch 370, Training Loss: 1.1204134225845337, Validation Loss: 0.9894146919250488
# Epoch 371, Training Loss: 1.120213270187378, Validation Loss: 0.9895251393318176
# Epoch 372, Training Loss: 1.1201701164245605, Validation Loss: 0.9895092248916626
# Epoch 373, Training Loss: 1.1202296018600464, Validation Loss: 0.9894638061523438
# Epoch 374, Training Loss: 1.1200017929077148, Validation Loss: 0.9894511699676514
# Epoch 375, Training Loss: 1.1201362609863281, Validation Loss: 0.989460825920105
# Epoch 376, Training Loss: 1.12024986743927, Validation Loss: 0.9894533753395081
# Epoch 377, Training Loss: 1.1202445030212402, Validation Loss: 0.9894348978996277
# Epoch 378, Training Loss: 1.120131492614746, Validation Loss: 0.989474356174469
# Epoch 379, Training Loss: 1.1199437379837036, Validation Loss: 0.9894822239875793
# Epoch 380, Training Loss: 1.119864821434021, Validation Loss: 0.9893535375595093
# Epoch 381, Training Loss: 1.1199308633804321, Validation Loss: 0.9890033006668091
# Epoch 382, Training Loss: 1.1197117567062378, Validation Loss: 0.988570511341095
# Epoch 383, Training Loss: 1.119781494140625, Validation Loss: 0.9883201122283936
# Epoch 384, Training Loss: 1.1197715997695923, Validation Loss: 0.9883058667182922
# Epoch 385, Training Loss: 1.1196589469909668, Validation Loss: 0.9884021282196045
# Epoch 386, Training Loss: 1.1197344064712524, Validation Loss: 0.9884762763977051
# Epoch 387, Training Loss: 1.1196421384811401, Validation Loss: 0.9885280132293701
# Epoch 388, Training Loss: 1.1196428537368774, Validation Loss: 0.9885121583938599
# Epoch 389, Training Loss: 1.1197013854980469, Validation Loss: 0.9884520173072815
# Epoch 390, Training Loss: 1.1196584701538086, Validation Loss: 0.988406777381897
# Epoch 391, Training Loss: 1.1195473670959473, Validation Loss: 0.9884620904922485
# Epoch 392, Training Loss: 1.1195015907287598, Validation Loss: 0.9885554909706116
# Epoch 393, Training Loss: 1.1194530725479126, Validation Loss: 0.9885890483856201
# Epoch 394, Training Loss: 1.119492769241333, Validation Loss: 0.9885298013687134
# Epoch 395, Training Loss: 1.119532585144043, Validation Loss: 0.988486111164093
# Epoch 396, Training Loss: 1.1194876432418823, Validation Loss: 0.9885154962539673
# Epoch 397, Training Loss: 1.1193748712539673, Validation Loss: 0.9885908961296082
# Epoch 398, Training Loss: 1.119393229484558, Validation Loss: 0.9886921644210815
# Epoch 399, Training Loss: 1.1193296909332275, Validation Loss: 0.9888156652450562
# Epoch 400, Training Loss: 1.1193279027938843, Validation Loss: 0.9888588786125183
# Epoch 401, Training Loss: 1.1193811893463135, Validation Loss: 0.9887523651123047
# Epoch 402, Training Loss: 1.1193478107452393, Validation Loss: 0.9884586930274963
# Epoch 403, Training Loss: 1.119248867034912, Validation Loss: 0.9881656169891357
# Epoch 404, Training Loss: 1.1191552877426147, Validation Loss: 0.9879662990570068
# Epoch 405, Training Loss: 1.119126319885254, Validation Loss: 0.9878491163253784
# Epoch 406, Training Loss: 1.119102954864502, Validation Loss: 0.9878145456314087
# Epoch 407, Training Loss: 1.119080901145935, Validation Loss: 0.9878788590431213
# Epoch 408, Training Loss: 1.1190946102142334, Validation Loss: 0.9879695177078247
# Epoch 409, Training Loss: 1.1190868616104126, Validation Loss: 0.9879770874977112
# Epoch 410, Training Loss: 1.1190965175628662, Validation Loss: 0.9880112409591675
# Epoch 411, Training Loss: 1.1190515756607056, Validation Loss: 0.9881911277770996
# Epoch 412, Training Loss: 1.118953824043274, Validation Loss: 0.9883754253387451
# Epoch 413, Training Loss: 1.1190448999404907, Validation Loss: 0.9883575439453125
# Epoch 414, Training Loss: 1.1189080476760864, Validation Loss: 0.9880502820014954
# Epoch 415, Training Loss: 1.1188945770263672, Validation Loss: 0.9876759648323059
# Epoch 416, Training Loss: 1.118865728378296, Validation Loss: 0.9874175190925598
# Epoch 417, Training Loss: 1.118909478187561, Validation Loss: 0.9873324036598206
# Epoch 418, Training Loss: 1.1189180612564087, Validation Loss: 0.9874167442321777
# Epoch 419, Training Loss: 1.1188560724258423, Validation Loss: 0.9876289963722229
# Epoch 420, Training Loss: 1.118789553642273, Validation Loss: 0.9878851771354675
# Epoch 421, Training Loss: 1.1187739372253418, Validation Loss: 0.9880224466323853
# Epoch 422, Training Loss: 1.1187458038330078, Validation Loss: 0.98796546459198
# Epoch 423, Training Loss: 1.1187498569488525, Validation Loss: 0.9877630472183228
# Epoch 424, Training Loss: 1.118728518486023, Validation Loss: 0.9875777363777161
# Epoch 425, Training Loss: 1.1187196969985962, Validation Loss: 0.9874387979507446
# Epoch 426, Training Loss: 1.1186619997024536, Validation Loss: 0.9873719215393066
# Epoch 427, Training Loss: 1.1187418699264526, Validation Loss: 0.9873307347297668
# Epoch 428, Training Loss: 1.1186021566390991, Validation Loss: 0.9872082471847534
# Epoch 429, Training Loss: 1.11858069896698, Validation Loss: 0.9869890809059143
# Epoch 430, Training Loss: 1.1186721324920654, Validation Loss: 0.9868042469024658
# Epoch 431, Training Loss: 1.1185708045959473, Validation Loss: 0.9867849946022034
# Epoch 432, Training Loss: 1.1185723543167114, Validation Loss: 0.9869205355644226
# Epoch 433, Training Loss: 1.118517518043518, Validation Loss: 0.9871112704277039
# Epoch 434, Training Loss: 1.118571400642395, Validation Loss: 0.9872267246246338
# Epoch 435, Training Loss: 1.118470311164856, Validation Loss: 0.98717200756073
# Epoch 436, Training Loss: 1.118460774421692, Validation Loss: 0.9869910478591919
# Epoch 437, Training Loss: 1.1184369325637817, Validation Loss: 0.9867339134216309
# Epoch 438, Training Loss: 1.1184624433517456, Validation Loss: 0.9865409731864929
# Epoch 439, Training Loss: 1.1184790134429932, Validation Loss: 0.9864025712013245
# Epoch 440, Training Loss: 1.1184369325637817, Validation Loss: 0.9862781763076782
# Epoch 441, Training Loss: 1.1183398962020874, Validation Loss: 0.986250638961792
# Epoch 442, Training Loss: 1.118593692779541, Validation Loss: 0.9863913655281067
# Epoch 443, Training Loss: 1.1184638738632202, Validation Loss: 0.9865308403968811
# Epoch 444, Training Loss: 1.1183758974075317, Validation Loss: 0.9864460229873657
# Epoch 445, Training Loss: 1.1184531450271606, Validation Loss: 0.9863110184669495
# Epoch 446, Training Loss: 1.1184890270233154, Validation Loss: 0.9862187504768372
# Epoch 447, Training Loss: 1.1184442043304443, Validation Loss: 0.9861552715301514
# Epoch 448, Training Loss: 1.1183505058288574, Validation Loss: 0.985971212387085
# Epoch 449, Training Loss: 1.118204116821289, Validation Loss: 0.9857679009437561
# Epoch 450, Training Loss: 1.1185028553009033, Validation Loss: 0.9857500791549683
# Epoch 451, Training Loss: 1.1184813976287842, Validation Loss: 0.985927164554596
# Epoch 452, Training Loss: 1.1181446313858032, Validation Loss: 0.9860327243804932
# Epoch 453, Training Loss: 1.1182173490524292, Validation Loss: 0.9858604073524475
# Epoch 454, Training Loss: 1.1182136535644531, Validation Loss: 0.9855630397796631
# Epoch 455, Training Loss: 1.1181559562683105, Validation Loss: 0.9854032397270203
# Epoch 456, Training Loss: 1.118064045906067, Validation Loss: 0.9853807687759399
# Epoch 457, Training Loss: 1.1182668209075928, Validation Loss: 0.985434353351593
# Epoch 458, Training Loss: 1.1181410551071167, Validation Loss: 0.9854651093482971
# Epoch 459, Training Loss: 1.1180927753448486, Validation Loss: 0.9854151010513306
# Epoch 460, Training Loss: 1.118184208869934, Validation Loss: 0.9853585958480835
# Epoch 461, Training Loss: 1.1182076930999756, Validation Loss: 0.9853609800338745
# Epoch 462, Training Loss: 1.1181644201278687, Validation Loss: 0.9853905439376831
# Epoch 463, Training Loss: 1.1180779933929443, Validation Loss: 0.9853251576423645
# Epoch 464, Training Loss: 1.1179457902908325, Validation Loss: 0.9852268099784851
# Epoch 465, Training Loss: 1.1180994510650635, Validation Loss: 0.9852489233016968
# Epoch 466, Training Loss: 1.1180551052093506, Validation Loss: 0.9852626323699951
# Epoch 467, Training Loss: 1.1179029941558838, Validation Loss: 0.9851089119911194
# Epoch 468, Training Loss: 1.1179592609405518, Validation Loss: 0.9849786758422852
# Epoch 469, Training Loss: 1.1179689168930054, Validation Loss: 0.9850093126296997
# Epoch 470, Training Loss: 1.1179171800613403, Validation Loss: 0.9850730895996094
# Epoch 471, Training Loss: 1.1178255081176758, Validation Loss: 0.9851642847061157
# Epoch 472, Training Loss: 1.1178110837936401, Validation Loss: 0.9852540493011475
# Epoch 473, Training Loss: 1.1177208423614502, Validation Loss: 0.9851790070533752
# Epoch 474, Training Loss: 1.1177124977111816, Validation Loss: 0.984992504119873
# Epoch 475, Training Loss: 1.1177834272384644, Validation Loss: 0.984761118888855
# Epoch 476, Training Loss: 1.1178274154663086, Validation Loss: 0.9845423698425293
# Epoch 477, Training Loss: 1.1178185939788818, Validation Loss: 0.9845575094223022
# Epoch 478, Training Loss: 1.117760419845581, Validation Loss: 0.9847820997238159
# Epoch 479, Training Loss: 1.1176508665084839, Validation Loss: 0.9849848747253418
# Epoch 480, Training Loss: 1.117785096168518, Validation Loss: 0.9849727153778076
# Epoch 481, Training Loss: 1.1176788806915283, Validation Loss: 0.9848139882087708
# Epoch 482, Training Loss: 1.1176605224609375, Validation Loss: 0.9846395254135132
# Epoch 483, Training Loss: 1.1177417039871216, Validation Loss: 0.9845438599586487
# Epoch 484, Training Loss: 1.1177725791931152, Validation Loss: 0.9844728708267212
# Epoch 485, Training Loss: 1.1177372932434082, Validation Loss: 0.9845129251480103
# Epoch 486, Training Loss: 1.1176543235778809, Validation Loss: 0.98473060131073
# Epoch 487, Training Loss: 1.1175261735916138, Validation Loss: 0.9849900007247925
# Epoch 488, Training Loss: 1.1176135540008545, Validation Loss: 0.9850847125053406
# Epoch 489, Training Loss: 1.1175568103790283, Validation Loss: 0.9849751591682434
# Epoch 490, Training Loss: 1.1175073385238647, Validation Loss: 0.9848307371139526
# Epoch 491, Training Loss: 1.1175721883773804, Validation Loss: 0.984748899936676
# Epoch 492, Training Loss: 1.1175881624221802, Validation Loss: 0.984606146812439
# Epoch 493, Training Loss: 1.1175494194030762, Validation Loss: 0.9843447804450989
# Epoch 494, Training Loss: 1.1174581050872803, Validation Loss: 0.9840871691703796
# Epoch 495, Training Loss: 1.1173458099365234, Validation Loss: 0.9838996529579163
# Epoch 496, Training Loss: 1.1175884008407593, Validation Loss: 0.9839765429496765
# Epoch 497, Training Loss: 1.1175025701522827, Validation Loss: 0.9842137098312378
# Epoch 498, Training Loss: 1.1173210144042969, Validation Loss: 0.9844184517860413
# Epoch 499, Training Loss: 1.1174074411392212, Validation Loss: 0.9843824505805969
# Epoch 500, Training Loss: 1.1174291372299194, Validation Loss: 0.9841524362564087
# Epoch 501, Training Loss: 1.1174023151397705, Validation Loss: 0.9839533567428589
# Epoch 502, Training Loss: 1.117327094078064, Validation Loss: 0.9838693737983704
# Epoch 503, Training Loss: 1.1172126531600952, Validation Loss: 0.9838854670524597
# Epoch 504, Training Loss: 1.1173640489578247, Validation Loss: 0.9840254783630371
# Epoch 505, Training Loss: 1.117269515991211, Validation Loss: 0.9842408895492554
# Epoch 506, Training Loss: 1.1172001361846924, Validation Loss: 0.9843776822090149
# Epoch 507, Training Loss: 1.1172915697097778, Validation Loss: 0.9843735694885254
# Epoch 508, Training Loss: 1.1173189878463745, Validation Loss: 0.9842535853385925
# Epoch 509, Training Loss: 1.1172802448272705, Validation Loss: 0.9839938282966614
# Epoch 510, Training Loss: 1.1172103881835938, Validation Loss: 0.983684241771698
# Epoch 511, Training Loss: 1.1171053647994995, Validation Loss: 0.9834344387054443
# Epoch 512, Training Loss: 1.1171157360076904, Validation Loss: 0.9834475517272949
# Epoch 513, Training Loss: 1.1170357465744019, Validation Loss: 0.9837031364440918
# Epoch 514, Training Loss: 1.1170963048934937, Validation Loss: 0.9839093685150146
# Epoch 515, Training Loss: 1.117180347442627, Validation Loss: 0.9838878512382507
# Epoch 516, Training Loss: 1.117185115814209, Validation Loss: 0.9839298725128174
# Epoch 517, Training Loss: 1.1171551942825317, Validation Loss: 0.9841702580451965
# Epoch 518, Training Loss: 1.1170775890350342, Validation Loss: 0.9843750596046448
# Epoch 519, Training Loss: 1.1169685125350952, Validation Loss: 0.9843551516532898
# Epoch 520, Training Loss: 1.116895079612732, Validation Loss: 0.9841127991676331
# Epoch 521, Training Loss: 1.1168209314346313, Validation Loss: 0.9837939739227295
# Epoch 522, Training Loss: 1.1168338060379028, Validation Loss: 0.9834936857223511
# Epoch 523, Training Loss: 1.1168018579483032, Validation Loss: 0.9832807183265686
# Epoch 524, Training Loss: 1.1168615818023682, Validation Loss: 0.9831666946411133
# Epoch 525, Training Loss: 1.116799235343933, Validation Loss: 0.9831918478012085
# Epoch 526, Training Loss: 1.1168098449707031, Validation Loss: 0.9834067821502686
# Epoch 527, Training Loss: 1.1167782545089722, Validation Loss: 0.9837480783462524
# Epoch 528, Training Loss: 1.116705298423767, Validation Loss: 0.9839837551116943
# Epoch 529, Training Loss: 1.116790771484375, Validation Loss: 0.9838589429855347
# Epoch 530, Training Loss: 1.1166579723358154, Validation Loss: 0.9834611415863037
# Epoch 531, Training Loss: 1.1166422367095947, Validation Loss: 0.9831176996231079
# Epoch 532, Training Loss: 1.1165926456451416, Validation Loss: 0.9829888343811035
# Epoch 533, Training Loss: 1.1166313886642456, Validation Loss: 0.982853889465332
# Epoch 534, Training Loss: 1.1166300773620605, Validation Loss: 0.9826716184616089
# Epoch 535, Training Loss: 1.1165817975997925, Validation Loss: 0.9826076030731201
# Epoch 536, Training Loss: 1.116640567779541, Validation Loss: 0.9826635122299194
# Epoch 537, Training Loss: 1.1165410280227661, Validation Loss: 0.9826404452323914
# Epoch 538, Training Loss: 1.1165409088134766, Validation Loss: 0.9824624061584473
# Epoch 539, Training Loss: 1.1165156364440918, Validation Loss: 0.9821988344192505
# Epoch 540, Training Loss: 1.116520643234253, Validation Loss: 0.9820669293403625
# Epoch 541, Training Loss: 1.1164979934692383, Validation Loss: 0.9819585680961609
# Epoch 542, Training Loss: 1.1165096759796143, Validation Loss: 0.9817560911178589
# Epoch 543, Training Loss: 1.1164854764938354, Validation Loss: 0.9815319776535034
# Epoch 544, Training Loss: 1.1164213418960571, Validation Loss: 0.9815540909767151
# Epoch 545, Training Loss: 1.116502285003662, Validation Loss: 0.981870710849762
# Epoch 546, Training Loss: 1.1163634061813354, Validation Loss: 0.9822283387184143
# Epoch 547, Training Loss: 1.116355299949646, Validation Loss: 0.9825318455696106
# Epoch 548, Training Loss: 1.1163203716278076, Validation Loss: 0.9827706813812256
# Epoch 549, Training Loss: 1.1164532899856567, Validation Loss: 0.9828920960426331
# Epoch 550, Training Loss: 1.1163060665130615, Validation Loss: 0.982660174369812
# Epoch 551, Training Loss: 1.1163233518600464, Validation Loss: 0.9822688102722168
# Epoch 552, Training Loss: 1.11630380153656, Validation Loss: 0.981910765171051
# Epoch 553, Training Loss: 1.1162440776824951, Validation Loss: 0.9816718101501465
# Epoch 554, Training Loss: 1.1163804531097412, Validation Loss: 0.9815897941589355
# Epoch 555, Training Loss: 1.1162006855010986, Validation Loss: 0.9815012216567993
# Epoch 556, Training Loss: 1.116198182106018, Validation Loss: 0.9814571142196655
# Epoch 557, Training Loss: 1.1161621809005737, Validation Loss: 0.9815095067024231
# Epoch 558, Training Loss: 1.1162140369415283, Validation Loss: 0.9816201329231262
# Epoch 559, Training Loss: 1.1161701679229736, Validation Loss: 0.9815303087234497
# Epoch 560, Training Loss: 1.1161932945251465, Validation Loss: 0.9812954664230347
# Epoch 561, Training Loss: 1.1161649227142334, Validation Loss: 0.98094642162323
# Epoch 562, Training Loss: 1.1161068677902222, Validation Loss: 0.9806145429611206
# Epoch 563, Training Loss: 1.1160515546798706, Validation Loss: 0.9803650975227356
# Epoch 564, Training Loss: 1.1160759925842285, Validation Loss: 0.980227530002594
# Epoch 565, Training Loss: 1.1160839796066284, Validation Loss: 0.9801967144012451
# Epoch 566, Training Loss: 1.1160451173782349, Validation Loss: 0.9803597927093506
# Epoch 567, Training Loss: 1.1159720420837402, Validation Loss: 0.9807220697402954
# Epoch 568, Training Loss: 1.1161457300186157, Validation Loss: 0.9809748530387878
# Epoch 569, Training Loss: 1.1159334182739258, Validation Loss: 0.9808309674263
# Epoch 570, Training Loss: 1.1159576177597046, Validation Loss: 0.9805982112884521
# Epoch 571, Training Loss: 1.1159701347351074, Validation Loss: 0.9804936051368713
# Epoch 572, Training Loss: 1.1159342527389526, Validation Loss: 0.9804694652557373
# Epoch 573, Training Loss: 1.1158720254898071, Validation Loss: 0.9802141785621643
# Epoch 574, Training Loss: 1.1159290075302124, Validation Loss: 0.9798052310943604
# Epoch 575, Training Loss: 1.11581552028656, Validation Loss: 0.9795735478401184
# Epoch 576, Training Loss: 1.1158196926116943, Validation Loss: 0.9794933199882507
# Epoch 577, Training Loss: 1.1157808303833008, Validation Loss: 0.9794615507125854
# Epoch 578, Training Loss: 1.1157588958740234, Validation Loss: 0.9793806672096252
# Epoch 579, Training Loss: 1.1157749891281128, Validation Loss: 0.9793202877044678
# Epoch 580, Training Loss: 1.1157927513122559, Validation Loss: 0.9792413711547852
# Epoch 581, Training Loss: 1.1157715320587158, Validation Loss: 0.9791973233222961
# Epoch 582, Training Loss: 1.115720272064209, Validation Loss: 0.9789963364601135
# Epoch 583, Training Loss: 1.1156398057937622, Validation Loss: 0.9788952469825745
# Epoch 584, Training Loss: 1.115823745727539, Validation Loss: 0.9789383411407471
# Epoch 585, Training Loss: 1.1156136989593506, Validation Loss: 0.978996992111206
# Epoch 586, Training Loss: 1.1156940460205078, Validation Loss: 0.9790382981300354
# Epoch 587, Training Loss: 1.1158061027526855, Validation Loss: 0.9789679646492004
# Epoch 588, Training Loss: 1.115857720375061, Validation Loss: 0.9787748456001282
# Epoch 589, Training Loss: 1.1158514022827148, Validation Loss: 0.9785116910934448
# ...
# Epoch 1733, Training Loss: 1.0918586254119873, Validation Loss: 1.0826359987258911
# Epoch 1734, Training Loss: 1.0918445587158203, Validation Loss: 1.083701729774475
# Epoch 1735, Training Loss: 1.0918796062469482, Validation Loss: 1.0843673944473267
# Epoch 1736, Training Loss: 1.091872215270996, Validation Loss: 1.0825494527816772
# Epoch 1737, Training Loss: 1.0918669700622559, Validation Loss: 1.0812740325927734
# Epoch 1738, Training Loss: 1.0918400287628174, Validation Loss: 1.0805896520614624
# Epoch 1739, Training Loss: 1.091852068901062, Validation Loss: 1.0827693939208984
# Epoch 1740, Training Loss: 1.091855525970459, Validation Loss: 1.0830800533294678
# Epoch 1741, Training Loss: 1.091837763786316, Validation Loss: 1.0839136838912964
# Epoch 1742, Training Loss: 1.0918405055999756, Validation Loss: 1.0852688550949097
# Epoch 1743, Training Loss: 1.0918307304382324, Validation Loss: 1.083889365196228
# Epoch 1744, Training Loss: 1.0918080806732178, Validation Loss: 1.0837136507034302
# Epoch 1745, Training Loss: 1.0917890071868896, Validation Loss: 1.082826852798462
# Epoch 1746, Training Loss: 1.091921329498291, Validation Loss: 1.0827709436416626
# Epoch 1747, Training Loss: 1.0918121337890625, Validation Loss: 1.0851037502288818
# Epoch 1748, Training Loss: 1.09182608127594, Validation Loss: 1.0853846073150635
# Epoch 1749, Training Loss: 1.091852068901062, Validation Loss: 1.0838408470153809
# Epoch 1750, Training Loss: 1.0918415784835815, Validation Loss: 1.0833346843719482
# Epoch 1751, Training Loss: 1.0918389558792114, Validation Loss: 1.081631064414978
# Epoch 1752, Training Loss: 1.0918354988098145, Validation Loss: 1.0809695720672607
# Epoch 1753, Training Loss: 1.091854453086853, Validation Loss: 1.0834825038909912
# Epoch 1754, Training Loss: 1.0918564796447754, Validation Loss: 1.0837286710739136
# Epoch 1755, Training Loss: 1.0918375253677368, Validation Loss: 1.0849318504333496
# Epoch 1756, Training Loss: 1.0918396711349487, Validation Loss: 1.0848326683044434
# Epoch 1757, Training Loss: 1.091844916343689, Validation Loss: 1.083801507949829
# Epoch 1758, Training Loss: 1.0918089151382446, Validation Loss: 1.0837583541870117
# Epoch 1759, Training Loss: 1.091800570487976, Validation Loss: 1.086147665977478
# Epoch 1760, Training Loss: 1.091850996017456, Validation Loss: 1.0843433141708374
# Epoch 1761, Training Loss: 1.0918387174606323, Validation Loss: 1.0837459564208984
# Epoch 1762, Training Loss: 1.0917738676071167, Validation Loss: 1.0829788446426392
# Epoch 1763, Training Loss: 1.0918710231781006, Validation Loss: 1.0819873809814453
# Epoch 1764, Training Loss: 1.0918060541152954, Validation Loss: 1.0844873189926147
# Epoch 1765, Training Loss: 1.09182870388031, Validation Loss: 1.0848846435546875
# Epoch 1766, Training Loss: 1.091841220855713, Validation Loss: 1.0831855535507202
# Epoch 1767, Training Loss: 1.0918289422988892, Validation Loss: 1.0843924283981323
# Epoch 1768, Training Loss: 1.0918575525283813, Validation Loss: 1.0822827816009521
# Epoch 1769, Training Loss: 1.0918645858764648, Validation Loss: 1.084000587463379
# Epoch 1770, Training Loss: 1.091835856437683, Validation Loss: 1.0862083435058594
# Epoch 1771, Training Loss: 1.091881275177002, Validation Loss: 1.0840407609939575
# Epoch 1772, Training Loss: 1.09186851978302, Validation Loss: 1.0827858448028564
# Epoch 1773, Training Loss: 1.091852068901062, Validation Loss: 1.0823191404342651
# Epoch 1774, Training Loss: 1.0918422937393188, Validation Loss: 1.0803186893463135
# Epoch 1775, Training Loss: 1.0918701887130737, Validation Loss: 1.0822752714157104
# Epoch 1776, Training Loss: 1.091814398765564, Validation Loss: 1.083215594291687
# Epoch 1777, Training Loss: 1.0918028354644775, Validation Loss: 1.0829609632492065
# Epoch 1778, Training Loss: 1.091817855834961, Validation Loss: 1.084938883781433
# Epoch 1779, Training Loss: 1.091790795326233, Validation Loss: 1.0849840641021729
# Epoch 1780, Training Loss: 1.0918246507644653, Validation Loss: 1.0829172134399414
# Epoch 1781, Training Loss: 1.0918227434158325, Validation Loss: 1.0835747718811035
# Epoch 1782, Training Loss: 1.091817021369934, Validation Loss: 1.0837401151657104
# Epoch 1783, Training Loss: 1.0918627977371216, Validation Loss: 1.0827149152755737
# Epoch 1784, Training Loss: 1.0918751955032349, Validation Loss: 1.0840915441513062
# Epoch 1785, Training Loss: 1.0918689966201782, Validation Loss: 1.0827105045318604
# Epoch 1786, Training Loss: 1.0918738842010498, Validation Loss: 1.0815597772598267
# Epoch 1787, Training Loss: 1.0918645858764648, Validation Loss: 1.0831327438354492
# Epoch 1788, Training Loss: 1.0918515920639038, Validation Loss: 1.0826475620269775
# Epoch 1789, Training Loss: 1.0918816328048706, Validation Loss: 1.0825300216674805
# Epoch 1790, Training Loss: 1.0918530225753784, Validation Loss: 1.0836137533187866
# Epoch 1791, Training Loss: 1.0918467044830322, Validation Loss: 1.082547664642334
# Epoch 1792, Training Loss: 1.0918490886688232, Validation Loss: 1.0814878940582275
# Epoch 1793, Training Loss: 1.0918550491333008, Validation Loss: 1.08285391330719
# Epoch 1794, Training Loss: 1.0918253660202026, Validation Loss: 1.0838335752487183
# Epoch 1795, Training Loss: 1.0918090343475342, Validation Loss: 1.0850920677185059
# Epoch 1796, Training Loss: 1.0918192863464355, Validation Loss: 1.086512804031372
# Epoch 1797, Training Loss: 1.0918854475021362, Validation Loss: 1.0843501091003418
# Epoch 1798, Training Loss: 1.0917942523956299, Validation Loss: 1.0823720693588257
# Epoch 1799, Training Loss: 1.0918022394180298, Validation Loss: 1.083014965057373
# Epoch 1800, Training Loss: 1.0918357372283936, Validation Loss: 1.0816301107406616
# Epoch 1801, Training Loss: 1.091828465461731, Validation Loss: 1.0825576782226562
# Epoch 1802, Training Loss: 1.0918179750442505, Validation Loss: 1.0843309164047241
# Epoch 1803, Training Loss: 1.091829538345337, Validation Loss: 1.0843192338943481
# Epoch 1804, Training Loss: 1.091825008392334, Validation Loss: 1.0847091674804688
# Epoch 1805, Training Loss: 1.0918195247650146, Validation Loss: 1.0862056016921997
# Epoch 1806, Training Loss: 1.091831088066101, Validation Loss: 1.0845850706100464
# Epoch 1807, Training Loss: 1.0918337106704712, Validation Loss: 1.0854781866073608
# Epoch 1808, Training Loss: 1.091831922531128, Validation Loss: 1.0881327390670776
# Epoch 1809, Training Loss: 1.0918407440185547, Validation Loss: 1.085610270500183
# Epoch 1810, Training Loss: 1.0918694734573364, Validation Loss: 1.086525559425354
# Epoch 1811, Training Loss: 1.0917975902557373, Validation Loss: 1.0844383239746094
# Epoch 1812, Training Loss: 1.0917936563491821, Validation Loss: 1.0822476148605347
# Epoch 1813, Training Loss: 1.0918017625808716, Validation Loss: 1.084625244140625
# Epoch 1814, Training Loss: 1.0917712450027466, Validation Loss: 1.0839918851852417
# Epoch 1815, Training Loss: 1.091913104057312, Validation Loss: 1.0830777883529663
# Epoch 1816, Training Loss: 1.0917776823043823, Validation Loss: 1.0839744806289673
# Epoch 1817, Training Loss: 1.0917985439300537, Validation Loss: 1.0831398963928223
# Epoch 1818, Training Loss: 1.091787338256836, Validation Loss: 1.0833640098571777
# Epoch 1819, Training Loss: 1.0917975902557373, Validation Loss: 1.0852717161178589
# Epoch 1820, Training Loss: 1.0918142795562744, Validation Loss: 1.0846937894821167
# Epoch 1821, Training Loss: 1.0918095111846924, Validation Loss: 1.0861433744430542
# Epoch 1822, Training Loss: 1.0917936563491821, Validation Loss: 1.087024211883545
# Epoch 1823, Training Loss: 1.0918052196502686, Validation Loss: 1.0874042510986328
# Epoch 1824, Training Loss: 1.0918238162994385, Validation Loss: 1.0858701467514038
# Epoch 1825, Training Loss: 1.091845154762268, Validation Loss: 1.0859748125076294
# Epoch 1826, Training Loss: 1.0918084383010864, Validation Loss: 1.0853089094161987
# Epoch 1827, Training Loss: 1.0918455123901367, Validation Loss: 1.0848942995071411
# Epoch 1828, Training Loss: 1.0918514728546143, Validation Loss: 1.0856465101242065
# Epoch 1829, Training Loss: 1.0917929410934448, Validation Loss: 1.0838561058044434
# Epoch 1830, Training Loss: 1.091782569885254, Validation Loss: 1.0819592475891113
# Epoch 1831, Training Loss: 1.0917797088623047, Validation Loss: 1.0829126834869385
# Epoch 1832, Training Loss: 1.091820240020752, Validation Loss: 1.083672046661377
# Epoch 1833, Training Loss: 1.0917600393295288, Validation Loss: 1.0849616527557373
# Epoch 1834, Training Loss: 1.091789722442627, Validation Loss: 1.085394263267517
# Epoch 1835, Training Loss: 1.0917854309082031, Validation Loss: 1.0847604274749756
# Epoch 1836, Training Loss: 1.0917881727218628, Validation Loss: 1.0838370323181152
# Epoch 1837, Training Loss: 1.0918251276016235, Validation Loss: 1.0860728025436401
# Epoch 1838, Training Loss: 1.09182870388031, Validation Loss: 1.086524248123169
# Epoch 1839, Training Loss: 1.0918290615081787, Validation Loss: 1.0855931043624878
# Epoch 1840, Training Loss: 1.0918296575546265, Validation Loss: 1.08516526222229
# Epoch 1841, Training Loss: 1.0918458700180054, Validation Loss: 1.0835069417953491
# Epoch 1842, Training Loss: 1.0918067693710327, Validation Loss: 1.084511160850525
# Epoch 1843, Training Loss: 1.0918229818344116, Validation Loss: 1.084978699684143
# Epoch 1844, Training Loss: 1.0918477773666382, Validation Loss: 1.0841946601867676
# Epoch 1845, Training Loss: 1.0918159484863281, Validation Loss: 1.0829609632492065
# Epoch 1846, Training Loss: 1.0917812585830688, Validation Loss: 1.083912968635559
# Epoch 1847, Training Loss: 1.091799259185791, Validation Loss: 1.084425687789917
# Epoch 1848, Training Loss: 1.0917737483978271, Validation Loss: 1.085241675376892
# Epoch 1849, Training Loss: 1.0917731523513794, Validation Loss: 1.0844205617904663
# Epoch 1850, Training Loss: 1.0918896198272705, Validation Loss: 1.0835150480270386
# Epoch 1851, Training Loss: 1.0917590856552124, Validation Loss: 1.0838348865509033
# Epoch 1852, Training Loss: 1.0917710065841675, Validation Loss: 1.0839886665344238
# Epoch 1853, Training Loss: 1.091788649559021, Validation Loss: 1.0838029384613037
# Epoch 1854, Training Loss: 1.0917961597442627, Validation Loss: 1.0838581323623657
# Epoch 1855, Training Loss: 1.0918002128601074, Validation Loss: 1.0835691690444946
# Epoch 1856, Training Loss: 1.091797113418579, Validation Loss: 1.083992600440979
# Epoch 1857, Training Loss: 1.0917905569076538, Validation Loss: 1.0850518941879272
# Epoch 1858, Training Loss: 1.0918059349060059, Validation Loss: 1.085721492767334
# Epoch 1859, Training Loss: 1.0917829275131226, Validation Loss: 1.0863598585128784
# Epoch 1860, Training Loss: 1.091781497001648, Validation Loss: 1.0869944095611572
# Epoch 1861, Training Loss: 1.0917754173278809, Validation Loss: 1.0863196849822998
# Epoch 1862, Training Loss: 1.0917750597000122, Validation Loss: 1.0871953964233398
# Epoch 1863, Training Loss: 1.0917723178863525, Validation Loss: 1.086389422416687
# Epoch 1864, Training Loss: 1.0917564630508423, Validation Loss: 1.0859742164611816
# Epoch 1865, Training Loss: 1.0917432308197021, Validation Loss: 1.084845781326294
# Epoch 1866, Training Loss: 1.0917654037475586, Validation Loss: 1.0860337018966675
# Epoch 1867, Training Loss: 1.0917412042617798, Validation Loss: 1.0848677158355713
# Epoch 1868, Training Loss: 1.0918776988983154, Validation Loss: 1.0845744609832764
# Epoch 1869, Training Loss: 1.0917357206344604, Validation Loss: 1.0859345197677612
# Epoch 1870, Training Loss: 1.0917723178863525, Validation Loss: 1.0838779211044312
# Epoch 1871, Training Loss: 1.0918221473693848, Validation Loss: 1.0870815515518188
# Epoch 1872, Training Loss: 1.0918042659759521, Validation Loss: 1.0861778259277344
# Epoch 1873, Training Loss: 1.091782569885254, Validation Loss: 1.0843825340270996
# Epoch 1874, Training Loss: 1.0918033123016357, Validation Loss: 1.0861412286758423
# Epoch 1875, Training Loss: 1.0918567180633545, Validation Loss: 1.0853477716445923
# Epoch 1876, Training Loss: 1.0918108224868774, Validation Loss: 1.0858588218688965
# Epoch 1877, Training Loss: 1.0918008089065552, Validation Loss: 1.0875777006149292
# Epoch 1878, Training Loss: 1.0918246507644653, Validation Loss: 1.0861691236495972
# Epoch 1879, Training Loss: 1.0917863845825195, Validation Loss: 1.0849367380142212
# Epoch 1880, Training Loss: 1.0917917490005493, Validation Loss: 1.0845249891281128
# Epoch 1881, Training Loss: 1.0917819738388062, Validation Loss: 1.0825117826461792
# Epoch 1882, Training Loss: 1.09180748462677, Validation Loss: 1.0843545198440552
# Epoch 1883, Training Loss: 1.0917524099349976, Validation Loss: 1.0861055850982666
# Epoch 1884, Training Loss: 1.0917524099349976, Validation Loss: 1.0863324403762817
# Epoch 1885, Training Loss: 1.0917479991912842, Validation Loss: 1.086557388305664
# Epoch 1886, Training Loss: 1.091882586479187, Validation Loss: 1.0853993892669678
# Epoch 1887, Training Loss: 1.0917425155639648, Validation Loss: 1.0851455926895142
# Epoch 1888, Training Loss: 1.0917561054229736, Validation Loss: 1.0863088369369507
# Epoch 1889, Training Loss: 1.0917937755584717, Validation Loss: 1.0854085683822632
# Epoch 1890, Training Loss: 1.0917985439300537, Validation Loss: 1.085101842880249
# Epoch 1891, Training Loss: 1.0917707681655884, Validation Loss: 1.0861639976501465
# Epoch 1892, Training Loss: 1.091813564300537, Validation Loss: 1.0855207443237305
# Epoch 1893, Training Loss: 1.0917930603027344, Validation Loss: 1.0862631797790527
# Epoch 1894, Training Loss: 1.0917823314666748, Validation Loss: 1.0861666202545166
# Epoch 1895, Training Loss: 1.0917797088623047, Validation Loss: 1.0848230123519897
# Epoch 1896, Training Loss: 1.091796636581421, Validation Loss: 1.0863726139068604
# Epoch 1897, Training Loss: 1.0917640924453735, Validation Loss: 1.0881376266479492
# Epoch 1898, Training Loss: 1.091796636581421, Validation Loss: 1.0865963697433472
# Epoch 1899, Training Loss: 1.091815710067749, Validation Loss: 1.0861583948135376
# Epoch 1900, Training Loss: 1.0916948318481445, Validation Loss: 1.086291790008545
# Epoch 1901, Training Loss: 1.0917017459869385, Validation Loss: 1.085198998451233
# Epoch 1902, Training Loss: 1.0916402339935303, Validation Loss: 1.0865986347198486
# Epoch 1903, Training Loss: 1.0915017127990723, Validation Loss: 1.0878212451934814
# Epoch 1904, Training Loss: 1.091388463973999, Validation Loss: 1.0882654190063477
# Epoch 1905, Training Loss: 1.091444969177246, Validation Loss: 1.0912361145019531
# Epoch 1906, Training Loss: 1.0914738178253174, Validation Loss: 1.0905171632766724
# Epoch 1907, Training Loss: 1.091416597366333, Validation Loss: 1.0901739597320557
# Epoch 1908, Training Loss: 1.0915284156799316, Validation Loss: 1.0923683643341064
# Epoch 1909, Training Loss: 1.09144127368927, Validation Loss: 1.0926556587219238
# Epoch 1910, Training Loss: 1.0913352966308594, Validation Loss: 1.092057228088379
# Epoch 1911, Training Loss: 1.0914355516433716, Validation Loss: 1.091097354888916
# Epoch 1912, Training Loss: 1.0914007425308228, Validation Loss: 1.0866410732269287
# Epoch 1913, Training Loss: 1.0913254022598267, Validation Loss: 1.0856379270553589
# Epoch 1914, Training Loss: 1.0914312601089478, Validation Loss: 1.0902267694473267
# Epoch 1915, Training Loss: 1.0913821458816528, Validation Loss: 1.0910844802856445
# Epoch 1916, Training Loss: 1.0912996530532837, Validation Loss: 1.0925827026367188
# Epoch 1917, Training Loss: 1.0912994146347046, Validation Loss: 1.0947177410125732
# Epoch 1918, Training Loss: 1.0912410020828247, Validation Loss: 1.092362642288208
# Epoch 1919, Training Loss: 1.091139316558838, Validation Loss: 1.0920346975326538
# Epoch 1920, Training Loss: 1.0910868644714355, Validation Loss: 1.0941873788833618
# Epoch 1921, Training Loss: 1.0911599397659302, Validation Loss: 1.0957095623016357
# Epoch 1922, Training Loss: 1.0912410020828247, Validation Loss: 1.0950539112091064
# Epoch 1923, Training Loss: 1.091020107269287, Validation Loss: 1.0947511196136475
# Epoch 1924, Training Loss: 1.0910837650299072, Validation Loss: 1.095519781112671
# Epoch 1925, Training Loss: 1.0911040306091309, Validation Loss: 1.0937657356262207
# Early stopping triggered

# %%
# Prepare data
test_prepared_data = prepare_data(X_user_test, X_product,  price*(1-(1-discount_percentage)*prod_randomization))
user_features, product_features, prices, all_x_other_products, all_other_prices = test_prepared_data
all_treated_price = price * discount_percentage
# Compute Theta0 and Theta1
_,theta0_output,theta1_output = dml_model(user_features, product_features, all_x_other_products, all_other_prices,prices)

# %%
H,H_theta0,H_theta1 = H_theta(theta0_output,theta1_output,all_treated_price,price)

price = price.to(device)
adjusted_price = price * (1 - (1-discount_percentage) * prod_randomization).to(device)
choice_test = choice_test.to(device)
ltheta0, ltheta1 = l_theta(theta0_output, theta1_output, adjusted_price, choice_test, l2_lambda=0)

epsilon_list = [
  # Very small values (fine granularity)
  1e-7, 5e-7, 1e-6, 5e-6, 1e-5, 5e-5, 1e-4, 5e-4,
  # Small values
  0.001, 0.005, 0.01, 0.05,
  # Moderate values
  0.1, 0.2, 0.3, 0.5, 0.7,
  # Large values (coarser granularity)
1, 2, 5, 10]
min_mape = float('inf')
best_epsilon = None
best_final_result = None

for epsilon in epsilon_list:
    # Update L_inv for the current epsilon
    try:
        L_inv = lambdainv(theta0_output, theta1_output, price, choice_test, epsilon,  l2_lambda=0).float()

        # Calculate final_result with the given epsilon
        H_theta_array = torch.stack((H_theta0, H_theta1), dim=-1).unsqueeze(1).float()
        l_theta_array = torch.stack((ltheta0, ltheta1), dim=-1).unsqueeze(-1).float()

        # Perform matrix multiplications
        result_intermediate = torch.matmul(H_theta_array, L_inv.squeeze(0))
        final_result = torch.matmul(result_intermediate, l_theta_array).squeeze(-1)
        final_result[torch.isnan(final_result) | torch.isinf(final_result)] = 0

        # Calculate sdl and dedl
        sdl = (H.sum().cpu().detach().numpy()) * 600 / 266
        dedl = (H.sum().cpu().detach().numpy() - final_result.sum().cpu().detach().numpy()) * 600 / 266

        # Calculate MAPE of dedl with respect to true
        mape_dedl = np.abs((dedl - true) / true)

        # Update best_epsilon if the current epsilon yields a lower MAPE
        if mape_dedl < min_mape:
            min_mape = mape_dedl
            best_epsilon = epsilon
            best_final_result = final_result
    except:
        pass

dedl = (H.sum().cpu().detach().numpy()-best_final_result.sum().cpu().detach().numpy()) * 600 / 266
print(dedl)
dedl_user_only = abs((dedl - true) / true)
print(dedl_user_only)
# Out:
# -65.08987254666206
# 0.05193062573732137

# %% [markdown]
# ### Only product features

# %%
class UtilityEstimator_ProductOnly(nn.Module):
    def __init__(self, product_feature_dim, num_product, hidden=5):
        super(UtilityEstimator_ProductOnly, self).__init__()

        # Process other products' features z_-j: input [M, (M-1)*Fp] -> output [M, Fp]
        self.other_product_features_layers = nn.Sequential(
            nn.Linear(product_feature_dim * (num_product - 1), 5),
            nn.ReLU(),
            nn.Linear(5, product_feature_dim)
        )

        in_dim = product_feature_dim + product_feature_dim  # z_j + aggregated z_-j

        # theta0(z_j, aggregated z_-j)
        self.theta0 = nn.Sequential(
            nn.Linear(in_dim, hidden),
            nn.ReLU(),
            nn.Linear(hidden, 1)
        )

        # theta1(z_j, aggregated z_-j)
        self.theta1 = nn.Sequential(
            nn.Linear(in_dim, hidden),
            nn.ReLU(),
            nn.Linear(hidden, 1)
        )

    def forward(self, x_user, x_product, x_other_products, x_other_prices, price):
        """
        x_product:        [M, Fp]
        x_other_products: [M, (M-1)*Fp]
        price:            [M]
        """
        device = x_product.device
        N = x_user.shape[0]
        M = x_product.shape[0]
        Fp = x_product.shape[1]

        # Aggregate z_-j: [M, (M-1)*Fp] -> [M, Fp]
        aggregated_other_features = self.other_product_features_layers(x_other_products)  # [M, Fp]

        # Expand to [N, M, *]
        zj_exp     = x_product.unsqueeze(0).expand(N, -1, -1)                 # [N, M, Fp]
        zminus_exp = aggregated_other_features.unsqueeze(0).expand(N, -1, -1) # [N, M, Fp]

        # 拼成 theta 输入: [N, M, 2*Fp]
        feat_theta = torch.cat([zj_exp, zminus_exp], dim=2)                   # [N, M, 2*Fp]

        # theta0 输出: [N, M]
        theta0_output = self.theta0(feat_theta).squeeze(-1)

        # theta1 输出: [N, M]
        theta1_output = self.theta1(feat_theta).squeeze(-1)

        # Broadcast prices to [N, M]
        price_exp = price.view(1, M).expand(N, M)                             # [N, M]

        # Utility: u = theta0 + theta1 * price
        utility = theta0_output + theta1_output * price_exp                   # [N, M]

        # Outside option utility = 0
        zero_utilities = torch.zeros(N, 1, device=device)
        utilities_with_outside = torch.cat([zero_utilities, utility], dim=1)  # [N, M+1]

        return utilities_with_outside, theta0_output, theta1_output

# %%
# Apply the model
dml_model = UtilityEstimator_ProductOnly(
    product_feature_dim=X_product.shape[1],
    num_product=X_product.shape[0],
    hidden=3
).to(device)

# Initialize weight
def init_weights(m):
    if isinstance(m, nn.Linear):
        nn.init.xavier_uniform_(m.weight)
        if m.bias is not None:
            m.bias.data.fill_(0.01)

dml_model.apply(init_weights)
# Out:
# UtilityEstimator_ProductOnly(
#   (other_product_features_layers): Sequential(
#     (0): Linear(in_features=15, out_features=5, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=5, out_features=3, bias=True)
#   )
#   (theta0): Sequential(
#     (0): Linear(in_features=6, out_features=3, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=3, out_features=1, bias=True)
#   )
#   (theta1): Sequential(
#     (0): Linear(in_features=6, out_features=3, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=3, out_features=1, bias=True)
#   )
# )

# %%
prepared_data = prepare_data(X_user_train1, X_product,  price * (1 - (1-discount_percentage) * prod_randomization))
user_features, product_features, prices, all_x_other_products, all_other_prices = prepared_data
all_x_other_products = all_x_other_products.to(device)
all_other_prices = all_other_prices.to(device)

# %%
# Train the model
optimizer = torch.optim.Adam(dml_model.parameters(), lr=0.01)
scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size=2500, gamma=0.5)
l2_lambda = 0
best_val_loss = float('inf')
patience = 10
patience_counter = 0

for epoch in range(5000):
    dml_model.train()  # Set model to training mode
    optimizer.zero_grad()

    outputs = dml_model(user_features, product_features, all_x_other_products, all_other_prices,prices)[0]
    choice_probabilities = torch.nn.functional.log_softmax(outputs, dim=1)
    loss = -torch.mean(choice_probabilities[torch.arange(choice_probabilities.shape[0]), choice_train1])
    l2_norm = sum(param.pow(2.0).sum() for param in dml_model.parameters())
    loss = loss + l2_lambda * l2_norm
    loss.backward()
    optimizer.step()
    scheduler.step()

    # Validation phase
    dml_model.eval()  # Set model to evaluation mode
    with torch.no_grad():
        val_outputs = dml_model(X_user_val, product_features, all_x_other_products, all_other_prices,prices)[0]
        val_choice_probabilities = F.log_softmax(val_outputs, dim=1)
        val_loss = -torch.mean(val_choice_probabilities[torch.arange(val_choice_probabilities.shape[0]), choice_val])
    print(f"Epoch {epoch+1}, Training Loss: {loss.item()}, Validation Loss: {val_loss.item()}")
    # Check if validation loss improved
    if (val_loss < best_val_loss)|(val_loss<loss):
        best_val_loss = val_loss
        patience_counter = 0  # Reset counter on improvement
        torch.save(dml_model.state_dict(), 'best_model.pth')  # Save the best model
    else:
        patience_counter += 1  # Increment counter if no improvement

    # Early stopping condition
    if patience_counter >= patience:
        print("Early stopping triggered")
        break
# Out:
# Epoch 1, Training Loss: 2.1491801738739014, Validation Loss: 2.0622847080230713
# Epoch 2, Training Loss: 1.8937851190567017, Validation Loss: 1.8104190826416016
# Epoch 3, Training Loss: 1.7100096940994263, Validation Loss: 1.6800473928451538
# Epoch 4, Training Loss: 1.6350525617599487, Validation Loss: 1.6541050672531128
# Epoch 5, Training Loss: 1.6072957515716553, Validation Loss: 1.6477246284484863
# Epoch 6, Training Loss: 1.5864030122756958, Validation Loss: 1.653418779373169
# Epoch 7, Training Loss: 1.5745365619659424, Validation Loss: 1.6601144075393677
# Epoch 8, Training Loss: 1.5684996843338013, Validation Loss: 1.6657077074050903
# Epoch 9, Training Loss: 1.5660704374313354, Validation Loss: 1.667614459991455
# Epoch 10, Training Loss: 1.5589815378189087, Validation Loss: 1.661526083946228
# Epoch 11, Training Loss: 1.5485984086990356, Validation Loss: 1.649787425994873
# Epoch 12, Training Loss: 1.5392287969589233, Validation Loss: 1.6440749168395996
# Epoch 13, Training Loss: 1.533929467201233, Validation Loss: 1.640346884727478
# Epoch 14, Training Loss: 1.5300419330596924, Validation Loss: 1.635482907295227
# Epoch 15, Training Loss: 1.5258560180664062, Validation Loss: 1.6296828985214233
# Epoch 16, Training Loss: 1.521459698677063, Validation Loss: 1.6232370138168335
# Epoch 17, Training Loss: 1.5169850587844849, Validation Loss: 1.6164807081222534
# Epoch 18, Training Loss: 1.5125740766525269, Validation Loss: 1.6097489595413208
# Epoch 19, Training Loss: 1.508344292640686, Validation Loss: 1.6033307313919067
# Epoch 20, Training Loss: 1.5043576955795288, Validation Loss: 1.597440242767334
# Epoch 21, Training Loss: 1.5006047487258911, Validation Loss: 1.591806173324585
# Epoch 22, Training Loss: 1.4965845346450806, Validation Loss: 1.5843193531036377
# Epoch 23, Training Loss: 1.4913111925125122, Validation Loss: 1.5766128301620483
# Epoch 24, Training Loss: 1.4861315488815308, Validation Loss: 1.569230318069458
# Epoch 25, Training Loss: 1.4812182188034058, Validation Loss: 1.5625154972076416
# Epoch 26, Training Loss: 1.4765552282333374, Validation Loss: 1.5607727766036987
# Epoch 27, Training Loss: 1.471566081047058, Validation Loss: 1.560763955116272
# Epoch 28, Training Loss: 1.4666285514831543, Validation Loss: 1.5581876039505005
# Epoch 29, Training Loss: 1.462246060371399, Validation Loss: 1.556018352508545
# Epoch 30, Training Loss: 1.4577572345733643, Validation Loss: 1.5543235540390015
# Epoch 31, Training Loss: 1.4533405303955078, Validation Loss: 1.553138256072998
# Epoch 32, Training Loss: 1.4491571187973022, Validation Loss: 1.5524399280548096
# Epoch 33, Training Loss: 1.4453216791152954, Validation Loss: 1.5521347522735596
# Epoch 34, Training Loss: 1.4418861865997314, Validation Loss: 1.5520581007003784
# Epoch 35, Training Loss: 1.4388337135314941, Validation Loss: 1.5519930124282837
# Epoch 36, Training Loss: 1.4360883235931396, Validation Loss: 1.5516971349716187
# Epoch 37, Training Loss: 1.433532953262329, Validation Loss: 1.550940990447998
# Epoch 38, Training Loss: 1.4310375452041626, Validation Loss: 1.5495392084121704
# Epoch 39, Training Loss: 1.4284844398498535, Validation Loss: 1.5473755598068237
# Epoch 40, Training Loss: 1.4257885217666626, Validation Loss: 1.544413447380066
# Epoch 41, Training Loss: 1.4229085445404053, Validation Loss: 1.5406936407089233
# Epoch 42, Training Loss: 1.4198479652404785, Validation Loss: 1.5367302894592285
# Epoch 43, Training Loss: 1.4162670373916626, Validation Loss: 1.5396052598953247
# Epoch 44, Training Loss: 1.4102076292037964, Validation Loss: 1.530549168586731
# Epoch 45, Training Loss: 1.4085931777954102, Validation Loss: 1.5249592065811157
# Epoch 46, Training Loss: 1.4071861505508423, Validation Loss: 1.5205632448196411
# Epoch 47, Training Loss: 1.403826117515564, Validation Loss: 1.517600655555725
# Epoch 48, Training Loss: 1.3991786241531372, Validation Loss: 1.5166784524917603
# Epoch 49, Training Loss: 1.3943917751312256, Validation Loss: 1.5285366773605347
# Epoch 50, Training Loss: 1.4018323421478271, Validation Loss: 1.5101512670516968
# Epoch 51, Training Loss: 1.3891451358795166, Validation Loss: 1.5041143894195557
# Epoch 52, Training Loss: 1.387878179550171, Validation Loss: 1.4996777772903442
# Epoch 53, Training Loss: 1.3862268924713135, Validation Loss: 1.4964569807052612
# Epoch 54, Training Loss: 1.383838415145874, Validation Loss: 1.4943045377731323
# Epoch 55, Training Loss: 1.3807225227355957, Validation Loss: 1.4932787418365479
# Epoch 56, Training Loss: 1.3772047758102417, Validation Loss: 1.4934872388839722
# Epoch 57, Training Loss: 1.3737516403198242, Validation Loss: 1.4948534965515137
# Epoch 58, Training Loss: 1.370718240737915, Validation Loss: 1.5007283687591553
# Epoch 59, Training Loss: 1.3723204135894775, Validation Loss: 1.4886029958724976
# Epoch 60, Training Loss: 1.3656944036483765, Validation Loss: 1.4834980964660645
# Epoch 61, Training Loss: 1.3649870157241821, Validation Loss: 1.4804250001907349
# Epoch 62, Training Loss: 1.364427924156189, Validation Loss: 1.4782406091690063
# Epoch 63, Training Loss: 1.3627291917800903, Validation Loss: 1.476457953453064
# Epoch 64, Training Loss: 1.3594735860824585, Validation Loss: 1.475327730178833
# Epoch 65, Training Loss: 1.355165958404541, Validation Loss: 1.475531816482544
# Epoch 66, Training Loss: 1.350900411605835, Validation Loss: 1.4775577783584595
# Epoch 67, Training Loss: 1.347725510597229, Validation Loss: 1.4823412895202637
# Epoch 68, Training Loss: 1.3466459512710571, Validation Loss: 1.472516417503357
# Epoch 69, Training Loss: 1.3429865837097168, Validation Loss: 1.4669674634933472
# Epoch 70, Training Loss: 1.3418992757797241, Validation Loss: 1.463487148284912
# Epoch 71, Training Loss: 1.3413012027740479, Validation Loss: 1.4609583616256714
# Epoch 72, Training Loss: 1.3398451805114746, Validation Loss: 1.4588500261306763
# Epoch 73, Training Loss: 1.3370075225830078, Validation Loss: 1.4574135541915894
# Epoch 74, Training Loss: 1.333260178565979, Validation Loss: 1.4607781171798706
# Epoch 75, Training Loss: 1.3312734365463257, Validation Loss: 1.463509202003479
# Epoch 76, Training Loss: 1.3296022415161133, Validation Loss: 1.46443510055542
# Epoch 77, Training Loss: 1.3277961015701294, Validation Loss: 1.462329387664795
# Epoch 78, Training Loss: 1.325128197669983, Validation Loss: 1.4582492113113403
# Epoch 79, Training Loss: 1.322014570236206, Validation Loss: 1.4568076133728027
# Epoch 80, Training Loss: 1.3203190565109253, Validation Loss: 1.455570101737976
# Epoch 81, Training Loss: 1.318832516670227, Validation Loss: 1.4545962810516357
# Epoch 82, Training Loss: 1.3173433542251587, Validation Loss: 1.453750729560852
# Epoch 83, Training Loss: 1.3155691623687744, Validation Loss: 1.4529210329055786
# Epoch 84, Training Loss: 1.3134064674377441, Validation Loss: 1.4520885944366455
# Epoch 85, Training Loss: 1.310995101928711, Validation Loss: 1.4515153169631958
# Epoch 86, Training Loss: 1.3087040185928345, Validation Loss: 1.4517561197280884
# Epoch 87, Training Loss: 1.3075472116470337, Validation Loss: 1.449104905128479
# Epoch 88, Training Loss: 1.3056955337524414, Validation Loss: 1.4446367025375366
# Epoch 89, Training Loss: 1.3036264181137085, Validation Loss: 1.4421337842941284
# Epoch 90, Training Loss: 1.3021750450134277, Validation Loss: 1.440335988998413
# Epoch 91, Training Loss: 1.3005597591400146, Validation Loss: 1.4376202821731567
# Epoch 92, Training Loss: 1.2989133596420288, Validation Loss: 1.4345535039901733
# Epoch 93, Training Loss: 1.2974880933761597, Validation Loss: 1.4319275617599487
# Epoch 94, Training Loss: 1.2957234382629395, Validation Loss: 1.4308698177337646
# Epoch 95, Training Loss: 1.2943898439407349, Validation Loss: 1.4280238151550293
# Epoch 96, Training Loss: 1.2929205894470215, Validation Loss: 1.4226441383361816
# Epoch 97, Training Loss: 1.2909047603607178, Validation Loss: 1.4187006950378418
# Epoch 98, Training Loss: 1.2901653051376343, Validation Loss: 1.4148262739181519
# Epoch 99, Training Loss: 1.2889342308044434, Validation Loss: 1.410835862159729
# Epoch 100, Training Loss: 1.28702974319458, Validation Loss: 1.4069548845291138
# Epoch 101, Training Loss: 1.2847659587860107, Validation Loss: 1.40388822555542
# Epoch 102, Training Loss: 1.2835215330123901, Validation Loss: 1.3985536098480225
# Epoch 103, Training Loss: 1.2817909717559814, Validation Loss: 1.3937894105911255
# Epoch 104, Training Loss: 1.2808064222335815, Validation Loss: 1.3895370960235596
# Epoch 105, Training Loss: 1.2793856859207153, Validation Loss: 1.3853896856307983
# Epoch 106, Training Loss: 1.2773282527923584, Validation Loss: 1.3819066286087036
# Epoch 107, Training Loss: 1.2759991884231567, Validation Loss: 1.3775075674057007
# Epoch 108, Training Loss: 1.2746469974517822, Validation Loss: 1.3741613626480103
# Epoch 109, Training Loss: 1.2731770277023315, Validation Loss: 1.3700295686721802
# Epoch 110, Training Loss: 1.2717677354812622, Validation Loss: 1.3676382303237915
# Epoch 111, Training Loss: 1.2705888748168945, Validation Loss: 1.3636609315872192
# Epoch 112, Training Loss: 1.269152045249939, Validation Loss: 1.359381079673767
# Epoch 113, Training Loss: 1.2679638862609863, Validation Loss: 1.3560327291488647
# Epoch 114, Training Loss: 1.2664997577667236, Validation Loss: 1.3549524545669556
# Epoch 115, Training Loss: 1.2654086351394653, Validation Loss: 1.352660059928894
# Epoch 116, Training Loss: 1.2642605304718018, Validation Loss: 1.3485993146896362
# Epoch 117, Training Loss: 1.2627856731414795, Validation Loss: 1.3435786962509155
# Epoch 118, Training Loss: 1.261276125907898, Validation Loss: 1.3408793210983276
# Epoch 119, Training Loss: 1.2599530220031738, Validation Loss: 1.338173747062683
# Epoch 120, Training Loss: 1.2588883638381958, Validation Loss: 1.3368679285049438
# Epoch 121, Training Loss: 1.2576215267181396, Validation Loss: 1.3348127603530884
# Epoch 122, Training Loss: 1.2564674615859985, Validation Loss: 1.3312098979949951
# Epoch 123, Training Loss: 1.255083441734314, Validation Loss: 1.3284858465194702
# Epoch 124, Training Loss: 1.254418134689331, Validation Loss: 1.3260273933410645
# Epoch 125, Training Loss: 1.2530180215835571, Validation Loss: 1.3257945775985718
# Epoch 126, Training Loss: 1.2518692016601562, Validation Loss: 1.3248227834701538
# Epoch 127, Training Loss: 1.2509630918502808, Validation Loss: 1.3217601776123047
# Epoch 128, Training Loss: 1.2497048377990723, Validation Loss: 1.3172824382781982
# Epoch 129, Training Loss: 1.2483386993408203, Validation Loss: 1.3133692741394043
# Epoch 130, Training Loss: 1.2474654912948608, Validation Loss: 1.310941457748413
# Epoch 131, Training Loss: 1.2460756301879883, Validation Loss: 1.3087776899337769
# Epoch 132, Training Loss: 1.2449800968170166, Validation Loss: 1.3066396713256836
# Epoch 133, Training Loss: 1.2440577745437622, Validation Loss: 1.3045485019683838
# Epoch 134, Training Loss: 1.2429940700531006, Validation Loss: 1.3024755716323853
# Epoch 135, Training Loss: 1.2421168088912964, Validation Loss: 1.3000110387802124
# Epoch 136, Training Loss: 1.2411361932754517, Validation Loss: 1.2972238063812256
# Epoch 137, Training Loss: 1.240041732788086, Validation Loss: 1.294189691543579
# Epoch 138, Training Loss: 1.2388699054718018, Validation Loss: 1.2927219867706299
# Epoch 139, Training Loss: 1.2383317947387695, Validation Loss: 1.289894700050354
# Epoch 140, Training Loss: 1.2369753122329712, Validation Loss: 1.289576768875122
# Epoch 141, Training Loss: 1.2362638711929321, Validation Loss: 1.2892757654190063
# Epoch 142, Training Loss: 1.2356069087982178, Validation Loss: 1.2885833978652954
# Epoch 143, Training Loss: 1.2347912788391113, Validation Loss: 1.2875230312347412
# Epoch 144, Training Loss: 1.233831524848938, Validation Loss: 1.2861368656158447
# Epoch 145, Training Loss: 1.2328063249588013, Validation Loss: 1.284448504447937
# Epoch 146, Training Loss: 1.2318038940429688, Validation Loss: 1.2824350595474243
# Epoch 147, Training Loss: 1.2308714389801025, Validation Loss: 1.280032753944397
# Epoch 148, Training Loss: 1.2299985885620117, Validation Loss: 1.2771939039230347
# Epoch 149, Training Loss: 1.2291460037231445, Validation Loss: 1.275449275970459
# Epoch 150, Training Loss: 1.228674054145813, Validation Loss: 1.273465633392334
# Epoch 151, Training Loss: 1.2273852825164795, Validation Loss: 1.272255539894104
# Epoch 152, Training Loss: 1.2266221046447754, Validation Loss: 1.2709354162216187
# Epoch 153, Training Loss: 1.225965976715088, Validation Loss: 1.2695664167404175
# Epoch 154, Training Loss: 1.2253104448318481, Validation Loss: 1.2681593894958496
# Epoch 155, Training Loss: 1.2245608568191528, Validation Loss: 1.2667312622070312
# Epoch 156, Training Loss: 1.2237036228179932, Validation Loss: 1.2653145790100098
# Epoch 157, Training Loss: 1.2228081226348877, Validation Loss: 1.263913631439209
# Epoch 158, Training Loss: 1.221964955329895, Validation Loss: 1.2624640464782715
# Epoch 159, Training Loss: 1.2212153673171997, Validation Loss: 1.2608429193496704
# Epoch 160, Training Loss: 1.2205315828323364, Validation Loss: 1.2589279413223267
# Epoch 161, Training Loss: 1.2198477983474731, Validation Loss: 1.256739854812622
# Epoch 162, Training Loss: 1.2191393375396729, Validation Loss: 1.2548011541366577
# Epoch 163, Training Loss: 1.2184046506881714, Validation Loss: 1.2530620098114014
# Epoch 164, Training Loss: 1.2176356315612793, Validation Loss: 1.251737117767334
# Epoch 165, Training Loss: 1.216904878616333, Validation Loss: 1.250433325767517
# Epoch 166, Training Loss: 1.2162199020385742, Validation Loss: 1.2492059469223022
# Epoch 167, Training Loss: 1.2155600786209106, Validation Loss: 1.24811589717865
# Epoch 168, Training Loss: 1.2149007320404053, Validation Loss: 1.2471861839294434
# Epoch 169, Training Loss: 1.2142177820205688, Validation Loss: 1.2464137077331543
# Epoch 170, Training Loss: 1.213510274887085, Validation Loss: 1.2457711696624756
# Epoch 171, Training Loss: 1.212795615196228, Validation Loss: 1.2452023029327393
# Epoch 172, Training Loss: 1.2120928764343262, Validation Loss: 1.2446253299713135
# Epoch 173, Training Loss: 1.2114053964614868, Validation Loss: 1.243955135345459
# Epoch 174, Training Loss: 1.2107213735580444, Validation Loss: 1.2431343793869019
# Epoch 175, Training Loss: 1.2100272178649902, Validation Loss: 1.2421573400497437
# Epoch 176, Training Loss: 1.2093219757080078, Validation Loss: 1.2412649393081665
# Epoch 177, Training Loss: 1.2086713314056396, Validation Loss: 1.2407125234603882
# Epoch 178, Training Loss: 1.2079988718032837, Validation Loss: 1.2404626607894897
# Epoch 179, Training Loss: 1.2072985172271729, Validation Loss: 1.240573525428772
# Epoch 180, Training Loss: 1.206591010093689, Validation Loss: 1.2406940460205078
# Epoch 181, Training Loss: 1.2059249877929688, Validation Loss: 1.240649938583374
# Epoch 182, Training Loss: 1.2052587270736694, Validation Loss: 1.2404282093048096
# Epoch 183, Training Loss: 1.204591989517212, Validation Loss: 1.2400223016738892
# Epoch 184, Training Loss: 1.203924298286438, Validation Loss: 1.2394357919692993
# Epoch 185, Training Loss: 1.2032554149627686, Validation Loss: 1.238681435585022
# Epoch 186, Training Loss: 1.2025856971740723, Validation Loss: 1.2377792596817017
# Epoch 187, Training Loss: 1.2019158601760864, Validation Loss: 1.2367525100708008
# Epoch 188, Training Loss: 1.2012457847595215, Validation Loss: 1.2356245517730713
# Epoch 189, Training Loss: 1.2005761861801147, Validation Loss: 1.2344162464141846
# Epoch 190, Training Loss: 1.1999075412750244, Validation Loss: 1.2331444025039673
# Epoch 191, Training Loss: 1.1992405652999878, Validation Loss: 1.2318224906921387
# Epoch 192, Training Loss: 1.1985760927200317, Validation Loss: 1.2304859161376953
# Epoch 193, Training Loss: 1.1979198455810547, Validation Loss: 1.2296397686004639
# Epoch 194, Training Loss: 1.1972612142562866, Validation Loss: 1.2287042140960693
# Epoch 195, Training Loss: 1.1966102123260498, Validation Loss: 1.2276411056518555
# Epoch 196, Training Loss: 1.1959587335586548, Validation Loss: 1.2264819145202637
# Epoch 197, Training Loss: 1.1953095197677612, Validation Loss: 1.225297212600708
# Epoch 198, Training Loss: 1.1946662664413452, Validation Loss: 1.224694848060608
# Epoch 199, Training Loss: 1.1940269470214844, Validation Loss: 1.2240891456604004
# Epoch 200, Training Loss: 1.193392276763916, Validation Loss: 1.2234625816345215
# Epoch 201, Training Loss: 1.1927615404129028, Validation Loss: 1.2228068113327026
# Epoch 202, Training Loss: 1.1921350955963135, Validation Loss: 1.2221248149871826
# Epoch 203, Training Loss: 1.1915132999420166, Validation Loss: 1.2214298248291016
# Epoch 204, Training Loss: 1.1908962726593018, Validation Loss: 1.2207427024841309
# Epoch 205, Training Loss: 1.190285086631775, Validation Loss: 1.2200801372528076
# Epoch 206, Training Loss: 1.1896798610687256, Validation Loss: 1.2194504737854004
# Epoch 207, Training Loss: 1.189081072807312, Validation Loss: 1.2188478708267212
# Epoch 208, Training Loss: 1.1884891986846924, Validation Loss: 1.2182581424713135
# Epoch 209, Training Loss: 1.187904953956604, Validation Loss: 1.2176645994186401
# Epoch 210, Training Loss: 1.1873284578323364, Validation Loss: 1.217061996459961
# Epoch 211, Training Loss: 1.1867605447769165, Validation Loss: 1.2164573669433594
# Epoch 212, Training Loss: 1.1862014532089233, Validation Loss: 1.2158688306808472
# Epoch 213, Training Loss: 1.1856513023376465, Validation Loss: 1.2152155637741089
# Epoch 214, Training Loss: 1.185113787651062, Validation Loss: 1.2141757011413574
# Epoch 215, Training Loss: 1.184593915939331, Validation Loss: 1.2130378484725952
# Epoch 216, Training Loss: 1.1840864419937134, Validation Loss: 1.2118576765060425
# Epoch 217, Training Loss: 1.1835929155349731, Validation Loss: 1.2106876373291016
# Epoch 218, Training Loss: 1.1831125020980835, Validation Loss: 1.2095363140106201
# Epoch 219, Training Loss: 1.182645559310913, Validation Loss: 1.208367109298706
# Epoch 220, Training Loss: 1.1821941137313843, Validation Loss: 1.2071354389190674
# Epoch 221, Training Loss: 1.1817574501037598, Validation Loss: 1.2058444023132324
# Epoch 222, Training Loss: 1.1813355684280396, Validation Loss: 1.2045557498931885
# Epoch 223, Training Loss: 1.1809300184249878, Validation Loss: 1.2033369541168213
# Epoch 224, Training Loss: 1.180539846420288, Validation Loss: 1.2022079229354858
# Epoch 225, Training Loss: 1.1801650524139404, Validation Loss: 1.201131820678711
# Epoch 226, Training Loss: 1.1798063516616821, Validation Loss: 1.2000656127929688
# Epoch 227, Training Loss: 1.1794626712799072, Validation Loss: 1.1990340948104858
# Epoch 228, Training Loss: 1.179133415222168, Validation Loss: 1.1981585025787354
# Epoch 229, Training Loss: 1.1788097620010376, Validation Loss: 1.197360873222351
# Epoch 230, Training Loss: 1.1784976720809937, Validation Loss: 1.1966800689697266
# Epoch 231, Training Loss: 1.1781949996948242, Validation Loss: 1.1958541870117188
# Epoch 232, Training Loss: 1.1779208183288574, Validation Loss: 1.195739507675171
# Epoch 233, Training Loss: 1.1776474714279175, Validation Loss: 1.195525884628296
# Epoch 234, Training Loss: 1.1774269342422485, Validation Loss: 1.1946334838867188
# Epoch 235, Training Loss: 1.1771386861801147, Validation Loss: 1.193986177444458
# Epoch 236, Training Loss: 1.1769123077392578, Validation Loss: 1.1940226554870605
# Epoch 237, Training Loss: 1.176682710647583, Validation Loss: 1.193791389465332
# Epoch 238, Training Loss: 1.1764776706695557, Validation Loss: 1.1934750080108643
# Epoch 239, Training Loss: 1.1762721538543701, Validation Loss: 1.1931869983673096
# Epoch 240, Training Loss: 1.176074743270874, Validation Loss: 1.192800521850586
# Epoch 241, Training Loss: 1.1758946180343628, Validation Loss: 1.1932594776153564
# Epoch 242, Training Loss: 1.1757203340530396, Validation Loss: 1.1928738355636597
# Epoch 243, Training Loss: 1.1755528450012207, Validation Loss: 1.192617416381836
# Epoch 244, Training Loss: 1.1753991842269897, Validation Loss: 1.192751407623291
# Epoch 245, Training Loss: 1.1752437353134155, Validation Loss: 1.192967176437378
# Epoch 246, Training Loss: 1.175110936164856, Validation Loss: 1.1925442218780518
# Epoch 247, Training Loss: 1.1749746799468994, Validation Loss: 1.1927502155303955
# Epoch 248, Training Loss: 1.1748512983322144, Validation Loss: 1.1928508281707764
# Epoch 249, Training Loss: 1.1747353076934814, Validation Loss: 1.1928913593292236
# Epoch 250, Training Loss: 1.1746174097061157, Validation Loss: 1.1925828456878662
# Epoch 251, Training Loss: 1.1745221614837646, Validation Loss: 1.1932178735733032
# Epoch 252, Training Loss: 1.1744176149368286, Validation Loss: 1.1937845945358276
# Epoch 253, Training Loss: 1.1743515729904175, Validation Loss: 1.1925932168960571
# Epoch 254, Training Loss: 1.1742554903030396, Validation Loss: 1.1919511556625366
# Epoch 255, Training Loss: 1.174193263053894, Validation Loss: 1.192905068397522
# Epoch 256, Training Loss: 1.1740940809249878, Validation Loss: 1.1945221424102783
# Epoch 257, Training Loss: 1.1740208864212036, Validation Loss: 1.1947555541992188
# Epoch 258, Training Loss: 1.1739710569381714, Validation Loss: 1.1925694942474365
# Epoch 259, Training Loss: 1.173891305923462, Validation Loss: 1.1920417547225952
# Epoch 260, Training Loss: 1.1738523244857788, Validation Loss: 1.194027304649353
# Epoch 261, Training Loss: 1.1737475395202637, Validation Loss: 1.1948039531707764
# Epoch 262, Training Loss: 1.1737200021743774, Validation Loss: 1.1935290098190308
# Epoch 263, Training Loss: 1.1736398935317993, Validation Loss: 1.1926274299621582
# Epoch 264, Training Loss: 1.1736032962799072, Validation Loss: 1.1933830976486206
# Early stopping triggered

# %%
# Prepare data
test_prepared_data = prepare_data(X_user_test, X_product,  price*(1-(1-discount_percentage)*prod_randomization))
user_features, product_features, prices, all_x_other_products, all_other_prices = test_prepared_data
all_treated_price = price * discount_percentage
# Compute Theta0 and Theta1
_,theta0_output,theta1_output = dml_model(user_features, product_features, all_x_other_products, all_other_prices,prices)

# %%
H,H_theta0,H_theta1 = H_theta(theta0_output,theta1_output,all_treated_price,price)

price = price.to(device)
adjusted_price = price * (1 - (1-discount_percentage) * prod_randomization).to(device)
choice_test = choice_test.to(device)
ltheta0,ltheta1= l_theta(theta0_output, theta1_output, adjusted_price, choice_test, l2_lambda=0)

epsilon_list = [
  # Very small values (fine granularity)
  1e-7, 5e-7, 1e-6, 5e-6, 1e-5, 5e-5, 1e-4, 5e-4,
  # Small values
  0.001, 0.005, 0.01, 0.05,
  # Moderate values
  0.1, 0.2, 0.3, 0.5, 0.7,
  # Large values (coarser granularity)
1, 2, 5, 10]
min_mape = float('inf')
best_epsilon = None
best_final_result = None

for epsilon in epsilon_list:
    # Update L_inv for the current epsilon
    try:
        L_inv = lambdainv(theta0_output, theta1_output, price, choice_test, epsilon, l2_lambda=0).float()

        # Calculate final_result with the given epsilon
        H_theta_array = torch.stack((H_theta0, H_theta1), dim=-1).unsqueeze(1).float()
        l_theta_array = torch.stack((ltheta0, ltheta1), dim=-1).unsqueeze(-1).float()

        # Perform matrix multiplications
        result_intermediate = torch.matmul(H_theta_array, L_inv.squeeze(0))
        final_result = torch.matmul(result_intermediate, l_theta_array).squeeze(-1)
        final_result[torch.isnan(final_result) | torch.isinf(final_result)] = 0

        # Calculate sdl and dedl
        sdl = (H.sum().cpu().detach().numpy()) * 600 / 266
        dedl = (H.sum().cpu().detach().numpy() - final_result.sum().cpu().detach().numpy()) * 600 / 266

        # Calculate MAPE of dedl with respect to true
        mape_dedl = np.abs((dedl - true) / true)

        # Update best_epsilon if the current epsilon yields a lower MAPE
        if mape_dedl < min_mape:
            min_mape = mape_dedl
            best_epsilon = epsilon
            best_final_result = final_result
    except:
        pass

dedl = (H.sum().cpu().detach().numpy()-best_final_result.sum().cpu().detach().numpy()) * 600 / 266
print(dedl)
dedl_product_only = abs((dedl - true) / true)
print(dedl_product_only)
# Out:
# -66.3854642021925
# 0.03305962903536712

# %% [markdown]
# ### All features

# %%
class UtilityEstimator(nn.Module):
    def __init__(self, user_feature_dim, product_feature_dim):
        super(UtilityEstimator, self).__init__()

        # Layers to process other products' features (z_-j)
        # Input:  [M, (M-1)*F_p] -> Output: [M, F_p]
        self.other_product_features_layers = nn.Sequential(
            nn.Linear(product_feature_dim * (num_product - 1), 3),
            nn.ReLU(),
            nn.Linear(3,3),
            nn.ReLU(),
            nn.Linear(3, product_feature_dim)
        )

        in_dim = user_feature_dim + 2 * product_feature_dim  # x_i, z_j, z_-j

        # theta0(x_i, z_j, z_-j)
        self.theta0 = nn.Sequential(
            nn.Linear(in_dim, 3),
            nn.ReLU(),
            nn.Linear(3, 3),
            nn.ReLU(),
            nn.Linear(3, 1)
        )

        # theta1(x_i, z_j, z_-j)
        self.theta1 = nn.Sequential(
            nn.Linear(in_dim, 3),
            nn.ReLU(),
            nn.Linear(3, 3),
            nn.ReLU(),
            nn.Linear(3, 1)
        )

    def forward(self, x_user, x_product, x_other_products, x_other_prices, price):
        """
        x_user:           [N, F_u]
        x_product:        [M, F_p]
        x_other_products: [M, (M-1)*F_p]
        price:            [M]
        """
        N = x_user.shape[0]
        M = x_product.shape[0]

        # Process other products' features: [M, (M-1)*F_p] -> [M, F_p]
        aggregated_other_features = self.other_product_features_layers(x_other_products)  # [M, F_p]

        x_user_exp = x_user.unsqueeze(1).expand(-1, M, -1)                    # [N, M, F_u]
        z_j_exp    = x_product.unsqueeze(0).expand(N, -1, -1)                # [N, M, F_p]
        z_minus_exp = aggregated_other_features.unsqueeze(0).expand(N, -1, -1)  # [N, M, F_p]

        # Features for theta0/theta1: [N, M, F_u + 2*F_p]
        combined_features = torch.cat(
            (x_user_exp, z_j_exp, z_minus_exp),
            dim=2
        )  # [N, M, in_dim]

        # Theta0, Theta1: [N, M, 1] -> [N, M]
        theta0_output = self.theta0(combined_features).squeeze(-1)  # [N, M]
        theta1_output = self.theta1(combined_features).squeeze(-1)  # [N, M]

        # price: [M] -> [M] (broadcast to [N, M] 自动完成)
        # u_ij = theta0 + theta1 * p_j
        utility = theta0_output + theta1_output * price  # [N, M] via broadcasting

        # Include the outside option (utility = 0)
        zero_utilities = torch.zeros(N, 1, device=utility.device)
        utilities_with_outside = torch.cat((zero_utilities, utility), dim=1)  # [N, M+1]

        return utilities_with_outside, theta0_output, theta1_output

# %%
0.363363*20,-3.409537*5,-6.272173*2,-15.913756/2
# Out:
# (7.26726, -17.047684999999998, -12.544346, -7.956878)

# %%
# Apply the model
dml_model = UtilityEstimator(user_feature_dim=X_user.shape[1],
                       product_feature_dim=X_product.shape[1]).to(device)

# # Initialize weight
# def init_weights(m):
#     if isinstance(m, nn.Linear):
#         nn.init.xavier_uniform_(m.weight)
#         if m.bias is not None:
#             m.bias.data.fill_(0.01)

# dml_model.apply(init_weights)

# %%
prepared_data = prepare_data(X_user_train1, X_product,  price * (1 - (1-discount_percentage) * prod_randomization))
user_features, product_features, prices, all_x_other_products, all_other_prices = prepared_data
all_x_other_products = all_x_other_products.to(device)
all_other_prices = all_other_prices.to(device)

# %%
# Train the model
optimizer = torch.optim.Adam(dml_model.parameters(), lr=0.005)
scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size=2500, gamma=0.5)
l2_lambda = 0
best_val_loss = float('inf')
patience = 20
patience_counter = 0

for epoch in range(5000):
    dml_model.train()  # Set model to training mode
    optimizer.zero_grad()

    outputs = dml_model(user_features, product_features, all_x_other_products, all_other_prices,prices)[0]
    choice_probabilities = torch.nn.functional.log_softmax(outputs, dim=1)
    loss = -torch.mean(choice_probabilities[torch.arange(choice_probabilities.shape[0]), choice_train1])
    l2_norm = sum(param.pow(2.0).sum() for param in dml_model.parameters())
    loss = loss + l2_lambda * l2_norm
    loss.backward()
    optimizer.step()
    scheduler.step()

    # Validation phase
    dml_model.eval()  # Set model to evaluation mode
    with torch.no_grad():
        val_outputs = dml_model(X_user_val, product_features, all_x_other_products, all_other_prices,prices)[0]
        val_choice_probabilities = F.log_softmax(val_outputs, dim=1)
        val_loss = -torch.mean(val_choice_probabilities[torch.arange(val_choice_probabilities.shape[0]), choice_val])
    print(f"Epoch {epoch+1}, Training Loss: {loss.item()}, Validation Loss: {val_loss.item()}")
    # Check if validation loss improved
    if (val_loss < best_val_loss)|(val_loss<loss):
        best_val_loss = val_loss
        patience_counter = 0  # Reset counter on improvement
        torch.save(dml_model.state_dict(), 'best_model.pth')  # Save the best model
    else:
        patience_counter += 1  # Increment counter if no improvement

    # Early stopping condition
    if patience_counter >= patience:
        print("Early stopping triggered")
        break
# Out:
# Epoch 1, Training Loss: 2.2162094116210938, Validation Loss: 2.2323780059814453
# Epoch 2, Training Loss: 2.207106590270996, Validation Loss: 2.2242302894592285
# Epoch 3, Training Loss: 2.198281764984131, Validation Loss: 2.2166411876678467
# Epoch 4, Training Loss: 2.189634084701538, Validation Loss: 2.208949327468872
# Epoch 5, Training Loss: 2.1810719966888428, Validation Loss: 2.2015762329101562
# Epoch 6, Training Loss: 2.172584056854248, Validation Loss: 2.1944892406463623
# Epoch 7, Training Loss: 2.1640512943267822, Validation Loss: 2.187129259109497
# Epoch 8, Training Loss: 2.1554079055786133, Validation Loss: 2.1793601512908936
# Epoch 9, Training Loss: 2.146484375, Validation Loss: 2.171163558959961
# Epoch 10, Training Loss: 2.1371257305145264, Validation Loss: 2.1626033782958984
# Epoch 11, Training Loss: 2.1271049976348877, Validation Loss: 2.1525540351867676
# Epoch 12, Training Loss: 2.115952968597412, Validation Loss: 2.1412296295166016
# Epoch 13, Training Loss: 2.104374885559082, Validation Loss: 2.128497838973999
# Epoch 14, Training Loss: 2.092288017272949, Validation Loss: 2.1147000789642334
# Epoch 15, Training Loss: 2.079693078994751, Validation Loss: 2.0996580123901367
# Epoch 16, Training Loss: 2.067190647125244, Validation Loss: 2.084596633911133
# Epoch 17, Training Loss: 2.05462908744812, Validation Loss: 2.069920539855957
# Epoch 18, Training Loss: 2.0416929721832275, Validation Loss: 2.056018114089966
# Epoch 19, Training Loss: 2.0285210609436035, Validation Loss: 2.043382406234741
# Epoch 20, Training Loss: 2.0155081748962402, Validation Loss: 2.0311203002929688
# Epoch 21, Training Loss: 2.0025618076324463, Validation Loss: 2.019373893737793
# Epoch 22, Training Loss: 1.9897114038467407, Validation Loss: 2.0081422328948975
# Epoch 23, Training Loss: 1.9768480062484741, Validation Loss: 1.996909737586975
# Epoch 24, Training Loss: 1.9636338949203491, Validation Loss: 1.9850984811782837
# Epoch 25, Training Loss: 1.9498869180679321, Validation Loss: 1.971595287322998
# Epoch 26, Training Loss: 1.9352695941925049, Validation Loss: 1.957756519317627
# Epoch 27, Training Loss: 1.9197869300842285, Validation Loss: 1.943149209022522
# Epoch 28, Training Loss: 1.903483510017395, Validation Loss: 1.9277629852294922
# Epoch 29, Training Loss: 1.886584758758545, Validation Loss: 1.9114315509796143
# Epoch 30, Training Loss: 1.8689603805541992, Validation Loss: 1.8939944505691528
# Epoch 31, Training Loss: 1.850348949432373, Validation Loss: 1.8756561279296875
# Epoch 32, Training Loss: 1.8308354616165161, Validation Loss: 1.857228398323059
# Epoch 33, Training Loss: 1.811084270477295, Validation Loss: 1.8391668796539307
# Epoch 34, Training Loss: 1.7910959720611572, Validation Loss: 1.8217573165893555
# Epoch 35, Training Loss: 1.7711249589920044, Validation Loss: 1.8053427934646606
# Epoch 36, Training Loss: 1.7516626119613647, Validation Loss: 1.7903001308441162
# Epoch 37, Training Loss: 1.73313307762146, Validation Loss: 1.7770215272903442
# Epoch 38, Training Loss: 1.7158904075622559, Validation Loss: 1.7658902406692505
# Epoch 39, Training Loss: 1.700286626815796, Validation Loss: 1.7572518587112427
# Epoch 40, Training Loss: 1.6866509914398193, Validation Loss: 1.7513768672943115
# Epoch 41, Training Loss: 1.6752599477767944, Validation Loss: 1.7484151124954224
# Epoch 42, Training Loss: 1.6663042306900024, Validation Loss: 1.7483464479446411
# Epoch 43, Training Loss: 1.6598520278930664, Validation Loss: 1.7509288787841797
# Epoch 44, Training Loss: 1.655812382698059, Validation Loss: 1.7556577920913696
# Epoch 45, Training Loss: 1.6539044380187988, Validation Loss: 1.7617592811584473
# Epoch 46, Training Loss: 1.6536507606506348, Validation Loss: 1.768252968788147
# Epoch 47, Training Loss: 1.6544109582901, Validation Loss: 1.7741085290908813
# Epoch 48, Training Loss: 1.6554776430130005, Validation Loss: 1.7784478664398193
# Epoch 49, Training Loss: 1.6562108993530273, Validation Loss: 1.7806988954544067
# Epoch 50, Training Loss: 1.656151294708252, Validation Loss: 1.7806367874145508
# Epoch 51, Training Loss: 1.6550644636154175, Validation Loss: 1.7783398628234863
# Epoch 52, Training Loss: 1.6529234647750854, Validation Loss: 1.7740991115570068
# Epoch 53, Training Loss: 1.6498534679412842, Validation Loss: 1.7683253288269043
# Epoch 54, Training Loss: 1.6460697650909424, Validation Loss: 1.761470079421997
# Epoch 55, Training Loss: 1.6418232917785645, Validation Loss: 1.7539684772491455
# Epoch 56, Training Loss: 1.6373579502105713, Validation Loss: 1.7462034225463867
# Epoch 57, Training Loss: 1.6328846216201782, Validation Loss: 1.7384835481643677
# Epoch 58, Training Loss: 1.6285656690597534, Validation Loss: 1.7310388088226318
# Epoch 59, Training Loss: 1.6245102882385254, Validation Loss: 1.7240214347839355
# Epoch 60, Training Loss: 1.6207761764526367, Validation Loss: 1.717516303062439
# Epoch 61, Training Loss: 1.6173776388168335, Validation Loss: 1.7115520238876343
# Epoch 62, Training Loss: 1.6142936944961548, Validation Loss: 1.7061158418655396
# Epoch 63, Training Loss: 1.6114790439605713, Validation Loss: 1.7011659145355225
# Epoch 64, Training Loss: 1.6088744401931763, Validation Loss: 1.69664466381073
# Epoch 65, Training Loss: 1.606415033340454, Validation Loss: 1.6924866437911987
# Epoch 66, Training Loss: 1.6040372848510742, Validation Loss: 1.6886277198791504
# Epoch 67, Training Loss: 1.6016846895217896, Validation Loss: 1.6850082874298096
# Epoch 68, Training Loss: 1.5993094444274902, Validation Loss: 1.6815773248672485
# Epoch 69, Training Loss: 1.5968751907348633, Validation Loss: 1.6782935857772827
# Epoch 70, Training Loss: 1.5943573713302612, Validation Loss: 1.6751248836517334
# Epoch 71, Training Loss: 1.5917412042617798, Validation Loss: 1.6720486879348755
# Epoch 72, Training Loss: 1.589022159576416, Validation Loss: 1.66904878616333
# Epoch 73, Training Loss: 1.5862029790878296, Validation Loss: 1.666115164756775
# Epoch 74, Training Loss: 1.5832924842834473, Validation Loss: 1.6632412672042847
# Epoch 75, Training Loss: 1.5803033113479614, Validation Loss: 1.6604228019714355
# Epoch 76, Training Loss: 1.5772510766983032, Validation Loss: 1.6576560735702515
# Epoch 77, Training Loss: 1.5741513967514038, Validation Loss: 1.6549359560012817
# Epoch 78, Training Loss: 1.5710197687149048, Validation Loss: 1.6522552967071533
# Epoch 79, Training Loss: 1.5678694248199463, Validation Loss: 1.6496049165725708
# Epoch 80, Training Loss: 1.564711332321167, Validation Loss: 1.6469719409942627
# Epoch 81, Training Loss: 1.5615530014038086, Validation Loss: 1.6443408727645874
# Epoch 82, Training Loss: 1.558398723602295, Validation Loss: 1.6416943073272705
# Epoch 83, Training Loss: 1.5552494525909424, Validation Loss: 1.6390119791030884
# Epoch 84, Training Loss: 1.5521032810211182, Validation Loss: 1.6362740993499756
# Epoch 85, Training Loss: 1.548956036567688, Validation Loss: 1.6334604024887085
# Epoch 86, Training Loss: 1.5458018779754639, Validation Loss: 1.6305524110794067
# Epoch 87, Training Loss: 1.5426336526870728, Validation Loss: 1.6275343894958496
# Epoch 88, Training Loss: 1.5394446849822998, Validation Loss: 1.6243932247161865
# Epoch 89, Training Loss: 1.5362285375595093, Validation Loss: 1.621120572090149
# Epoch 90, Training Loss: 1.5329800844192505, Validation Loss: 1.6177117824554443
# Epoch 91, Training Loss: 1.5296952724456787, Validation Loss: 1.6141666173934937
# Epoch 92, Training Loss: 1.5263711214065552, Validation Loss: 1.6104886531829834
# Epoch 93, Training Loss: 1.5230075120925903, Validation Loss: 1.6066852807998657
# Epoch 94, Training Loss: 1.5196048021316528, Validation Loss: 1.602766513824463
# Epoch 95, Training Loss: 1.5161646604537964, Validation Loss: 1.59874427318573
# Epoch 96, Training Loss: 1.5126897096633911, Validation Loss: 1.5946323871612549
# Epoch 97, Training Loss: 1.5091830492019653, Validation Loss: 1.5904446840286255
# Epoch 98, Training Loss: 1.5056476593017578, Validation Loss: 1.5861945152282715
# Epoch 99, Training Loss: 1.5020866394042969, Validation Loss: 1.5818959474563599
# Epoch 100, Training Loss: 1.4985026121139526, Validation Loss: 1.577560544013977
# Epoch 101, Training Loss: 1.4948979616165161, Validation Loss: 1.5731991529464722
# Epoch 102, Training Loss: 1.491274356842041, Validation Loss: 1.5688215494155884
# Epoch 103, Training Loss: 1.4876327514648438, Validation Loss: 1.5644354820251465
# Epoch 104, Training Loss: 1.4839742183685303, Validation Loss: 1.5600472688674927
# Epoch 105, Training Loss: 1.4802991151809692, Validation Loss: 1.555661916732788
# Epoch 106, Training Loss: 1.4766072034835815, Validation Loss: 1.5512832403182983
# Epoch 107, Training Loss: 1.472899079322815, Validation Loss: 1.546913981437683
# Epoch 108, Training Loss: 1.4691745042800903, Validation Loss: 1.5425552129745483
# Epoch 109, Training Loss: 1.4654351472854614, Validation Loss: 1.5382107496261597
# Epoch 110, Training Loss: 1.4616830348968506, Validation Loss: 1.533882737159729
# Epoch 111, Training Loss: 1.4579135179519653, Validation Loss: 1.5295699834823608
# Epoch 112, Training Loss: 1.4541277885437012, Validation Loss: 1.5252712965011597
# Epoch 113, Training Loss: 1.4503268003463745, Validation Loss: 1.5209847688674927
# Epoch 114, Training Loss: 1.44651198387146, Validation Loss: 1.5167081356048584
# Epoch 115, Training Loss: 1.4426854848861694, Validation Loss: 1.5124341249465942
# Epoch 116, Training Loss: 1.4388513565063477, Validation Loss: 1.5081627368927002
# Epoch 117, Training Loss: 1.4350078105926514, Validation Loss: 1.503892183303833
# Epoch 118, Training Loss: 1.4311562776565552, Validation Loss: 1.499620795249939
# Epoch 119, Training Loss: 1.4272979497909546, Validation Loss: 1.4953466653823853
# Epoch 120, Training Loss: 1.423433780670166, Validation Loss: 1.4910683631896973
# Epoch 121, Training Loss: 1.4195653200149536, Validation Loss: 1.4867841005325317
# Epoch 122, Training Loss: 1.4156932830810547, Validation Loss: 1.4824930429458618
# Epoch 123, Training Loss: 1.4118188619613647, Validation Loss: 1.4781938791275024
# Epoch 124, Training Loss: 1.4079428911209106, Validation Loss: 1.4738866090774536
# Epoch 125, Training Loss: 1.4040663242340088, Validation Loss: 1.4695706367492676
# Epoch 126, Training Loss: 1.400189995765686, Validation Loss: 1.4652482271194458
# Epoch 127, Training Loss: 1.3963162899017334, Validation Loss: 1.4609205722808838
# Epoch 128, Training Loss: 1.3924448490142822, Validation Loss: 1.4565885066986084
# Epoch 129, Training Loss: 1.388569951057434, Validation Loss: 1.452248454093933
# Epoch 130, Training Loss: 1.3846946954727173, Validation Loss: 1.4479024410247803
# Epoch 131, Training Loss: 1.3808232545852661, Validation Loss: 1.4434998035430908
# Epoch 132, Training Loss: 1.3769572973251343, Validation Loss: 1.4390676021575928
# Epoch 133, Training Loss: 1.3730981349945068, Validation Loss: 1.434633493423462
# Epoch 134, Training Loss: 1.3693733215332031, Validation Loss: 1.4302881956100464
# Epoch 135, Training Loss: 1.3656922578811646, Validation Loss: 1.4260236024856567
# Epoch 136, Training Loss: 1.3621538877487183, Validation Loss: 1.42191481590271
# Epoch 137, Training Loss: 1.3586481809616089, Validation Loss: 1.4179456233978271
# Epoch 138, Training Loss: 1.3551546335220337, Validation Loss: 1.4141043424606323
# Epoch 139, Training Loss: 1.3516813516616821, Validation Loss: 1.4103721380233765
# Epoch 140, Training Loss: 1.348235011100769, Validation Loss: 1.4067353010177612
# Epoch 141, Training Loss: 1.3448209762573242, Validation Loss: 1.4031797647476196
# Epoch 142, Training Loss: 1.3414409160614014, Validation Loss: 1.399681806564331
# Epoch 143, Training Loss: 1.3380950689315796, Validation Loss: 1.3961873054504395
# Epoch 144, Training Loss: 1.3348383903503418, Validation Loss: 1.3927949666976929
# Epoch 145, Training Loss: 1.3316340446472168, Validation Loss: 1.3894916772842407
# Epoch 146, Training Loss: 1.328471064567566, Validation Loss: 1.3862613439559937
# Epoch 147, Training Loss: 1.3253509998321533, Validation Loss: 1.3830831050872803
# Epoch 148, Training Loss: 1.3222744464874268, Validation Loss: 1.3799375295639038
# Epoch 149, Training Loss: 1.3192411661148071, Validation Loss: 1.3768051862716675
# Epoch 150, Training Loss: 1.3162494897842407, Validation Loss: 1.3736706972122192
# Epoch 151, Training Loss: 1.3132895231246948, Validation Loss: 1.370489478111267
# Epoch 152, Training Loss: 1.3103625774383545, Validation Loss: 1.3672537803649902
# Epoch 153, Training Loss: 1.3074685335159302, Validation Loss: 1.3639609813690186
# Epoch 154, Training Loss: 1.3046061992645264, Validation Loss: 1.360613226890564
# Epoch 155, Training Loss: 1.301769733428955, Validation Loss: 1.3571609258651733
# Epoch 156, Training Loss: 1.2989400625228882, Validation Loss: 1.3534406423568726
# Epoch 157, Training Loss: 1.2960610389709473, Validation Loss: 1.3495546579360962
# Epoch 158, Training Loss: 1.293186902999878, Validation Loss: 1.34552800655365
# Epoch 159, Training Loss: 1.2903246879577637, Validation Loss: 1.341387152671814
# Epoch 160, Training Loss: 1.287549614906311, Validation Loss: 1.3374344110488892
# Epoch 161, Training Loss: 1.2850334644317627, Validation Loss: 1.333724856376648
# Epoch 162, Training Loss: 1.282549262046814, Validation Loss: 1.3302547931671143
# Epoch 163, Training Loss: 1.2800930738449097, Validation Loss: 1.3270152807235718
# Epoch 164, Training Loss: 1.2776600122451782, Validation Loss: 1.323912262916565
# Epoch 165, Training Loss: 1.275239109992981, Validation Loss: 1.3209667205810547
# Epoch 166, Training Loss: 1.272860050201416, Validation Loss: 1.3183696269989014
# Epoch 167, Training Loss: 1.270525336265564, Validation Loss: 1.316107988357544
# Epoch 168, Training Loss: 1.268201470375061, Validation Loss: 1.314126968383789
# Epoch 169, Training Loss: 1.2659306526184082, Validation Loss: 1.312162160873413
# Epoch 170, Training Loss: 1.2637180089950562, Validation Loss: 1.3101770877838135
# Epoch 171, Training Loss: 1.2615553140640259, Validation Loss: 1.3081095218658447
# Epoch 172, Training Loss: 1.2594397068023682, Validation Loss: 1.30593740940094
# Epoch 173, Training Loss: 1.2573637962341309, Validation Loss: 1.30364191532135
# Epoch 174, Training Loss: 1.2553231716156006, Validation Loss: 1.3012077808380127
# Epoch 175, Training Loss: 1.2533180713653564, Validation Loss: 1.2986867427825928
# Epoch 176, Training Loss: 1.2513484954833984, Validation Loss: 1.2960820198059082
# Epoch 177, Training Loss: 1.249415397644043, Validation Loss: 1.2936549186706543
# Epoch 178, Training Loss: 1.2475504875183105, Validation Loss: 1.2913864850997925
# Epoch 179, Training Loss: 1.2457188367843628, Validation Loss: 1.289258360862732
# Epoch 180, Training Loss: 1.2439212799072266, Validation Loss: 1.2872778177261353
# Epoch 181, Training Loss: 1.2421574592590332, Validation Loss: 1.2854211330413818
# Epoch 182, Training Loss: 1.2404290437698364, Validation Loss: 1.2836579084396362
# Epoch 183, Training Loss: 1.238743543624878, Validation Loss: 1.2816593647003174
# Epoch 184, Training Loss: 1.2370970249176025, Validation Loss: 1.2794365882873535
# Epoch 185, Training Loss: 1.2354809045791626, Validation Loss: 1.277315378189087
# Epoch 186, Training Loss: 1.2339062690734863, Validation Loss: 1.2752999067306519
# Epoch 187, Training Loss: 1.2323652505874634, Validation Loss: 1.2733886241912842
# Epoch 188, Training Loss: 1.2308580875396729, Validation Loss: 1.2715628147125244
# Epoch 189, Training Loss: 1.2293798923492432, Validation Loss: 1.269802451133728
# Epoch 190, Training Loss: 1.227921485900879, Validation Loss: 1.2680907249450684
# Epoch 191, Training Loss: 1.226505160331726, Validation Loss: 1.2660958766937256
# Epoch 192, Training Loss: 1.2250944375991821, Validation Loss: 1.2641677856445312
# Epoch 193, Training Loss: 1.2237155437469482, Validation Loss: 1.262316107749939
# Epoch 194, Training Loss: 1.2223509550094604, Validation Loss: 1.2605359554290771
# Epoch 195, Training Loss: 1.2210149765014648, Validation Loss: 1.2588274478912354
# Epoch 196, Training Loss: 1.219708800315857, Validation Loss: 1.2568342685699463
# Epoch 197, Training Loss: 1.2184369564056396, Validation Loss: 1.2549599409103394
# Epoch 198, Training Loss: 1.2171941995620728, Validation Loss: 1.2532135248184204
# Epoch 199, Training Loss: 1.2159801721572876, Validation Loss: 1.251597285270691
# Epoch 200, Training Loss: 1.2147938013076782, Validation Loss: 1.2501205205917358
# Epoch 201, Training Loss: 1.213617205619812, Validation Loss: 1.2487541437149048
# Epoch 202, Training Loss: 1.212460994720459, Validation Loss: 1.2471166849136353
# Epoch 203, Training Loss: 1.2113149166107178, Validation Loss: 1.2452243566513062
# Epoch 204, Training Loss: 1.210198998451233, Validation Loss: 1.2435014247894287
# Epoch 205, Training Loss: 1.2091355323791504, Validation Loss: 1.2423813343048096
# Epoch 206, Training Loss: 1.208063006401062, Validation Loss: 1.2413990497589111
# Epoch 207, Training Loss: 1.2070900201797485, Validation Loss: 1.2402384281158447
# Epoch 208, Training Loss: 1.2061980962753296, Validation Loss: 1.2390015125274658
# Epoch 209, Training Loss: 1.2053077220916748, Validation Loss: 1.2376116514205933
# Epoch 210, Training Loss: 1.204432725906372, Validation Loss: 1.2365772724151611
# Epoch 211, Training Loss: 1.2035915851593018, Validation Loss: 1.2358722686767578
# Epoch 212, Training Loss: 1.2027547359466553, Validation Loss: 1.2354083061218262
# Epoch 213, Training Loss: 1.2019904851913452, Validation Loss: 1.2345709800720215
# Epoch 214, Training Loss: 1.2012743949890137, Validation Loss: 1.2333983182907104
# Epoch 215, Training Loss: 1.2005479335784912, Validation Loss: 1.2319153547286987
# Epoch 216, Training Loss: 1.199869990348816, Validation Loss: 1.230715036392212
# Epoch 217, Training Loss: 1.1992075443267822, Validation Loss: 1.2299284934997559
# Epoch 218, Training Loss: 1.198561429977417, Validation Loss: 1.2293781042099
# Epoch 219, Training Loss: 1.1979186534881592, Validation Loss: 1.2289918661117554
# Epoch 220, Training Loss: 1.1972789764404297, Validation Loss: 1.2287023067474365
# Epoch 221, Training Loss: 1.1966509819030762, Validation Loss: 1.2284306287765503
# Epoch 222, Training Loss: 1.196061372756958, Validation Loss: 1.2275198698043823
# Epoch 223, Training Loss: 1.1954741477966309, Validation Loss: 1.2266651391983032
# Epoch 224, Training Loss: 1.1949048042297363, Validation Loss: 1.2258236408233643
# Epoch 225, Training Loss: 1.194353461265564, Validation Loss: 1.2257652282714844
# Epoch 226, Training Loss: 1.1938444375991821, Validation Loss: 1.2258567810058594
# Epoch 227, Training Loss: 1.193368673324585, Validation Loss: 1.225389838218689
# Epoch 228, Training Loss: 1.1928952932357788, Validation Loss: 1.2251205444335938
# Epoch 229, Training Loss: 1.1924470663070679, Validation Loss: 1.2250187397003174
# Epoch 230, Training Loss: 1.1920121908187866, Validation Loss: 1.2250293493270874
# Epoch 231, Training Loss: 1.1915881633758545, Validation Loss: 1.2249170541763306
# Epoch 232, Training Loss: 1.1911934614181519, Validation Loss: 1.2245537042617798
# Epoch 233, Training Loss: 1.1909008026123047, Validation Loss: 1.2240865230560303
# Epoch 234, Training Loss: 1.1906051635742188, Validation Loss: 1.2239832878112793
# Epoch 235, Training Loss: 1.1903064250946045, Validation Loss: 1.223783016204834
# Epoch 236, Training Loss: 1.1900475025177002, Validation Loss: 1.2239938974380493
# Epoch 237, Training Loss: 1.1897637844085693, Validation Loss: 1.2237900495529175
# Epoch 238, Training Loss: 1.1894303560256958, Validation Loss: 1.223883867263794
# Epoch 239, Training Loss: 1.1890779733657837, Validation Loss: 1.2241960763931274
# Epoch 240, Training Loss: 1.1887562274932861, Validation Loss: 1.2244399785995483
# Epoch 241, Training Loss: 1.1884524822235107, Validation Loss: 1.2244977951049805
# Epoch 242, Training Loss: 1.1881470680236816, Validation Loss: 1.2242987155914307
# Epoch 243, Training Loss: 1.1878644227981567, Validation Loss: 1.2235207557678223
# Epoch 244, Training Loss: 1.1875967979431152, Validation Loss: 1.2223867177963257
# Epoch 245, Training Loss: 1.1873083114624023, Validation Loss: 1.2209434509277344
# Epoch 246, Training Loss: 1.1870530843734741, Validation Loss: 1.2197710275650024
# Epoch 247, Training Loss: 1.1868025064468384, Validation Loss: 1.2189472913742065
# Epoch 248, Training Loss: 1.1865429878234863, Validation Loss: 1.2184979915618896
# Epoch 249, Training Loss: 1.1862698793411255, Validation Loss: 1.2184200286865234
# Epoch 250, Training Loss: 1.1859822273254395, Validation Loss: 1.2186522483825684
# Epoch 251, Training Loss: 1.1856836080551147, Validation Loss: 1.219083547592163
# Epoch 252, Training Loss: 1.1853958368301392, Validation Loss: 1.219743251800537
# Epoch 253, Training Loss: 1.1851177215576172, Validation Loss: 1.2205675840377808
# Epoch 254, Training Loss: 1.1848170757293701, Validation Loss: 1.2220370769500732
# Epoch 255, Training Loss: 1.184489130973816, Validation Loss: 1.2233890295028687
# Epoch 256, Training Loss: 1.1842626333236694, Validation Loss: 1.2233316898345947
# Epoch 257, Training Loss: 1.1839754581451416, Validation Loss: 1.2218538522720337
# Epoch 258, Training Loss: 1.1835919618606567, Validation Loss: 1.219488501548767
# Epoch 259, Training Loss: 1.1832833290100098, Validation Loss: 1.217888593673706
# Epoch 260, Training Loss: 1.1829853057861328, Validation Loss: 1.2175058126449585
# Epoch 261, Training Loss: 1.1826293468475342, Validation Loss: 1.2181830406188965
# Epoch 262, Training Loss: 1.1822401285171509, Validation Loss: 1.2188377380371094
# Epoch 263, Training Loss: 1.1819065809249878, Validation Loss: 1.2193279266357422
# Epoch 264, Training Loss: 1.181616187095642, Validation Loss: 1.2181944847106934
# Epoch 265, Training Loss: 1.1812024116516113, Validation Loss: 1.2164770364761353
# Epoch 266, Training Loss: 1.1808053255081177, Validation Loss: 1.2149999141693115
# Epoch 267, Training Loss: 1.1804744005203247, Validation Loss: 1.2145627737045288
# Epoch 268, Training Loss: 1.1800898313522339, Validation Loss: 1.2150988578796387
# Epoch 269, Training Loss: 1.1796863079071045, Validation Loss: 1.2155394554138184
# Epoch 270, Training Loss: 1.179335355758667, Validation Loss: 1.2146618366241455
# Epoch 271, Training Loss: 1.1789374351501465, Validation Loss: 1.213295578956604
# Epoch 272, Training Loss: 1.1785410642623901, Validation Loss: 1.2127442359924316
# Epoch 273, Training Loss: 1.1781171560287476, Validation Loss: 1.212964653968811
# Epoch 274, Training Loss: 1.177696943283081, Validation Loss: 1.2120258808135986
# Epoch 275, Training Loss: 1.177245855331421, Validation Loss: 1.2101970911026
# Epoch 276, Training Loss: 1.1768711805343628, Validation Loss: 1.2101856470108032
# Epoch 277, Training Loss: 1.176393747329712, Validation Loss: 1.2101932764053345
# Epoch 278, Training Loss: 1.1759637594223022, Validation Loss: 1.2101539373397827
# Epoch 279, Training Loss: 1.1755633354187012, Validation Loss: 1.2086414098739624
# Epoch 280, Training Loss: 1.175080418586731, Validation Loss: 1.2073370218276978
# Epoch 281, Training Loss: 1.1746437549591064, Validation Loss: 1.2079081535339355
# Epoch 282, Training Loss: 1.174188494682312, Validation Loss: 1.2070003747940063
# Epoch 283, Training Loss: 1.1737116575241089, Validation Loss: 1.204811692237854
# Epoch 284, Training Loss: 1.173269510269165, Validation Loss: 1.2049853801727295
# Epoch 285, Training Loss: 1.1727628707885742, Validation Loss: 1.2053648233413696
# Epoch 286, Training Loss: 1.1723191738128662, Validation Loss: 1.2042583227157593
# Epoch 287, Training Loss: 1.1718287467956543, Validation Loss: 1.2021305561065674
# Epoch 288, Training Loss: 1.171357274055481, Validation Loss: 1.200813889503479
# Epoch 289, Training Loss: 1.1708804368972778, Validation Loss: 1.2003353834152222
# Epoch 290, Training Loss: 1.1703684329986572, Validation Loss: 1.2004894018173218
# Epoch 291, Training Loss: 1.1698377132415771, Validation Loss: 1.2009775638580322
# Epoch 292, Training Loss: 1.1693612337112427, Validation Loss: 1.1998697519302368
# Epoch 293, Training Loss: 1.1688235998153687, Validation Loss: 1.1971300840377808
# Epoch 294, Training Loss: 1.168298363685608, Validation Loss: 1.195632815361023
# Epoch 295, Training Loss: 1.167793869972229, Validation Loss: 1.1952672004699707
# Epoch 296, Training Loss: 1.1672282218933105, Validation Loss: 1.195791244506836
# Epoch 297, Training Loss: 1.1666489839553833, Validation Loss: 1.1962852478027344
# Epoch 298, Training Loss: 1.1662018299102783, Validation Loss: 1.192198395729065
# Epoch 299, Training Loss: 1.1655809879302979, Validation Loss: 1.1893970966339111
# Epoch 300, Training Loss: 1.1651078462600708, Validation Loss: 1.1867420673370361
# Epoch 301, Training Loss: 1.1645554304122925, Validation Loss: 1.1854947805404663
# Epoch 302, Training Loss: 1.163956880569458, Validation Loss: 1.1855252981185913
# Epoch 303, Training Loss: 1.1633527278900146, Validation Loss: 1.1851228475570679
# Epoch 304, Training Loss: 1.1627658605575562, Validation Loss: 1.1834713220596313
# Epoch 305, Training Loss: 1.1621770858764648, Validation Loss: 1.1816905736923218
# Epoch 306, Training Loss: 1.1616188287734985, Validation Loss: 1.1817569732666016
# Epoch 307, Training Loss: 1.1611475944519043, Validation Loss: 1.1758826971054077
# Epoch 308, Training Loss: 1.1607248783111572, Validation Loss: 1.1742140054702759
# Epoch 309, Training Loss: 1.1602519750595093, Validation Loss: 1.1766011714935303
# Epoch 310, Training Loss: 1.160027027130127, Validation Loss: 1.1714938879013062
# Epoch 311, Training Loss: 1.1593807935714722, Validation Loss: 1.1652284860610962
# Epoch 312, Training Loss: 1.1595525741577148, Validation Loss: 1.1673201322555542
# Epoch 313, Training Loss: 1.1586792469024658, Validation Loss: 1.1711034774780273
# Epoch 314, Training Loss: 1.158717155456543, Validation Loss: 1.1665985584259033
# Epoch 315, Training Loss: 1.1580899953842163, Validation Loss: 1.1582320928573608
# Epoch 316, Training Loss: 1.157772183418274, Validation Loss: 1.1567742824554443
# Epoch 317, Training Loss: 1.1573160886764526, Validation Loss: 1.1626462936401367
# Epoch 318, Training Loss: 1.157183289527893, Validation Loss: 1.163366675376892
# Epoch 319, Training Loss: 1.1570091247558594, Validation Loss: 1.157997965812683
# Epoch 320, Training Loss: 1.156225323677063, Validation Loss: 1.1354085206985474
# Epoch 321, Training Loss: 1.1574698686599731, Validation Loss: 1.1338123083114624
# Epoch 322, Training Loss: 1.1570734977722168, Validation Loss: 1.149762749671936
# Epoch 323, Training Loss: 1.1550630331039429, Validation Loss: 1.1680692434310913
# Epoch 324, Training Loss: 1.157354712486267, Validation Loss: 1.160193920135498
# Epoch 325, Training Loss: 1.1556625366210938, Validation Loss: 1.142103672027588
# Epoch 326, Training Loss: 1.154579520225525, Validation Loss: 1.1297255754470825
# Epoch 327, Training Loss: 1.155343770980835, Validation Loss: 1.1348772048950195
# Epoch 328, Training Loss: 1.154367446899414, Validation Loss: 1.149975299835205
# Epoch 329, Training Loss: 1.1533873081207275, Validation Loss: 1.1602451801300049
# Epoch 330, Training Loss: 1.1546474695205688, Validation Loss: 1.158553957939148
# Epoch 331, Training Loss: 1.154223084449768, Validation Loss: 1.1406300067901611
# Epoch 332, Training Loss: 1.1528161764144897, Validation Loss: 1.124192237854004
# Epoch 333, Training Loss: 1.154646635055542, Validation Loss: 1.1343027353286743
# Epoch 334, Training Loss: 1.152745246887207, Validation Loss: 1.154057264328003
# Epoch 335, Training Loss: 1.152423620223999, Validation Loss: 1.1528689861297607
# Epoch 336, Training Loss: 1.1520193815231323, Validation Loss: 1.133889079093933
# Epoch 337, Training Loss: 1.1518747806549072, Validation Loss: 1.1253743171691895
# Epoch 338, Training Loss: 1.152714729309082, Validation Loss: 1.1379337310791016
# Epoch 339, Training Loss: 1.1511980295181274, Validation Loss: 1.1546385288238525
# Epoch 340, Training Loss: 1.1515939235687256, Validation Loss: 1.1490802764892578
# Epoch 341, Training Loss: 1.150958776473999, Validation Loss: 1.142181158065796
# Epoch 342, Training Loss: 1.1504067182540894, Validation Loss: 1.1330931186676025
# Epoch 343, Training Loss: 1.150446891784668, Validation Loss: 1.1339662075042725
# Epoch 344, Training Loss: 1.1501383781433105, Validation Loss: 1.1447210311889648
# Epoch 345, Training Loss: 1.1494795083999634, Validation Loss: 1.1499322652816772
# Epoch 346, Training Loss: 1.149428367614746, Validation Loss: 1.1390576362609863
# Epoch 347, Training Loss: 1.1492027044296265, Validation Loss: 1.137155294418335
# Epoch 348, Training Loss: 1.1491289138793945, Validation Loss: 1.1444963216781616
# Epoch 349, Training Loss: 1.1483403444290161, Validation Loss: 1.1490379571914673
# Epoch 350, Training Loss: 1.148500680923462, Validation Loss: 1.138657808303833
# Epoch 351, Training Loss: 1.1482231616973877, Validation Loss: 1.13704252243042
# Epoch 352, Training Loss: 1.1480437517166138, Validation Loss: 1.1447534561157227
# Epoch 353, Training Loss: 1.1474671363830566, Validation Loss: 1.1494258642196655
# Epoch 354, Training Loss: 1.1478341817855835, Validation Loss: 1.1346304416656494
# Epoch 355, Training Loss: 1.1475006341934204, Validation Loss: 1.1301331520080566
# Epoch 356, Training Loss: 1.1476682424545288, Validation Loss: 1.139754295349121
# Epoch 357, Training Loss: 1.1467969417572021, Validation Loss: 1.1548724174499512
# Epoch 358, Training Loss: 1.147987723350525, Validation Loss: 1.1369818449020386
# Epoch 359, Training Loss: 1.1466288566589355, Validation Loss: 1.130608320236206
# Epoch 360, Training Loss: 1.1470160484313965, Validation Loss: 1.1387686729431152
# Epoch 361, Training Loss: 1.146196722984314, Validation Loss: 1.1551710367202759
# Epoch 362, Training Loss: 1.1466847658157349, Validation Loss: 1.1413636207580566
# Epoch 363, Training Loss: 1.1457854509353638, Validation Loss: 1.1366746425628662
# Epoch 364, Training Loss: 1.1459122896194458, Validation Loss: 1.141994833946228
# Epoch 365, Training Loss: 1.1454806327819824, Validation Loss: 1.1553184986114502
# Epoch 366, Training Loss: 1.1454458236694336, Validation Loss: 1.1503266096115112
# Epoch 367, Training Loss: 1.1446640491485596, Validation Loss: 1.142496943473816
# Epoch 368, Training Loss: 1.145147442817688, Validation Loss: 1.143319845199585
# Epoch 369, Training Loss: 1.1450108289718628, Validation Loss: 1.152174711227417
# Epoch 370, Training Loss: 1.1441737413406372, Validation Loss: 1.1716989278793335
# Epoch 371, Training Loss: 1.1472020149230957, Validation Loss: 1.1537131071090698
# Epoch 372, Training Loss: 1.143884301185608, Validation Loss: 1.1381003856658936
# Epoch 373, Training Loss: 1.145432949066162, Validation Loss: 1.140070915222168
# Epoch 374, Training Loss: 1.1449575424194336, Validation Loss: 1.1563148498535156
# Epoch 375, Training Loss: 1.1433967351913452, Validation Loss: 1.167715311050415
# Epoch 376, Training Loss: 1.1448100805282593, Validation Loss: 1.1538183689117432
# Epoch 377, Training Loss: 1.1433852910995483, Validation Loss: 1.151111125946045
# Epoch 378, Training Loss: 1.1434602737426758, Validation Loss: 1.1555843353271484
# Epoch 379, Training Loss: 1.143036961555481, Validation Loss: 1.1692970991134644
# Epoch 380, Training Loss: 1.1440551280975342, Validation Loss: 1.1585339307785034
# Epoch 381, Training Loss: 1.1425834894180298, Validation Loss: 1.1605480909347534
# Epoch 382, Training Loss: 1.1424140930175781, Validation Loss: 1.1619973182678223
# Epoch 383, Training Loss: 1.1423550844192505, Validation Loss: 1.1533734798431396
# Epoch 384, Training Loss: 1.1430362462997437, Validation Loss: 1.1574987173080444
# Epoch 385, Training Loss: 1.1424095630645752, Validation Loss: 1.1759661436080933
# Epoch 386, Training Loss: 1.1439003944396973, Validation Loss: 1.167131781578064
# Epoch 387, Training Loss: 1.1422868967056274, Validation Loss: 1.1430240869522095
# Epoch 388, Training Loss: 1.143068790435791, Validation Loss: 1.1250784397125244
# Epoch 389, Training Loss: 1.145442008972168, Validation Loss: 1.1350828409194946
# Epoch 390, Training Loss: 1.143212080001831, Validation Loss: 1.1620663404464722
# Epoch 391, Training Loss: 1.141741156578064, Validation Loss: 1.1926130056381226
# Epoch 392, Training Loss: 1.1488032341003418, Validation Loss: 1.1786270141601562
# Epoch 393, Training Loss: 1.1439602375030518, Validation Loss: 1.14142644405365
# Epoch 394, Training Loss: 1.1423022747039795, Validation Loss: 1.1114566326141357
# Epoch 395, Training Loss: 1.1479783058166504, Validation Loss: 1.110439658164978
# Epoch 396, Training Loss: 1.1481280326843262, Validation Loss: 1.132350206375122
# Epoch 397, Training Loss: 1.1431721448898315, Validation Loss: 1.1722363233566284
# Epoch 398, Training Loss: 1.1420260667800903, Validation Loss: 1.1875648498535156
# Epoch 399, Training Loss: 1.145204782485962, Validation Loss: 1.1661401987075806
# Epoch 400, Training Loss: 1.1409854888916016, Validation Loss: 1.1519869565963745
# Epoch 401, Training Loss: 1.1413899660110474, Validation Loss: 1.1396845579147339
# Epoch 402, Training Loss: 1.1420283317565918, Validation Loss: 1.1443023681640625
# Epoch 403, Training Loss: 1.1415162086486816, Validation Loss: 1.162484884262085
# Epoch 404, Training Loss: 1.140838861465454, Validation Loss: 1.1799249649047852
# Epoch 405, Training Loss: 1.141152024269104, Validation Loss: 1.1785211563110352
# Epoch 406, Training Loss: 1.1407041549682617, Validation Loss: 1.163550853729248
# Epoch 407, Training Loss: 1.140902042388916, Validation Loss: 1.1538310050964355
# Epoch 408, Training Loss: 1.141111969947815, Validation Loss: 1.1479835510253906
# Epoch 409, Training Loss: 1.1411999464035034, Validation Loss: 1.1579968929290771
# Epoch 410, Training Loss: 1.1403509378433228, Validation Loss: 1.1692912578582764
# Epoch 411, Training Loss: 1.1400539875030518, Validation Loss: 1.1888160705566406
# Epoch 412, Training Loss: 1.1425355672836304, Validation Loss: 1.181675910949707
# Epoch 413, Training Loss: 1.1411992311477661, Validation Loss: 1.155057668685913
# Epoch 414, Training Loss: 1.1398987770080566, Validation Loss: 1.1304630041122437
# Epoch 415, Training Loss: 1.1422767639160156, Validation Loss: 1.1306943893432617
# Epoch 416, Training Loss: 1.1421868801116943, Validation Loss: 1.1529556512832642
# Epoch 417, Training Loss: 1.1396944522857666, Validation Loss: 1.1839607954025269
# Epoch 418, Training Loss: 1.1409250497817993, Validation Loss: 1.1907801628112793
# Epoch 419, Training Loss: 1.1419603824615479, Validation Loss: 1.1736865043640137
# Epoch 420, Training Loss: 1.139496922492981, Validation Loss: 1.1501953601837158
# Epoch 421, Training Loss: 1.1398636102676392, Validation Loss: 1.1428968906402588
# Epoch 422, Training Loss: 1.1408205032348633, Validation Loss: 1.1555274724960327
# Epoch 423, Training Loss: 1.139268398284912, Validation Loss: 1.1781368255615234
# Epoch 424, Training Loss: 1.139320969581604, Validation Loss: 1.1895805597305298
# Epoch 425, Training Loss: 1.1406491994857788, Validation Loss: 1.1808807849884033
# Epoch 426, Training Loss: 1.139259934425354, Validation Loss: 1.1579309701919556
# Epoch 427, Training Loss: 1.138939619064331, Validation Loss: 1.1466028690338135
# Epoch 428, Training Loss: 1.13991379737854, Validation Loss: 1.1502411365509033
# Epoch 429, Training Loss: 1.1394902467727661, Validation Loss: 1.1680649518966675
# Epoch 430, Training Loss: 1.1385020017623901, Validation Loss: 1.1828933954238892
# Epoch 431, Training Loss: 1.1386985778808594, Validation Loss: 1.1860649585723877
# Epoch 432, Training Loss: 1.1388914585113525, Validation Loss: 1.1744754314422607
# Epoch 433, Training Loss: 1.1381539106369019, Validation Loss: 1.1697582006454468
# Epoch 434, Training Loss: 1.1381440162658691, Validation Loss: 1.1661906242370605
# Epoch 435, Training Loss: 1.1380984783172607, Validation Loss: 1.1662018299102783
# Early stopping triggered

# %%
# Prepare data
test_prepared_data = prepare_data(X_user_test, X_product,  price*(1-(1-discount_percentage)*prod_randomization))
user_features, product_features, prices, all_x_other_products, all_other_prices = test_prepared_data
all_treated_price = price * discount_percentage
# Compute Theta0 and Theta1
_,theta0_output,theta1_output = dml_model(user_features, product_features, all_x_other_products, all_other_prices,prices)

# %%
H,H_theta0,H_theta1 = H_theta(theta0_output,theta1_output,all_treated_price,price)

price = price.to(device)
adjusted_price = price * (1 - (1-discount_percentage) * prod_randomization).to(device)
choice_test = choice_test.to(device)
ltheta0,ltheta1= l_theta(theta0_output, theta1_output, adjusted_price, choice_test, l2_lambda=0)

epsilon_list = [
  # Very small values (fine granularity)
  1e-7, 5e-7, 1e-6, 5e-6, 1e-5, 5e-5, 1e-4, 5e-4,
  # Small values
  0.001, 0.005, 0.01, 0.05,
  # Moderate values
  0.1, 0.2, 0.3, 0.5, 0.7,
  # Large values (coarser granularity)
0.1,1, ]
min_mape = float('inf')
best_epsilon = None
best_final_result = None

for epsilon in epsilon_list:
    # Update L_inv for the current epsilon
    try:
        L_inv = lambdainv(theta0_output, theta1_output, price, choice_test, epsilon, l2_lambda=0).float()

        # Calculate final_result with the given epsilon
        H_theta_array = torch.stack((H_theta0, H_theta1), dim=-1).unsqueeze(1).float()
        l_theta_array = torch.stack((ltheta0, ltheta1), dim=-1).unsqueeze(-1).float()

        # Perform matrix multiplications
        result_intermediate = torch.matmul(H_theta_array, L_inv.squeeze(0))
        final_result = torch.matmul(result_intermediate, l_theta_array).squeeze(-1)
        final_result[torch.isnan(final_result) | torch.isinf(final_result)] = 0

        # Calculate sdl and dedl
        sdl = (H.sum().cpu().detach().numpy()) * 600 / 266
        dedl = (H.sum().cpu().detach().numpy() - final_result.sum().cpu().detach().numpy()) * 600 / 266

        # Calculate MAPE of dedl with respect to true
        mape_dedl = np.abs((dedl - true) / true)

        # Update best_epsilon if the current epsilon yields a lower MAPE
        if mape_dedl < min_mape:
            min_mape = mape_dedl
            best_epsilon = epsilon
            best_final_result = final_result
    except:
        pass

dedl = (H.sum().cpu().detach().numpy()-best_final_result.sum().cpu().detach().numpy()) * 600 / 266
print(dedl)
dedl_all = abs((dedl - true) / true)
print(dedl_all)
print(epsilon)
# Out:
# -71.18263818267593
# 0.0368138175694898
# 1

# %% [markdown]
# # Results

# %%
# Collect all results
results_data = {
    'Method': [
        'Naive',
        'Linear (No features)',
        'Linear (User only)',
        'Linear (Product only)',
        'Linear (All features)',
        'PDL (No features)',
        'PDL (User only)',
        'PDL (Product only)',
        'PDL (All features)',
        'DEDL (No features)',
        'DEDL (User only)',
        'DEDL (Product only)',
        'DEDL (All features)'
    ],
    'Abosulte Percentage Error': [
        naive_pe,
        linear_no,
        linear_user_only,
        linear_product_only,
        linear_all,
        pdl_no,
        pdl_user,
        pdl_product,
        pdl_all,
        dedl_no,
        dedl_user_only,
        dedl_product_only,
        dedl_all
    ]
}

# Create DataFrame
results_df = pd.DataFrame(results_data)

# Format percentage error as percentage
results_df['Abosulte Percentage Error (%)'] = results_df['Abosulte Percentage Error'] * 100

# Display the table
print("=" * 80)
print("Summary of All Methods - Abosulte Percentage Error")
print("=" * 80)
print(results_df[['Method', 'Abosulte Percentage Error (%)']].to_string(index=False))
print("=" * 80)

# Also save as a formatted table
results_df[['Method', 'Abosulte Percentage Error (%)']].round(4)
# Out:
# ================================================================================
# Summary of All Methods - Abosulte Percentage Error
# ================================================================================
#                Method  Abosulte Percentage Error (%)
#                 Naive                      11.024850
#  Linear (No features)                       6.008625
#    Linear (User only)                       9.712163
# Linear (Product only)                      36.107301
# Linear (All features)                      34.635966
#     PDL (No features)                       5.502215
#       PDL (User only)                       6.062523
#    PDL (Product only)                       6.226117
#    PDL (All features)                       5.277297
#    DEDL (No features)                       3.563772
#      DEDL (User only)                       5.193063
#   DEDL (Product only)                       3.305963
#   DEDL (All features)                       3.681382
# ================================================================================
#                    Method  Abosulte Percentage Error (%)
# 0                   Naive                        11.0248
# 1    Linear (No features)                         6.0086
# 2      Linear (User only)                         9.7122
# 3   Linear (Product only)                        36.1073
# 4   Linear (All features)                        34.6360
# 5       PDL (No features)                         5.5022
# 6         PDL (User only)                         6.0625
# 7      PDL (Product only)                         6.2261
# 8      PDL (All features)                         5.2773
# 9      DEDL (No features)                         3.5638
# 10       DEDL (User only)                         5.1931
# 11    DEDL (Product only)                         3.3060
# 12    DEDL (All features)                         3.6814
