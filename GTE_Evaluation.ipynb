# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import MinMaxScaler,StandardScaler
import torch
from sklearn.model_selection import train_test_split
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
import math
import random

# %% [markdown]
# # Prepare Data

# %%
df_no = pd.read_csv('no_discount.csv')
df_all = pd.read_csv('all_discount.csv')
df_half = pd.read_csv('half_discount.csv')
df_prod = pd.read_csv('product.csv')

# %%
# Map user features to number
dataframes = {'all': df_all, 'half': df_half, 'no': df_no}
feature_cols = ['user_feature_1', 'user_feature_2', 'user_feature_3']
category_maps = {}

# 1. Build mapping for each feature across all dataframes
for col in feature_cols:
    # Collect unique values from all dataframes for this column
    unique_vals = pd.concat([df[col] for df in dataframes.values()]).unique()
    cat_map = {cat: i+1 for i, cat in enumerate(sorted(unique_vals))}
    category_maps[col] = cat_map

# 2. Apply the mapping to each dataframe
for df in dataframes.values():
    for col in feature_cols:
        df[col + '_num'] = df[col].map(category_maps[col])

# 3. Show mapping for each feature
for col in feature_cols:
    print(f"\nMapping for {col}:")
    for cat, idx in category_maps[col].items():
        print(f"{idx}: {cat}")
# Out:
# Mapping for user_feature_1:
# 1: Female
# 2: Male
# 3: Non-binary / third gender
# 4: Prefer not to say
#
# Mapping for user_feature_2:
# 1: 1-2 years ago
# 2: 2-3 years ago
# 3: 3-4 yeas ago
# 4: Currently, I don't have a phone
# 5: Less than 1 year ago
# 6: More than 4 years ago
#
# Mapping for user_feature_3:
# 1: Brand reputation
# 2: Design and appearance
# 3: Good price
# 4: Product quality

# %%
# Map choice to number (no discount)
# Define the mapping for 'choice'
choice_map = {
    "Do not purchase; save the $30 or use it for other expenses ($30 is roughly enough to cover two meals at a fast-food restaurant in the U.S.)": 0,
    "Color: Black; Style: Solid color; Weight: 2.66 pounds; Price: $24 (MSRP: $24)": 1,
    "Color: Black; Style: Gradient color; Weight: 2.66 pounds; Price: $26 (MSRP: $26)": 2,
    "Color: Dark blue; Style: Solid color; Weight: 2.61 pounds; Price: $25 (MSRP: $25)": 3,
    "Color: Dark blue; Style: Gradient color; Weight: 2.64 pounds; Price: $25 (MSRP: $25)": 4,
    "Color: Light blue; Style: Gradient color; Weight: 2.68 pounds; Price: $26 (MSRP: $26)": 5,
    "Color: White; Style: Solid color; Weight: 2.68 pounds; Price: $27 (MSRP: $27)": 6
}

# Apply the mapping
df_no['choice_num'] = df_no['choice'].map(choice_map)

# %%
# Map choice to number (all discount)
# Define the mapping for 'choice'
choice_map = {
    "Do not purchase; save the $30 or use it for other expenses ($30 is roughly enough to cover two meals at a fast-food restaurant in the U.S.)": 0,
    "Color: Black; Style: Solid color; Weight: 2.66 pounds; Price: $4.8 (MSRP: $24)": 1,
    "Color: Black; Style: Gradient color; Weight: 2.66 pounds; Price: $5.2 (MSRP: $26)": 2,
    "Color: Dark blue; Style: Solid color; Weight: 2.61 pounds; Price: $5 (MSRP: $25)": 3,
    "Color: Dark blue; Style: Gradient color; Weight: 2.64 pounds; Price: $5 (MSRP: $25)": 4,
    "Color: Light blue; Style: Gradient color; Weight: 2.68 pounds; Price: $5.2 (MSRP: $26)": 5,
    "Color: White; Style: Solid color; Weight: 2.68 pounds; Price: $5.4 (MSRP: $27)": 6
}

# Apply the mapping
df_all['choice_num'] = df_all['choice'].map(choice_map)

# %%
# Map choice to number (half discount)
# Define the mapping for 'choice'
choice_map = {
    "Do not purchase; save the $30 or use it for other expenses ($30 is roughly enough to cover two meals at a fast-food restaurant in the U.S.)": 0,
    "Color: Black; Style: Solid color; Weight: 2.66 pounds; Price: $4.8 (MSRP: $24)": 1,
    "Color: Black; Style: Gradient color; Weight: 2.66 pounds; Price: $26 (MSRP: $26)": 2,
    "Color: Dark blue; Style: Solid color; Weight: 2.61 pounds; Price: $25 (MSRP: $25)": 3,
    "Color: Dark blue; Style: Gradient color; Weight: 2.64 pounds; Price: $25 (MSRP: $25)": 4,
    "Color: Light blue; Style: Gradient color; Weight: 2.68 pounds; Price: $5.2 (MSRP: $26)": 5,
    "Color: White; Style: Solid color; Weight: 2.68 pounds; Price: $5.4 (MSRP: $27)": 6
}

# Apply the mapping
df_half['choice_num'] = df_half['choice'].map(choice_map)

# %%
# Normalization:  price
# Define the columns to scale
columns_to_scale = ['price']

# Initialize the scaler
scaler = MinMaxScaler()

# Fit and transform the selected columns
df_prod[columns_to_scale] = scaler.fit_transform(df_prod[columns_to_scale])

# %%
# Set parameters
discount_percentage = 0.2
num_product = 6

# %%
# Check the number of valid data
num_row_no = len(df_no)
num_row_all = len(df_all)
num_row_half = len(df_half)
print(num_row_no)
print(num_row_all)
print(num_row_half)
# Out:
# 291
# 278
# 266

# %% [markdown]
# # True GTE

# %%
# All products are control (no discount)
# Merge the purchasing data with the product data
merged_no = df_no.merge(df_prod, left_on='choice_num', right_on='product_id', how='left')

# Calculate the total revenue
revenue_control = 0
revenue_control = merged_no['price'].sum() * 300/291

# All products are treated (all discount)
# Merge the purchasing data with the product data
merged_all = df_all.merge(df_prod, left_on='choice_num', right_on='product_id', how='left')

# Calculate the total revenue
revenue_treated = 0
revenue_treated = merged_all['price'].sum() * discount_percentage * 300/278

# Calculate the GTE
true = revenue_treated - revenue_control
print(true)
# Out:
# -68.6551789496238

# %% [markdown]
# # Prepare Function

# %% [markdown]
# ## DIM

# %%
def calculate_total_revenue(df):
    revenue_treated = 0.0
    revenue_control = 0.0
    df['adjusted_price'] = df.apply(
        lambda row: row['price'] * discount_percentage if row['if_treated'] == 1 else row['price'], axis=1
    )
    for _, row in df.iterrows():
        if row['if_treated'] == 0:
            revenue_control += row['adjusted_price']
        elif row['if_treated'] == 1:
            revenue_treated += row['adjusted_price']
    return revenue_control, revenue_treated

# %% [markdown]
# ## MNL

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
def prepare_data_bootstrap(prod, df):
    """
    Prepare data from a dataframe (can be full dataset or bootstrap sample)
    """
    # Product features (skip the first row)
    feature_cols = ['product_feature_1', 'product_feature_2', 'product_feature_3']
    X_product = torch.tensor(
        prod[feature_cols].iloc[1:].to_numpy(),
        dtype=torch.float
    )

    # Price (skip first row)
    price = torch.tensor(
        prod['price'].iloc[1:].to_numpy(),
        dtype=torch.float
    )

    # Product randomization (skip first row)
    prod_randomization = torch.tensor(
        prod['if_treated'].iloc[1:].to_numpy(),
        dtype=torch.bool
    )

    # User features
    user_num_cols = ['user_feature_1_num', 'user_feature_2_num', 'user_feature_3_num']
    X_user = torch.tensor(
        df[user_num_cols].to_numpy(),
        dtype=torch.float
    )

    # User choice
    choice = torch.tensor(
        df['choice_num'].to_numpy(),
        dtype=torch.long
    )

    X_user = X_user.to(device)
    X_product = X_product.to(device)
    price = price.to(device)
    prod_randomization = prod_randomization.to(device)
    choice = choice.to(device)

    return X_user, choice, X_product, price, prod_randomization

# %%
def set_seed(seed: int):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False

# %%
def init_weights(m):
    if isinstance(m, nn.Linear):
        nn.init.xavier_uniform_(m.weight)
        if m.bias is not None:
            m.bias.data.fill_(0.01)

# %%
def init_weights(m):
    if isinstance(m, nn.Linear):
        nn.init.xavier_uniform_(m.weight)
        if m.bias is not None:
            m.bias.data.fill_(0.01)

# %%
class LinearMNLModel_No(nn.Module):
    def __init__(self):
        super(LinearMNLModel_No, self).__init__()
        # v is the same constant value for all products.
        self.v = nn.Parameter(torch.tensor(1.0))
        # gamma is the price sensitivity parameter.
        self.gamma = nn.Parameter(torch.tensor(-1.0))

    def forward(self, x_user, X_product, price, prod_randomization):
        N = x_user.shape[0]
        # Adjust prices for treated products (discounted)
        adjusted_price = torch.where(
            prod_randomization,
            price * discount_percentage,
            price
        )
        # Compute utilities: shape [M]
        utility = self.v + self.gamma * adjusted_price
        # Expand to shape [N, M]
        utility = utility.expand(N, -1)
        # Add outside option (utility = 0)
        zero_utilities = torch.zeros(N, 1, device=utility.device)
        utilities_with_outside = torch.cat((zero_utilities, utility), dim=1)
        return utilities_with_outside

# %%
class LinearMNLModel_UserOnly(nn.Module):
    def __init__(self, user_feature_dim):
        super(LinearMNLModel_UserOnly, self).__init__()
        self.beta_user = nn.Parameter(torch.randn(user_feature_dim))
        self.beta_price = nn.Parameter(torch.tensor(-1.0))

    def forward(self, x_user, X_product, price, prod_randomization):
        N, M = x_user.shape[0], X_product.shape[0]

        # Expand user features
        x_user_expanded = x_user.unsqueeze(1).expand(-1, M, -1).detach()
        utility_user = torch.sum(x_user_expanded * self.beta_user, dim=2)

        # Price adjustment
        adjusted_price = torch.where(
            prod_randomization.unsqueeze(0),
            price * discount_percentage,
            price
        )
        utility_price = adjusted_price * self.beta_price
        utility_price = utility_price.expand(N, M)

        total_utility = utility_user + utility_price

        # Outside option
        zero_utilities = torch.zeros(N, 1, device=total_utility.device)
        utilities_with_outside = torch.cat((zero_utilities,total_utility), dim=1)
        return utilities_with_outside

# %%
class LinearMNLModel_ProductOnly(nn.Module):
    def __init__(self, product_feature_dim):
        super(LinearMNLModel_ProductOnly, self).__init__()
        self.beta_product = nn.Parameter(torch.randn(product_feature_dim))
        self.beta_price = nn.Parameter(torch.tensor(-1.0))

    def forward(self, x_user, X_product, price, prod_randomization):
        N, M = x_user.shape[0], X_product.shape[0]

        # Expand product features
        X_product_expanded = X_product.unsqueeze(0).expand(N, -1, -1).detach()
        utility_product = torch.sum(X_product_expanded * self.beta_product, dim=2)

        # Price adjustment
        adjusted_price = torch.where(
            prod_randomization.unsqueeze(0),
            price * discount_percentage,
            price
        )
        utility_price = adjusted_price * self.beta_price
        utility_price = utility_price.expand(N, M)

        total_utility = utility_product + utility_price

        # Outside option
        zero_utilities = torch.zeros(N, 1, device=total_utility.device)
        utilities_with_outside = torch.cat((zero_utilities,total_utility), dim=1)
        return utilities_with_outside

# %%
# MNL choice model
class LinearMNLModel(nn.Module):
    def __init__(self, user_feature_dim, product_feature_dim):
        super(LinearMNLModel, self).__init__()
        # Initialize parameters for user and product features
        self.beta_user = nn.Parameter(torch.randn(user_feature_dim))
        self.beta_product = nn.Parameter(torch.randn(product_feature_dim))
        self.beta_price = nn.Parameter(torch.tensor(-1.0))
    def forward(self, x_user, X_product, price, prod_randomization):
        N, M = x_user.shape[0], X_product.shape[0]

        # Expand user and product features to create a [N, M, F] shaped tensor for each
        x_user_expanded = x_user.unsqueeze(1).expand(-1, M, -1).detach()
        X_product_expanded = X_product.unsqueeze(0).expand(N, -1, -1).detach()

        # Calculate linear utility from features
        utility_user = torch.sum(x_user_expanded * self.beta_user, dim=2)
        utility_product = torch.sum(X_product_expanded * self.beta_product, dim=2)

        # Adjust prices based on randomization
        adjusted_price = torch.where(
            prod_randomization.unsqueeze(0),
            price * discount_percentage,
            price
        )

        # Calculate utility from price, properly expanding its dimension
        utility_price = adjusted_price * self.beta_price  # [M]
        utility_price = utility_price.expand(N, M)  # [N, M]

        # Total utility including features and price
        total_utility = utility_user + utility_product + utility_price

        # Incorporate the outside option with utility 0
        zero_utilities = torch.zeros(N, 1, device=total_utility.device)
        utilities_with_outside = torch.cat((zero_utilities,total_utility), dim=1)

        return utilities_with_outside

# %%
# Helper function to check loss drop
def loss_drop(hist, window=5):
    if len(hist) < 2 * window:
        return 0.0
    early = np.mean(hist[:window])
    late = np.mean(hist[-window:])
    return early - late

# %%
#Function to train model and compute revenue difference
# Returns: (linear_pe, linear_ape, trained_ok)
def train_and_estimate_linear_no(X_user, X_user_train1, X_user_test, choice_train1, choice_test, X_user_val, choice_val, X_product, price, prod_randomization, device, num_epochs=1000, lr=0.01, step_size=2500, gamma=0.5, patience=10, attempt=0,
    ci_alpha=0.05, return_ci=True):
    # Initialize the model
    model = LinearMNLModel_No().to(device)
    model.apply(init_weights)

    optimizer = optim.Adam(model.parameters(), lr)
    scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size, gamma)

    best_val_loss = float('inf')
    best_epoch = -1
    patience_counter = 0
    trained_ok = False
    train_hist, val_hist = [], []
    best_path = f'best_model_attempt_linear_no{attempt}.pth'

    K = None  # choice set size (including outside)

    # Train the model
    for epoch in range(num_epochs):
        model.train()
        optimizer.zero_grad()

        # Forward pass (Training)
        utilities = model(X_user_train1, X_product, price, prod_randomization)
        
        if epoch == 0:
            K = utilities.shape[1]
        
        choice_probabilities = F.log_softmax(utilities, dim=1)
        loss = -torch.mean(choice_probabilities[torch.arange(choice_probabilities.shape[0]), choice_train1])


        # Numerical stability check
        if not torch.isfinite(loss).all():
            print(f"[attempt={attempt}] NaN/Inf loss at epoch {epoch}. Aborting.")
            return None, None, False

        # Backward pass
        loss.backward()
        optimizer.step()
        scheduler.step()

        model.eval()
        with torch.no_grad():
            val_utilities = model(X_user_val, X_product, price, prod_randomization)
            val_utilities = val_utilities - val_utilities.max(dim=1, keepdim=True).values
            val_choice_probabilities = F.log_softmax(val_utilities, dim=1)
            val_loss = -torch.mean(val_choice_probabilities[torch.arange(val_choice_probabilities.shape[0]), choice_val])

        train_hist.append(loss.item())
        val_hist.append(val_loss.item())

        # Early stopping
        if val_loss.item() < best_val_loss:
            best_val_loss = val_loss.item()
            best_epoch = epoch
            patience_counter = 0
            torch.save(model.state_dict(), best_path)
            trained_ok = True
        else:
            patience_counter += 1

        if patience_counter >= patience:
            print(f"[attempt={attempt}] Early stopping at epoch {epoch+1} (best epoch {best_epoch}, best val {best_val_loss:.4f})")
            break

    # Load best model
    if trained_ok:
        model.load_state_dict(torch.load(best_path))
    else:
        print(f"[attempt={attempt}] WARNING: no validation improvement.")
        return None, None, False

    # Check if training was meaningful
    drop_train = loss_drop(train_hist)
    drop_val = loss_drop(val_hist)
    if (drop_train < 1e-3) or (drop_val < 1e-3):
        print(f"[attempt={attempt}] Skipping — no meaningful training (Δtrain={drop_train:.3g}, Δval={drop_val:.3g}).")
        return None, None, False

    # Check near-random model
    if K is not None and best_val_loss > (math.log(K) - 0.05):
        print(f"[attempt={attempt}] Mark UNSTABLE: near_random, best_val={best_val_loss:.4f}, lnK={math.log(K):.4f}")
        return None, None, False

    # =========================
    # Evaluate expected revenue + CI
    # =========================
    N_products = X_product.shape[0]
    price_with_outside = torch.cat((torch.zeros(1, device=price.device), price), dim=0)  # [K], K=J+1

    # Control
    all_control = torch.zeros(N_products, dtype=torch.bool, device=device)
    utilities_control = model(X_user_test, X_product, price, all_control)
    probs_control = F.softmax(utilities_control, dim=1)  # [n_test, K]
    rev_control_i = torch.sum(
        probs_control * price_with_outside.unsqueeze(0).expand_as(probs_control),
        dim=1
    )  # [n_test]

    # Treated
    all_treated = torch.ones(N_products, dtype=torch.bool, device=device)
    utilities_treated = model(X_user_test, X_product, price, all_treated)
    probs_treated = F.softmax(utilities_treated, dim=1)
    rev_treated_i = torch.sum(
        probs_treated * price_with_outside.unsqueeze(0).expand_as(probs_treated),
        dim=1
    ) * float(discount_percentage)  # [n_test]

    diff_i = rev_treated_i - rev_control_i  # [n_test]

    n_test = diff_i.shape[0]
    scale = 300.0 / float(n_test)

    linear = (diff_i.sum() * scale).item()  # sum(diff_i)*300/n_test

    # --- CI (CLT over users) ---
    diff_sd = diff_i.std(unbiased=True)
    se_linear = (diff_sd / math.sqrt(float(n_test)) * 300.0).item()

    z = torch.distributions.Normal(0.0, 1.0).icdf(torch.tensor(1 - ci_alpha / 2)).item()
    ci_low = linear - z * se_linear
    ci_high = linear + z * se_linear

    covered = None
    if true is not None:
        covered = (ci_low <= float(true) <= ci_high)

    # --- Your PE/APE ---
    if true is None:
        linear_pe, linear_ape = None, None
    else:
        linear_pe = (linear - float(true)) / float(true)
        linear_ape = abs(linear_pe)

    if return_ci:
        print(
            f"[attempt={attempt}] est={linear:.6f}, SE={se_linear:.6f}, "
            f"{int((1-ci_alpha)*100)}% CI=[{ci_low:.6f}, {ci_high:.6f}], "
            f"covered={covered}"
        )
        return linear_pe, linear_ape, (ci_low, ci_high), covered, True

    return linear_pe, linear_ape, True

# %%
#Function to train model and compute revenue difference
# Returns: (linear_pe, linear_ape, trained_ok)
def train_and_estimate_linear_user(X_user, X_user_train1, X_user_test, choice_train1, choice_test, X_user_val, choice_val, X_product, price, prod_randomization, device, num_epochs=1000, lr=0.01, step_size=2500, gamma=0.5, patience=10, attempt=0,
    ci_alpha=0.05, return_ci=True):
    # Initialize the model
    model = LinearMNLModel_UserOnly(user_feature_dim=X_user.shape[1]).to(device)
    model.apply(init_weights)

    optimizer = optim.Adam(model.parameters(), lr)
    scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size, gamma)

    best_val_loss = float('inf')
    best_epoch = -1
    patience_counter = 0
    trained_ok = False
    train_hist, val_hist = [], []
    best_path = f'best_model_attempt_linear_user{attempt}.pth'

    K = None  # choice set size (including outside)

    # Train the model
    for epoch in range(num_epochs):
        model.train()
        optimizer.zero_grad()

        # Forward pass (Training)
        utilities = model(X_user_train1, X_product, price, prod_randomization)
        
        if epoch == 0:
            K = utilities.shape[1]
        
        choice_probabilities = F.log_softmax(utilities, dim=1)
        loss = -torch.mean(choice_probabilities[torch.arange(choice_probabilities.shape[0]), choice_train1])


        # Numerical stability check
        if not torch.isfinite(loss).all():
            print(f"[attempt={attempt}] NaN/Inf loss at epoch {epoch}. Aborting.")
            return None, None, False

        # Backward pass
        loss.backward()
        optimizer.step()
        scheduler.step()

        model.eval()
        with torch.no_grad():
            val_utilities = model(X_user_val, X_product, price, prod_randomization)
            val_utilities = val_utilities - val_utilities.max(dim=1, keepdim=True).values
            val_choice_probabilities = F.log_softmax(val_utilities, dim=1)
            val_loss = -torch.mean(val_choice_probabilities[torch.arange(val_choice_probabilities.shape[0]), choice_val])

        train_hist.append(loss.item())
        val_hist.append(val_loss.item())

        # Early stopping
        if val_loss.item() < best_val_loss:
            best_val_loss = val_loss.item()
            best_epoch = epoch
            patience_counter = 0
            torch.save(model.state_dict(), best_path)
            trained_ok = True
        else:
            patience_counter += 1

        if patience_counter >= patience:
            print(f"[attempt={attempt}] Early stopping at epoch {epoch+1} (best epoch {best_epoch}, best val {best_val_loss:.4f})")
            break

    # Load best model
    if trained_ok:
        model.load_state_dict(torch.load(best_path))
    else:
        print(f"[attempt={attempt}] WARNING: no validation improvement.")
        return None, None, False

    # Check if training was meaningful
    drop_train = loss_drop(train_hist)
    drop_val = loss_drop(val_hist)
    if (drop_train < 1e-3) or (drop_val < 1e-3):
        print(f"[attempt={attempt}] Skipping — no meaningful training (Δtrain={drop_train:.3g}, Δval={drop_val:.3g}).")
        return None, None, False

    # Check near-random model
    if K is not None and best_val_loss > (math.log(K) - 0.05):
        print(f"[attempt={attempt}] Mark UNSTABLE: near_random, best_val={best_val_loss:.4f}, lnK={math.log(K):.4f}")
        return None, None, False

    # =========================
    # Evaluate expected revenue + CI
    # =========================
    N_products = X_product.shape[0]
    price_with_outside = torch.cat((torch.zeros(1, device=price.device), price), dim=0)  # [K], K=J+1

    # Control
    all_control = torch.zeros(N_products, dtype=torch.bool, device=device)
    utilities_control = model(X_user_test, X_product, price, all_control)
    probs_control = F.softmax(utilities_control, dim=1)  # [n_test, K]
    rev_control_i = torch.sum(
        probs_control * price_with_outside.unsqueeze(0).expand_as(probs_control),
        dim=1
    )  # [n_test]

    # Treated
    all_treated = torch.ones(N_products, dtype=torch.bool, device=device)
    utilities_treated = model(X_user_test, X_product, price, all_treated)
    probs_treated = F.softmax(utilities_treated, dim=1)
    rev_treated_i = torch.sum(
        probs_treated * price_with_outside.unsqueeze(0).expand_as(probs_treated),
        dim=1
    ) * float(discount_percentage)  # [n_test]

    diff_i = rev_treated_i - rev_control_i  # [n_test]

    n_test = diff_i.shape[0]
    scale = 300.0 / float(n_test)

    linear = (diff_i.sum() * scale).item()  # sum(diff_i)*300/n_test

    # --- CI (CLT over users) ---
    diff_sd = diff_i.std(unbiased=True)
    se_linear = (diff_sd / math.sqrt(float(n_test)) * 300.0).item()

    z = torch.distributions.Normal(0.0, 1.0).icdf(torch.tensor(1 - ci_alpha / 2)).item()
    ci_low = linear - z * se_linear
    ci_high = linear + z * se_linear

    covered = None
    if true is not None:
        covered = (ci_low <= float(true) <= ci_high)

    # --- Your PE/APE ---
    if true is None:
        linear_pe, linear_ape = None, None
    else:
        linear_pe = (linear - float(true)) / float(true)
        linear_ape = abs(linear_pe)

    if return_ci:
        print(
            f"[attempt={attempt}] est={linear:.6f}, SE={se_linear:.6f}, "
            f"{int((1-ci_alpha)*100)}% CI=[{ci_low:.6f}, {ci_high:.6f}], "
            f"covered={covered}"
        )
        return linear_pe, linear_ape, (ci_low, ci_high), covered, True

    return linear_pe, linear_ape, True

# %%
#Function to train model and compute revenue difference
# Returns: (linear_pe, linear_ape, trained_ok)
def train_and_estimate_linear_product(X_user, X_user_train1, X_user_test, choice_train1, choice_test, X_user_val, choice_val, X_product, price, prod_randomization, device, num_epochs=1000, lr=0.01, step_size=2500, gamma=0.5, patience=10, attempt=0,
    ci_alpha=0.05, return_ci=True):
    # Initialize the model
    model = LinearMNLModel_ProductOnly(product_feature_dim=X_product.shape[1]).to(device)
    model.apply(init_weights)

    optimizer = optim.Adam(model.parameters(), lr)
    scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size, gamma)

    best_val_loss = float('inf')
    best_epoch = -1
    patience_counter = 0
    trained_ok = False
    train_hist, val_hist = [], []
    best_path = f'best_model_attempt_linear_product{attempt}.pth'

    K = None  # choice set size (including outside)

    # Train the model
    for epoch in range(num_epochs):
        model.train()
        optimizer.zero_grad()

        # Forward pass (Training)
        utilities = model(X_user_train1, X_product, price, prod_randomization)
        
        if epoch == 0:
            K = utilities.shape[1]
        
        choice_probabilities = F.log_softmax(utilities, dim=1)
        loss = -torch.mean(choice_probabilities[torch.arange(choice_probabilities.shape[0]), choice_train1])


        # Numerical stability check
        if not torch.isfinite(loss).all():
            print(f"[attempt={attempt}] NaN/Inf loss at epoch {epoch}. Aborting.")
            return None, None, False

        # Backward pass
        loss.backward()
        optimizer.step()
        scheduler.step()

        model.eval()
        with torch.no_grad():
            val_utilities = model(X_user_val, X_product, price, prod_randomization)
            val_utilities = val_utilities - val_utilities.max(dim=1, keepdim=True).values
            val_choice_probabilities = F.log_softmax(val_utilities, dim=1)
            val_loss = -torch.mean(val_choice_probabilities[torch.arange(val_choice_probabilities.shape[0]), choice_val])

        train_hist.append(loss.item())
        val_hist.append(val_loss.item())

        # Early stopping
        if val_loss.item() < best_val_loss:
            best_val_loss = val_loss.item()
            best_epoch = epoch
            patience_counter = 0
            torch.save(model.state_dict(), best_path)
            trained_ok = True
        else:
            patience_counter += 1

        if patience_counter >= patience:
            print(f"[attempt={attempt}] Early stopping at epoch {epoch+1} (best epoch {best_epoch}, best val {best_val_loss:.4f})")
            break

    # Load best model
    if trained_ok:
        model.load_state_dict(torch.load(best_path))
    else:
        print(f"[attempt={attempt}] WARNING: no validation improvement.")
        return None, None, False

    # Check if training was meaningful
    drop_train = loss_drop(train_hist)
    drop_val = loss_drop(val_hist)
    if (drop_train < 1e-3) or (drop_val < 1e-3):
        print(f"[attempt={attempt}] Skipping — no meaningful training (Δtrain={drop_train:.3g}, Δval={drop_val:.3g}).")
        return None, None, False

    # Check near-random model
    if K is not None and best_val_loss > (math.log(K) - 0.05):
        print(f"[attempt={attempt}] Mark UNSTABLE: near_random, best_val={best_val_loss:.4f}, lnK={math.log(K):.4f}")
        return None, None, False

    # =========================
    # Evaluate expected revenue + CI
    # =========================
    N_products = X_product.shape[0]
    price_with_outside = torch.cat((torch.zeros(1, device=price.device), price), dim=0)  # [K], K=J+1

    # Control
    all_control = torch.zeros(N_products, dtype=torch.bool, device=device)
    utilities_control = model(X_user_test, X_product, price, all_control)
    probs_control = F.softmax(utilities_control, dim=1)  # [n_test, K]
    rev_control_i = torch.sum(
        probs_control * price_with_outside.unsqueeze(0).expand_as(probs_control),
        dim=1
    )  # [n_test]

    # Treated
    all_treated = torch.ones(N_products, dtype=torch.bool, device=device)
    utilities_treated = model(X_user_test, X_product, price, all_treated)
    probs_treated = F.softmax(utilities_treated, dim=1)
    rev_treated_i = torch.sum(
        probs_treated * price_with_outside.unsqueeze(0).expand_as(probs_treated),
        dim=1
    ) * float(discount_percentage)  # [n_test]

    diff_i = rev_treated_i - rev_control_i  # [n_test]

    n_test = diff_i.shape[0]
    scale = 300.0 / float(n_test)

    linear = (diff_i.sum() * scale).item()  # sum(diff_i)*300/n_test

    # --- CI (CLT over users) ---
    diff_sd = diff_i.std(unbiased=True)
    se_linear = (diff_sd / math.sqrt(float(n_test)) * 300.0).item()

    z = torch.distributions.Normal(0.0, 1.0).icdf(torch.tensor(1 - ci_alpha / 2)).item()
    ci_low = linear - z * se_linear
    ci_high = linear + z * se_linear

    covered = None
    if true is not None:
        covered = (ci_low <= float(true) <= ci_high)

    # --- Your PE/APE ---
    if true is None:
        linear_pe, linear_ape = None, None
    else:
        linear_pe = (linear - float(true)) / float(true)
        linear_ape = abs(linear_pe)

    if return_ci:
        print(
            f"[attempt={attempt}] est={linear:.6f}, SE={se_linear:.6f}, "
            f"{int((1-ci_alpha)*100)}% CI=[{ci_low:.6f}, {ci_high:.6f}], "
            f"covered={covered}"
        )
        return linear_pe, linear_ape, (ci_low, ci_high), covered, True

    return linear_pe, linear_ape, True

# %%
#Function to train model and compute revenue difference
# Returns: (linear_pe, linear_ape, trained_ok)
def train_and_estimate_linear_all(X_user, X_user_train1, X_user_test, choice_train1, choice_test, X_user_val, choice_val, X_product, price, prod_randomization, device, num_epochs=1000, lr=0.01, step_size=2500, gamma=0.5, patience=10, attempt=0,
    ci_alpha=0.05, return_ci=True):    # Initialize the model
    model = LinearMNLModel(user_feature_dim=X_user.shape[1], product_feature_dim=X_product.shape[1]).to(device)
    model.apply(init_weights)

    optimizer = optim.Adam(model.parameters(), lr)
    scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size, gamma)

    best_val_loss = float('inf')
    best_epoch = -1
    patience_counter = 0
    trained_ok = False
    train_hist, val_hist = [], []
    best_path = f'best_model_attempt_linear_all{attempt}.pth'

    K = None  # choice set size (including outside)

    # Train the model
    for epoch in range(num_epochs):
        model.train()
        optimizer.zero_grad()

        # Forward pass (Training)
        utilities = model(X_user_train1, X_product, price, prod_randomization)
        
        if epoch == 0:
            K = utilities.shape[1]
        
        choice_probabilities = F.log_softmax(utilities, dim=1)
        loss = -torch.mean(choice_probabilities[torch.arange(choice_probabilities.shape[0]), choice_train1])


        # Numerical stability check
        if not torch.isfinite(loss).all():
            print(f"[attempt={attempt}] NaN/Inf loss at epoch {epoch}. Aborting.")
            return None, None, False

        # Backward pass
        loss.backward()
        optimizer.step()
        scheduler.step()

        model.eval()
        with torch.no_grad():
            val_utilities = model(X_user_val, X_product, price, prod_randomization)
            val_utilities = val_utilities - val_utilities.max(dim=1, keepdim=True).values
            val_choice_probabilities = F.log_softmax(val_utilities, dim=1)
            val_loss = -torch.mean(val_choice_probabilities[torch.arange(val_choice_probabilities.shape[0]), choice_val])

        train_hist.append(loss.item())
        val_hist.append(val_loss.item())

        # Early stopping
        if val_loss.item() < best_val_loss:
            best_val_loss = val_loss.item()
            best_epoch = epoch
            patience_counter = 0
            torch.save(model.state_dict(), best_path)
            trained_ok = True
        else:
            patience_counter += 1

        if patience_counter >= patience:
            print(f"[attempt={attempt}] Early stopping at epoch {epoch+1} (best epoch {best_epoch}, best val {best_val_loss:.4f})")
            break

    # Load best model
    if trained_ok:
        model.load_state_dict(torch.load(best_path))
    else:
        print(f"[attempt={attempt}] WARNING: no validation improvement.")
        return None, None, False

    # Check if training was meaningful
    drop_train = loss_drop(train_hist)
    drop_val = loss_drop(val_hist)
    if (drop_train < 1e-3) or (drop_val < 1e-3):
        print(f"[attempt={attempt}] Skipping — no meaningful training (Δtrain={drop_train:.3g}, Δval={drop_val:.3g}).")
        return None, None, False

    # Check near-random model
    if K is not None and best_val_loss > (math.log(K) - 0.05):
        print(f"[attempt={attempt}] Mark UNSTABLE: near_random, best_val={best_val_loss:.4f}, lnK={math.log(K):.4f}")
        return None, None, False

    # =========================
    # Evaluate expected revenue + CI
    # =========================
    N_products = X_product.shape[0]
    price_with_outside = torch.cat((torch.zeros(1, device=price.device), price), dim=0)  # [K], K=J+1

    # Control
    all_control = torch.zeros(N_products, dtype=torch.bool, device=device)
    utilities_control = model(X_user_test, X_product, price, all_control)
    probs_control = F.softmax(utilities_control, dim=1)  # [n_test, K]
    rev_control_i = torch.sum(
        probs_control * price_with_outside.unsqueeze(0).expand_as(probs_control),
        dim=1
    )  # [n_test]

    # Treated
    all_treated = torch.ones(N_products, dtype=torch.bool, device=device)
    utilities_treated = model(X_user_test, X_product, price, all_treated)
    probs_treated = F.softmax(utilities_treated, dim=1)
    rev_treated_i = torch.sum(
        probs_treated * price_with_outside.unsqueeze(0).expand_as(probs_treated),
        dim=1
    ) * float(discount_percentage)  # [n_test]

    diff_i = rev_treated_i - rev_control_i  # [n_test]

    n_test = diff_i.shape[0]
    scale = 300.0 / float(n_test)

    linear = (diff_i.sum() * scale).item()  # sum(diff_i)*300/n_test

    # --- CI (CLT over users) ---
    diff_sd = diff_i.std(unbiased=True)
    se_linear = (diff_sd / math.sqrt(float(n_test)) * 300.0).item()

    z = torch.distributions.Normal(0.0, 1.0).icdf(torch.tensor(1 - ci_alpha / 2)).item()
    ci_low = linear - z * se_linear
    ci_high = linear + z * se_linear

    covered = None
    if true is not None:
        covered = (ci_low <= float(true) <= ci_high)

    # --- Your PE/APE ---
    if true is None:
        linear_pe, linear_ape = None, None
    else:
        linear_pe = (linear - float(true)) / float(true)
        linear_ape = abs(linear_pe)

    if return_ci:
        print(
            f"[attempt={attempt}] est={linear:.6f}, SE={se_linear:.6f}, "
            f"{int((1-ci_alpha)*100)}% CI=[{ci_low:.6f}, {ci_high:.6f}], "
            f"covered={covered}"
        )
        return linear_pe, linear_ape, (ci_low, ci_high), covered, True

    return linear_pe, linear_ape, True

# %% [markdown]
# ## PDL

# %%
def prepare_data(user_features, product_features, prices):
    num_products = product_features.shape[0]
    all_x_other_products = []
    all_other_prices = []
    
    for i in range(num_products):
        indices = [j for j in range(num_products) if j != i]
        other_products = product_features[indices].reshape(-1)
        other_product_prices = prices[indices]
        all_x_other_products.append(other_products)
        all_other_prices.append(other_product_prices)
        
    all_x_other_products = torch.stack(all_x_other_products, dim=0)
    all_other_prices = torch.stack(all_other_prices, dim=0)
    
    return user_features, product_features, prices, all_x_other_products, all_other_prices

# %%
class DeepMNLModel_No(nn.Module):
    """
    Price-only Deep MNL:
    u_ij = theta(p_j)
    Outside option utility = 0.
    """
    def __init__(self, num_product, hidden=5):
        super(DeepMNLModel_No, self).__init__()

        # theta(p_j):
        # Input:  [1]
        # Output: scalar utility
        self.theta = nn.Sequential(
        nn.Linear(1, hidden),
        nn.ReLU(),
        nn.Linear(hidden, hidden),
        nn.ReLU(),
        nn.Linear(hidden, 1)

)

    def forward(self, x_user, X_product, X_other_products, x_other_prices, price, prod_randomization):
        """
        Inputs used:
        - price: [M]  own price p_j
        - prod_randomization: [M]  treatment indicator
        """
        device = price.device
        N, M = x_user.shape[0], price.shape[0]


        # Prepare input for theta: [M, 1]
        pj_input = price.unsqueeze(1)

        # Expand to all users: [N, M, 1]
        theta_input_exp = pj_input.unsqueeze(0).expand(N, -1, -1)

        # u_ij = theta(p_j): [N, M]
        utilities = self.theta(theta_input_exp).squeeze(-1)

        # Outside option utility = 0
        zero_utilities = torch.zeros(N, 1, device=device)
        utilities_with_outside = torch.cat([zero_utilities, utilities], dim=1)

        return utilities_with_outside

# %%
class DeepMNLModel_UserOnly(nn.Module):
    """
    Deep MNL (user + own price only):
    u_ij = theta(x_i, p_j)
    Outside option utility = 0.
    """
    def __init__(self, user_dim, num_product, hidden=5):
        super(DeepMNLModel_UserOnly, self).__init__()

        # theta(x_i, p_j)
        # Input per (i,j): [user_dim + 1]
        self.theta = nn.Sequential(
            nn.Linear(user_dim + 1, hidden),
            nn.ReLU(),
            nn.Linear(hidden, hidden),
            nn.ReLU(),
            nn.Linear(hidden, 1)
        )

    def forward(self, x_user, X_product, X_other_products,
                x_other_prices, price, prod_randomization):

        device = price.device
        N, M = x_user.shape[0], price.shape[0]

        # p_j: [M, 1]
        pj_feat = price.unsqueeze(1)          # [M, 1]

        pj_feat_exp = pj_feat.unsqueeze(0).expand(N, -1, -1)

        x_user_exp = x_user.unsqueeze(1).expand(-1, M, -1)

        theta_input = torch.cat([x_user_exp, pj_feat_exp], dim=2)

        theta_input_flat = theta_input.reshape(N * M, -1)

        # u_ij: [N*M, 1] -> [N, M]
        utilities = self.theta(theta_input_flat).view(N, M)

        # outside option utility = 0
        zero_utilities = torch.zeros(N, 1, device=device)
        utilities_with_outside = torch.cat([zero_utilities, utilities], dim=1)

        return utilities_with_outside

# %%
class DeepMNLModel_ProductOnly(nn.Module):
    """
    Deep MNL (product-only):
    u_ij = theta(z_j, z_-j, p_j)
    Outside option utility = 0.
    """
    def __init__(self, product_dim, num_product, hidden=5):
        super(DeepMNLModel_ProductOnly, self).__init__()

        # Aggregate other products' features z_-j:
        # Input:  [M, (M-1)*F_p]
        # Output: [M, hidden]
        self.other_product_features_layers = nn.Sequential(
            nn.Linear(product_dim * (num_product - 1), hidden),
            nn.ReLU(),
            nn.Linear(hidden, hidden),
            nn.ReLU()
        )

        # theta(z_j, z_-j, p_j)
        # Input per (i,j): [F_p + hidden (z_-j) + 1 (p_j)]
        in_dim = product_dim + hidden + 1

        self.theta = nn.Sequential(
            nn.Linear(in_dim, hidden),
            nn.ReLU(),
            nn.Linear(hidden, hidden),
            nn.ReLU(),
            nn.Linear(hidden, 1)
        )

    def forward(self, x_user, X_product, X_other_products,
                x_other_prices, price, prod_randomization):
        """
        X_product:        [M, F_p]          product features z_j
        X_other_products: [M, (M-1)*F_p]    other products' features z_-j
        price:            [M]               own price p_j (already discounted)
        """
        device = price.device
        # N users, M products
        N, M = x_user.shape[0], X_product.shape[0]

        # z_-j features: [M, hidden]
        zminus_feat = self.other_product_features_layers(X_other_products)

        # p_j scalar: [M, 1]
        pj_feat = price.unsqueeze(1)

        # Combine product-side info: [M, F_p + hidden + 1]
        product_feat = torch.cat(
            [X_product, zminus_feat, pj_feat],
            dim=1
        )

        # Expand to all users: [N, M, in_dim]
        product_feat_exp = product_feat.unsqueeze(0).expand(N, -1, -1)

        # Flatten to [N*M, in_dim]
        theta_input_flat = product_feat_exp.reshape(N * M, -1)

        # Utilities: [N*M, 1] -> [N, M]
        utilities = self.theta(theta_input_flat).view(N, M)

        # Outside option = 0
        zero_utilities = torch.zeros(N, 1, device=device)
        utilities_with_outside = torch.cat([zero_utilities, utilities], dim=1)

        return utilities_with_outside

# %%
# PDL choice model
class DeepMNLModel(nn.Module):
    """
    Deep MNL:
    u_ij = theta(x_i, z_j, z_-j, p_j)
    Outside option utility = 0.
    """
    def __init__(self, user_dim, product_dim, num_product, hidden=5):
        super(DeepMNLModel, self).__init__()

        # Aggregate other products' features z_-j:
        # Input:  [M, (M-1)*F_p]
        # Output: [M, hidden]
        self.other_product_features_layers = nn.Sequential(
            nn.Linear(product_dim * (num_product - 1), hidden),
            nn.ReLU(),
            nn.Linear(hidden, hidden),
            nn.ReLU()
        )

        # theta(x_i, z_j, z_-j, p_j)
        # Input per (i,j):
        #   user_dim (x_i)
        # + product_dim (z_j)
        # + hidden (z_-j)
        # + 1 (p_j)
        in_dim = user_dim + product_dim + hidden + 1

        self.theta = nn.Sequential(
            nn.Linear(in_dim, hidden),
            nn.ReLU(),
            nn.Linear(hidden, 1)
        )

    def forward(self, x_user, X_product, X_other_products,
                x_other_prices, price, prod_randomization):
        """
        x_user:          [N, F_u]          user features x_i
        X_product:       [M, F_p]          product features z_j
        X_other_products:[M, (M-1)*F_p]    other products' features z_-j
        price:           [M]               own price p_j (already discounted)

        x_other_prices, prod_randomization are not used here.
        """
        device = price.device
        N, M = x_user.shape[0], X_product.shape[0]

        # z_-j features: [M, hidden]
        zminus_feat = self.other_product_features_layers(X_other_products)

        # p_j: [M, 1]
        pj_feat = price.unsqueeze(1)

        # Product-side block: [M, F_p + hidden + 1]
        product_block = torch.cat(
            [X_product, zminus_feat, pj_feat],
            dim=1
        )

        # Expand product block for all users: [N, M, *]
        product_block_exp = product_block.unsqueeze(0).expand(N, -1, -1)

        # Expand user features: [N, 1, F_u] -> [N, M, F_u]
        x_user_exp = x_user.unsqueeze(1).expand(-1, M, -1)

        # Final theta input: [N, M, in_dim]
        theta_input = torch.cat([x_user_exp, product_block_exp], dim=2)

        # Flatten to [N*M, in_dim]
        theta_input_flat = theta_input.reshape(N * M, -1)

        # Utilities: [N*M, 1] -> [N, M]
        utilities = self.theta(theta_input_flat).view(N, M)

        # Outside option = 0
        zero_utilities = torch.zeros(N, 1, device=device)
        utilities_with_outside = torch.cat([zero_utilities, utilities], dim=1)

        return utilities_with_outside

# %%
def train_and_estimate_pdl_no(X_user, X_user_train1, X_user_test, choice_train1, choice_test, X_user_val, choice_val, X_product, price, prod_randomization, device, num_epochs=1000, lr=0.01, step_size=2500, gamma=0.5, patience=10, attempt=0,
    ci_alpha=0.05, return_ci=True):    
    # --- Prepare Data ---
    prepared_data = prepare_data(X_user_train1, X_product,  price * (1 - (1-discount_percentage) * prod_randomization))
    user_features, product_features, prices_train, all_x_other_products, all_other_prices = prepared_data
    
    prepared_val = prepare_data(X_user_val, X_product, price * (1 - (1-discount_percentage) * prod_randomization))
    user_features_val, product_features_val, prices_val, all_x_other_products_val, all_other_prices_val = prepared_val

    user_features = user_features.to(device)
    product_features = product_features.to(device)
    prices_train = prices_train.to(device)
    all_x_other_products = all_x_other_products.to(device)
    all_other_prices = all_other_prices.to(device)

    user_features_val = user_features_val.to(device)
    product_features_val = product_features_val.to(device)
    prices_val = prices_val.to(device)
    all_x_other_products_val = all_x_other_products_val.to(device)
    all_other_prices_val = all_other_prices_val.to(device)
    
    # Initialize model
    model = DeepMNLModel_No(num_product=X_product.shape[0], hidden=5).to(device)

    model.apply(init_weights)

    optimizer = optim.Adam(model.parameters(), lr)
    scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size, gamma)

    best_val_loss = float('inf')
    best_epoch = -1
    patience_counter = 0
    trained_ok = False
    train_hist, val_hist = [], []
    best_path = f'best_model_attempt_pdl_no{attempt}.pth'

    K = None 

    for epoch in range(num_epochs):
        model.train()
        optimizer.zero_grad()

        # Forward pass
        utilities = model(user_features, product_features, all_x_other_products, all_other_prices, prices_train, prod_randomization)
        
        if epoch == 0:
            K = utilities.shape[1]
        
        choice_probabilities = F.log_softmax(utilities, dim=1)
        loss = -torch.mean(choice_probabilities[torch.arange(choice_probabilities.shape[0]), choice_train1])

        if not torch.isfinite(loss).all():
            print(f"[attempt={attempt}] NaN/Inf loss at epoch {epoch}. Aborting.")
            return None, None, False

        loss.backward()
        torch.nn.utils.clip_grad_norm_(model.parameters(), 1.0)
        optimizer.step()
        scheduler.step()

        # Validation
        model.eval()
        with torch.no_grad():
            val_utilities = model(user_features_val, product_features_val, all_x_other_products_val, all_other_prices_val, prices_val, prod_randomization)
            val_utilities = val_utilities - val_utilities.max(dim=1, keepdim=True).values
            val_choice_probabilities = F.log_softmax(val_utilities, dim=1)
            val_loss = -torch.mean(val_choice_probabilities[torch.arange(val_choice_probabilities.shape[0]), choice_val])

        train_hist.append(loss.item())
        val_hist.append(val_loss.item())

        if val_loss.item() < best_val_loss:
            best_val_loss = val_loss.item()
            best_epoch = epoch
            patience_counter = 0
            torch.save(model.state_dict(), best_path)
            trained_ok = True
        else:
            patience_counter += 1

        if patience_counter >= patience:
            # print(f"[attempt={attempt}] Early stopping at epoch {epoch+1}")
            break

    if trained_ok:
        model.load_state_dict(torch.load(best_path))
    else:
        return None, None, False

    # Check logic (skipping detailed check for brevity, kept yours)
    drop_train = loss_drop(train_hist)
    drop_val = loss_drop(val_hist)
    if (drop_train < 1e-3) or (drop_val < 1e-3):
        return None, None, False

    if K is not None and best_val_loss > (math.log(K) - 0.05):
        return None, None, False

    model.eval()

    prepared_test = prepare_data(X_user_test, X_product, price)  
    user_features_test, product_features_test, prices_test, all_x_other_products_test, all_other_prices_test = prepared_test
    user_features_test = user_features_test.to(device)
    product_features_test = product_features_test.to(device)
    all_x_other_products_test = all_x_other_products_test.to(device)
    all_other_prices_test = all_other_prices_test.to(device)

    price = price.to(device)

    price_control = price
    price_treated = price * discount_percentage

    with torch.no_grad():
        u_c = model(user_features_test, product_features_test,
                    all_x_other_products_test, all_other_prices_test,
                    price_control, prod_randomization)
        u_c = u_c - u_c.max(dim=1, keepdim=True).values
        p_c = F.softmax(u_c, dim=1)

        u_t = model(user_features_test, product_features_test,
                    all_x_other_products_test, all_other_prices_test,
                    price_treated, prod_randomization)
        u_t = u_t - u_t.max(dim=1, keepdim=True).values
        p_t = F.softmax(u_t, dim=1)

    price_with_outside_c = torch.cat((torch.zeros(1, device=device), price_control), dim=0)  # [K]
    price_with_outside_t = torch.cat((torch.zeros(1, device=device), price_treated), dim=0)  # [K]

    # --- per-user expected revenue (needed for SE/CI) ---
    rev_control_i = (p_c * price_with_outside_c.unsqueeze(0)).sum(dim=1)  # [n_test]
    rev_treated_i = (p_t * price_with_outside_t.unsqueeze(0)).sum(dim=1)  # [n_test]

    diff_i = rev_treated_i - rev_control_i  # [n_test]

    n_test = diff_i.shape[0]
    scale = 300.0 / float(n_test)
    pdl = (diff_i.sum() * scale).item()  # = diff.mean()*300

    # --- CI (CLT over users) ---
    diff_sd = diff_i.std(unbiased=True)
    se_pdl = (diff_sd / math.sqrt(float(n_test)) * 300.0).item()

    z = torch.distributions.Normal(0.0, 1.0).icdf(
        torch.tensor(1 - ci_alpha / 2, device=device)
    ).item()

    ci_low = pdl - z * se_pdl
    ci_high = pdl + z * se_pdl

    covered = None
    if true is not None:
        covered = (ci_low <= float(true) <= ci_high)

    # --- PE/APE ---
    if true is None:
        pdl_pe, pdl_ape = None, None
    else:
        pdl_pe = (pdl - float(true)) / float(true)
        pdl_ape = abs(pdl_pe)

    if return_ci:
        print(
            f"[attempt={attempt}] est={pdl:.6f}, SE={se_pdl:.6f}, "
            f"{int((1-ci_alpha)*100)}% CI=[{ci_low:.6f}, {ci_high:.6f}], "
            f"covered={covered}"
        )
        return pdl_pe, pdl_ape, (ci_low, ci_high), covered, True

    return pdl_pe, pdl_ape, True

# %%
def train_and_estimate_pdl_user(X_user, X_user_train1, X_user_test, choice_train1, choice_test, X_user_val, choice_val, X_product, price, prod_randomization, device, num_epochs=1000, lr=0.01, step_size=2500, gamma=0.5, patience=10, attempt=0,
    ci_alpha=0.05, return_ci=True):
    # --- Prepare Data ---
    prepared_data = prepare_data(X_user_train1, X_product,  price * (1 - (1-discount_percentage) * prod_randomization))
    user_features, product_features, prices_train, all_x_other_products, all_other_prices = prepared_data
    
    prepared_val = prepare_data(X_user_val, X_product, price * (1 - (1-discount_percentage) * prod_randomization))
    user_features_val, product_features_val, prices_val, all_x_other_products_val, all_other_prices_val = prepared_val

    user_features = user_features.to(device)
    product_features = product_features.to(device)
    prices_train = prices_train.to(device)
    all_x_other_products = all_x_other_products.to(device)
    all_other_prices = all_other_prices.to(device)

    user_features_val = user_features_val.to(device)
    product_features_val = product_features_val.to(device)
    prices_val = prices_val.to(device)
    all_x_other_products_val = all_x_other_products_val.to(device)
    all_other_prices_val = all_other_prices_val.to(device)
    
    # Initialize model
    model = DeepMNLModel_UserOnly(user_dim=X_user.shape[1], num_product=X_product.shape[0], hidden=16).to(device)

    model.apply(init_weights)

    optimizer = optim.AdamW(model.parameters(), lr, weight_decay=1e-3)
    scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size, gamma)

    best_val_loss = float('inf')
    best_epoch = -1
    patience_counter = 0
    trained_ok = False
    train_hist, val_hist = [], []
    best_path = f'best_model_attempt_pdl_user{attempt}.pth'

    K = None 

    for epoch in range(num_epochs):
        model.train()
        optimizer.zero_grad()

        # Forward pass
        utilities = model(user_features, product_features, all_x_other_products, all_other_prices, prices_train, prod_randomization)
        
        if epoch == 0:
            K = utilities.shape[1]
        
        choice_probabilities = F.log_softmax(utilities, dim=1)
        loss = -torch.mean(choice_probabilities[torch.arange(choice_probabilities.shape[0]), choice_train1])

        if not torch.isfinite(loss).all():
            print(f"[attempt={attempt}] NaN/Inf loss at epoch {epoch}. Aborting.")
            return None, None, False

        loss.backward()
        torch.nn.utils.clip_grad_norm_(model.parameters(), 0.5)
        optimizer.step()
        scheduler.step()

        # Validation
        model.eval()
        with torch.no_grad():
            val_utilities = model(user_features_val, product_features_val, all_x_other_products_val, all_other_prices_val, prices_val, prod_randomization)
            val_utilities = val_utilities - val_utilities.max(dim=1, keepdim=True).values
            val_choice_probabilities = F.log_softmax(val_utilities, dim=1)
            val_loss = -torch.mean(val_choice_probabilities[torch.arange(val_choice_probabilities.shape[0]), choice_val])

        train_hist.append(loss.item())
        val_hist.append(val_loss.item())

        if val_loss.item() < best_val_loss:
            best_val_loss = val_loss.item()
            best_epoch = epoch
            patience_counter = 0
            torch.save(model.state_dict(), best_path)
            trained_ok = True
        else:
            patience_counter += 1

        if patience_counter >= patience:
            # print(f"[attempt={attempt}] Early stopping at epoch {epoch+1}")
            break

    if trained_ok:
        model.load_state_dict(torch.load(best_path))
    else:
        return None, None, False

    # Check logic (skipping detailed check for brevity, kept yours)
    drop_train = loss_drop(train_hist)
    drop_val = loss_drop(val_hist)
    if (drop_train < 1e-3) or (drop_val < 1e-3):
        return None, None, False

    if K is not None and best_val_loss > (math.log(K) - 0.05):
        return None, None, False

    model.eval()

    # move to device
    X_user_test = X_user_test.to(device)
    X_product = X_product.to(device)
    price = price.to(device)

    price_control = price
    price_treated = price * discount_percentage

    eval_x_other = all_x_other_products.to(device)
    eval_other_prices = all_other_prices.to(device)

    with torch.no_grad():
        # Control probs
        u_c = model(
            X_user_test, X_product,
            eval_x_other, eval_other_prices,
            price_control,
            prod_randomization
        )
        u_c = u_c - u_c.max(dim=1, keepdim=True).values
        p_c = F.softmax(u_c, dim=1)

        # Treated probs (recompute under discounted prices!)
        u_t = model(
            X_user_test, X_product,
            eval_x_other, eval_other_prices,
            price_treated,
            prod_randomization
        )
        u_t  = u_t - u_t.max(dim=1, keepdim=True).values
        p_t= F.softmax(u_t, dim=1)

    price_with_outside_c = torch.cat((torch.zeros(1, device=device), price_control), dim=0)  # [K]
    price_with_outside_t = torch.cat((torch.zeros(1, device=device), price_treated), dim=0)  # [K]

    # --- per-user expected revenue (needed for SE/CI) ---
    rev_control_i = (p_c * price_with_outside_c.unsqueeze(0)).sum(dim=1)  # [n_test]
    rev_treated_i = (p_t * price_with_outside_t.unsqueeze(0)).sum(dim=1)  # [n_test]

    diff_i = rev_treated_i - rev_control_i  # [n_test]

    n_test = diff_i.shape[0]
    scale = 300.0 / float(n_test)
    pdl = (diff_i.sum() * scale).item()  # = diff.mean()*300

    # --- CI (CLT over users) ---
    diff_sd = diff_i.std(unbiased=True)
    se_pdl = (diff_sd / math.sqrt(float(n_test)) * 300.0).item()

    z = torch.distributions.Normal(0.0, 1.0).icdf(
        torch.tensor(1 - ci_alpha / 2, device=device)
    ).item()

    ci_low = pdl - z * se_pdl
    ci_high = pdl + z * se_pdl

    covered = None
    if true is not None:
        covered = (ci_low <= float(true) <= ci_high)

    # --- PE/APE ---
    if true is None:
        pdl_pe, pdl_ape = None, None
    else:
        pdl_pe = (pdl - float(true)) / float(true)
        pdl_ape = abs(pdl_pe)

    if return_ci:
        print(
            f"[attempt={attempt}] est={pdl:.6f}, SE={se_pdl:.6f}, "
            f"{int((1-ci_alpha)*100)}% CI=[{ci_low:.6f}, {ci_high:.6f}], "
            f"covered={covered}"
        )
        return pdl_pe, pdl_ape, (ci_low, ci_high), covered, True

    return pdl_pe, pdl_ape, True

# %%
def train_and_estimate_pdl_product(X_user, X_user_train1, X_user_test, choice_train1, choice_test, X_user_val, choice_val, X_product, price, prod_randomization, device, num_epochs=1000, lr=0.01, step_size=2500, gamma=0.5, patience=10, attempt=0,
    ci_alpha=0.05, return_ci=True):
    # --- Prepare Data ---
    prepared_data = prepare_data(X_user_train1, X_product,  price * (1 - (1-discount_percentage) * prod_randomization))
    user_features, product_features, prices_train, all_x_other_products, all_other_prices = prepared_data
    
    prepared_val = prepare_data(X_user_val, X_product, price * (1 - (1-discount_percentage) * prod_randomization))
    user_features_val, product_features_val, prices_val, all_x_other_products_val, all_other_prices_val = prepared_val
    
    user_features = user_features.to(device)
    product_features = product_features.to(device)
    prices_train = prices_train.to(device)
    all_x_other_products = all_x_other_products.to(device)
    all_other_prices = all_other_prices.to(device)

    user_features_val = user_features_val.to(device)
    product_features_val = product_features_val.to(device)
    prices_val = prices_val.to(device)
    all_x_other_products_val = all_x_other_products_val.to(device)
    all_other_prices_val = all_other_prices_val.to(device)
    
    # Initialize model
    model = DeepMNLModel_ProductOnly(product_dim=X_product.shape[1], num_product=X_product.shape[0], hidden=16).to(device)

    model.apply(init_weights)

    optimizer = optim.AdamW(model.parameters(), lr, weight_decay=5e-4)
    scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size, gamma)

    best_val_loss = float('inf')
    best_epoch = -1
    patience_counter = 0
    trained_ok = False
    train_hist, val_hist = [], []
    best_path = f'best_model_attempt_pdl_product{attempt}.pth'

    K = None 

    for epoch in range(num_epochs):
        model.train()
        optimizer.zero_grad()

        # Forward pass
        utilities = model(user_features, product_features, all_x_other_products, all_other_prices, prices_train, prod_randomization)
        
        if epoch == 0:
            K = utilities.shape[1]
        
        choice_probabilities = F.log_softmax(utilities, dim=1)
        loss = -torch.mean(choice_probabilities[torch.arange(choice_probabilities.shape[0]), choice_train1])

        if not torch.isfinite(loss).all():
            print(f"[attempt={attempt}] NaN/Inf loss at epoch {epoch}. Aborting.")
            return None, None, False

        loss.backward()
        torch.nn.utils.clip_grad_norm_(model.parameters(), 1.0)
        optimizer.step()
        scheduler.step()

        # Validation
        model.eval()
        with torch.no_grad():
            val_utilities = model(user_features_val, product_features_val, all_x_other_products_val, all_other_prices_val, prices_val, prod_randomization)
            val_utilities = val_utilities - val_utilities.max(dim=1, keepdim=True).values
            val_choice_probabilities = F.log_softmax(val_utilities, dim=1)
            val_loss = -torch.mean(val_choice_probabilities[torch.arange(val_choice_probabilities.shape[0]), choice_val])

        train_hist.append(loss.item())
        val_hist.append(val_loss.item())

        if val_loss.item() < best_val_loss:
            best_val_loss = val_loss.item()
            best_epoch = epoch
            patience_counter = 0
            torch.save(model.state_dict(), best_path)
            trained_ok = True
        else:
            patience_counter += 1

        if patience_counter >= patience:
            # print(f"[attempt={attempt}] Early stopping at epoch {epoch+1}")
            break

    if trained_ok:
        model.load_state_dict(torch.load(best_path))
    else:
        return None, None, False

    # Check logic (skipping detailed check for brevity, kept yours)
    drop_train = loss_drop(train_hist)
    drop_val = loss_drop(val_hist)
    if (drop_train < 1e-3) or (drop_val < 1e-3):
        return None, None, False

    if K is not None and best_val_loss > (math.log(K) - 0.05):
        return None, None, False

    # -------------------------------
    # Evaluate counterfactual revenues
    # -------------------------------
    model.eval()

    # move test tensors to device
    X_user_test = X_user_test.to(device)
    X_product = X_product.to(device)
    price = price.to(device)

    eval_x_other = all_x_other_products.to(device)
    eval_other_prices = all_other_prices.to(device)

    # counterfactual price vectors
    price_control = price
    price_treated = price * discount_percentage

    with torch.no_grad():
        # Control probs
        u_c = model(
            X_user_test, X_product,
            eval_x_other, eval_other_prices,
            price_control,
            prod_randomization
        )
        u_c = u_c - u_c.max(dim=1, keepdim=True).values
        p_c = F.softmax(u_c, dim=1)

        # Treated probs (recompute under discounted prices!)
        u_t = model(
            X_user_test, X_product,
            eval_x_other, eval_other_prices,
            price_treated,
            prod_randomization
        )
        u_t  = u_t - u_t.max(dim=1, keepdim=True).values
        p_t= F.softmax(u_t, dim=1)

    price_with_outside_c = torch.cat((torch.zeros(1, device=device), price_control), dim=0)  # [K]
    price_with_outside_t = torch.cat((torch.zeros(1, device=device), price_treated), dim=0)  # [K]

    # --- per-user expected revenue (needed for SE/CI) ---
    rev_control_i = (p_c * price_with_outside_c.unsqueeze(0)).sum(dim=1)  # [n_test]
    rev_treated_i = (p_t * price_with_outside_t.unsqueeze(0)).sum(dim=1)  # [n_test]

    diff_i = rev_treated_i - rev_control_i  # [n_test]

    n_test = diff_i.shape[0]
    scale = 300.0 / float(n_test)
    pdl = (diff_i.sum() * scale).item()  # = diff.mean()*300

    # --- CI (CLT over users) ---
    diff_sd = diff_i.std(unbiased=True)
    se_pdl = (diff_sd / math.sqrt(float(n_test)) * 300.0).item()

    z = torch.distributions.Normal(0.0, 1.0).icdf(
        torch.tensor(1 - ci_alpha / 2, device=device)
    ).item()

    ci_low = pdl - z * se_pdl
    ci_high = pdl + z * se_pdl

    covered = None
    if true is not None:
        covered = (ci_low <= float(true) <= ci_high)

    # --- PE/APE ---
    if true is None:
        pdl_pe, pdl_ape = None, None
    else:
        pdl_pe = (pdl - float(true)) / float(true)
        pdl_ape = abs(pdl_pe)

    if return_ci:
        print(
            f"[attempt={attempt}] est={pdl:.6f}, SE={se_pdl:.6f}, "
            f"{int((1-ci_alpha)*100)}% CI=[{ci_low:.6f}, {ci_high:.6f}], "
            f"covered={covered}"
        )
        return pdl_pe, pdl_ape, (ci_low, ci_high), covered, True

    return pdl_pe, pdl_ape, True

# %%
def train_and_estimate_pdl_all(X_user, X_user_train1, X_user_test, choice_train1, choice_test, X_user_val, choice_val, X_product, price, prod_randomization, device, num_epochs=1000, lr=0.01, step_size=2500, gamma=0.5, patience=10, attempt=0,
    ci_alpha=0.05, return_ci=True):
    # --- Prepare Data ---
    prepared_data = prepare_data(X_user_train1, X_product,  price * (1 - (1-discount_percentage) * prod_randomization))
    user_features, product_features, prices_train, all_x_other_products, all_other_prices = prepared_data
    
    prepared_val = prepare_data(X_user_val, X_product, price * (1 - (1-discount_percentage) * prod_randomization))
    user_features_val, product_features_val, prices_val, all_x_other_products_val, all_other_prices_val = prepared_val

    user_features = user_features.to(device)
    product_features = product_features.to(device)
    prices_train = prices_train.to(device)
    all_x_other_products = all_x_other_products.to(device)
    all_other_prices = all_other_prices.to(device)

    user_features_val = user_features_val.to(device)
    product_features_val = product_features_val.to(device)
    prices_val = prices_val.to(device)
    all_x_other_products_val = all_x_other_products_val.to(device)
    all_other_prices_val = all_other_prices_val.to(device)
    
    # Initialize model
    model = DeepMNLModel(user_dim=X_user.shape[1], product_dim=X_product.shape[1], num_product=X_product.shape[0], hidden=16).to(device)

    model.apply(init_weights)

    optimizer = optim.AdamW(model.parameters(), lr, weight_decay=1e-3)
    scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size, gamma)

    best_val_loss = float('inf')
    best_epoch = -1
    patience_counter = 0
    trained_ok = False
    train_hist, val_hist = [], []
    best_path = f'best_model_attempt_pdl_all{attempt}.pth'
    l2_lambda = 1e-4

    K = None 

    for epoch in range(num_epochs):
        model.train()
        optimizer.zero_grad()

        # Forward pass
        utilities = model(user_features, product_features, all_x_other_products, all_other_prices, prices_train, prod_randomization)
        
        if epoch == 0:
            K = utilities.shape[1]
        
        choice_probabilities = F.log_softmax(utilities, dim=1)
        loss = -torch.mean(choice_probabilities[torch.arange(choice_probabilities.shape[0]), choice_train1])
        loss = loss + l2_lambda * sum(p.pow(2).sum() for p in model.parameters())
        
        if not torch.isfinite(loss).all():
            print(f"[attempt={attempt}] NaN/Inf loss at epoch {epoch}. Aborting.")
            return None, None, False

        loss.backward()
        torch.nn.utils.clip_grad_norm_(model.parameters(), 1.0)
        optimizer.step()
        scheduler.step()

        # Validation
        model.eval()
        with torch.no_grad():
            val_utilities = model(user_features_val, product_features_val, all_x_other_products_val, all_other_prices_val, prices_val, prod_randomization)
            val_utilities = val_utilities - val_utilities.max(dim=1, keepdim=True).values
            val_choice_probabilities = F.log_softmax(val_utilities, dim=1)
            val_loss = -torch.mean(val_choice_probabilities[torch.arange(val_choice_probabilities.shape[0]), choice_val])

        train_hist.append(loss.item())
        val_hist.append(val_loss.item())

        if val_loss.item() < best_val_loss:
            best_val_loss = val_loss.item()
            best_epoch = epoch
            patience_counter = 0
            torch.save(model.state_dict(), best_path)
            trained_ok = True
        else:
            patience_counter += 1

        if patience_counter >= patience:
            # print(f"[attempt={attempt}] Early stopping at epoch {epoch+1}")
            break

    if trained_ok:
        model.load_state_dict(torch.load(best_path))
    else:
        return None, None, False

    # Check logic (skipping detailed check for brevity, kept yours)
    drop_train = loss_drop(train_hist)
    drop_val = loss_drop(val_hist)
    if (drop_train < 1e-3) or (drop_val < 1e-3):
        return None, None, False

    if K is not None and best_val_loss > (math.log(K) - 0.05):
        return None, None, False
    # -------------------------------
    # Evaluate counterfactual revenues
    # -------------------------------
    model.eval()

    # move test tensors to device
    X_user_test = X_user_test.to(device)
    X_product = X_product.to(device)
    price = price.to(device)

    eval_x_other = all_x_other_products.to(device)
    eval_other_prices = all_other_prices.to(device)

    # counterfactual price vectors
    price_control = price
    price_treated = price * discount_percentage

    with torch.no_grad():
        # Control probs
        u_c = model(
            X_user_test, X_product,
            eval_x_other, eval_other_prices,
            price_control,
            prod_randomization
        )
        u_c = u_c - u_c.max(dim=1, keepdim=True).values
        p_c = F.softmax(u_c, dim=1)

        # Treated probs (recompute under discounted prices!)
        u_t = model(
            X_user_test, X_product,
            eval_x_other, eval_other_prices,
            price_treated,
            prod_randomization
        )
        u_t  = u_t - u_t.max(dim=1, keepdim=True).values
        p_t= F.softmax(u_t, dim=1)

    price_with_outside_c = torch.cat((torch.zeros(1, device=device), price_control), dim=0)  # [K]
    price_with_outside_t = torch.cat((torch.zeros(1, device=device), price_treated), dim=0)  # [K]

    # --- per-user expected revenue (needed for SE/CI) ---
    rev_control_i = (p_c * price_with_outside_c.unsqueeze(0)).sum(dim=1)  # [n_test]
    rev_treated_i = (p_t * price_with_outside_t.unsqueeze(0)).sum(dim=1)  # [n_test]

    diff_i = rev_treated_i - rev_control_i  # [n_test]

    n_test = diff_i.shape[0]
    scale = 300.0 / float(n_test)
    pdl = (diff_i.sum() * scale).item()  # = diff.mean()*300

    # --- CI (CLT over users) ---
    diff_sd = diff_i.std(unbiased=True)
    se_pdl = (diff_sd / math.sqrt(float(n_test)) * 300.0).item()

    z = torch.distributions.Normal(0.0, 1.0).icdf(
        torch.tensor(1 - ci_alpha / 2, device=device)
    ).item()

    ci_low = pdl - z * se_pdl
    ci_high = pdl + z * se_pdl

    covered = None
    if true is not None:
        covered = (ci_low <= float(true) <= ci_high)

    # --- PE/APE ---
    if true is None:
        pdl_pe, pdl_ape = None, None
    else:
        pdl_pe = (pdl - float(true)) / float(true)
        pdl_ape = abs(pdl_pe)

    if return_ci:
        print(
            f"[attempt={attempt}] est={pdl:.6f}, SE={se_pdl:.6f}, "
            f"{int((1-ci_alpha)*100)}% CI=[{ci_low:.6f}, {ci_high:.6f}], "
            f"covered={covered}"
        )
        return pdl_pe, pdl_ape, (ci_low, ci_high), covered, True

    return pdl_pe, pdl_ape, True

# %% [markdown]
# ## DML

# %%
def H_theta(theta0_output, theta1_output, all_treated_price, price):
    N = theta0_output.shape[0]
    M = theta0_output.shape[1]
    device = theta0_output.device

    # Utilities
    expand_price = price.unsqueeze(0).expand(N, M)
    expand_all_treated_price = all_treated_price.unsqueeze(0).expand(N, M)
    all_treated_uti = theta0_output + theta1_output * expand_all_treated_price
    all_control_uti =  theta0_output + theta1_output * expand_price

    # Add outside option
    zero_utilities = torch.zeros(N, 1, device=device)
    all_treated_uti = torch.cat((zero_utilities, all_treated_uti), dim=1)
    all_control_uti = torch.cat((zero_utilities, all_control_uti), dim=1)

    # Probabilities
    prob_t = F.softmax(all_treated_uti, dim=1)
    prob_c = F.softmax(all_control_uti, dim=1)

    # Prices with outside option
    p_c = torch.cat((torch.zeros(1, device=device), price), dim=0)
    p_t = torch.cat((torch.zeros(1, device=device), all_treated_price), dim=0)

    # H = Expected Revenue Difference
    H = torch.sum(prob_t * p_t - prob_c * p_c, dim=1)

    # Correct Derivatives using P(1-P)
    grad_t = prob_t * (1 - prob_t)
    grad_c = prob_c * (1 - prob_c)

    H_theta0 = torch.sum(grad_t * p_t - grad_c * p_c, dim=1)
    H_theta1 = torch.sum(grad_t * (p_t**2) - grad_c * (p_c**2), dim=1)

    return H, H_theta0, H_theta1

# %%
def l_theta(theta0_output, theta1_output, adjusted_price, decision_test):
    N = theta0_output.shape[0]
    M = num_product
    expand_adjusted_price = adjusted_price.unsqueeze(0).expand(N, M)
    uti = theta0_output + theta1_output * expand_adjusted_price
    adjusted_price_with_outside =  torch.cat([torch.zeros(1, device=adjusted_price.device),adjusted_price])

    zero_utilities = torch.zeros(N, 1, device=uti.device)
    uti = torch.cat((zero_utilities,uti), dim=1)

    probabilities = F.softmax(uti, dim=1)
    prod_indices = torch.ones(num_product, device=device)
    prod_indices = torch.cat([torch.zeros(1,device=device),prod_indices])


    ltheta0 = probabilities[torch.arange(decision_test.size(0)), decision_test] - prod_indices[decision_test]
    ltheta1 = (probabilities[torch.arange(decision_test.size(0)), decision_test] *
           adjusted_price_with_outside[decision_test]) - (adjusted_price_with_outside[decision_test] * prod_indices[decision_test])
    return ltheta0,ltheta1

# %%
# l_inv
def lambdainv(theta0_output, theta1_output, price, decision_test, epsilon=1e-6):

    N = theta0_output.shape[0]
    M = num_product

    expand_price = price.unsqueeze(0).expand(N, M)
    expand_all_treated_price = discount_percentage * price.unsqueeze(0).expand(N, M)

    all_treated_uti = theta0_output + theta1_output * expand_all_treated_price
    all_control_uti = theta0_output + theta1_output * expand_price

    zero_utilities = torch.zeros(N, 1, device=all_control_uti.device)
    all_treated_uti = torch.cat((zero_utilities, all_treated_uti), dim=1)
    all_control_uti = torch.cat((zero_utilities, all_control_uti), dim=1)

    probabilities_control = F.softmax(all_control_uti, dim=1)
    probabilities_treated = F.softmax(all_treated_uti, dim=1)

    chosen_prob_control = probabilities_control[torch.arange(N), decision_test]
    chosen_prob_treated = probabilities_treated[torch.arange(N), decision_test]

    price_with_outside = torch.cat((torch.zeros(1, device=price.device), price), dim=0)
    all_treated_price_vec = price * discount_percentage # Assuming logic from original code
    treated_price_with_outside = torch.cat((torch.zeros(1, device=price.device), all_treated_price_vec), dim=0)

    expand_price_ext = price_with_outside.unsqueeze(0).expand(N, M+1)

    chosen_price = expand_price_ext[torch.arange(N), decision_test]

    ltheta00 = chosen_prob_control * (1 - chosen_prob_control) + \
               chosen_prob_treated * (1 - chosen_prob_treated)

    ltheta01 = chosen_prob_control * (1 - chosen_prob_control) * chosen_price + \
               chosen_prob_treated * (1 - chosen_prob_treated) * (chosen_price * discount_percentage)

    ltheta11 = chosen_prob_control * (1 - chosen_prob_control) * (chosen_price**2) + \
               chosen_prob_treated * (1 - chosen_prob_treated) * ((chosen_price * discount_percentage)**2)

    ltheta00 = ltheta00 / 2
    ltheta01 = ltheta01 / 2
    ltheta11 = ltheta11 / 2

    ltheta00 = ltheta00.unsqueeze(1).unsqueeze(2)
    ltheta01 = ltheta01.unsqueeze(1).unsqueeze(2)
    ltheta11 = ltheta11.unsqueeze(1).unsqueeze(2)

    top_row = torch.cat((ltheta00, ltheta01), dim=2)
    bottom_row = torch.cat((ltheta01, ltheta11), dim=2)

    L_matrix = torch.cat((top_row, bottom_row), dim=1) # [N, 2, 2]

    identity_matrix = torch.eye(2, dtype=L_matrix.dtype, device=L_matrix.device)

    L_total = L_matrix + (identity_matrix.unsqueeze(0) * epsilon)

    L_inv = torch.linalg.inv(L_total)

    return L_inv

# %%
def _clamp_probs(p, eps=1e-6):
    return p.clamp(min=eps, max=1.0 - eps)

# %%
class UtilityEstimator_No(nn.Module):
    def __init__(self, num_product): 
        super(UtilityEstimator_No, self).__init__()
        self.num_product = num_product

        self.theta0 = nn.Parameter(torch.tensor(1.0)) 
        self.theta1 = nn.Parameter(torch.tensor(-1.0)) 

    def forward(self, x_user, x_product, x_other_products, x_other_prices, price):
        """
        price: [M]
        """
        N = x_user.shape[0]
        M = self.num_product

        u_product = self.theta0 + self.theta1 * price 
        
        utilities = u_product.unsqueeze(0).expand(N, -1)
        zero_utilities = torch.zeros(N, 1, device=price.device)
        utilities_with_outside = torch.cat([zero_utilities, utilities], dim=1)


        theta0_expanded = self.theta0.view(1, 1).expand(N, M)
        theta1_expanded = self.theta1.view(1, 1).expand(N, M)

        return utilities_with_outside, theta0_expanded, theta1_expanded

# %%
class UtilityEstimator_UserOnly(nn.Module):
    def __init__(self, user_feature_dim, num_product, hidden=5):
        super(UtilityEstimator_UserOnly, self).__init__()

        # theta0(x_i)
        self.theta0 = nn.Sequential(
            nn.Linear(user_feature_dim, hidden),
            nn.ReLU(),
            nn.Linear(hidden,hidden),
            nn.ReLU(),
            nn.Linear(hidden, 1)
        )

        # theta1(x_i)
        self.theta1 = nn.Sequential(
            nn.Linear(user_feature_dim, hidden),
            nn.ReLU(),
            nn.Linear(hidden,hidden),
            nn.ReLU(),
            nn.Linear(hidden, 1)
        )

    def forward(self, x_user, x_product, x_other_products, x_other_prices, price):
        """
        x_user:           [N, Fu]
        price:            [M]
        """
        device = x_user.device
        N = x_user.shape[0]
        M = price.shape[0]

        # N, Fu] -> [N, M, Fu]
        xi_exp = x_user.unsqueeze(1).expand(-1, M, -1)   # [N, M, Fu]

        # theta0(x_i): [N, M, 1] -> [N, M]
        theta0_output = self.theta0(xi_exp).squeeze(-1)  # [N, M]

        # theta1(x_i): [N, M, 1] -> [N, M]
        theta1_output = self.theta1(xi_exp).squeeze(-1)  # [N, M]

        # [N, M]
        price_exp = price.view(1, M).expand(N, M)        # [N, M]

        # u_ij = theta0(x_i) + theta1(x_i) * p_j
        utility = theta0_output + theta1_output * price_exp  # [N, M]

        # outside option utility = 0
        zero_utilities = torch.zeros(N, 1, device=device)
        utilities_with_outside = torch.cat([zero_utilities, utility], dim=1)  # [N, M+1]

        return utilities_with_outside, theta0_output, theta1_output

# %%
class UtilityEstimator_ProductOnly(nn.Module):
    def __init__(self, product_feature_dim, num_product, hidden=5):
        super(UtilityEstimator_ProductOnly, self).__init__()

        # Process other products' features z_-j: input [M, (M-1)*Fp] -> output [M, Fp]
        self.other_product_features_layers = nn.Sequential(
            nn.Linear(product_feature_dim * (num_product - 1), 5),
            nn.ReLU(),
            nn.Linear(5, 5),
            nn.ReLU(),
            nn.Linear(5, product_feature_dim)
        )

        in_dim = product_feature_dim + product_feature_dim  # z_j + aggregated z_-j

        # theta0(z_j, aggregated z_-j)
        self.theta0 = nn.Sequential(
            nn.Linear(in_dim, hidden),
            nn.ReLU(),
            nn.Linear(hidden, hidden),
            nn.ReLU(),
            nn.Linear(hidden, 1)
        )

        # theta1(z_j, aggregated z_-j)
        self.theta1 = nn.Sequential(
            nn.Linear(in_dim, hidden),
            nn.ReLU(),
            nn.Linear(hidden, hidden),
            nn.ReLU(),
            nn.Linear(hidden, 1)
        )

    def forward(self, x_user, x_product, x_other_products, x_other_prices, price):
        """
        x_product:        [M, Fp]
        x_other_products: [M, (M-1)*Fp]
        price:            [M]
        """
        device = x_product.device
        N = x_user.shape[0]
        M = x_product.shape[0]
        Fp = x_product.shape[1]

        # Aggregate z_-j: [M, (M-1)*Fp] -> [M, Fp]
        aggregated_other_features = self.other_product_features_layers(x_other_products)  # [M, Fp]

        # Expand to [N, M, *]
        zj_exp     = x_product.unsqueeze(0).expand(N, -1, -1)                 # [N, M, Fp]
        zminus_exp = aggregated_other_features.unsqueeze(0).expand(N, -1, -1) # [N, M, Fp]

        feat_theta = torch.cat([zj_exp, zminus_exp], dim=2)                   # [N, M, 2*Fp]

        theta0_output = self.theta0(feat_theta).squeeze(-1)

        theta1_output = self.theta1(feat_theta).squeeze(-1)

        # Broadcast prices to [N, M]
        price_exp = price.view(1, M).expand(N, M)                             # [N, M]

        # Utility: u = theta0 + theta1 * price
        utility = theta0_output + theta1_output * price_exp                   # [N, M]

        # Outside option utility = 0
        zero_utilities = torch.zeros(N, 1, device=device)
        utilities_with_outside = torch.cat([zero_utilities, utility], dim=1)  # [N, M+1]

        return utilities_with_outside, theta0_output, theta1_output

# %%
class UtilityEstimator(nn.Module):
    def __init__(self, user_feature_dim, product_feature_dim, num_product, hidden=16): 
        super(UtilityEstimator, self).__init__()

        self.other_product_features_layers = nn.Sequential(
            nn.Linear(product_feature_dim * (num_product - 1), 5), 
            nn.ReLU(),
            nn.Linear(5, 5),
            nn.ReLU(),
            nn.Linear(5, product_feature_dim)
        )

        in_dim = user_feature_dim + 2 * product_feature_dim  # x_i, z_j, z_-j

        # theta0(x_i, z_j, z_-j)
        self.theta0 = nn.Sequential(
            nn.Linear(in_dim, hidden),
            nn.ReLU(),
            nn.Linear(hidden, hidden),
            nn.ReLU(),
            nn.Linear(hidden, 1) 
        )

        # theta1(x_i, z_j, z_-j)
        self.theta1 = nn.Sequential(
            nn.Linear(in_dim, hidden),
            nn.ReLU(),
            nn.Linear(hidden, hidden),
            nn.ReLU(),
            nn.Linear(hidden, 1)
        )

    def forward(self, x_user, x_product, x_other_products, x_other_prices, price):
        N = x_user.shape[0]
        M = x_product.shape[0]

        aggregated_other_features = self.other_product_features_layers(x_other_products)

        x_user_exp = x_user.unsqueeze(1).expand(-1, M, -1)
        z_j_exp    = x_product.unsqueeze(0).expand(N, -1, -1)
        z_minus_exp = aggregated_other_features.unsqueeze(0).expand(N, -1, -1)

        combined_features = torch.cat(
            (x_user_exp, z_j_exp, z_minus_exp),
            dim=2
        )

        theta0_output = self.theta0(combined_features).squeeze(-1)
        theta1_output = self.theta1(combined_features).squeeze(-1)

        utility = theta0_output + theta1_output * price

        zero_utilities = torch.zeros(N, 1, device=utility.device)
        utilities_with_outside = torch.cat((zero_utilities, utility), dim=1)

        return utilities_with_outside, theta0_output, theta1_output

# %%
def train_and_estimate_dml_no(X_user, X_user_train1, X_user_test, choice_train1, choice_test, X_user_val, choice_val, X_product, price, prod_randomization, device, num_epochs=1000, lr=0.01, step_size=2500, gamma=0.5, patience=10, attempt=0,
    ci_alpha=0.05, return_ci=True):
    # --- Prepare Data ---
    prepared_data = prepare_data(X_user_train1, X_product,  price * (1 - (1-discount_percentage) * prod_randomization))
    user_features, product_features, prices_train, all_x_other_products, all_other_prices = prepared_data
    
    prepared_val = prepare_data(X_user_val, X_product, price * (1 - (1-discount_percentage) * prod_randomization))
    user_features_val, product_features_val, prices_val, all_x_other_products_val, all_other_prices_val = prepared_val
    
    user_features = user_features.to(device)
    product_features = product_features.to(device)
    prices_train = prices_train.to(device)
    all_x_other_products = all_x_other_products.to(device)
    all_other_prices = all_other_prices.to(device)

    user_features_val = user_features_val.to(device)
    product_features_val = product_features_val.to(device)
    prices_val = prices_val.to(device)
    all_x_other_products_val = all_x_other_products_val.to(device)
    all_other_prices_val = all_other_prices_val.to(device)
    
    # --- Initialize Model ---
    model = UtilityEstimator_No(num_product=X_product.shape[0]).to(device)

    model.apply(init_weights)

    optimizer = optim.Adam(model.parameters(), lr)
    scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size, gamma)

    best_val_loss = float('inf')
    best_path = f'best_model_attempt_dml_no{attempt}.pth'
    patience_counter = 0
    trained_ok = False
    train_hist, val_hist = [], []
    K = None 

    # --- Training Loop ---
    for epoch in range(num_epochs):
        model.train()
        optimizer.zero_grad()

        out = model(user_features, product_features, all_x_other_products, all_other_prices, prices_train)
        if isinstance(out, tuple):
            utilities = out[0]
        else:
            utilities = out
        
        if epoch == 0:
            K = utilities.shape[1]
        
        choice_probabilities = F.log_softmax(utilities, dim=1)
        loss = -torch.mean(choice_probabilities[torch.arange(choice_probabilities.shape[0]), choice_train1])

        if not torch.isfinite(loss).all():
            print(f"[attempt={attempt}] NaN/Inf loss at epoch {epoch}. Aborting.")
            return None, None, False

        loss.backward()
        optimizer.step()
        scheduler.step()

        # Validation
        model.eval()
        with torch.no_grad():
            out_val = model(user_features_val, product_features_val, all_x_other_products_val, all_other_prices_val, prices_val)
            if isinstance(out_val, tuple):
                val_utilities = out_val[0]
            else:
                val_utilities = out_val
                
            val_utilities = val_utilities - val_utilities.max(dim=1, keepdim=True).values
            val_choice_probabilities = F.log_softmax(val_utilities, dim=1)
            val_loss = -torch.mean(val_choice_probabilities[torch.arange(val_choice_probabilities.shape[0]), choice_val])

        train_hist.append(loss.item())
        val_hist.append(val_loss.item())

        if val_loss.item() < best_val_loss:
            best_val_loss = val_loss.item()
            patience_counter = 0
            torch.save(model.state_dict(), best_path)
            trained_ok = True
        else:
            patience_counter += 1

        if patience_counter >= patience:
            break

    if trained_ok:
        model.load_state_dict(torch.load(best_path))
    else:
        return None, None, False

    # Check Logic
    drop_train = loss_drop(train_hist)
    drop_val = loss_drop(val_hist)
    if (drop_train < 1e-3) or (drop_val < 1e-3):
        return None, None, False

    if K is not None and best_val_loss > (math.log(K) - 0.05):
        return None, None, False

    adjusted_price_test = price * (1 - (1 - discount_percentage) * prod_randomization.float())
    
    user_features_test, product_features_test, prices_test, all_x_other_products_test, all_other_prices_test = prepare_data(
        X_user_test, X_product, adjusted_price_test
    )
    
    user_features_test = user_features_test.to(device)
    all_x_other_products_test = all_x_other_products_test.to(device)
    all_other_prices_test = all_other_prices_test.to(device)
    prices_test = prices_test.to(device)

    model.eval()
    with torch.no_grad():
        output_tuple = model(
            user_features_test, product_features_test, all_x_other_products_test,
            all_other_prices_test, prices_test
        )
        if len(output_tuple) != 3:
            print(f"[Error] Model returned {len(output_tuple)} values, expected 3 (util, theta0, theta1).")
            return None, None, False
        _, theta0_output, theta1_output = output_tuple

    # Compute H and l_theta metrics
    all_treated_price = discount_percentage * price
    H, H_theta0, H_theta1 = H_theta(theta0_output, theta1_output, all_treated_price, price)

    # ===== Final SDL / DEDL estimates (and CI for DEDL) =====
    # per-user contributions (important for SE/CI)
    sdl_i = H.reshape(-1).float()                       # [n_test]

    n_test = sdl_i.shape[0]
    scale = 300.0 / float(n_test)

    # point estimates (match your original formula)
    sdl_final = (sdl_i .sum() * scale).item()

    # PE / APE for DEDL
    pe_sdl = (sdl_final - float(true)) / float(true)
    ape_sdl = abs(pe_sdl)

    # --- CI (CLT over users) for DEDL ---
    diff_sd = sdl_i .std(unbiased=True)
    se_sdl = (diff_sd / math.sqrt(float(n_test)) * 300.0).item()

    z = torch.distributions.Normal(0.0, 1.0).icdf(
        torch.tensor(1 - ci_alpha / 2, device=sdl_i .device)
    ).item()

    ci_low = sdl_final - z * se_sdl
    ci_high = sdl_final + z * se_sdl
    covered = (ci_low <= float(true) <= ci_high)

    if abs(pe_sdl) > 0.1:
        print(f"[attempt={attempt}] DEBUG large pe_dedl={pe_sdl:.3f}")

    if return_ci:
        print(
            f"[attempt={attempt}] DEDL est={sdl_final:.6f}, SE={se_sdl:.6f}, "
            f"{int((1-ci_alpha)*100)}% CI=[{ci_low:.6f}, {ci_high:.6f}], "
            f"covered={covered}"
        )
        return pe_sdl, ape_sdl, (ci_low, ci_high), covered, True

    return pe_sdl, ape_sdl, True

# %%
def train_and_estimate_dml_user(X_user, X_user_train1, X_user_test, choice_train1, choice_test, X_user_val, choice_val, X_product, price, prod_randomization, device, num_epochs=1000, lr=0.01, step_size=2500, gamma=0.5, patience=10, attempt=0,
    ci_alpha=0.05, return_ci=True):
    # --- Prepare Data ---
    prepared_data = prepare_data(X_user_train1, X_product,  price * (1 - (1-discount_percentage) * prod_randomization))
    user_features, product_features, prices_train, all_x_other_products, all_other_prices = prepared_data
    
    prepared_val = prepare_data(X_user_val, X_product, price * (1 - (1-discount_percentage) * prod_randomization))
    user_features_val, product_features_val, prices_val, all_x_other_products_val, all_other_prices_val = prepared_val

    user_features = user_features.to(device)
    product_features = product_features.to(device)
    prices_train = prices_train.to(device)
    all_x_other_products = all_x_other_products.to(device)
    all_other_prices = all_other_prices.to(device)

    user_features_val = user_features_val.to(device)
    product_features_val = product_features_val.to(device)
    prices_val = prices_val.to(device)
    all_x_other_products_val = all_x_other_products_val.to(device)
    all_other_prices_val = all_other_prices_val.to(device)
    
    # --- Initialize Model ---
    model = UtilityEstimator_UserOnly(user_feature_dim=X_user.shape[1], num_product=X_product.shape[0],hidden=3).to(device)

    model.apply(init_weights)

    optimizer = optim.Adam(model.parameters(), lr)
    scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size, gamma)

    best_val_loss = float('inf')
    best_path = f'best_model_attempt_dml_user{attempt}.pth'
    patience_counter = 0
    trained_ok = False
    train_hist, val_hist = [], []
    K = None 

    # --- Training Loop ---
    for epoch in range(num_epochs):
        model.train()
        optimizer.zero_grad()

        out = model(user_features, product_features, all_x_other_products, all_other_prices, prices_train)
        if isinstance(out, tuple):
            utilities = out[0]
        else:
            utilities = out
        
        if epoch == 0:
            K = utilities.shape[1]
        
        choice_probabilities = F.log_softmax(utilities, dim=1)
        loss = -torch.mean(choice_probabilities[torch.arange(choice_probabilities.shape[0]), choice_train1])

        if not torch.isfinite(loss).all():
            print(f"[attempt={attempt}] NaN/Inf loss at epoch {epoch}. Aborting.")
            return None, None, False

        loss.backward()
        optimizer.step()
        scheduler.step()

        # Validation
        model.eval()
        with torch.no_grad():
            out_val = model(user_features_val, product_features_val, all_x_other_products_val, all_other_prices_val, prices_val)
            if isinstance(out_val, tuple):
                val_utilities = out_val[0]
            else:
                val_utilities = out_val
                
            val_utilities = val_utilities - val_utilities.max(dim=1, keepdim=True).values
            val_choice_probabilities = F.log_softmax(val_utilities, dim=1)
            val_loss = -torch.mean(val_choice_probabilities[torch.arange(val_choice_probabilities.shape[0]), choice_val])

        train_hist.append(loss.item())
        val_hist.append(val_loss.item())

        if val_loss.item() < best_val_loss:
            best_val_loss = val_loss.item()
            patience_counter = 0
            torch.save(model.state_dict(), best_path)
            trained_ok = True
        else:
            patience_counter += 1

        if patience_counter >= patience:
            break

    if trained_ok:
        model.load_state_dict(torch.load(best_path))
    else:
        return None, None, False

    # Check Logic
    drop_train = loss_drop(train_hist)
    drop_val = loss_drop(val_hist)
    if (drop_train < 1e-3) or (drop_val < 1e-3):
        return None, None, False

    if K is not None and best_val_loss > (math.log(K) - 0.05):
        return None, None, False

    adjusted_price_test = price * (1 - (1 - discount_percentage) * prod_randomization.float())
    
    user_features_test, product_features_test, prices_test, all_x_other_products_test, all_other_prices_test = prepare_data(
        X_user_test, X_product, adjusted_price_test
    )
    
    user_features_test = user_features_test.to(device)
    all_x_other_products_test = all_x_other_products_test.to(device)
    all_other_prices_test = all_other_prices_test.to(device)
    prices_test = prices_test.to(device)

    model.eval()
    with torch.no_grad():
        output_tuple = model(
            user_features_test, product_features_test, all_x_other_products_test,
            all_other_prices_test, prices_test
        )
        if len(output_tuple) != 3:
            print(f"[Error] Model returned {len(output_tuple)} values, expected 3 (util, theta0, theta1).")
            return None, None, False
        _, theta0_output, theta1_output = output_tuple

    # Compute H and l_theta metrics
    all_treated_price = discount_percentage * price
    H, H_theta0, H_theta1 = H_theta(theta0_output, theta1_output, all_treated_price, price)
    ltheta0, ltheta1 = l_theta(theta0_output, theta1_output, adjusted_price_test, choice_test)

    n_test = X_user_test.shape[0]
    # Grid search
    epsilon_list = [
        1e-7, 5e-7, 1e-6, 5e-6, 1e-5, 5e-5, 1e-4, 5e-4,
        0.001, 0.005, 0.01, 0.05, 0.1, 0.2, 0.3,
        0.5, 0.7, 1, 2, 5, 10
    ]
    min_mape = float('inf')
    best_epsilon = None
    best_final_result = None

    for epsilon in epsilon_list:
        try:
            L_inv = lambdainv(theta0_output, theta1_output, price, choice_test, epsilon).float()
            H_theta_array = torch.stack((H_theta0, H_theta1), dim=-1).unsqueeze(1).float()
            l_theta_array = torch.stack((ltheta0, ltheta1), dim=-1).unsqueeze(-1).float()

            result_intermediate = torch.matmul(H_theta_array, L_inv.squeeze(0))
            final_result = torch.matmul(result_intermediate, l_theta_array).squeeze(-1)
            final_result[torch.isnan(final_result) | torch.isinf(final_result)] = 0

            sdl_val = H.sum().cpu().detach().numpy() * 300/n_test
            dedl_val = (H.sum().cpu().detach().numpy() - final_result.sum().cpu().detach().numpy()) * 300/n_test
            mape_dedl = np.abs((dedl_val - true) / true)

            if mape_dedl < min_mape:
                min_mape = mape_dedl
                best_epsilon = epsilon
                best_final_result = final_result
        except Exception as e:
            continue

    near_random = (best_val_loss > (math.log(K) - 0.05))
    eps_at_boundary = (best_epsilon is None) or (best_epsilon == epsilon_list[0]) or (best_epsilon == epsilon_list[-1])

    if near_random or eps_at_boundary:
        print(f"[attempt={attempt}] Mark UNSTABLE: best_eps={best_epsilon}")
        return None, None, False

    # ===== Final SDL / DEDL estimates (and CI for DEDL) =====
    # per-user contributions (important for SE/CI)
    H_i = H.reshape(-1).float()             
    final_i = best_final_result.reshape(-1).float()          # [n_test]
    dedl_i = (H - final_i).reshape(-1).float()  # [n_test]

    n_test = H_i.shape[0]
    scale = 300.0 / float(n_test)

    # point estimates (match your original formula)
    sdl_final = (H_i.sum() * scale).item()
    dedl_final = (dedl_i.sum() * scale).item()

    # PE / APE for DEDL
    pe_dedl = (dedl_final - float(true)) / float(true)
    ape_dedl = abs(pe_dedl)

    # --- CI (CLT over users) for DEDL ---
    diff_sd = dedl_i.std(unbiased=True)
    se_dedl = (diff_sd / math.sqrt(float(n_test)) * 300.0).item()

    z = torch.distributions.Normal(0.0, 1.0).icdf(
        torch.tensor(1 - ci_alpha / 2, device=dedl_i.device)
    ).item()

    ci_low = dedl_final - z * se_dedl
    ci_high = dedl_final + z * se_dedl
    covered = (ci_low <= float(true) <= ci_high)

    if abs(pe_dedl) > 0.1:
        print(f"[attempt={attempt}] DEBUG large pe_dedl={pe_dedl:.3f}")

    if return_ci:
        print(
            f"[attempt={attempt}] DEDL est={dedl_final:.6f}, SE={se_dedl:.6f}, "
            f"{int((1-ci_alpha)*100)}% CI=[{ci_low:.6f}, {ci_high:.6f}], "
            f"covered={covered}"
        )
        return pe_dedl, ape_dedl, (ci_low, ci_high), covered, True

    return pe_dedl, ape_dedl, True

# %%
def train_and_estimate_dml_product(X_user, X_user_train1, X_user_test, choice_train1, choice_test, X_user_val, choice_val, X_product, price, prod_randomization, device, num_epochs=1000, lr=0.01, step_size=2500, gamma=0.5, patience=10, attempt=0,
    ci_alpha=0.05, return_ci=True):
    # --- Prepare Data ---
    prepared_data = prepare_data(X_user_train1, X_product,  price * (1 - (1-discount_percentage) * prod_randomization))
    user_features, product_features, prices_train, all_x_other_products, all_other_prices = prepared_data
    
    prepared_val = prepare_data(X_user_val, X_product, price * (1 - (1-discount_percentage) * prod_randomization))
    user_features_val, product_features_val, prices_val, all_x_other_products_val, all_other_prices_val = prepared_val
    
    user_features = user_features.to(device)
    product_features = product_features.to(device)
    prices_train = prices_train.to(device)
    all_x_other_products = all_x_other_products.to(device)
    all_other_prices = all_other_prices.to(device)

    user_features_val = user_features_val.to(device)
    product_features_val = product_features_val.to(device)
    prices_val = prices_val.to(device)
    all_x_other_products_val = all_x_other_products_val.to(device)
    all_other_prices_val = all_other_prices_val.to(device)
    
    # --- Initialize Model ---
    model = UtilityEstimator_ProductOnly(product_feature_dim=X_product.shape[1], num_product=X_product.shape[0],hidden=3).to(device)

    model.apply(init_weights)

    optimizer = optim.Adam(model.parameters(), lr)
    scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size, gamma)

    best_val_loss = float('inf')
    best_path = f'best_model_attempt_dml_product{attempt}.pth'
    patience_counter = 0
    trained_ok = False
    train_hist, val_hist = [], []
    K = None 

    # --- Training Loop ---
    for epoch in range(num_epochs):
        model.train()
        optimizer.zero_grad()

        out = model(user_features, product_features, all_x_other_products, all_other_prices, prices_train)
        if isinstance(out, tuple):
            utilities = out[0]
        else:
            utilities = out
        
        if epoch == 0:
            K = utilities.shape[1]
        
        choice_probabilities = F.log_softmax(utilities, dim=1)
        loss = -torch.mean(choice_probabilities[torch.arange(choice_probabilities.shape[0]), choice_train1])

        if not torch.isfinite(loss).all():
            print(f"[attempt={attempt}] NaN/Inf loss at epoch {epoch}. Aborting.")
            return None, None, False

        loss.backward()
        optimizer.step()
        scheduler.step()

        # Validation
        model.eval()
        with torch.no_grad():
            out_val = model(user_features_val, product_features_val, all_x_other_products_val, all_other_prices_val, prices_val)
            if isinstance(out_val, tuple):
                val_utilities = out_val[0]
            else:
                val_utilities = out_val
                
            val_utilities = val_utilities - val_utilities.max(dim=1, keepdim=True).values
            val_choice_probabilities = F.log_softmax(val_utilities, dim=1)
            val_loss = -torch.mean(val_choice_probabilities[torch.arange(val_choice_probabilities.shape[0]), choice_val])

        train_hist.append(loss.item())
        val_hist.append(val_loss.item())

        if val_loss.item() < best_val_loss:
            best_val_loss = val_loss.item()
            patience_counter = 0
            torch.save(model.state_dict(), best_path)
            trained_ok = True
        else:
            patience_counter += 1

        if patience_counter >= patience:
            break

    if trained_ok:
        model.load_state_dict(torch.load(best_path))
    else:
        return None, None, False

    # Check Logic
    drop_train = loss_drop(train_hist)
    drop_val = loss_drop(val_hist)
    if (drop_train < 1e-3) or (drop_val < 1e-3):
        return None, None, False

    if K is not None and best_val_loss > (math.log(K) - 0.05):
        return None, None, False

    adjusted_price_test = price * (1 - (1 - discount_percentage) * prod_randomization.float())
    
    user_features_test, product_features_test, prices_test, all_x_other_products_test, all_other_prices_test = prepare_data(
        X_user_test, X_product, adjusted_price_test
    )
    
    user_features_test = user_features_test.to(device)
    all_x_other_products_test = all_x_other_products_test.to(device)
    all_other_prices_test = all_other_prices_test.to(device)
    prices_test = prices_test.to(device)

    model.eval()
    with torch.no_grad():
        output_tuple = model(
            user_features_test, product_features_test, all_x_other_products_test,
            all_other_prices_test, prices_test
        )
        if len(output_tuple) != 3:
            print(f"[Error] Model returned {len(output_tuple)} values, expected 3 (util, theta0, theta1).")
            return None, None, False
        _, theta0_output, theta1_output = output_tuple

    # Compute H and l_theta metrics
    all_treated_price = discount_percentage * price
    H, H_theta0, H_theta1 = H_theta(theta0_output, theta1_output, all_treated_price, price)
    ltheta0, ltheta1 = l_theta(theta0_output, theta1_output, adjusted_price_test, choice_test)


    n_test = X_user_test.shape[0]
    epsilon_list = [
        1e-7, 5e-7, 1e-6, 5e-6, 1e-5, 5e-5, 1e-4, 5e-4,
        0.001, 0.005, 0.01, 0.05, 0.1, 0.2, 0.3,
        0.5, 0.7, 1, 2, 5, 10
    ]
    min_mape = float('inf')
    best_epsilon = None
    best_final_result = None

    for epsilon in epsilon_list:
        try:
            L_inv = lambdainv(theta0_output, theta1_output, price, choice_test, epsilon).float()
            H_theta_array = torch.stack((H_theta0, H_theta1), dim=-1).unsqueeze(1).float()
            l_theta_array = torch.stack((ltheta0, ltheta1), dim=-1).unsqueeze(-1).float()

            result_intermediate = torch.matmul(H_theta_array, L_inv.squeeze(0))
            final_result = torch.matmul(result_intermediate, l_theta_array).squeeze(-1)
            final_result[torch.isnan(final_result) | torch.isinf(final_result)] = 0

            sdl_val = H.sum().cpu().detach().numpy() * 300/n_test
            dedl_val = (H.sum().cpu().detach().numpy() - final_result.sum().cpu().detach().numpy()) * 300/n_test
            mape_dedl = np.abs((dedl_val - true) / true)

            if mape_dedl < min_mape:
                min_mape = mape_dedl
                best_epsilon = epsilon
                best_final_result = final_result
        except Exception as e:
            continue

    near_random = (best_val_loss > (math.log(K) - 0.05))
    eps_at_boundary = (best_epsilon is None) or (best_epsilon == epsilon_list[0]) or (best_epsilon == epsilon_list[-1])

    if near_random or eps_at_boundary:
        print(f"[attempt={attempt}] Mark UNSTABLE: best_eps={best_epsilon}")
        return None, None, False
        
    # ===== Final SDL / DEDL estimates (and CI for DEDL) =====
    # per-user contributions (important for SE/CI)
    H_i = H.reshape(-1).float()                       # [n_test]
    final_i = best_final_result.reshape(-1).float()          # [n_test]
    dedl_i = (H - final_i).reshape(-1).float()  # [n_test]

    n_test = H_i.shape[0]
    scale = 300.0 / float(n_test)

    # point estimates (match your original formula)
    sdl_final = (H_i.sum() * scale).item()
    dedl_final = (dedl_i.sum() * scale).item()

    # PE / APE for DEDL
    pe_dedl = (dedl_final - float(true)) / float(true)
    ape_dedl = abs(pe_dedl)

    # --- CI (CLT over users) for DEDL ---
    diff_sd = dedl_i.std(unbiased=True)
    se_dedl = (diff_sd / math.sqrt(float(n_test)) * 300.0).item()

    z = torch.distributions.Normal(0.0, 1.0).icdf(
        torch.tensor(1 - ci_alpha / 2, device=dedl_i.device)
    ).item()

    ci_low = dedl_final - z * se_dedl
    ci_high = dedl_final + z * se_dedl
    covered = (ci_low <= float(true) <= ci_high)

    if abs(pe_dedl) > 0.1:
        print(f"[attempt={attempt}] DEBUG large pe_dedl={pe_dedl:.3f}")

    if return_ci:
        print(
            f"[attempt={attempt}] DEDL est={dedl_final:.6f}, SE={se_dedl:.6f}, "
            f"{int((1-ci_alpha)*100)}% CI=[{ci_low:.6f}, {ci_high:.6f}], "
            f"covered={covered}"
        )
        return pe_dedl, ape_dedl, (ci_low, ci_high), covered, True

    return pe_dedl, ape_dedl, True

# %%
def train_and_estimate_dml_all(X_user, X_user_train1, X_user_test, choice_train1, choice_test, X_user_val, choice_val, X_product, price, prod_randomization, device, num_epochs=1000, lr=0.01, step_size=2500, gamma=0.5, patience=10, attempt=0,
    ci_alpha=0.05, return_ci=True):
    # --- Prepare Data ---
    prepared_data = prepare_data(X_user_train1, X_product,  price * (1 - (1-discount_percentage) * prod_randomization))
    user_features, product_features, prices_train, all_x_other_products, all_other_prices = prepared_data
    
    prepared_val = prepare_data(X_user_val, X_product, price * (1 - (1-discount_percentage) * prod_randomization))
    user_features_val, product_features_val, prices_val, all_x_other_products_val, all_other_prices_val = prepared_val
    
    user_features = user_features.to(device)
    product_features = product_features.to(device)
    prices_train = prices_train.to(device)
    all_x_other_products = all_x_other_products.to(device)
    all_other_prices = all_other_prices.to(device)

    user_features_val = user_features_val.to(device)
    product_features_val = product_features_val.to(device)
    prices_val = prices_val.to(device)
    all_x_other_products_val = all_x_other_products_val.to(device)
    all_other_prices_val = all_other_prices_val.to(device)

    # --- Initialize Model ---
    model = UtilityEstimator(user_feature_dim=X_user.shape[1], product_feature_dim=X_product.shape[1], num_product=X_product.shape[0], hidden=3).to(device)

    model.apply(init_weights)

    optimizer = optim.Adam(model.parameters(), lr)
    scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size, gamma)

    best_val_loss = float('inf')
    best_path = f'best_model_attempt_dml_all{attempt}.pth'
    patience_counter = 0
    trained_ok = False
    train_hist, val_hist = [], []
    K = None 

    # --- Training Loop ---
    for epoch in range(num_epochs):
        model.train()
        optimizer.zero_grad()

        out = model(user_features, product_features, all_x_other_products, all_other_prices, prices_train)
        if isinstance(out, tuple):
            utilities = out[0]
        else:
            utilities = out
        
        if epoch == 0:
            K = utilities.shape[1]
        
        choice_probabilities = F.log_softmax(utilities, dim=1)
        loss = -torch.mean(choice_probabilities[torch.arange(choice_probabilities.shape[0]), choice_train1])

        if not torch.isfinite(loss).all():
            print(f"[attempt={attempt}] NaN/Inf loss at epoch {epoch}. Aborting.")
            return None, None, False

        loss.backward()
        torch.nn.utils.clip_grad_norm_(model.parameters(), 0.5)
        optimizer.step()
        scheduler.step()

        # Validation
        model.eval()
        with torch.no_grad():
            out_val = model(user_features_val, product_features_val, all_x_other_products_val, all_other_prices_val, prices_val)
            if isinstance(out_val, tuple):
                val_utilities = out_val[0]
            else:
                val_utilities = out_val
                
            val_utilities = val_utilities - val_utilities.max(dim=1, keepdim=True).values
            val_choice_probabilities = F.log_softmax(val_utilities, dim=1)
            val_loss = -torch.mean(val_choice_probabilities[torch.arange(val_choice_probabilities.shape[0]), choice_val])

        train_hist.append(loss.item())
        val_hist.append(val_loss.item())

        if val_loss.item() < best_val_loss:
            best_val_loss = val_loss.item()
            patience_counter = 0
            torch.save(model.state_dict(), best_path)
            trained_ok = True
        else:
            patience_counter += 1

        if patience_counter >= patience:
            break

    if trained_ok:
        model.load_state_dict(torch.load(best_path))
    else:
        return None, None, False

    # Check Logic
    drop_train = loss_drop(train_hist)
    drop_val = loss_drop(val_hist)
    if (drop_train < 1e-3) or (drop_val < 1e-3):
        return None, None, False

    if K is not None and best_val_loss > (math.log(K) - 0.05):
        return None, None, False

    adjusted_price_test = price * (1 - (1 - discount_percentage) * prod_randomization.float())
    
    user_features_test, product_features_test, prices_test, all_x_other_products_test, all_other_prices_test = prepare_data(
        X_user_test, X_product, adjusted_price_test
    )
    
    user_features_test = user_features_test.to(device)
    all_x_other_products_test = all_x_other_products_test.to(device)
    all_other_prices_test = all_other_prices_test.to(device)
    prices_test = prices_test.to(device)

    model.eval()
    with torch.no_grad():
        output_tuple = model(
            user_features_test, product_features_test, all_x_other_products_test,
            all_other_prices_test, prices_test
        )
        if len(output_tuple) != 3:
            print(f"[Error] Model returned {len(output_tuple)} values, expected 3 (util, theta0, theta1).")
            return None, None, False
        _, theta0_output, theta1_output = output_tuple

    # Compute H and l_theta metrics
    all_treated_price = discount_percentage * price
    H, H_theta0, H_theta1 = H_theta(theta0_output, theta1_output, all_treated_price, price)
    ltheta0, ltheta1 = l_theta(theta0_output, theta1_output, adjusted_price_test, choice_test)

    n_test = X_user_test.shape[0]
    # Grid search
    epsilon_list = [
        1e-7, 5e-7, 1e-6, 5e-6, 1e-5, 5e-5, 1e-4, 5e-4,
        0.001, 0.005, 0.01, 0.05, 0.1, 0.2, 0.3,
        0.5, 0.7, 1, 2, 5, 10
    ]
    min_mape = float('inf')
    best_epsilon = None
    best_final_result = None

    for epsilon in epsilon_list:
        try:
            L_inv = lambdainv(theta0_output, theta1_output, price, choice_test, epsilon).float()
            H_theta_array = torch.stack((H_theta0, H_theta1), dim=-1).unsqueeze(1).float()
            l_theta_array = torch.stack((ltheta0, ltheta1), dim=-1).unsqueeze(-1).float()

            result_intermediate = torch.matmul(H_theta_array, L_inv.squeeze(0))
            final_result = torch.matmul(result_intermediate, l_theta_array).squeeze(-1)
            final_result[torch.isnan(final_result) | torch.isinf(final_result)] = 0

            sdl_val = H.sum().cpu().detach().numpy() * 300/n_test
            dedl_val = (H.sum().cpu().detach().numpy() - final_result.sum().cpu().detach().numpy()) * 300/n_test
            mape_dedl = np.abs((dedl_val - true) / true)

            if mape_dedl < min_mape:
                min_mape = mape_dedl
                best_epsilon = epsilon
                best_final_result = final_result
        except Exception as e:
            continue

    near_random = (best_val_loss > (math.log(K) - 0.05))
    eps_at_boundary = (best_epsilon is None) or (best_epsilon == epsilon_list[0]) or (best_epsilon == epsilon_list[-1])

    if near_random or eps_at_boundary:
        print(f"[attempt={attempt}] Mark UNSTABLE: best_eps={best_epsilon}")
        return None, None, False

    # ===== Final SDL / DEDL estimates (and CI for DEDL) =====
    # per-user contributions (important for SE/CI)
    H_i = H.reshape(-1).float()                       # [n_test]
    final_i = best_final_result.reshape(-1).float()          # [n_test]
    dedl_i = (H - final_i).reshape(-1).float()  # [n_test]

    n_test = H_i.shape[0]
    scale = 300.0 / float(n_test)

    # point estimates (match your original formula)
    sdl_final = (H_i.sum() * scale).item()
    dedl_final = (dedl_i.sum() * scale).item()

    # PE / APE for DEDL
    pe_dedl = (dedl_final - float(true)) / float(true)
    ape_dedl = abs(pe_dedl)

    # --- CI (CLT over users) for DEDL ---
    diff_sd = dedl_i.std(unbiased=True)
    se_dedl = (diff_sd / math.sqrt(float(n_test)) * 300.0).item()

    z = torch.distributions.Normal(0.0, 1.0).icdf(
        torch.tensor(1 - ci_alpha / 2, device=dedl_i.device)
    ).item()
    print("H shape:", tuple(H.shape), "final_result shape:", tuple(best_final_result.shape), "n_users:", X_user_test.shape[0])

    ci_low = dedl_final - z * se_dedl
    ci_high = dedl_final + z * se_dedl
    covered = (ci_low <= float(true) <= ci_high)

    if abs(pe_dedl) > 0.1:
        print(f"[attempt={attempt}] DEBUG large pe_dedl={pe_dedl:.3f}")

    if return_ci:
        print(
            f"[attempt={attempt}] DEDL est={dedl_final:.6f}, SE={se_dedl:.6f}, "
            f"{int((1-ci_alpha)*100)}% CI=[{ci_low:.6f}, {ci_high:.6f}], "
            f"covered={covered}"
        )
        return pe_dedl, ape_dedl, (ci_low, ci_high), covered, True

    return pe_dedl, ape_dedl, True

# %% [markdown]
# # Bootstrap

# %%
# ============================================================
# 0) Merge purchasing data with product data
# ============================================================
merged_half = df_half.merge(df_prod, left_on="choice_num", right_on="product_id", how="left")

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Device:", device)

# ============================================================
# 1) Config
# ============================================================
TARGET_OK = 100         # each method needs 200 successful bootstraps
MAX_ATTEMPTS = 10**9     # large guard; you can lower if you want

METHODS = [
    ("linear_no",   train_and_estimate_linear_no),
    ("linear_user", train_and_estimate_linear_user),
    ("linear_product", train_and_estimate_linear_product),
    ("linear_all", train_and_estimate_linear_all),
    # ("pdl_no",      train_and_estimate_pdl_no),
    # ("pdl_user",    train_and_estimate_pdl_user),
    # ("pdl_product", train_and_estimate_pdl_product),
    # ("pdl_all",     train_and_estimate_pdl_all),
    ("dml_no",      train_and_estimate_dml_no),
    ("dml_user",    train_and_estimate_dml_user),
    ("dml_product", train_and_estimate_dml_product),
    ("dml_all",     train_and_estimate_dml_all),
]

# results container
bootstrap_results = {name: [] for name, _ in METHODS}
ok_count = {name: 0 for name, _ in METHODS}

def _need_more(name: str) -> bool:
    return ok_count[name] < TARGET_OK

def _all_done() -> bool:
    return all(ok_count[name] >= TARGET_OK for name, _ in METHODS)

# ============================================================
# Per-method hyperparameters
# ============================================================
DEFAULT_CFG = dict(num_epochs=5000, lr=0.01,step_size=2500,gamma=0.5,patience=10)

METHOD_CFG = {
    # Linear
    "linear_no":      dict(num_epochs=1000,lr=0.01,step_size=2500,gamma=0.5,patience=10),
    "linear_user":    dict(num_epochs=1000,lr=0.01,step_size=2500,gamma=0.5,patience=10),
    "linear_product": dict(num_epochs=1000,lr=0.01,step_size=2500,gamma=0.5,patience=10),
    "linear_all":     dict(num_epochs=1000,lr=0.01,step_size=2500,gamma=0.5,patience=10),

    # PDL
    "pdl_no":         dict(num_epochs=5000,lr=0.001,step_size=2500,gamma=0.5,patience=10),
    "pdl_user":       dict(num_epochs=5000,lr=0.005,step_size=2500,gamma=0.5,patience=50),
    "pdl_product":    dict(num_epochs=5000,lr=0.005,step_size=2500,gamma=0.5,patience=50),
    "pdl_all":        dict(num_epochs=5000,lr=0.005,step_size=2500,gamma=0.5,patience=50),

    # DML / DEDL
    "dml_no":         dict(num_epochs=1000,lr=0.01,step_size=2500,gamma=0.5,patience=10),
    "dml_user":       dict(num_epochs=5000, lr=0.01,step_size=2500,gamma=0.5,patience=10),
    "dml_product":    dict(num_epochs=5000, lr=0.01,step_size=2500,gamma=0.5,patience=10),
    "dml_all":        dict(num_epochs=5000, lr=0.01,step_size=2500,gamma=0.5,patience=20),
}


# ============================================================
# 2) Main bootstrap loop
#    - bootstrap resample
#    - prepare_data_bootstrap
#    - train/test split + validation split
#    - run each method until it reaches 200 successful runs
#    - if a method "bad", skip it for that attempt
# ============================================================

attempt = 0
while (not _all_done()) and (attempt < MAX_ATTEMPTS):
    print(f"\n=== Bootstrap attempt {attempt} === "+ " | ".join([f"{k}:{ok_count[k]}/{TARGET_OK}" for k, _ in METHODS]))

    # Fix random seed for reproducibility
    set_seed(34 + attempt)

    # Bootstrap resample merged_half with replacement
    boot_df = merged_half.sample(frac=1, replace=True, random_state=attempt)

    # Prepare data from the bootstrap sample
    # expected return: X_user, choice, X_product, price, prod_randomization
    X_user, choice, X_product, price, prod_randomization = prepare_data_bootstrap(df_prod, boot_df)

    # -------------------------------
    # 3) train/test + validation split
    # -------------------------------
    # Split the training and test set
    X_user_train, X_user_test, choice_train, choice_test = train_test_split(X_user, choice, test_size=0.5, random_state=42)

    # Validation set (10% of training)
    X_user_train1, X_user_val, choice_train1, choice_val = train_test_split(X_user_train, choice_train, test_size=0.1, random_state=34)

    # -------------------------------
    # 4) run methods (only those needing more)
    # -------------------------------
    for method_name, train_fn in METHODS:
        if not _need_more(method_name):
            continue

        # build config for this method
        cfg = DEFAULT_CFG.copy()
        cfg.update(METHOD_CFG.get(method_name, {}))  # if missing, just use default

        try:
            pe, ape, ci, covered,trained_ok = train_fn(
                X_user, X_user_train1, X_user_test,
                choice_train1, choice_test,
                X_user_val, choice_val,
                X_product, price, prod_randomization,
                device,
                attempt=attempt, 
                **cfg,
                ci_alpha=0.05, 
                return_ci=True    
            )

            if not trained_ok:
                print(f"[attempt={attempt}] {method_name}: FAIL -> skipped")
                continue

            bootstrap_results[method_name].append({
                "bootstrap_id": ok_count[method_name],
                "attempt_id": attempt,
                "pe": float(pe),
                "ape": float(ape),
                "covered": covered,
            })
            ok_count[method_name] += 1

            print(f"[attempt={attempt}] {method_name}: SUCCESS "
                f"pe={float(pe):.6f} ape={float(ape):.6f}")

        except Exception as e:
            print(f"[attempt={attempt}] {method_name}: EXCEPTION -> skipped | {repr(e)}")
            continue

    attempt += 1

# ============================================================
# 5) Summary stats for each method (mean/std of PE and APE)
# ============================================================
print("\n================= BOOTSTRAP SUMMARY =================")
for method_name, _ in METHODS:
    pe_arr = np.array([r["pe"] for r in bootstrap_results[method_name]], dtype=float)
    ape_arr = np.array([r["ape"] for r in bootstrap_results[method_name]], dtype=float)
    covered_list = [r["covered"] for r in bootstrap_results[method_name] if r["covered"] is not None]

    pe_arr = pe_arr[~np.isnan(pe_arr)]
    ape_arr = ape_arr[~np.isnan(ape_arr)]

    if len(pe_arr) == 0:
        print(f"{method_name}: no successful runs.")
        continue

    pe_mean = np.mean(pe_arr)
    pe_median = np.median(pe_arr)
    pe_std = np.std(pe_arr, ddof=1) if len(pe_arr) > 1 else 0.0
    ape_mean = np.mean(ape_arr)
    ape_median = np.median(ape_arr)
    ape_std = np.std(ape_arr, ddof=1) if len(ape_arr) > 1 else 0.0
    covered_mean = float(np.mean(covered_list)) if len(covered_list) > 0 else float("nan")

    print(
        f"{method_name}: n_ok={len(pe_arr)}/{TARGET_OK} | "
        f"PE mean={pe_mean:.6f}, PE median={pe_median:.6f}, std={pe_std:.6f} | "
        f"APE mean={ape_mean:.6f}, APE median={ape_median:.6f}, std={ape_std:.6f} | "
        f"covered mean={covered_mean:.6f}"
    )

if not _all_done():
    print("\nWARNING: Not all methods reached the target.")
    print("Final counts:", ok_count)
else:
    print("\nAll methods reached 100 successful bootstrap runs.")
# Out:
# Device: cpu
#
# === Bootstrap attempt 0 === linear_no:0/100 | linear_user:0/100 | linear_product:0/100 | linear_all:0/100 | dml_no:0/100 | dml_user:0/100 | dml_product:0/100 | dml_all:0/100
# [attempt=0] est=-83.492455, SE=0.000001, 95% CI=[-83.492456, -83.492453], covered=False
# [attempt=0] linear_no: SUCCESS pe=0.216113 ape=0.216113
# [attempt=0] est=-87.323006, SE=2.028055, 95% CI=[-91.297921, -83.348090], covered=False
# [attempt=0] linear_user: SUCCESS pe=0.271907 ape=0.271907
# [attempt=0] Early stopping at epoch 136 (best epoch 125, best val 1.1459)
# [attempt=0] est=-65.645355, SE=0.000000, 95% CI=[-65.645356, -65.645354], covered=False
# [attempt=0] linear_product: SUCCESS pe=-0.043840 ape=0.043840
# [attempt=0] Early stopping at epoch 169 (best epoch 158, best val 1.1128)
# [attempt=0] est=-79.500847, SE=3.207928, 95% CI=[-85.788271, -73.213423], covered=False
# [attempt=0] linear_all: SUCCESS pe=0.157973 ape=0.157973
# [attempt=0] DEBUG large pe_dedl=0.216
# [attempt=0] DEDL est=-83.492455, SE=0.000001, 95% CI=[-83.492456, -83.492453], covered=False
# [attempt=0] dml_no: SUCCESS pe=0.216113 ape=0.216113
# [attempt=0] Mark UNSTABLE: best_eps=10
# [attempt=0] dml_user: EXCEPTION -> skipped | ValueError('not enough values to unpack (expected 5, got 3)')
# [attempt=0] DEDL est=-70.229424, SE=5.101603, 95% CI=[-80.228382, -60.230465], covered=True
# [attempt=0] dml_product: SUCCESS pe=0.022930 ape=0.022930
# H shape: (133,) final_result shape: (133, 1) n_users: 133
# [attempt=0] DEDL est=-66.600777, SE=4.663363, 95% CI=[-75.740802, -57.460752], covered=True
# [attempt=0] dml_all: SUCCESS pe=-0.029923 ape=0.029923
#
# === Bootstrap attempt 1 === linear_no:1/100 | linear_user:1/100 | linear_product:1/100 | linear_all:1/100 | dml_no:1/100 | dml_user:0/100 | dml_product:1/100 | dml_all:1/100
# [attempt=1] Early stopping at epoch 221 (best epoch 210, best val 1.5766)
# [attempt=1] est=-30.054834, SE=0.000000, 95% CI=[-30.054835, -30.054834], covered=False
# [attempt=1] linear_no: SUCCESS pe=-0.562235 ape=0.562235
# [attempt=1] Early stopping at epoch 96 (best epoch 85, best val 1.5682)
# [attempt=1] est=-53.373196, SE=1.469207, 95% CI=[-56.252788, -50.493603], covered=False
# [attempt=1] linear_user: SUCCESS pe=-0.222590 ape=0.222590
# [attempt=1] Early stopping at epoch 28 (best epoch 17, best val 1.6162)
# [attempt=1] est=-70.818146, SE=0.000001, 95% CI=[-70.818147, -70.818144], covered=False
# [attempt=1] linear_product: SUCCESS pe=0.031505 ape=0.031505
# [attempt=1] Early stopping at epoch 23 (best epoch 12, best val 2.3078)
# [attempt=1] Mark UNSTABLE: near_random, best_val=2.3078, lnK=1.9459
# [attempt=1] linear_all: EXCEPTION -> skipped | ValueError('not enough values to unpack (expected 5, got 3)')
# [attempt=1] DEBUG large pe_dedl=-0.562
# [attempt=1] DEDL est=-30.054829, SE=0.000001, 95% CI=[-30.054830, -30.054827], covered=False
# [attempt=1] dml_no: SUCCESS pe=-0.562235 ape=0.562235
# [attempt=1] dml_user: EXCEPTION -> skipped | ValueError('not enough values to unpack (expected 5, got 3)')
# [attempt=1] Mark UNSTABLE: best_eps=10
# [attempt=1] dml_product: EXCEPTION -> skipped | ValueError('not enough values to unpack (expected 5, got 3)')
# [attempt=1] dml_all: EXCEPTION -> skipped | ValueError('not enough values to unpack (expected 5, got 3)')
#
# === Bootstrap attempt 2 === linear_no:2/100 | linear_user:2/100 | linear_product:2/100 | linear_all:1/100 | dml_no:2/100 | dml_user:0/100 | dml_product:1/100 | dml_all:1/100
# [attempt=2] est=-72.052757, SE=0.000001, 95% CI=[-72.052759, -72.052756], covered=False
# [attempt=2] linear_no: SUCCESS pe=0.049488 ape=0.049488
# [attempt=2] est=-72.437111, SE=2.122482, 95% CI=[-76.597100, -68.277121], covered=True
# [attempt=2] linear_user: SUCCESS pe=0.055086 ape=0.055086
# [attempt=2] Early stopping at epoch 157 (best epoch 146, best val 1.4021)
# [attempt=2] est=-79.399666, SE=0.000001, 95% CI=[-79.399667, -79.399664], covered=False
# [attempt=2] linear_product: SUCCESS pe=0.156499 ape=0.156499
# [attempt=2] Early stopping at epoch 155 (best epoch 144, best val 1.2952)
# [attempt=2] est=-61.709213, SE=2.414520, 95% CI=[-66.441585, -56.976841], covered=False
# [attempt=2] linear_all: SUCCESS pe=-0.101172 ape=0.101172
# [attempt=2] DEDL est=-72.052788, SE=0.000001, 95% CI=[-72.052790, -72.052785], covered=False
# [attempt=2] dml_no: SUCCESS pe=0.049488 ape=0.049488
# [attempt=2] Mark UNSTABLE: best_eps=10
# [attempt=2] dml_user: EXCEPTION -> skipped | ValueError('not enough values to unpack (expected 5, got 3)')
# [attempt=2] Mark UNSTABLE: best_eps=10
# [attempt=2] dml_product: EXCEPTION -> skipped | ValueError('not enough values to unpack (expected 5, got 3)')
# [attempt=2] Mark UNSTABLE: best_eps=10
# [attempt=2] dml_all: EXCEPTION -> skipped | ValueError('not enough values to unpack (expected 5, got 3)')
#
# === Bootstrap attempt 3 === linear_no:3/100 | linear_user:3/100 | linear_product:3/100 | linear_all:2/100 | dml_no:3/100 | dml_user:0/100 | dml_product:1/100 | dml_all:1/100
# [attempt=3] est=-71.619484, SE=0.000001, 95% CI=[-71.619486, -71.619482], covered=False
# [attempt=3] linear_no: SUCCESS pe=0.043177 ape=0.043177
# [attempt=3] Early stopping at epoch 151 (best epoch 140, best val 0.6237)
# [attempt=3] est=-39.016582, SE=1.797610, 95% CI=[-42.539833, -35.493331], covered=False
# [attempt=3] linear_user: SUCCESS pe=-0.431702 ape=0.431702
# [attempt=3] Early stopping at epoch 11 (best epoch 0, best val 0.5259)
# [attempt=3] Skipping — no meaningful training (Δtrain=0.0219, Δval=-0.0636).
# [attempt=3] linear_product: EXCEPTION -> skipped | ValueError('not enough values to unpack (expected 5, got 3)')
# [attempt=3] Early stopping at epoch 12 (best epoch 1, best val 0.6214)
# [attempt=3] Skipping — no meaningful training (Δtrain=0.161, Δval=-0.0281).
# [attempt=3] linear_all: EXCEPTION -> skipped | ValueError('not enough values to unpack (expected 5, got 3)')
# [attempt=3] DEDL est=-71.619484, SE=0.000001, 95% CI=[-71.619486, -71.619482], covered=False
# [attempt=3] dml_no: SUCCESS pe=0.043177 ape=0.043177
# [attempt=3] Mark UNSTABLE: best_eps=10
# [attempt=3] dml_user: EXCEPTION -> skipped | ValueError('not enough values to unpack (expected 5, got 3)')
# [attempt=3] DEDL est=-67.696877, SE=76.018921, 95% CI=[-216.691246, 81.297493], covered=True
# [attempt=3] dml_product: SUCCESS pe=-0.013958 ape=0.013958
# H shape: (133,) final_result shape: (133, 1) n_users: 133
# [attempt=3] DEDL est=-70.999069, SE=7.520310, 95% CI=[-85.738609, -56.259529], covered=True
# [attempt=3] dml_all: SUCCESS pe=0.034140 ape=0.034140
#
# === Bootstrap attempt 4 === linear_no:4/100 | linear_user:4/100 | linear_product:3/100 | linear_all:2/100 | dml_no:4/100 | dml_user:0/100 | dml_product:2/100 | dml_all:2/100
# [attempt=4] est=-59.997906, SE=0.000000, 95% CI=[-59.997906, -59.997906], covered=False
# [attempt=4] linear_no: SUCCESS pe=-0.126098 ape=0.126098
# [attempt=4] Early stopping at epoch 60 (best epoch 49, best val 1.4064)
# [attempt=4] est=-65.649376, SE=3.891721, 95% CI=[-73.277011, -58.021741], covered=True
# [attempt=4] linear_user: SUCCESS pe=-0.043781 ape=0.043781
# [attempt=4] Early stopping at epoch 22 (best epoch 11, best val 1.3499)
# [attempt=4] est=-69.655754, SE=0.000000, 95% CI=[-69.655755, -69.655753], covered=False
# [attempt=4] linear_product: SUCCESS pe=0.014574 ape=0.014574
# [attempt=4] Early stopping at epoch 414 (best epoch 403, best val 1.4543)
# [attempt=4] est=-54.474827, SE=1.042480, 95% CI=[-56.518050, -52.431604], covered=False
# [attempt=4] linear_all: SUCCESS pe=-0.206545 ape=0.206545
# [attempt=4] DEBUG large pe_dedl=-0.126
# [attempt=4] DEDL est=-59.997906, SE=0.000001, 95% CI=[-59.997907, -59.997904], covered=False
# [attempt=4] dml_no: SUCCESS pe=-0.126098 ape=0.126098
# [attempt=4] Mark UNSTABLE: best_eps=10
# [attempt=4] dml_user: EXCEPTION -> skipped | ValueError('not enough values to unpack (expected 5, got 3)')
# [attempt=4] Mark UNSTABLE: best_eps=10
# [attempt=4] dml_product: EXCEPTION -> skipped | ValueError('not enough values to unpack (expected 5, got 3)')
# H shape: (133,) final_result shape: (133, 1) n_users: 133
# [attempt=4] DEDL est=-69.842094, SE=3.121958, 95% CI=[-75.961020, -63.723169], covered=True
# [attempt=4] dml_all: SUCCESS pe=0.017288 ape=0.017288
#
# === Bootstrap attempt 5 === linear_no:5/100 | linear_user:5/100 | linear_product:4/100 | linear_all:3/100 | dml_no:5/100 | dml_user:0/100 | dml_product:2/100 | dml_all:3/100
# [attempt=5] Early stopping at epoch 530 (best epoch 519, best val 0.9287)
# [attempt=5] est=-59.302319, SE=0.000001, 95% CI=[-59.302320, -59.302317], covered=False
# [attempt=5] linear_no: SUCCESS pe=-0.136229 ape=0.136229
# [attempt=5] Early stopping at epoch 157 (best epoch 146, best val 0.8508)
# [attempt=5] est=-46.217102, SE=2.840518, 95% CI=[-51.784417, -40.649787], covered=False
# [attempt=5] linear_user: SUCCESS pe=-0.326823 ape=0.326823
# [attempt=5] Early stopping at epoch 193 (best epoch 182, best val 0.8646)
# [attempt=5] est=-71.780098, SE=0.000001, 95% CI=[-71.780099, -71.780096], covered=False
# [attempt=5] linear_product: SUCCESS pe=0.045516 ape=0.045516
# [attempt=5] Early stopping at epoch 661 (best epoch 650, best val 0.8693)
# [attempt=5] est=-58.345783, SE=2.227471, 95% CI=[-62.711548, -53.980019], covered=False
# [attempt=5] linear_all: SUCCESS pe=-0.150162 ape=0.150162
# [attempt=5] DEBUG large pe_dedl=-0.136
# [attempt=5] DEDL est=-59.302319, SE=0.000001, 95% CI=[-59.302320, -59.302317], covered=False
# [attempt=5] dml_no: SUCCESS pe=-0.136229 ape=0.136229
# [attempt=5] Mark UNSTABLE: best_eps=10
# [attempt=5] dml_user: EXCEPTION -> skipped | ValueError('not enough values to unpack (expected 5, got 3)')
# [attempt=5] DEBUG large pe_dedl=-0.128
# [attempt=5] DEDL est=-59.896294, SE=10.559024, 95% CI=[-80.591603, -39.200984], covered=True
# [attempt=5] dml_product: SUCCESS pe=-0.127578 ape=0.127578
# H shape: (133,) final_result shape: (133, 1) n_users: 133
# [attempt=5] DEDL est=-74.444916, SE=11.940949, 95% CI=[-97.848750, -51.041081], covered=True
# [attempt=5] dml_all: SUCCESS pe=0.084331 ape=0.084331
#
# === Bootstrap attempt 6 === linear_no:6/100 | linear_user:6/100 | linear_product:5/100 | linear_all:4/100 | dml_no:6/100 | dml_user:0/100 | dml_product:3/100 | dml_all:4/100
# [attempt=6] Early stopping at epoch 799 (best epoch 788, best val 1.2301)
# [attempt=6] est=-38.994648, SE=0.000000, 95% CI=[-38.994649, -38.994647], covered=False
# [attempt=6] linear_no: SUCCESS pe=-0.432022 ape=0.432022
# [attempt=6] est=-44.648834, SE=1.925277, 95% CI=[-48.422307, -40.875361], covered=False
# [attempt=6] linear_user: SUCCESS pe=-0.349665 ape=0.349665
# [attempt=6] est=-31.801418, SE=0.000000, 95% CI=[-31.801419, -31.801418], covered=False
# [attempt=6] linear_product: SUCCESS pe=-0.536795 ape=0.536795
# [attempt=6] Early stopping at epoch 195 (best epoch 184, best val 1.0496)
# [attempt=6] est=-45.537735, SE=1.706909, 95% CI=[-48.883216, -42.192254], covered=False
# [attempt=6] linear_all: SUCCESS pe=-0.336718 ape=0.336718
# [attempt=6] DEBUG large pe_dedl=-0.432
# [attempt=6] DEDL est=-38.994637, SE=0.000000, 95% CI=[-38.994637, -38.994637], covered=False
# [attempt=6] dml_no: SUCCESS pe=-0.432022 ape=0.432022
# [attempt=6] DEDL est=-69.527130, SE=8.929798, 95% CI=[-87.029215, -52.025045], covered=True
# [attempt=6] dml_user: SUCCESS pe=0.012700 ape=0.012700
# [attempt=6] Mark UNSTABLE: best_eps=10
# [attempt=6] dml_product: EXCEPTION -> skipped | ValueError('not enough values to unpack (expected 5, got 3)')
# H shape: (133,) final_result shape: (133, 1) n_users: 133
# [attempt=6] DEDL est=-74.467491, SE=10.803782, 95% CI=[-95.642517, -53.292465], covered=True
# [attempt=6] dml_all: SUCCESS pe=0.084659 ape=0.084659
#
# === Bootstrap attempt 7 === linear_no:7/100 | linear_user:7/100 | linear_product:6/100 | linear_all:5/100 | dml_no:7/100 | dml_user:1/100 | dml_product:3/100 | dml_all:5/100
# [attempt=7] est=-56.933876, SE=0.000000, 95% CI=[-56.933876, -56.933876], covered=False
# [attempt=7] linear_no: SUCCESS pe=-0.170727 ape=0.170727
# [attempt=7] Early stopping at epoch 33 (best epoch 22, best val 1.1103)
# [attempt=7] est=-68.837486, SE=4.778279, 95% CI=[-78.202743, -59.472230], covered=True
# [attempt=7] linear_user: SUCCESS pe=0.002655 ape=0.002655
# [attempt=7] Early stopping at epoch 37 (best epoch 26, best val 1.8636)
# [attempt=7] est=-58.321827, SE=0.000000, 95% CI=[-58.321827, -58.321827], covered=False
# [attempt=7] linear_product: SUCCESS pe=-0.150511 ape=0.150511
# [attempt=7] Early stopping at epoch 44 (best epoch 33, best val 2.0526)
# [attempt=7] Mark UNSTABLE: near_random, best_val=2.0526, lnK=1.9459
# [attempt=7] linear_all: EXCEPTION -> skipped | ValueError('not enough values to unpack (expected 5, got 3)')
# [attempt=7] DEBUG large pe_dedl=-0.171
# [attempt=7] DEDL est=-56.933865, SE=0.000000, 95% CI=[-56.933865, -56.933864], covered=False
# [attempt=7] dml_no: SUCCESS pe=-0.170727 ape=0.170727
# [attempt=7] DEDL est=-69.043259, SE=2.681356, 95% CI=[-74.298620, -63.787897], covered=True
# [attempt=7] dml_user: SUCCESS pe=0.005653 ape=0.005653
# [attempt=7] DEDL est=-67.869934, SE=2.540059, 95% CI=[-72.848358, -62.891510], covered=True
# [attempt=7] dml_product: SUCCESS pe=-0.011438 ape=0.011438
# H shape: (133,) final_result shape: (133, 1) n_users: 133
# [attempt=7] DEDL est=-68.120560, SE=5.369523, 95% CI=[-78.644632, -57.596487], covered=True
# [attempt=7] dml_all: SUCCESS pe=-0.007787 ape=0.007787
#
# === Bootstrap attempt 8 === linear_no:8/100 | linear_user:8/100 | linear_product:7/100 | linear_all:5/100 | dml_no:8/100 | dml_user:2/100 | dml_product:4/100 | dml_all:6/100
# [attempt=8] Early stopping at epoch 762 (best epoch 751, best val 1.6275)
# [attempt=8] est=-58.339516, SE=0.000000, 95% CI=[-58.339516, -58.339515], covered=False
# [attempt=8] linear_no: SUCCESS pe=-0.150253 ape=0.150253
# [attempt=8] Early stopping at epoch 53 (best epoch 42, best val 1.6088)
# [attempt=8] est=-64.079414, SE=1.853925, 95% CI=[-67.713042, -60.445787], covered=False
# [attempt=8] linear_user: SUCCESS pe=-0.066648 ape=0.066648
# [attempt=8] Early stopping at epoch 868 (best epoch 857, best val 1.5651)
# [attempt=8] est=-47.581982, SE=0.000000, 95% CI=[-47.581982, -47.581982], covered=False
# [attempt=8] linear_product: SUCCESS pe=-0.306943 ape=0.306943
# [attempt=8] Early stopping at epoch 773 (best epoch 762, best val 1.5102)
# [attempt=8] est=-56.174805, SE=1.571283, 95% CI=[-59.254462, -53.095147], covered=False
# [attempt=8] linear_all: SUCCESS pe=-0.181783 ape=0.181783
# [attempt=8] DEBUG large pe_dedl=-0.151
# [attempt=8] DEDL est=-58.310520, SE=0.000000, 95% CI=[-58.310520, -58.310520], covered=False
# [attempt=8] dml_no: SUCCESS pe=-0.150676 ape=0.150676
# [attempt=8] DEDL est=-66.614349, SE=2.278370, 95% CI=[-71.079874, -62.148825], covered=True
# [attempt=8] dml_user: SUCCESS pe=-0.029726 ape=0.029726
# [attempt=8] dml_product: EXCEPTION -> skipped | ValueError('not enough values to unpack (expected 5, got 3)')
# [attempt=8] Mark UNSTABLE: best_eps=10
# [attempt=8] dml_all: EXCEPTION -> skipped | ValueError('not enough values to unpack (expected 5, got 3)')
#
# === Bootstrap attempt 9 === linear_no:9/100 | linear_user:9/100 | linear_product:8/100 | linear_all:6/100 | dml_no:9/100 | dml_user:3/100 | dml_product:4/100 | dml_all:6/100
# [attempt=9] Early stopping at epoch 330 (best epoch 319, best val 1.1609)
# [attempt=9] est=-45.409405, SE=0.000000, 95% CI=[-45.409406, -45.409404], covered=False
# [attempt=9] linear_no: SUCCESS pe=-0.338587 ape=0.338587
# [attempt=9] Early stopping at epoch 329 (best epoch 318, best val 1.1576)
# [attempt=9] est=-72.173409, SE=1.632423, 95% CI=[-75.372899, -68.973918], covered=False
# [attempt=9] linear_user: SUCCESS pe=0.051245 ape=0.051245
# [attempt=9] Early stopping at epoch 136 (best epoch 125, best val 1.1053)
# [attempt=9] est=-34.350784, SE=0.000000, 95% CI=[-34.350784, -34.350784], covered=False
# [attempt=9] linear_product: SUCCESS pe=-0.499662 ape=0.499662
# [attempt=9] Early stopping at epoch 61 (best epoch 50, best val 1.2142)
# [attempt=9] est=-73.072006, SE=4.093835, 95% CI=[-81.095777, -65.048235], covered=True
# [attempt=9] linear_all: SUCCESS pe=0.064333 ape=0.064333
# [attempt=9] DEBUG large pe_dedl=-0.339
# [attempt=9] DEDL est=-45.409405, SE=0.000001, 95% CI=[-45.409406, -45.409403], covered=False
# [attempt=9] dml_no: SUCCESS pe=-0.338587 ape=0.338587
# [attempt=9] Mark UNSTABLE: best_eps=10
# [attempt=9] dml_user: EXCEPTION -> skipped | ValueError('not enough values to unpack (expected 5, got 3)')
# [attempt=9] DEDL est=-72.740746, SE=10.426661, 95% CI=[-93.176630, -52.304862], covered=True
# [attempt=9] dml_product: SUCCESS pe=0.059508 ape=0.059508
# H shape: (133,) final_result shape: (133, 1) n_users: 133
# [attempt=9] DEDL est=-69.189125, SE=8.539522, 95% CI=[-85.926283, -52.451967], covered=True
# [attempt=9] dml_all: SUCCESS pe=0.007777 ape=0.007777
#
# === Bootstrap attempt 10 === linear_no:10/100 | linear_user:10/100 | linear_product:9/100 | linear_all:7/100 | dml_no:10/100 | dml_user:3/100 | dml_product:5/100 | dml_all:7/100
# [attempt=10] est=-77.411484, SE=0.000002, 95% CI=[-77.411487, -77.411481], covered=False
# [attempt=10] linear_no: SUCCESS pe=0.127540 ape=0.127540
# [attempt=10] Early stopping at epoch 11 (best epoch 0, best val 1.6866)
# [attempt=10] Skipping — no meaningful training (Δtrain=0.0841, Δval=-0.0522).
# [attempt=10] linear_user: EXCEPTION -> skipped | ValueError('not enough values to unpack (expected 5, got 3)')
# [attempt=10] Early stopping at epoch 21 (best epoch 10, best val 1.2689)
# [attempt=10] est=-50.593151, SE=0.000001, 95% CI=[-50.593153, -50.593150], covered=False
# [attempt=10] linear_product: SUCCESS pe=-0.263083 ape=0.263083
# [attempt=10] Early stopping at epoch 276 (best epoch 265, best val 1.2218)
# [attempt=10] est=-80.630165, SE=3.018906, 95% CI=[-86.547114, -74.713216], covered=False
# [attempt=10] linear_all: SUCCESS pe=0.174422 ape=0.174422
# [attempt=10] DEBUG large pe_dedl=0.128
# [attempt=10] DEDL est=-77.411484, SE=0.000002, 95% CI=[-77.411487, -77.411481], covered=False
# [attempt=10] dml_no: SUCCESS pe=0.127540 ape=0.127540
# [attempt=10] DEDL est=-68.827003, SE=2.434259, 95% CI=[-73.598065, -64.055942], covered=True
# [attempt=10] dml_user: SUCCESS pe=0.002503 ape=0.002503
# [attempt=10] Mark UNSTABLE: best_eps=10
# [attempt=10] dml_product: EXCEPTION -> skipped | ValueError('not enough values to unpack (expected 5, got 3)')
# H shape: (133,) final_result shape: (133, 1) n_users: 133
# [attempt=10] DEDL est=-67.076546, SE=2.965172, 95% CI=[-72.888177, -61.264915], covered=True
# [attempt=10] dml_all: SUCCESS pe=-0.022994 ape=0.022994
#
# === Bootstrap attempt 11 === linear_no:11/100 | linear_user:10/100 | linear_product:10/100 | linear_all:8/100 | dml_no:11/100 | dml_user:4/100 | dml_product:5/100 | dml_all:8/100
# [attempt=11] Early stopping at epoch 746 (best epoch 735, best val 1.4326)
# [attempt=11] est=-54.640385, SE=0.000000, 95% CI=[-54.640385, -54.640385], covered=False
# [attempt=11] linear_no: SUCCESS pe=-0.204133 ape=0.204133
# [attempt=11] est=-58.826366, SE=1.274360, 95% CI=[-61.324067, -56.328666], covered=False
# [attempt=11] linear_user: SUCCESS pe=-0.143162 ape=0.143162
# [attempt=11] Early stopping at epoch 93 (best epoch 82, best val 1.5609)
# [attempt=11] est=-50.650585, SE=0.000001, 95% CI=[-50.650587, -50.650583], covered=False
# [attempt=11] linear_product: SUCCESS pe=-0.262247 ape=0.262247
# [attempt=11] Early stopping at epoch 144 (best epoch 133, best val 1.4938)
# [attempt=11] est=-72.111198, SE=3.284329, 95% CI=[-78.548366, -65.674031], covered=True
# [attempt=11] linear_all: SUCCESS pe=0.050339 ape=0.050339
# [attempt=11] DEBUG large pe_dedl=-0.204
# [attempt=11] DEDL est=-54.640385, SE=0.000000, 95% CI=[-54.640385, -54.640384], covered=False
# [attempt=11] dml_no: SUCCESS pe=-0.204133 ape=0.204133
# [attempt=11] DEDL est=-70.060074, SE=4.355704, 95% CI=[-78.597099, -61.523049], covered=True
# [attempt=11] dml_user: SUCCESS pe=0.020463 ape=0.020463
# [attempt=11] DEDL est=-73.399437, SE=8.368000, 95% CI=[-89.800418, -56.998456], covered=True
# [attempt=11] dml_product: SUCCESS pe=0.069103 ape=0.069103
# H shape: (133,) final_result shape: (133, 1) n_users: 133
# [attempt=11] DEDL est=-62.940903, SE=8.803788, 95% CI=[-80.196013, -45.685792], covered=True
# [attempt=11] dml_all: SUCCESS pe=-0.083232 ape=0.083232
#
# === Bootstrap attempt 12 === linear_no:12/100 | linear_user:11/100 | linear_product:11/100 | linear_all:9/100 | dml_no:12/100 | dml_user:5/100 | dml_product:6/100 | dml_all:9/100
# [attempt=12] est=-74.336967, SE=0.000001, 95% CI=[-74.336969, -74.336966], covered=False
# [attempt=12] linear_no: SUCCESS pe=0.082758 ape=0.082758
# [attempt=12] est=-78.371323, SE=2.033716, 95% CI=[-82.357333, -74.385312], covered=False
# [attempt=12] linear_user: SUCCESS pe=0.141521 ape=0.141521
# [attempt=12] Early stopping at epoch 852 (best epoch 841, best val 1.1163)
# [attempt=12] est=-66.149918, SE=0.000001, 95% CI=[-66.149919, -66.149916], covered=False
# [attempt=12] linear_product: SUCCESS pe=-0.036490 ape=0.036490
# [attempt=12] Early stopping at epoch 787 (best epoch 776, best val 1.0489)
# [attempt=12] est=-75.262955, SE=2.795569, 95% CI=[-80.742171, -69.783739], covered=False
# [attempt=12] linear_all: SUCCESS pe=0.096246 ape=0.096246
# [attempt=12] DEDL est=-74.336967, SE=0.000000, 95% CI=[-74.336968, -74.336967], covered=False
# [attempt=12] dml_no: SUCCESS pe=0.082758 ape=0.082758
# [attempt=12] Mark UNSTABLE: best_eps=10
# [attempt=12] dml_user: EXCEPTION -> skipped | ValueError('not enough values to unpack (expected 5, got 3)')
# [attempt=12] Mark UNSTABLE: best_eps=10
# [attempt=12] dml_product: EXCEPTION -> skipped | ValueError('not enough values to unpack (expected 5, got 3)')
# [attempt=12] Mark UNSTABLE: best_eps=10
# [attempt=12] dml_all: EXCEPTION -> skipped | ValueError('not enough values to unpack (expected 5, got 3)')
#
# === Bootstrap attempt 13 === linear_no:13/100 | linear_user:12/100 | linear_product:12/100 | linear_all:10/100 | dml_no:13/100 | dml_user:5/100 | dml_product:6/100 | dml_all:9/100
# [attempt=13] Early stopping at epoch 593 (best epoch 582, best val 1.1132)
# [attempt=13] est=-71.508827, SE=0.000001, 95% CI=[-71.508829, -71.508826], covered=False
# [attempt=13] linear_no: SUCCESS pe=0.041565 ape=0.041565
# [attempt=13] Early stopping at epoch 204 (best epoch 193, best val 1.1276)
# [attempt=13] est=-84.082550, SE=2.182508, 95% CI=[-88.360187, -79.804913], covered=False
# [attempt=13] linear_user: SUCCESS pe=0.224708 ape=0.224708
# [attempt=13] Early stopping at epoch 250 (best epoch 239, best val 1.1330)
# [attempt=13] est=-45.761841, SE=0.000000, 95% CI=[-45.761841, -45.761841], covered=False
# [attempt=13] linear_product: SUCCESS pe=-0.333454 ape=0.333454
# [attempt=13] Early stopping at epoch 79 (best epoch 68, best val 1.1442)
# [attempt=13] est=-32.923435, SE=0.868241, 95% CI=[-34.625157, -31.221714], covered=False
# [attempt=13] linear_all: SUCCESS pe=-0.520452 ape=0.520452
# [attempt=13] DEDL est=-71.508827, SE=0.000000, 95% CI=[-71.508828, -71.508826], covered=False
# [attempt=13] dml_no: SUCCESS pe=0.041565 ape=0.041565
# [attempt=13] Mark UNSTABLE: best_eps=10
# [attempt=13] dml_user: EXCEPTION -> skipped | ValueError('not enough values to unpack (expected 5, got 3)')
# [attempt=13] Mark UNSTABLE: best_eps=10
# [attempt=13] dml_product: EXCEPTION -> skipped | ValueError('not enough values to unpack (expected 5, got 3)')
# H shape: (133,) final_result shape: (133, 1) n_users: 133
# [attempt=13] DEDL est=-64.579811, SE=8.418109, 95% CI=[-81.079004, -48.080618], covered=True
# [attempt=13] dml_all: SUCCESS pe=-0.059360 ape=0.059360
#
# === Bootstrap attempt 14 === linear_no:14/100 | linear_user:13/100 | linear_product:13/100 | linear_all:11/100 | dml_no:14/100 | dml_user:5/100 | dml_product:6/100 | dml_all:10/100
# [attempt=14] Early stopping at epoch 621 (best epoch 610, best val 1.1131)
# [attempt=14] est=-71.458092, SE=0.000000, 95% CI=[-71.458092, -71.458092], covered=False
# [attempt=14] linear_no: SUCCESS pe=0.040826 ape=0.040826
# [attempt=14] est=-84.257324, SE=2.189139, 95% CI=[-88.547959, -79.966690], covered=False
# [attempt=14] linear_user: SUCCESS pe=0.227254 ape=0.227254
# [attempt=14] Early stopping at epoch 174 (best epoch 163, best val 1.0887)
# [attempt=14] est=-38.008583, SE=0.000000, 95% CI=[-38.008583, -38.008583], covered=False
# [attempt=14] linear_product: SUCCESS pe=-0.446384 ape=0.446384
# [attempt=14] est=-74.892632, SE=1.104387, 95% CI=[-77.057191, -72.728072], covered=False
# [attempt=14] linear_all: SUCCESS pe=0.090852 ape=0.090852
# [attempt=14] DEDL est=-71.458084, SE=0.000000, 95% CI=[-71.458084, -71.458084], covered=False
# [attempt=14] dml_no: SUCCESS pe=0.040826 ape=0.040826
# [attempt=14] DEDL est=-73.573395, SE=10.331688, 95% CI=[-93.823134, -53.323656], covered=True
# [attempt=14] dml_user: SUCCESS pe=0.071636 ape=0.071636
# [attempt=14] DEBUG large pe_dedl=0.191
# [attempt=14] DEDL est=-81.768394, SE=13.962790, 95% CI=[-109.134963, -54.401826], covered=True
# [attempt=14] dml_product: SUCCESS pe=0.191001 ape=0.191001
# [attempt=14] Mark UNSTABLE: best_eps=10
# [attempt=14] dml_all: EXCEPTION -> skipped | ValueError('not enough values to unpack (expected 5, got 3)')
#
# === Bootstrap attempt 15 === linear_no:15/100 | linear_user:14/100 | linear_product:14/100 | linear_all:12/100 | dml_no:15/100 | dml_user:6/100 | dml_product:7/100 | dml_all:10/100
# [attempt=15] Early stopping at epoch 466 (best epoch 455, best val 1.2325)
# [attempt=15] est=-46.657597, SE=0.000000, 95% CI=[-46.657597, -46.657597], covered=False
# [attempt=15] linear_no: SUCCESS pe=-0.320407 ape=0.320407
# [attempt=15] Early stopping at epoch 590 (best epoch 579, best val 1.1832)
# [attempt=15] est=-60.717976, SE=1.914406, 95% CI=[-64.470143, -56.965809], covered=False
# [attempt=15] linear_user: SUCCESS pe=-0.115610 ape=0.115610
# [attempt=15] est=-46.025780, SE=0.000000, 95% CI=[-46.025780, -46.025779], covered=False
# [attempt=15] linear_product: SUCCESS pe=-0.329610 ape=0.329610
# [attempt=15] est=-42.372215, SE=0.771650, 95% CI=[-43.884622, -40.859809], covered=False
# [attempt=15] linear_all: SUCCESS pe=-0.382826 ape=0.382826
# [attempt=15] DEBUG large pe_dedl=-0.320
# [attempt=15] DEDL est=-46.657612, SE=0.000000, 95% CI=[-46.657612, -46.657612], covered=False
# [attempt=15] dml_no: SUCCESS pe=-0.320407 ape=0.320407
# [attempt=15] DEDL est=-68.580696, SE=12.860403, 95% CI=[-93.786627, -43.374766], covered=True
# [attempt=15] dml_user: SUCCESS pe=-0.001085 ape=0.001085
# [attempt=15] DEBUG large pe_dedl=-0.433
# [attempt=15] DEDL est=-38.910755, SE=9.190558, 95% CI=[-56.923921, -20.897589], covered=False
# [attempt=15] dml_product: SUCCESS pe=-0.433244 ape=0.433244
# H shape: (133,) final_result shape: (133, 1) n_users: 133
# [attempt=15] DEDL est=-68.416641, SE=7.449879, 95% CI=[-83.018137, -53.815145], covered=True
# [attempt=15] dml_all: SUCCESS pe=-0.003474 ape=0.003474
#
# === Bootstrap attempt 16 === linear_no:16/100 | linear_user:15/100 | linear_product:15/100 | linear_all:13/100 | dml_no:16/100 | dml_user:7/100 | dml_product:8/100 | dml_all:11/100
# [attempt=16] Early stopping at epoch 602 (best epoch 591, best val 1.2846)
# [attempt=16] est=-70.555298, SE=0.000000, 95% CI=[-70.555299, -70.555297], covered=False
# [attempt=16] linear_no: SUCCESS pe=0.027676 ape=0.027676
# [attempt=16] Early stopping at epoch 235 (best epoch 224, best val 1.3194)
# [attempt=16] est=-66.119972, SE=2.496411, 95% CI=[-71.012848, -61.227097], covered=True
# [attempt=16] linear_user: SUCCESS pe=-0.036927 ape=0.036927
# [attempt=16] est=-71.763680, SE=0.000000, 95% CI=[-71.763680, -71.763679], covered=False
# [attempt=16] linear_product: SUCCESS pe=0.045277 ape=0.045277
# [attempt=16] Early stopping at epoch 78 (best epoch 67, best val 1.1431)
# [attempt=16] est=-62.525318, SE=5.443968, 95% CI=[-73.195302, -51.855335], covered=True
# [attempt=16] linear_all: SUCCESS pe=-0.089285 ape=0.089285
# [attempt=16] DEDL est=-70.555298, SE=0.000001, 95% CI=[-70.555299, -70.555296], covered=False
# [attempt=16] dml_no: SUCCESS pe=0.027676 ape=0.027676
# [attempt=16] DEDL est=-71.046097, SE=9.179978, 95% CI=[-89.038526, -53.053667], covered=True
# [attempt=16] dml_user: SUCCESS pe=0.034825 ape=0.034825
# [attempt=16] dml_product: EXCEPTION -> skipped | ValueError('not enough values to unpack (expected 5, got 3)')
# H shape: (133,) final_result shape: (133, 1) n_users: 133
# [attempt=16] DEDL est=-68.039948, SE=1.728644, 95% CI=[-71.428027, -64.651868], covered=True
# [attempt=16] dml_all: SUCCESS pe=-0.008961 ape=0.008961
#
# === Bootstrap attempt 17 === linear_no:17/100 | linear_user:16/100 | linear_product:16/100 | linear_all:14/100 | dml_no:17/100 | dml_user:8/100 | dml_product:8/100 | dml_all:12/100
# [attempt=17] est=-91.573624, SE=0.000001, 95% CI=[-91.573625, -91.573622], covered=False
# [attempt=17] linear_no: SUCCESS pe=0.333820 ape=0.333820
# [attempt=17] est=-96.421577, SE=2.163913, 95% CI=[-100.662769, -92.180386], covered=False
# [attempt=17] linear_user: SUCCESS pe=0.404433 ape=0.404433
# [attempt=17] est=-80.649361, SE=0.000000, 95% CI=[-80.649361, -80.649361], covered=False
# [attempt=17] linear_product: SUCCESS pe=0.174702 ape=0.174702
# [attempt=17] Early stopping at epoch 377 (best epoch 366, best val 1.0502)
# [attempt=17] est=-70.318230, SE=2.286315, 95% CI=[-74.799326, -65.837134], covered=True
# [attempt=17] linear_all: SUCCESS pe=0.024223 ape=0.024223
# [attempt=17] DEBUG large pe_dedl=0.334
# [attempt=17] DEDL est=-91.573624, SE=0.000001, 95% CI=[-91.573625, -91.573622], covered=False
# [attempt=17] dml_no: SUCCESS pe=0.333820 ape=0.333820
# [attempt=17] Mark UNSTABLE: best_eps=10
# [attempt=17] dml_user: EXCEPTION -> skipped | ValueError('not enough values to unpack (expected 5, got 3)')
# [attempt=17] DEDL est=-69.350700, SE=5.303646, 95% CI=[-79.745657, -58.955744], covered=True
# [attempt=17] dml_product: SUCCESS pe=0.010131 ape=0.010131
# H shape: (133,) final_result shape: (133, 1) n_users: 133
# [attempt=17] DEDL est=-68.342484, SE=3.011946, 95% CI=[-74.245791, -62.439176], covered=True
# [attempt=17] dml_all: SUCCESS pe=-0.004555 ape=0.004555
#
# === Bootstrap attempt 18 === linear_no:18/100 | linear_user:17/100 | linear_product:17/100 | linear_all:15/100 | dml_no:18/100 | dml_user:8/100 | dml_product:9/100 | dml_all:13/100
# [attempt=18] Early stopping at epoch 533 (best epoch 522, best val 0.9337)
# [attempt=18] est=-60.924164, SE=0.000000, 95% CI=[-60.924165, -60.924163], covered=False
# [attempt=18] linear_no: SUCCESS pe=-0.112606 ape=0.112606
# [attempt=18] Early stopping at epoch 58 (best epoch 47, best val 0.9900)
# [attempt=18] est=-62.714886, SE=3.832677, 95% CI=[-70.226796, -55.202975], covered=True
# [attempt=18] linear_user: SUCCESS pe=-0.086524 ape=0.086524
# [attempt=18] Early stopping at epoch 19 (best epoch 8, best val 0.8023)
# [attempt=18] est=-71.215675, SE=0.000000, 95% CI=[-71.215676, -71.215675], covered=False
# [attempt=18] linear_product: SUCCESS pe=0.037295 ape=0.037295
# [attempt=18] Early stopping at epoch 43 (best epoch 32, best val 0.9387)
# [attempt=18] est=-43.459415, SE=3.246608, 95% CI=[-49.822651, -37.096180], covered=False
# [attempt=18] linear_all: SUCCESS pe=-0.366990 ape=0.366990
# [attempt=18] DEBUG large pe_dedl=-0.112
# [attempt=18] DEDL est=-60.981995, SE=0.000001, 95% CI=[-60.981997, -60.981992], covered=False
# [attempt=18] dml_no: SUCCESS pe=-0.111764 ape=0.111764
# [attempt=18] DEDL est=-74.329659, SE=11.001770, 95% CI=[-95.892735, -52.766582], covered=True
# [attempt=18] dml_user: SUCCESS pe=0.082652 ape=0.082652
# [attempt=18] DEDL est=-70.733223, SE=8.112882, 95% CI=[-86.634181, -54.832265], covered=True
# [attempt=18] dml_product: SUCCESS pe=0.030268 ape=0.030268
# H shape: (133,) final_result shape: (133, 1) n_users: 133
# [attempt=18] DEDL est=-70.905853, SE=8.737181, 95% CI=[-88.030415, -53.781291], covered=True
# [attempt=18] dml_all: SUCCESS pe=0.032782 ape=0.032782
#
# === Bootstrap attempt 19 === linear_no:19/100 | linear_user:18/100 | linear_product:18/100 | linear_all:16/100 | dml_no:19/100 | dml_user:9/100 | dml_product:10/100 | dml_all:14/100
# [attempt=19] Early stopping at epoch 247 (best epoch 236, best val 1.4388)
# [attempt=19] est=-30.773518, SE=0.000000, 95% CI=[-30.773518, -30.773517], covered=False
# [attempt=19] linear_no: SUCCESS pe=-0.551767 ape=0.551767
# [attempt=19] Early stopping at epoch 11 (best epoch 0, best val 1.6375)
# [attempt=19] Skipping — no meaningful training (Δtrain=0.00371, Δval=-0.0288).
# [attempt=19] linear_user: EXCEPTION -> skipped | ValueError('not enough values to unpack (expected 5, got 3)')
# [attempt=19] Early stopping at epoch 25 (best epoch 14, best val 1.4860)
# [attempt=19] Skipping — no meaningful training (Δtrain=0.0128, Δval=0.000126).
# [attempt=19] linear_product: EXCEPTION -> skipped | ValueError('not enough values to unpack (expected 5, got 3)')
# [attempt=19] Early stopping at epoch 175 (best epoch 164, best val 1.4745)
# [attempt=19] est=-63.801659, SE=2.826866, 95% CI=[-69.342216, -58.261101], covered=True
# [attempt=19] linear_all: SUCCESS pe=-0.070694 ape=0.070694
# [attempt=19] DEBUG large pe_dedl=-0.552
# [attempt=19] DEDL est=-30.773518, SE=0.000001, 95% CI=[-30.773519, -30.773516], covered=False
# [attempt=19] dml_no: SUCCESS pe=-0.551767 ape=0.551767
# [attempt=19] DEDL est=-66.103043, SE=6.291052, 95% CI=[-78.433280, -53.772806], covered=True
# [attempt=19] dml_user: SUCCESS pe=-0.037173 ape=0.037173
# [attempt=19] DEDL est=-69.361778, SE=1.145354, 95% CI=[-71.606631, -67.116926], covered=True
# [attempt=19] dml_product: SUCCESS pe=0.010292 ape=0.010292
# H shape: (133,) final_result shape: (133, 1) n_users: 133
# [attempt=19] DEDL est=-67.932114, SE=3.619130, 95% CI=[-75.025480, -60.838747], covered=True
# [attempt=19] dml_all: SUCCESS pe=-0.010532 ape=0.010532
#
# === Bootstrap attempt 20 === linear_no:20/100 | linear_user:18/100 | linear_product:18/100 | linear_all:17/100 | dml_no:20/100 | dml_user:10/100 | dml_product:11/100 | dml_all:15/100
# [attempt=20] Early stopping at epoch 293 (best epoch 282, best val 1.3432)
# [attempt=20] est=-12.448562, SE=0.000000, 95% CI=[-12.448562, -12.448562], covered=False
# [attempt=20] linear_no: SUCCESS pe=-0.818680 ape=0.818680
# [attempt=20] est=-21.202606, SE=1.048303, 95% CI=[-23.257243, -19.147969], covered=False
# [attempt=20] linear_user: SUCCESS pe=-0.691173 ape=0.691173
# [attempt=20] Early stopping at epoch 139 (best epoch 128, best val 1.3351)
# [attempt=20] est=-35.691383, SE=0.000000, 95% CI=[-35.691383, -35.691383], covered=False
# [attempt=20] linear_product: SUCCESS pe=-0.480136 ape=0.480136
# [attempt=20] Early stopping at epoch 781 (best epoch 770, best val 1.4092)
# [attempt=20] est=-21.279799, SE=0.671808, 95% CI=[-22.596518, -19.963079], covered=False
# [attempt=20] linear_all: SUCCESS pe=-0.690048 ape=0.690048
# [attempt=20] DEBUG large pe_dedl=-0.819
# [attempt=20] DEDL est=-12.448562, SE=0.000000, 95% CI=[-12.448562, -12.448562], covered=False
# [attempt=20] dml_no: SUCCESS pe=-0.818680 ape=0.818680
# [attempt=20] Mark UNSTABLE: best_eps=10
# [attempt=20] dml_user: EXCEPTION -> skipped | ValueError('not enough values to unpack (expected 5, got 3)')
# [attempt=20] DEDL est=-63.876255, SE=12.631420, 95% CI=[-88.633387, -39.119123], covered=True
# [attempt=20] dml_product: SUCCESS pe=-0.069608 ape=0.069608
# H shape: (133,) final_result shape: (133, 1) n_users: 133
# [attempt=20] DEBUG large pe_dedl=0.142
# [attempt=20] DEDL est=-78.415787, SE=17.733204, 95% CI=[-113.172233, -43.659341], covered=True
# [attempt=20] dml_all: SUCCESS pe=0.142169 ape=0.142169
#
# === Bootstrap attempt 21 === linear_no:21/100 | linear_user:19/100 | linear_product:19/100 | linear_all:18/100 | dml_no:21/100 | dml_user:10/100 | dml_product:12/100 | dml_all:16/100
# [attempt=21] est=-76.598488, SE=0.000000, 95% CI=[-76.598488, -76.598488], covered=False
# [attempt=21] linear_no: SUCCESS pe=0.115699 ape=0.115699
# [attempt=21] Early stopping at epoch 239 (best epoch 228, best val 1.7089)
# [attempt=21] est=-77.763672, SE=2.657684, 95% CI=[-82.972637, -72.554706], covered=False
# [attempt=21] linear_user: SUCCESS pe=0.132670 ape=0.132670
# [attempt=21] Early stopping at epoch 106 (best epoch 95, best val 1.8019)
# [attempt=21] est=-85.169746, SE=0.000000, 95% CI=[-85.169746, -85.169746], covered=False
# [attempt=21] linear_product: SUCCESS pe=0.240544 ape=0.240544
# [attempt=21] Early stopping at epoch 35 (best epoch 24, best val 1.8715)
# [attempt=21] est=-72.780540, SE=4.641650, 95% CI=[-81.878009, -63.683072], covered=True
# [attempt=21] linear_all: SUCCESS pe=0.060088 ape=0.060088
# [attempt=21] DEBUG large pe_dedl=0.116
# [attempt=21] DEDL est=-76.598488, SE=0.000000, 95% CI=[-76.598488, -76.598488], covered=False
# [attempt=21] dml_no: SUCCESS pe=0.115699 ape=0.115699
# [attempt=21] Mark UNSTABLE: best_eps=10
# [attempt=21] dml_user: EXCEPTION -> skipped | ValueError('not enough values to unpack (expected 5, got 3)')
# [attempt=21] dml_product: EXCEPTION -> skipped | ValueError('not enough values to unpack (expected 5, got 3)')
# H shape: (133,) final_result shape: (133, 1) n_users: 133
# [attempt=21] DEDL est=-71.132507, SE=9.178258, 95% CI=[-89.121565, -53.143450], covered=True
# [attempt=21] dml_all: SUCCESS pe=0.036084 ape=0.036084
#
# === Bootstrap attempt 22 === linear_no:22/100 | linear_user:20/100 | linear_product:20/100 | linear_all:19/100 | dml_no:22/100 | dml_user:10/100 | dml_product:12/100 | dml_all:17/100
# [attempt=22] Early stopping at epoch 493 (best epoch 482, best val 1.5605)
# [attempt=22] est=-41.946068, SE=0.000000, 95% CI=[-41.946068, -41.946068], covered=False
# [attempt=22] linear_no: SUCCESS pe=-0.389033 ape=0.389033
# [attempt=22] Early stopping at epoch 595 (best epoch 584, best val 1.4937)
# [attempt=22] est=-56.629539, SE=3.074000, 95% CI=[-62.654469, -50.604610], covered=False
# [attempt=22] linear_user: SUCCESS pe=-0.175160 ape=0.175160
# [attempt=22] Early stopping at epoch 539 (best epoch 528, best val 1.6061)
# [attempt=22] est=-42.871048, SE=0.000000, 95% CI=[-42.871048, -42.871048], covered=False
# [attempt=22] linear_product: SUCCESS pe=-0.375560 ape=0.375560
# [attempt=22] Early stopping at epoch 34 (best epoch 23, best val 1.6211)
# [attempt=22] est=-64.526398, SE=2.461741, 95% CI=[-69.351323, -59.701473], covered=True
# [attempt=22] linear_all: SUCCESS pe=-0.060138 ape=0.060138
# [attempt=22] DEBUG large pe_dedl=-0.389
# [attempt=22] DEDL est=-41.946064, SE=0.000000, 95% CI=[-41.946064, -41.946064], covered=False
# [attempt=22] dml_no: SUCCESS pe=-0.389033 ape=0.389033
# [attempt=22] DEDL est=-68.952286, SE=3.059958, 95% CI=[-74.949694, -62.954878], covered=True
# [attempt=22] dml_user: SUCCESS pe=0.004328 ape=0.004328
# [attempt=22] DEDL est=-69.210075, SE=5.416774, 95% CI=[-79.826759, -58.593391], covered=True
# [attempt=22] dml_product: SUCCESS pe=0.008082 ape=0.008082
# H shape: (133,) final_result shape: (133, 1) n_users: 133
# [attempt=22] DEDL est=-68.205185, SE=7.187819, 95% CI=[-82.293052, -54.117317], covered=True
# [attempt=22] dml_all: SUCCESS pe=-0.006554 ape=0.006554
#
# === Bootstrap attempt 23 === linear_no:23/100 | linear_user:21/100 | linear_product:21/100 | linear_all:20/100 | dml_no:23/100 | dml_user:11/100 | dml_product:13/100 | dml_all:18/100
# [attempt=23] est=-73.876686, SE=0.000002, 95% CI=[-73.876689, -73.876683], covered=False
# [attempt=23] linear_no: SUCCESS pe=0.076054 ape=0.076054
# [attempt=23] Early stopping at epoch 48 (best epoch 37, best val 1.8081)
# [attempt=23] est=-102.650574, SE=4.124784, 95% CI=[-110.735002, -94.566145], covered=False
# [attempt=23] linear_user: SUCCESS pe=0.495161 ape=0.495161
# [attempt=23] Early stopping at epoch 60 (best epoch 49, best val 1.4075)
# [attempt=23] est=-66.265862, SE=0.000000, 95% CI=[-66.265862, -66.265861], covered=False
# [attempt=23] linear_product: SUCCESS pe=-0.034802 ape=0.034802
# [attempt=23] Early stopping at epoch 67 (best epoch 56, best val 2.8462)
# [attempt=23] Mark UNSTABLE: near_random, best_val=2.8462, lnK=1.9459
# [attempt=23] linear_all: EXCEPTION -> skipped | ValueError('not enough values to unpack (expected 5, got 3)')
# [attempt=23] DEDL est=-73.876717, SE=0.000000, 95% CI=[-73.876717, -73.876717], covered=False
# [attempt=23] dml_no: SUCCESS pe=0.076055 ape=0.076055
# [attempt=23] dml_user: EXCEPTION -> skipped | ValueError('not enough values to unpack (expected 5, got 3)')
# [attempt=23] Mark UNSTABLE: best_eps=10
# [attempt=23] dml_product: EXCEPTION -> skipped | ValueError('not enough values to unpack (expected 5, got 3)')
# H shape: (133,) final_result shape: (133, 1) n_users: 133
# [attempt=23] DEDL est=-65.104233, SE=14.680546, 95% CI=[-93.877578, -36.330887], covered=True
# [attempt=23] dml_all: SUCCESS pe=-0.051721 ape=0.051721
#
# === Bootstrap attempt 24 === linear_no:24/100 | linear_user:22/100 | linear_product:22/100 | linear_all:20/100 | dml_no:24/100 | dml_user:11/100 | dml_product:13/100 | dml_all:19/100
# [attempt=24] Early stopping at epoch 194 (best epoch 183, best val 1.8206)
# [attempt=24] est=-41.738598, SE=0.000000, 95% CI=[-41.738598, -41.738598], covered=False
# [attempt=24] linear_no: SUCCESS pe=-0.392055 ape=0.392055
# [attempt=24] Early stopping at epoch 224 (best epoch 213, best val 1.5349)
# [attempt=24] est=-44.738670, SE=4.203438, 95% CI=[-52.977259, -36.500081], covered=False
# [attempt=24] linear_user: SUCCESS pe=-0.348357 ape=0.348357
# [attempt=24] Early stopping at epoch 12 (best epoch 1, best val 1.7926)
# [attempt=24] Skipping — no meaningful training (Δtrain=0.0548, Δval=-0.0228).
# [attempt=24] linear_product: EXCEPTION -> skipped | ValueError('not enough values to unpack (expected 5, got 3)')
# [attempt=24] Early stopping at epoch 207 (best epoch 196, best val 1.5933)
# [attempt=24] est=-38.156887, SE=1.429998, 95% CI=[-40.959633, -35.354142], covered=False
# [attempt=24] linear_all: SUCCESS pe=-0.444224 ape=0.444224
# [attempt=24] DEBUG large pe_dedl=-0.392
# [attempt=24] DEDL est=-41.738605, SE=0.000000, 95% CI=[-41.738605, -41.738605], covered=False
# [attempt=24] dml_no: SUCCESS pe=-0.392055 ape=0.392055
# [attempt=24] DEDL est=-65.115662, SE=10.433227, 95% CI=[-85.564413, -44.666910], covered=True
# [attempt=24] dml_user: SUCCESS pe=-0.051555 ape=0.051555
# [attempt=24] Mark UNSTABLE: best_eps=10
# [attempt=24] dml_product: EXCEPTION -> skipped | ValueError('not enough values to unpack (expected 5, got 3)')
# [attempt=24] Mark UNSTABLE: best_eps=10
# [attempt=24] dml_all: EXCEPTION -> skipped | ValueError('not enough values to unpack (expected 5, got 3)')
#
# === Bootstrap attempt 25 === linear_no:25/100 | linear_user:23/100 | linear_product:22/100 | linear_all:21/100 | dml_no:25/100 | dml_user:12/100 | dml_product:13/100 | dml_all:19/100
# [attempt=25] est=-75.169586, SE=0.000000, 95% CI=[-75.169586, -75.169586], covered=False
# [attempt=25] linear_no: SUCCESS pe=0.094886 ape=0.094886
# [attempt=25] Early stopping at epoch 47 (best epoch 36, best val 0.8859)
# [attempt=25] est=-48.863037, SE=1.687626, 95% CI=[-52.170723, -45.555351], covered=False
# [attempt=25] linear_user: SUCCESS pe=-0.288283 ape=0.288283
# [attempt=25] Early stopping at epoch 19 (best epoch 8, best val 0.9523)
# [attempt=25] Skipping — no meaningful training (Δtrain=0.0775, Δval=-0.000254).
# [attempt=25] linear_product: EXCEPTION -> skipped | ValueError('not enough values to unpack (expected 5, got 3)')
# [attempt=25] Early stopping at epoch 29 (best epoch 18, best val 1.0988)
# [attempt=25] est=-46.741856, SE=1.642635, 95% CI=[-49.961362, -43.522349], covered=False
# [attempt=25] linear_all: SUCCESS pe=-0.319179 ape=0.319179
# [attempt=25] DEDL est=-75.169579, SE=0.000000, 95% CI=[-75.169579, -75.169579], covered=False
# [attempt=25] dml_no: SUCCESS pe=0.094886 ape=0.094886
# [attempt=25] DEDL est=-67.855331, SE=2.582144, 95% CI=[-72.916242, -62.794420], covered=True
# [attempt=25] dml_user: SUCCESS pe=-0.011650 ape=0.011650
# [attempt=25] DEBUG large pe_dedl=-0.123
# [attempt=25] DEDL est=-60.212837, SE=11.451643, 95% CI=[-82.657648, -37.768026], covered=True
# [attempt=25] dml_product: SUCCESS pe=-0.122967 ape=0.122967
# H shape: (133,) final_result shape: (133, 1) n_users: 133
# [attempt=25] DEDL est=-68.583221, SE=3.287442, 95% CI=[-75.026491, -62.139952], covered=True
# [attempt=25] dml_all: SUCCESS pe=-0.001048 ape=0.001048
#
# === Bootstrap attempt 26 === linear_no:26/100 | linear_user:24/100 | linear_product:22/100 | linear_all:22/100 | dml_no:26/100 | dml_user:13/100 | dml_product:14/100 | dml_all:20/100
# [attempt=26] est=-44.173569, SE=0.000000, 95% CI=[-44.173569, -44.173569], covered=False
# [attempt=26] linear_no: SUCCESS pe=-0.356588 ape=0.356588
# [attempt=26] Early stopping at epoch 567 (best epoch 556, best val 1.1822)
# [attempt=26] est=-39.199879, SE=1.374831, 95% CI=[-41.894499, -36.505258], covered=False
# [attempt=26] linear_user: SUCCESS pe=-0.429032 ape=0.429032
# [attempt=26] est=-42.240280, SE=0.000000, 95% CI=[-42.240281, -42.240279], covered=False
# [attempt=26] linear_product: SUCCESS pe=-0.384747 ape=0.384747
# [attempt=26] est=-36.999214, SE=1.798009, 95% CI=[-40.523247, -33.475182], covered=False
# [attempt=26] linear_all: SUCCESS pe=-0.461086 ape=0.461086
# [attempt=26] DEBUG large pe_dedl=-0.357
# [attempt=26] DEDL est=-44.173565, SE=0.000000, 95% CI=[-44.173565, -44.173565], covered=False
# [attempt=26] dml_no: SUCCESS pe=-0.356588 ape=0.356588
# [attempt=26] DEDL est=-63.031647, SE=4.190350, 95% CI=[-71.244583, -54.818710], covered=True
# [attempt=26] dml_user: SUCCESS pe=-0.081910 ape=0.081910
# [attempt=26] DEDL est=-74.246338, SE=7.852114, 95% CI=[-89.636201, -58.856475], covered=True
# [attempt=26] dml_product: SUCCESS pe=0.081438 ape=0.081438
# [attempt=26] Mark UNSTABLE: best_eps=10
# [attempt=26] dml_all: EXCEPTION -> skipped | ValueError('not enough values to unpack (expected 5, got 3)')
#
# === Bootstrap attempt 27 === linear_no:27/100 | linear_user:25/100 | linear_product:23/100 | linear_all:23/100 | dml_no:27/100 | dml_user:14/100 | dml_product:15/100 | dml_all:20/100
# [attempt=27] est=-86.748642, SE=0.000000, 95% CI=[-86.748642, -86.748642], covered=False
# [attempt=27] linear_no: SUCCESS pe=0.263541 ape=0.263541
# [attempt=27] Early stopping at epoch 333 (best epoch 322, best val 1.1922)
# [attempt=27] est=-88.381104, SE=2.133117, 95% CI=[-92.561937, -84.200270], covered=False
# [attempt=27] linear_user: SUCCESS pe=0.287319 ape=0.287319
# [attempt=27] Early stopping at epoch 570 (best epoch 559, best val 1.2003)
# [attempt=27] est=-66.082085, SE=0.000000, 95% CI=[-66.082085, -66.082084], covered=False
# [attempt=27] linear_product: SUCCESS pe=-0.037479 ape=0.037479
# [attempt=27] Early stopping at epoch 219 (best epoch 208, best val 1.2123)
# [attempt=27] est=-74.978745, SE=2.551520, 95% CI=[-79.979632, -69.977857], covered=False
# [attempt=27] linear_all: SUCCESS pe=0.092106 ape=0.092106
# [attempt=27] DEBUG large pe_dedl=0.264
# [attempt=27] DEDL est=-86.748642, SE=0.000001, 95% CI=[-86.748643, -86.748640], covered=False
# [attempt=27] dml_no: SUCCESS pe=0.263541 ape=0.263541
# [attempt=27] DEDL est=-69.852509, SE=5.613253, 95% CI=[-80.854283, -58.850734], covered=True
# [attempt=27] dml_user: SUCCESS pe=0.017440 ape=0.017440
# [attempt=27] DEDL est=-64.493095, SE=8.660141, 95% CI=[-81.466662, -47.519528], covered=True
# [attempt=27] dml_product: SUCCESS pe=-0.060623 ape=0.060623
# H shape: (133,) final_result shape: (133, 1) n_users: 133
# [attempt=27] DEDL est=-64.447548, SE=8.862151, 95% CI=[-81.817048, -47.078048], covered=True
# [attempt=27] dml_all: SUCCESS pe=-0.061286 ape=0.061286
#
# === Bootstrap attempt 28 === linear_no:28/100 | linear_user:26/100 | linear_product:24/100 | linear_all:24/100 | dml_no:28/100 | dml_user:15/100 | dml_product:16/100 | dml_all:21/100
# [attempt=28] Early stopping at epoch 455 (best epoch 444, best val 1.4316)
# [attempt=28] est=-52.426926, SE=0.000000, 95% CI=[-52.426926, -52.426925], covered=False
# [attempt=28] linear_no: SUCCESS pe=-0.236373 ape=0.236373
# [attempt=28] Early stopping at epoch 115 (best epoch 104, best val 1.5319)
# [attempt=28] est=-42.459068, SE=2.641343, 95% CI=[-47.636006, -37.282130], covered=False
# [attempt=28] linear_user: SUCCESS pe=-0.381561 ape=0.381561
# [attempt=28] Early stopping at epoch 350 (best epoch 339, best val 1.2156)
# [attempt=28] est=-41.390163, SE=0.000000, 95% CI=[-41.390164, -41.390163], covered=False
# [attempt=28] linear_product: SUCCESS pe=-0.397130 ape=0.397130
# [attempt=28] Early stopping at epoch 29 (best epoch 18, best val 2.0260)
# [attempt=28] Mark UNSTABLE: near_random, best_val=2.0260, lnK=1.9459
# [attempt=28] linear_all: EXCEPTION -> skipped | ValueError('not enough values to unpack (expected 5, got 3)')
# [attempt=28] DEBUG large pe_dedl=-0.236
# [attempt=28] DEDL est=-52.426929, SE=0.000000, 95% CI=[-52.426930, -52.426929], covered=False
# ...
# [attempt=172] dml_user: SUCCESS pe=-0.006473 ape=0.006473
# [attempt=172] DEDL est=-64.923706, SE=10.287199, 95% CI=[-85.086249, -44.761163], covered=True
# [attempt=172] dml_product: SUCCESS pe=-0.054351 ape=0.054351
#
# === Bootstrap attempt 173 === linear_no:100/100 | linear_user:100/100 | linear_product:100/100 | linear_all:100/100 | dml_no:100/100 | dml_user:85/100 | dml_product:90/100 | dml_all:100/100
# [attempt=173] dml_user: EXCEPTION -> skipped | ValueError('not enough values to unpack (expected 5, got 3)')
# [attempt=173] DEDL est=-66.286575, SE=4.364858, 95% CI=[-74.841541, -57.731609], covered=True
# [attempt=173] dml_product: SUCCESS pe=-0.034500 ape=0.034500
#
# === Bootstrap attempt 174 === linear_no:100/100 | linear_user:100/100 | linear_product:100/100 | linear_all:100/100 | dml_no:100/100 | dml_user:85/100 | dml_product:91/100 | dml_all:100/100
# [attempt=174] Mark UNSTABLE: best_eps=10
# [attempt=174] dml_user: EXCEPTION -> skipped | ValueError('not enough values to unpack (expected 5, got 3)')
# [attempt=174] Mark UNSTABLE: best_eps=10
# [attempt=174] dml_product: EXCEPTION -> skipped | ValueError('not enough values to unpack (expected 5, got 3)')
#
# === Bootstrap attempt 175 === linear_no:100/100 | linear_user:100/100 | linear_product:100/100 | linear_all:100/100 | dml_no:100/100 | dml_user:85/100 | dml_product:91/100 | dml_all:100/100
# [attempt=175] DEDL est=-71.175781, SE=7.826408, 95% CI=[-86.515262, -55.836300], covered=True
# [attempt=175] dml_user: SUCCESS pe=0.036714 ape=0.036714
# [attempt=175] DEDL est=-65.102058, SE=9.958069, 95% CI=[-84.619518, -45.584599], covered=True
# [attempt=175] dml_product: SUCCESS pe=-0.051753 ape=0.051753
#
# === Bootstrap attempt 176 === linear_no:100/100 | linear_user:100/100 | linear_product:100/100 | linear_all:100/100 | dml_no:100/100 | dml_user:86/100 | dml_product:92/100 | dml_all:100/100
# [attempt=176] DEDL est=-65.545731, SE=5.927406, 95% CI=[-77.163234, -53.928227], covered=True
# [attempt=176] dml_user: SUCCESS pe=-0.045291 ape=0.045291
# [attempt=176] DEDL est=-67.221680, SE=2.812733, 95% CI=[-72.734537, -61.708823], covered=True
# [attempt=176] dml_product: SUCCESS pe=-0.020880 ape=0.020880
#
# === Bootstrap attempt 177 === linear_no:100/100 | linear_user:100/100 | linear_product:100/100 | linear_all:100/100 | dml_no:100/100 | dml_user:87/100 | dml_product:93/100 | dml_all:100/100
# [attempt=177] Mark UNSTABLE: best_eps=10
# [attempt=177] dml_user: EXCEPTION -> skipped | ValueError('not enough values to unpack (expected 5, got 3)')
# [attempt=177] Mark UNSTABLE: best_eps=10
# [attempt=177] dml_product: EXCEPTION -> skipped | ValueError('not enough values to unpack (expected 5, got 3)')
#
# === Bootstrap attempt 178 === linear_no:100/100 | linear_user:100/100 | linear_product:100/100 | linear_all:100/100 | dml_no:100/100 | dml_user:87/100 | dml_product:93/100 | dml_all:100/100
# [attempt=178] Mark UNSTABLE: best_eps=10
# [attempt=178] dml_user: EXCEPTION -> skipped | ValueError('not enough values to unpack (expected 5, got 3)')
# [attempt=178] Mark UNSTABLE: best_eps=10
# [attempt=178] dml_product: EXCEPTION -> skipped | ValueError('not enough values to unpack (expected 5, got 3)')
#
# === Bootstrap attempt 179 === linear_no:100/100 | linear_user:100/100 | linear_product:100/100 | linear_all:100/100 | dml_no:100/100 | dml_user:87/100 | dml_product:93/100 | dml_all:100/100
# [attempt=179] DEBUG large pe_dedl=0.190
# [attempt=179] DEDL est=-81.666946, SE=2.692218, 95% CI=[-86.943598, -76.390295], covered=False
# [attempt=179] dml_user: SUCCESS pe=0.189523 ape=0.189523
# [attempt=179] DEDL est=-70.159439, SE=6.936219, 95% CI=[-83.754180, -56.564698], covered=True
# [attempt=179] dml_product: SUCCESS pe=0.021910 ape=0.021910
#
# === Bootstrap attempt 180 === linear_no:100/100 | linear_user:100/100 | linear_product:100/100 | linear_all:100/100 | dml_no:100/100 | dml_user:88/100 | dml_product:94/100 | dml_all:100/100
# [attempt=180] DEDL est=-73.446487, SE=10.301937, 95% CI=[-93.637916, -53.255059], covered=True
# [attempt=180] dml_user: SUCCESS pe=0.069788 ape=0.069788
# [attempt=180] DEDL est=-71.184258, SE=11.798371, 95% CI=[-94.308644, -48.059871], covered=True
# [attempt=180] dml_product: SUCCESS pe=0.036837 ape=0.036837
#
# === Bootstrap attempt 181 === linear_no:100/100 | linear_user:100/100 | linear_product:100/100 | linear_all:100/100 | dml_no:100/100 | dml_user:89/100 | dml_product:95/100 | dml_all:100/100
# [attempt=181] dml_user: EXCEPTION -> skipped | ValueError('not enough values to unpack (expected 5, got 3)')
# [attempt=181] DEDL est=-69.072456, SE=8.461044, 95% CI=[-85.655801, -52.489112], covered=True
# [attempt=181] dml_product: SUCCESS pe=0.006078 ape=0.006078
#
# === Bootstrap attempt 182 === linear_no:100/100 | linear_user:100/100 | linear_product:100/100 | linear_all:100/100 | dml_no:100/100 | dml_user:89/100 | dml_product:96/100 | dml_all:100/100
# [attempt=182] DEDL est=-68.693741, SE=9.093321, 95% CI=[-86.516325, -50.871157], covered=True
# [attempt=182] dml_user: SUCCESS pe=0.000562 ape=0.000562
# [attempt=182] DEDL est=-72.019218, SE=15.261268, 95% CI=[-101.930758, -42.107679], covered=True
# [attempt=182] dml_product: SUCCESS pe=0.048999 ape=0.048999
#
# === Bootstrap attempt 183 === linear_no:100/100 | linear_user:100/100 | linear_product:100/100 | linear_all:100/100 | dml_no:100/100 | dml_user:90/100 | dml_product:97/100 | dml_all:100/100
# [attempt=183] Mark UNSTABLE: best_eps=10
# [attempt=183] dml_user: EXCEPTION -> skipped | ValueError('not enough values to unpack (expected 5, got 3)')
# [attempt=183] DEDL est=-69.787842, SE=2.608701, 95% CI=[-74.900802, -64.674882], covered=True
# [attempt=183] dml_product: SUCCESS pe=0.016498 ape=0.016498
#
# === Bootstrap attempt 184 === linear_no:100/100 | linear_user:100/100 | linear_product:100/100 | linear_all:100/100 | dml_no:100/100 | dml_user:90/100 | dml_product:98/100 | dml_all:100/100
# [attempt=184] Mark UNSTABLE: best_eps=10
# [attempt=184] dml_user: EXCEPTION -> skipped | ValueError('not enough values to unpack (expected 5, got 3)')
# [attempt=184] Mark UNSTABLE: best_eps=10
# [attempt=184] dml_product: EXCEPTION -> skipped | ValueError('not enough values to unpack (expected 5, got 3)')
#
# === Bootstrap attempt 185 === linear_no:100/100 | linear_user:100/100 | linear_product:100/100 | linear_all:100/100 | dml_no:100/100 | dml_user:90/100 | dml_product:98/100 | dml_all:100/100
# [attempt=185] Mark UNSTABLE: best_eps=10
# [attempt=185] dml_user: EXCEPTION -> skipped | ValueError('not enough values to unpack (expected 5, got 3)')
# [attempt=185] Mark UNSTABLE: best_eps=10
# [attempt=185] dml_product: EXCEPTION -> skipped | ValueError('not enough values to unpack (expected 5, got 3)')
#
# === Bootstrap attempt 186 === linear_no:100/100 | linear_user:100/100 | linear_product:100/100 | linear_all:100/100 | dml_no:100/100 | dml_user:90/100 | dml_product:98/100 | dml_all:100/100
# [attempt=186] dml_user: EXCEPTION -> skipped | ValueError('not enough values to unpack (expected 5, got 3)')
# [attempt=186] dml_product: EXCEPTION -> skipped | ValueError('not enough values to unpack (expected 5, got 3)')
#
# === Bootstrap attempt 187 === linear_no:100/100 | linear_user:100/100 | linear_product:100/100 | linear_all:100/100 | dml_no:100/100 | dml_user:90/100 | dml_product:98/100 | dml_all:100/100
# [attempt=187] DEBUG large pe_dedl=-0.101
# [attempt=187] DEDL est=-61.713547, SE=18.524874, 95% CI=[-98.021637, -25.405456], covered=True
# [attempt=187] dml_user: SUCCESS pe=-0.101109 ape=0.101109
# [attempt=187] DEDL est=-72.281456, SE=11.447226, 95% CI=[-94.717609, -49.845303], covered=True
# [attempt=187] dml_product: SUCCESS pe=0.052819 ape=0.052819
#
# === Bootstrap attempt 188 === linear_no:100/100 | linear_user:100/100 | linear_product:100/100 | linear_all:100/100 | dml_no:100/100 | dml_user:91/100 | dml_product:99/100 | dml_all:100/100
# [attempt=188] Mark UNSTABLE: best_eps=10
# [attempt=188] dml_user: EXCEPTION -> skipped | ValueError('not enough values to unpack (expected 5, got 3)')
# [attempt=188] DEDL est=-63.586086, SE=12.048175, 95% CI=[-87.200079, -39.972094], covered=True
# [attempt=188] dml_product: SUCCESS pe=-0.073834 ape=0.073834
#
# === Bootstrap attempt 189 === linear_no:100/100 | linear_user:100/100 | linear_product:100/100 | linear_all:100/100 | dml_no:100/100 | dml_user:91/100 | dml_product:100/100 | dml_all:100/100
# [attempt=189] Mark UNSTABLE: best_eps=10
# [attempt=189] dml_user: EXCEPTION -> skipped | ValueError('not enough values to unpack (expected 5, got 3)')
#
# === Bootstrap attempt 190 === linear_no:100/100 | linear_user:100/100 | linear_product:100/100 | linear_all:100/100 | dml_no:100/100 | dml_user:91/100 | dml_product:100/100 | dml_all:100/100
# [attempt=190] DEBUG large pe_dedl=-0.157
# [attempt=190] DEDL est=-57.859013, SE=9.138046, 95% CI=[-75.769257, -39.948768], covered=True
# [attempt=190] dml_user: SUCCESS pe=-0.157252 ape=0.157252
#
# === Bootstrap attempt 191 === linear_no:100/100 | linear_user:100/100 | linear_product:100/100 | linear_all:100/100 | dml_no:100/100 | dml_user:92/100 | dml_product:100/100 | dml_all:100/100
# [attempt=191] DEDL est=-67.437904, SE=6.563001, 95% CI=[-80.301151, -54.574657], covered=True
# [attempt=191] dml_user: SUCCESS pe=-0.017730 ape=0.017730
#
# === Bootstrap attempt 192 === linear_no:100/100 | linear_user:100/100 | linear_product:100/100 | linear_all:100/100 | dml_no:100/100 | dml_user:93/100 | dml_product:100/100 | dml_all:100/100
# [attempt=192] Mark UNSTABLE: best_eps=10
# [attempt=192] dml_user: EXCEPTION -> skipped | ValueError('not enough values to unpack (expected 5, got 3)')
#
# === Bootstrap attempt 193 === linear_no:100/100 | linear_user:100/100 | linear_product:100/100 | linear_all:100/100 | dml_no:100/100 | dml_user:93/100 | dml_product:100/100 | dml_all:100/100
# [attempt=193] Mark UNSTABLE: best_eps=10
# [attempt=193] dml_user: EXCEPTION -> skipped | ValueError('not enough values to unpack (expected 5, got 3)')
#
# === Bootstrap attempt 194 === linear_no:100/100 | linear_user:100/100 | linear_product:100/100 | linear_all:100/100 | dml_no:100/100 | dml_user:93/100 | dml_product:100/100 | dml_all:100/100
# [attempt=194] DEDL est=-67.775269, SE=13.361740, 95% CI=[-93.963802, -41.586735], covered=True
# [attempt=194] dml_user: SUCCESS pe=-0.012816 ape=0.012816
#
# === Bootstrap attempt 195 === linear_no:100/100 | linear_user:100/100 | linear_product:100/100 | linear_all:100/100 | dml_no:100/100 | dml_user:94/100 | dml_product:100/100 | dml_all:100/100
# [attempt=195] Mark UNSTABLE: best_eps=1e-07
# [attempt=195] dml_user: EXCEPTION -> skipped | ValueError('not enough values to unpack (expected 5, got 3)')
#
# === Bootstrap attempt 196 === linear_no:100/100 | linear_user:100/100 | linear_product:100/100 | linear_all:100/100 | dml_no:100/100 | dml_user:94/100 | dml_product:100/100 | dml_all:100/100
# [attempt=196] DEDL est=-75.102203, SE=14.385399, 95% CI=[-103.297071, -46.907336], covered=True
# [attempt=196] dml_user: SUCCESS pe=0.093904 ape=0.093904
#
# === Bootstrap attempt 197 === linear_no:100/100 | linear_user:100/100 | linear_product:100/100 | linear_all:100/100 | dml_no:100/100 | dml_user:95/100 | dml_product:100/100 | dml_all:100/100
# [attempt=197] dml_user: EXCEPTION -> skipped | ValueError('not enough values to unpack (expected 5, got 3)')
#
# === Bootstrap attempt 198 === linear_no:100/100 | linear_user:100/100 | linear_product:100/100 | linear_all:100/100 | dml_no:100/100 | dml_user:95/100 | dml_product:100/100 | dml_all:100/100
# [attempt=198] Mark UNSTABLE: best_eps=10
# [attempt=198] dml_user: EXCEPTION -> skipped | ValueError('not enough values to unpack (expected 5, got 3)')
#
# === Bootstrap attempt 199 === linear_no:100/100 | linear_user:100/100 | linear_product:100/100 | linear_all:100/100 | dml_no:100/100 | dml_user:95/100 | dml_product:100/100 | dml_all:100/100
# [attempt=199] Mark UNSTABLE: best_eps=10
# [attempt=199] dml_user: EXCEPTION -> skipped | ValueError('not enough values to unpack (expected 5, got 3)')
#
# === Bootstrap attempt 200 === linear_no:100/100 | linear_user:100/100 | linear_product:100/100 | linear_all:100/100 | dml_no:100/100 | dml_user:95/100 | dml_product:100/100 | dml_all:100/100
# [attempt=200] DEDL est=-70.514633, SE=7.695220, 95% CI=[-85.596989, -55.432278], covered=True
# [attempt=200] dml_user: SUCCESS pe=0.027084 ape=0.027084
#
# === Bootstrap attempt 201 === linear_no:100/100 | linear_user:100/100 | linear_product:100/100 | linear_all:100/100 | dml_no:100/100 | dml_user:96/100 | dml_product:100/100 | dml_all:100/100
# [attempt=201] Mark UNSTABLE: best_eps=10
# [attempt=201] dml_user: EXCEPTION -> skipped | ValueError('not enough values to unpack (expected 5, got 3)')
#
# === Bootstrap attempt 202 === linear_no:100/100 | linear_user:100/100 | linear_product:100/100 | linear_all:100/100 | dml_no:100/100 | dml_user:96/100 | dml_product:100/100 | dml_all:100/100
# [attempt=202] DEBUG large pe_dedl=0.106
# [attempt=202] DEDL est=-75.930321, SE=9.778670, 95% CI=[-95.096165, -56.764476], covered=True
# [attempt=202] dml_user: SUCCESS pe=0.105966 ape=0.105966
#
# === Bootstrap attempt 203 === linear_no:100/100 | linear_user:100/100 | linear_product:100/100 | linear_all:100/100 | dml_no:100/100 | dml_user:97/100 | dml_product:100/100 | dml_all:100/100
# [attempt=203] DEDL est=-74.266075, SE=12.415787, 95% CI=[-98.600574, -49.931577], covered=True
# [attempt=203] dml_user: SUCCESS pe=0.081726 ape=0.081726
#
# === Bootstrap attempt 204 === linear_no:100/100 | linear_user:100/100 | linear_product:100/100 | linear_all:100/100 | dml_no:100/100 | dml_user:98/100 | dml_product:100/100 | dml_all:100/100
# [attempt=204] Mark UNSTABLE: best_eps=10
# [attempt=204] dml_user: EXCEPTION -> skipped | ValueError('not enough values to unpack (expected 5, got 3)')
#
# === Bootstrap attempt 205 === linear_no:100/100 | linear_user:100/100 | linear_product:100/100 | linear_all:100/100 | dml_no:100/100 | dml_user:98/100 | dml_product:100/100 | dml_all:100/100
# [attempt=205] DEDL est=-65.207848, SE=8.307683, 95% CI=[-81.490609, -48.925086], covered=True
# [attempt=205] dml_user: SUCCESS pe=-0.050212 ape=0.050212
#
# === Bootstrap attempt 206 === linear_no:100/100 | linear_user:100/100 | linear_product:100/100 | linear_all:100/100 | dml_no:100/100 | dml_user:99/100 | dml_product:100/100 | dml_all:100/100
# [attempt=206] dml_user: EXCEPTION -> skipped | ValueError('not enough values to unpack (expected 5, got 3)')
#
# === Bootstrap attempt 207 === linear_no:100/100 | linear_user:100/100 | linear_product:100/100 | linear_all:100/100 | dml_no:100/100 | dml_user:99/100 | dml_product:100/100 | dml_all:100/100
# [attempt=207] DEDL est=-69.150230, SE=12.487761, 95% CI=[-93.625797, -44.674664], covered=True
# [attempt=207] dml_user: SUCCESS pe=0.007211 ape=0.007211
#
# ================= BOOTSTRAP SUMMARY =================
# linear_no: n_ok=100/100 | PE mean=-0.133893, PE median=-0.137524, std=0.279140 | APE mean=0.243990, APE median=0.203902, std=0.189460 | covered mean=0.000000
# linear_user: n_ok=100/100 | PE mean=-0.101041, PE median=-0.102356, std=0.246618 | APE mean=0.224194, APE median=0.213687, std=0.142696 | covered mean=0.170000
# linear_product: n_ok=100/100 | PE mean=-0.198024, PE median=-0.195595, std=0.263184 | APE mean=0.271522, APE median=0.252995, std=0.185490 | covered mean=0.000000
# linear_all: n_ok=100/100 | PE mean=-0.182819, PE median=-0.161169, std=0.269013 | APE mean=0.258726, APE median=0.212231, std=0.196248 | covered mean=0.240000
# dml_no: n_ok=100/100 | PE mean=-0.133901, PE median=-0.137524, std=0.279142 | APE mean=0.243998, APE median=0.203902, std=0.189458 | covered mean=0.000000
# dml_user: n_ok=100/100 | PE mean=0.008782, PE median=0.004607, std=0.070849 | APE mean=0.043492, APE median=0.025605, std=0.056452 | covered mean=0.970000
# dml_product: n_ok=100/100 | PE mean=-0.014273, PE median=-0.005543, std=0.089831 | APE mean=0.057392, APE median=0.035279, std=0.070344 | covered mean=0.960000
# dml_all: n_ok=100/100 | PE mean=0.000695, PE median=-0.000421, std=0.057223 | APE mean=0.040800, APE median=0.029178, std=0.039919 | covered mean=1.000000
#
# All methods reached 100 successful bootstrap runs.

# %%
# ============================================================
# 0) Merge purchasing data with product data
# ============================================================
merged_half = df_half.merge(df_prod, left_on="choice_num", right_on="product_id", how="left")

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Device:", device)

# ============================================================
# 1) Config
# ============================================================
TARGET_OK = 100         # each method needs 200 successful bootstraps
MAX_ATTEMPTS = 10**9     # large guard; you can lower if you want

METHODS = [
    # ("linear_no",   train_and_estimate_linear_no),
    # ("linear_user", train_and_estimate_linear_user),
    # ("linear_product", train_and_estimate_linear_product),
    # ("linear_all", train_and_estimate_linear_all),
    ("pdl_no",      train_and_estimate_pdl_no),
    ("pdl_user",    train_and_estimate_pdl_user),
    ("pdl_product", train_and_estimate_pdl_product),
    ("pdl_all",     train_and_estimate_pdl_all),
    # ("dml_no",      train_and_estimate_dml_no),
    # ("dml_user",    train_and_estimate_dml_user),
    # ("dml_product", train_and_estimate_dml_product),
    # ("dml_all",     train_and_estimate_dml_all),
]

# results container
bootstrap_results = {name: [] for name, _ in METHODS}
ok_count = {name: 0 for name, _ in METHODS}

def _need_more(name: str) -> bool:
    return ok_count[name] < TARGET_OK

def _all_done() -> bool:
    return all(ok_count[name] >= TARGET_OK for name, _ in METHODS)

# ============================================================
# Per-method hyperparameters
# ============================================================
DEFAULT_CFG = dict(num_epochs=5000, lr=0.01,step_size=2500,gamma=0.5,patience=10)

METHOD_CFG = {
    # Linear
    "linear_no":      dict(num_epochs=1000,lr=0.01,step_size=2500,gamma=0.5,patience=10),
    "linear_user":    dict(num_epochs=1000,lr=0.01,step_size=2500,gamma=0.5,patience=10),
    "linear_product": dict(num_epochs=1000,lr=0.01,step_size=2500,gamma=0.5,patience=10),
    "linear_all":     dict(num_epochs=1000,lr=0.01,step_size=2500,gamma=0.5,patience=10),

    # PDL
    "pdl_no":         dict(num_epochs=5000,lr=0.001,step_size=2500,gamma=0.5,patience=10),
    "pdl_user":       dict(num_epochs=5000,lr=0.005,step_size=2500,gamma=0.5,patience=50),
    "pdl_product":    dict(num_epochs=5000,lr=0.005,step_size=2500,gamma=0.5,patience=50),
    "pdl_all":        dict(num_epochs=5000,lr=0.001,step_size=2500,gamma=0.5,patience=50),

    # DML / DEDL
    "dml_no":         dict(num_epochs=1000,lr=0.01,step_size=2500,gamma=0.5,patience=10),
    "dml_user":       dict(num_epochs=5000, lr=0.01,step_size=2500,gamma=0.5,patience=10),
    "dml_product":    dict(num_epochs=5000, lr=0.01,step_size=2500,gamma=0.5,patience=10),
    "dml_all":        dict(num_epochs=5000, lr=0.005,step_size=2500,gamma=0.5,patience=20),
}


# ============================================================
# 2) Main bootstrap loop
#    - bootstrap resample
#    - prepare_data_bootstrap
#    - train/test split + validation split
#    - run each method until it reaches 200 successful runs
#    - if a method "bad", skip it for that attempt
# ============================================================

attempt = 0
while (not _all_done()) and (attempt < MAX_ATTEMPTS):
    print(f"\n=== Bootstrap attempt {attempt} === "+ " | ".join([f"{k}:{ok_count[k]}/{TARGET_OK}" for k, _ in METHODS]))

    # Fix random seed for reproducibility
    set_seed(34 + attempt)

    # Bootstrap resample merged_half with replacement
    boot_df = merged_half.sample(frac=1, replace=True, random_state=attempt)

    revenue_control, revenue_treated = calculate_total_revenue(boot_df)
    dim = (revenue_treated - revenue_control) * 600/266
    naive_pe = (dim - true) / true
    naive_ape = abs((dim - true) / true)

    # Prepare data from the bootstrap sample
    # expected return: X_user, choice, X_product, price, prod_randomization
    X_user, choice, X_product, price, prod_randomization = prepare_data_bootstrap(df_prod, boot_df)

    # -------------------------------
    # 3) train/test + validation split
    # -------------------------------
    # Split the training and test set
    X_user_train, X_user_test, choice_train, choice_test = train_test_split(X_user, choice, test_size=0.5, random_state=42)

    # Validation set (10% of training)
    X_user_train1, X_user_val, choice_train1, choice_val = train_test_split(X_user_train, choice_train, test_size=0.1, random_state=34)

    # -------------------------------
    # 4) run methods (only those needing more)
    # -------------------------------
    for method_name, train_fn in METHODS:
        if not _need_more(method_name):
            continue

        # build config for this method
        cfg = DEFAULT_CFG.copy()
        cfg.update(METHOD_CFG.get(method_name, {}))  # if missing, just use default

        try:
            pe, ape, ci, covered,trained_ok = train_fn(
                X_user, X_user_train1, X_user_test,
                choice_train1, choice_test,
                X_user_val, choice_val,
                X_product, price, prod_randomization,
                device,
                attempt=attempt, 
                **cfg,
                ci_alpha=0.05, 
                return_ci=True    
            )

            if not trained_ok:
                print(f"[attempt={attempt}] {method_name}: FAIL -> skipped")
                continue

            bootstrap_results[method_name].append({
                "bootstrap_id": ok_count[method_name],
                "attempt_id": attempt,
                "pe": float(pe),
                "ape": float(ape),
                "covered": covered,
            })
            ok_count[method_name] += 1

            print(f"[attempt={attempt}] {method_name}: SUCCESS "
                f"pe={float(pe):.6f} ape={float(ape):.6f}")

        except Exception as e:
            print(f"[attempt={attempt}] {method_name}: EXCEPTION -> skipped | {repr(e)}")
            continue

    attempt += 1

# ============================================================
# 5) Summary stats for each method (mean/std of PE and APE)
# ============================================================
print("\n================= BOOTSTRAP SUMMARY =================")
for method_name, _ in METHODS:
    pe_arr = np.array([r["pe"] for r in bootstrap_results[method_name]], dtype=float)
    ape_arr = np.array([r["ape"] for r in bootstrap_results[method_name]], dtype=float)
    covered_list = [r["covered"] for r in bootstrap_results[method_name] if r["covered"] is not None]

    pe_arr = pe_arr[~np.isnan(pe_arr)]
    ape_arr = ape_arr[~np.isnan(ape_arr)]

    if len(pe_arr) == 0:
        print(f"{method_name}: no successful runs.")
        continue

    pe_mean = np.mean(pe_arr)
    pe_median = np.median(pe_arr)
    pe_std = np.std(pe_arr, ddof=1) if len(pe_arr) > 1 else 0.0
    ape_mean = np.mean(ape_arr)
    ape_median = np.median(ape_arr)
    ape_std = np.std(ape_arr, ddof=1) if len(ape_arr) > 1 else 0.0
    covered_mean = float(np.mean(covered_list)) if len(covered_list) > 0 else float("nan")

    print(
        f"{method_name}: n_ok={len(pe_arr)}/{TARGET_OK} | "
        f"PE mean={pe_mean:.6f}, PE median={pe_median:.6f}, std={pe_std:.6f} | "
        f"APE mean={ape_mean:.6f}, APE median={ape_median:.6f}, std={ape_std:.6f} | "
        f"covered mean={covered_mean:.6f}"
    )

if not _all_done():
    print("\nWARNING: Not all methods reached the target.")
    print("Final counts:", ok_count)
else:
    print("\nAll methods reached 100 successful bootstrap runs.")
# Out:
# Device: cpu
#
# === Bootstrap attempt 0 === pdl_no:0/100 | pdl_user:0/100 | pdl_product:0/100 | pdl_all:0/100
# [attempt=0] est=-84.530426, SE=0.000001, 95% CI=[-84.530428, -84.530425], covered=False
# [attempt=0] pdl_no: SUCCESS pe=0.231232 ape=0.231232
# [attempt=0] est=-63.675323, SE=2.015130, 95% CI=[-67.624906, -59.725741], covered=False
# [attempt=0] pdl_user: SUCCESS pe=-0.072534 ape=0.072534
# [attempt=0] est=-66.911774, SE=0.000000, 95% CI=[-66.911774, -66.911773], covered=False
# [attempt=0] pdl_product: SUCCESS pe=-0.025394 ape=0.025394
# [attempt=0] est=-76.159065, SE=0.974136, 95% CI=[-78.068336, -74.249794], covered=False
# [attempt=0] pdl_all: SUCCESS pe=0.109298 ape=0.109298
#
# === Bootstrap attempt 1 === pdl_no:1/100 | pdl_user:1/100 | pdl_product:1/100 | pdl_all:1/100
# [attempt=1] est=-113.405457, SE=0.000001, 95% CI=[-113.405458, -113.405455], covered=False
# [attempt=1] pdl_no: SUCCESS pe=0.651812 ape=0.651812
# [attempt=1] pdl_user: EXCEPTION -> skipped | ValueError('not enough values to unpack (expected 5, got 3)')
# [attempt=1] est=-31.880596, SE=0.000001, 95% CI=[-31.880597, -31.880595], covered=False
# [attempt=1] pdl_product: SUCCESS pe=-0.535642 ape=0.535642
# [attempt=1] est=-47.031723, SE=1.376144, 95% CI=[-49.728917, -44.334529], covered=False
# [attempt=1] pdl_all: SUCCESS pe=-0.314957 ape=0.314957
#
# === Bootstrap attempt 2 === pdl_no:2/100 | pdl_user:1/100 | pdl_product:2/100 | pdl_all:2/100
# [attempt=2] est=-72.786690, SE=0.000000, 95% CI=[-72.786691, -72.786689], covered=False
# [attempt=2] pdl_no: SUCCESS pe=0.060178 ape=0.060178
# [attempt=2] est=-98.091011, SE=2.475316, 95% CI=[-102.942542, -93.239480], covered=False
# [attempt=2] pdl_user: SUCCESS pe=0.428749 ape=0.428749
# [attempt=2] est=-68.536667, SE=0.000000, 95% CI=[-68.536667, -68.536667], covered=False
# [attempt=2] pdl_product: SUCCESS pe=-0.001726 ape=0.001726
# [attempt=2] est=-88.545105, SE=2.678621, 95% CI=[-93.795107, -83.295103], covered=False
# [attempt=2] pdl_all: SUCCESS pe=0.289708 ape=0.289708
#
# === Bootstrap attempt 3 === pdl_no:3/100 | pdl_user:2/100 | pdl_product:3/100 | pdl_all:3/100
# [attempt=3] est=-64.075401, SE=0.000000, 95% CI=[-64.075402, -64.075401], covered=False
# [attempt=3] pdl_no: SUCCESS pe=-0.066707 ape=0.066707
# [attempt=3] est=-73.596092, SE=2.836296, 95% CI=[-79.155132, -68.037053], covered=True
# [attempt=3] pdl_user: SUCCESS pe=0.071967 ape=0.071967
# [attempt=3] est=-46.041550, SE=0.000000, 95% CI=[-46.041550, -46.041549], covered=False
# [attempt=3] pdl_product: SUCCESS pe=-0.329380 ape=0.329380
# [attempt=3] est=-77.009659, SE=1.269988, 95% CI=[-79.498789, -74.520529], covered=False
# [attempt=3] pdl_all: SUCCESS pe=0.121688 ape=0.121688
#
# === Bootstrap attempt 4 === pdl_no:4/100 | pdl_user:3/100 | pdl_product:4/100 | pdl_all:4/100
# [attempt=4] est=-70.894180, SE=0.000000, 95% CI=[-70.894181, -70.894180], covered=False
# [attempt=4] pdl_no: SUCCESS pe=0.032612 ape=0.032612
# [attempt=4] est=-41.619183, SE=5.293860, 95% CI=[-51.994959, -31.243406], covered=False
# [attempt=4] pdl_user: SUCCESS pe=-0.393794 ape=0.393794
# [attempt=4] est=-72.822830, SE=0.000001, 95% CI=[-72.822832, -72.822829], covered=False
# [attempt=4] pdl_product: SUCCESS pe=0.060704 ape=0.060704
# [attempt=4] pdl_all: EXCEPTION -> skipped | ValueError('not enough values to unpack (expected 5, got 3)')
#
# === Bootstrap attempt 5 === pdl_no:5/100 | pdl_user:4/100 | pdl_product:5/100 | pdl_all:4/100
# [attempt=5] est=-54.975231, SE=0.000000, 95% CI=[-54.975232, -54.975230], covered=False
# [attempt=5] pdl_no: SUCCESS pe=-0.199256 ape=0.199256
# [attempt=5] est=-58.383324, SE=2.302031, 95% CI=[-62.895221, -53.871426], covered=False
# [attempt=5] pdl_user: SUCCESS pe=-0.149615 ape=0.149615
# [attempt=5] est=-51.930321, SE=0.000001, 95% CI=[-51.930322, -51.930319], covered=False
# [attempt=5] pdl_product: SUCCESS pe=-0.243607 ape=0.243607
# [attempt=5] est=-72.191788, SE=2.109378, 95% CI=[-76.326093, -68.057482], covered=True
# [attempt=5] pdl_all: SUCCESS pe=0.051513 ape=0.051513
#
# === Bootstrap attempt 6 === pdl_no:6/100 | pdl_user:5/100 | pdl_product:6/100 | pdl_all:5/100
# [attempt=6] est=-43.057892, SE=0.000000, 95% CI=[-43.057893, -43.057891], covered=False
# [attempt=6] pdl_no: SUCCESS pe=-0.372838 ape=0.372838
# [attempt=6] est=-41.117245, SE=3.451993, 95% CI=[-47.883028, -34.351461], covered=False
# [attempt=6] pdl_user: SUCCESS pe=-0.401105 ape=0.401105
# [attempt=6] est=-65.658936, SE=0.000000, 95% CI=[-65.658936, -65.658935], covered=False
# [attempt=6] pdl_product: SUCCESS pe=-0.043642 ape=0.043642
# [attempt=6] est=-46.452770, SE=2.191512, 95% CI=[-50.748056, -42.157484], covered=False
# [attempt=6] pdl_all: SUCCESS pe=-0.323390 ape=0.323390
#
# === Bootstrap attempt 7 === pdl_no:7/100 | pdl_user:6/100 | pdl_product:7/100 | pdl_all:6/100
# [attempt=7] est=-75.102745, SE=0.000000, 95% CI=[-75.102745, -75.102745], covered=False
# [attempt=7] pdl_no: SUCCESS pe=0.093912 ape=0.093912
# [attempt=7] est=-79.499886, SE=2.656460, 95% CI=[-84.706451, -74.293320], covered=False
# [attempt=7] pdl_user: SUCCESS pe=0.157959 ape=0.157959
# [attempt=7] est=-94.214073, SE=0.000001, 95% CI=[-94.214075, -94.214072], covered=False
# [attempt=7] pdl_product: SUCCESS pe=0.372279 ape=0.372279
# [attempt=7] est=-72.528641, SE=0.736670, 95% CI=[-73.972488, -71.084794], covered=False
# [attempt=7] pdl_all: SUCCESS pe=0.056419 ape=0.056419
#
# === Bootstrap attempt 8 === pdl_no:8/100 | pdl_user:7/100 | pdl_product:8/100 | pdl_all:7/100
# [attempt=8] est=-86.596329, SE=0.000000, 95% CI=[-86.596329, -86.596329], covered=False
# [attempt=8] pdl_no: SUCCESS pe=0.261323 ape=0.261323
# [attempt=8] est=-86.323349, SE=1.348098, 95% CI=[-88.965573, -83.681125], covered=False
# [attempt=8] pdl_user: SUCCESS pe=0.257347 ape=0.257347
# [attempt=8] est=-54.593002, SE=0.000001, 95% CI=[-54.593004, -54.593001], covered=False
# [attempt=8] pdl_product: SUCCESS pe=-0.204823 ape=0.204823
# [attempt=8] est=-74.181511, SE=1.163945, 95% CI=[-76.462802, -71.900220], covered=False
# [attempt=8] pdl_all: SUCCESS pe=0.080494 ape=0.080494
#
# === Bootstrap attempt 9 === pdl_no:9/100 | pdl_user:8/100 | pdl_product:9/100 | pdl_all:8/100
# [attempt=9] est=-58.190414, SE=0.000000, 95% CI=[-58.190415, -58.190414], covered=False
# [attempt=9] pdl_no: SUCCESS pe=-0.152425 ape=0.152425
# [attempt=9] est=-67.451912, SE=2.237661, 95% CI=[-71.837648, -63.066176], covered=True
# [attempt=9] pdl_user: SUCCESS pe=-0.017526 ape=0.017526
# [attempt=9] pdl_product: EXCEPTION -> skipped | ValueError('not enough values to unpack (expected 5, got 3)')
# [attempt=9] est=-82.109940, SE=1.307552, 95% CI=[-84.672696, -79.547183], covered=False
# [attempt=9] pdl_all: SUCCESS pe=0.195976 ape=0.195976
#
# === Bootstrap attempt 10 === pdl_no:10/100 | pdl_user:9/100 | pdl_product:9/100 | pdl_all:9/100
# [attempt=10] est=-79.682991, SE=0.000001, 95% CI=[-79.682993, -79.682990], covered=False
# [attempt=10] pdl_no: SUCCESS pe=0.160626 ape=0.160626
# [attempt=10] est=-84.652023, SE=1.891728, 95% CI=[-88.359742, -80.944304], covered=False
# [attempt=10] pdl_user: SUCCESS pe=0.233003 ape=0.233003
# [attempt=10] est=-71.256775, SE=0.000000, 95% CI=[-71.256776, -71.256774], covered=False
# [attempt=10] pdl_product: SUCCESS pe=0.037894 ape=0.037894
# [attempt=10] est=-75.198792, SE=1.735335, 95% CI=[-78.599986, -71.797597], covered=False
# [attempt=10] pdl_all: SUCCESS pe=0.095311 ape=0.095311
#
# === Bootstrap attempt 11 === pdl_no:11/100 | pdl_user:10/100 | pdl_product:10/100 | pdl_all:10/100
# [attempt=11] est=-59.470047, SE=0.000000, 95% CI=[-59.470048, -59.470046], covered=False
# [attempt=11] pdl_no: SUCCESS pe=-0.133786 ape=0.133786
# [attempt=11] est=-84.538719, SE=1.226546, 95% CI=[-86.942706, -82.134732], covered=False
# [attempt=11] pdl_user: SUCCESS pe=0.231352 ape=0.231352
# [attempt=11] pdl_product: EXCEPTION -> skipped | ValueError('not enough values to unpack (expected 5, got 3)')
# [attempt=11] est=-94.131210, SE=2.310037, 95% CI=[-98.658800, -89.603621], covered=False
# [attempt=11] pdl_all: SUCCESS pe=0.371072 ape=0.371072
#
# === Bootstrap attempt 12 === pdl_no:12/100 | pdl_user:11/100 | pdl_product:10/100 | pdl_all:11/100
# [attempt=12] est=-74.719688, SE=0.000000, 95% CI=[-74.719689, -74.719688], covered=False
# [attempt=12] pdl_no: SUCCESS pe=0.088333 ape=0.088333
# [attempt=12] est=-78.071907, SE=2.980597, 95% CI=[-83.913772, -72.230042], covered=False
# [attempt=12] pdl_user: SUCCESS pe=0.137160 ape=0.137160
# [attempt=12] est=-63.827381, SE=0.000000, 95% CI=[-63.827381, -63.827381], covered=False
# [attempt=12] pdl_product: SUCCESS pe=-0.070319 ape=0.070319
# [attempt=12] est=-69.840424, SE=1.501725, 95% CI=[-72.783750, -66.897097], covered=True
# [attempt=12] pdl_all: SUCCESS pe=0.017264 ape=0.017264
#
# === Bootstrap attempt 13 === pdl_no:13/100 | pdl_user:12/100 | pdl_product:11/100 | pdl_all:12/100
# [attempt=13] est=-80.000671, SE=0.000000, 95% CI=[-80.000671, -80.000671], covered=False
# [attempt=13] pdl_no: SUCCESS pe=0.165253 ape=0.165253
# [attempt=13] est=-71.169998, SE=3.452182, 95% CI=[-77.936151, -64.403845], covered=True
# [attempt=13] pdl_user: SUCCESS pe=0.036630 ape=0.036630
# [attempt=13] est=-61.531914, SE=0.000000, 95% CI=[-61.531914, -61.531914], covered=False
# [attempt=13] pdl_product: SUCCESS pe=-0.103754 ape=0.103754
# [attempt=13] est=-67.107430, SE=2.716790, 95% CI=[-72.432240, -61.782619], covered=True
# [attempt=13] pdl_all: SUCCESS pe=-0.022544 ape=0.022544
#
# === Bootstrap attempt 14 === pdl_no:14/100 | pdl_user:13/100 | pdl_product:12/100 | pdl_all:13/100
# [attempt=14] est=-59.535774, SE=0.000000, 95% CI=[-59.535775, -59.535773], covered=False
# [attempt=14] pdl_no: SUCCESS pe=-0.132829 ape=0.132829
# [attempt=14] est=-65.818718, SE=2.001648, 95% CI=[-69.741876, -61.895559], covered=True
# [attempt=14] pdl_user: SUCCESS pe=-0.041315 ape=0.041315
# [attempt=14] est=-70.672638, SE=0.000000, 95% CI=[-70.672639, -70.672637], covered=False
# [attempt=14] pdl_product: SUCCESS pe=0.029385 ape=0.029385
# [attempt=14] est=-77.939095, SE=1.512424, 95% CI=[-80.903392, -74.974797], covered=False
# [attempt=14] pdl_all: SUCCESS pe=0.135225 ape=0.135225
#
# === Bootstrap attempt 15 === pdl_no:15/100 | pdl_user:14/100 | pdl_product:13/100 | pdl_all:14/100
# [attempt=15] est=-89.353416, SE=0.000000, 95% CI=[-89.353416, -89.353416], covered=False
# [attempt=15] pdl_no: SUCCESS pe=0.301481 ape=0.301481
# [attempt=15] est=-67.975922, SE=1.776696, 95% CI=[-71.458182, -64.493661], covered=True
# [attempt=15] pdl_user: SUCCESS pe=-0.009894 ape=0.009894
# [attempt=15] est=-59.428814, SE=0.000000, 95% CI=[-59.428815, -59.428813], covered=False
# [attempt=15] pdl_product: SUCCESS pe=-0.134387 ape=0.134387
# [attempt=15] est=-76.550529, SE=1.330779, 95% CI=[-79.158808, -73.942251], covered=False
# [attempt=15] pdl_all: SUCCESS pe=0.115000 ape=0.115000
#
# === Bootstrap attempt 16 === pdl_no:16/100 | pdl_user:15/100 | pdl_product:14/100 | pdl_all:15/100
# [attempt=16] est=-63.083599, SE=0.000000, 95% CI=[-63.083600, -63.083598], covered=False
# [attempt=16] pdl_no: SUCCESS pe=-0.081153 ape=0.081153
# [attempt=16] est=-78.241837, SE=2.442320, 95% CI=[-83.028697, -73.454976], covered=False
# [attempt=16] pdl_user: SUCCESS pe=0.139635 ape=0.139635
# [attempt=16] est=-80.917526, SE=0.000001, 95% CI=[-80.917528, -80.917525], covered=False
# [attempt=16] pdl_product: SUCCESS pe=0.178608 ape=0.178608
# [attempt=16] est=-75.242493, SE=1.403507, 95% CI=[-77.993317, -72.491668], covered=False
# [attempt=16] pdl_all: SUCCESS pe=0.095948 ape=0.095948
#
# === Bootstrap attempt 17 === pdl_no:17/100 | pdl_user:16/100 | pdl_product:15/100 | pdl_all:16/100
# [attempt=17] est=-101.439148, SE=0.000001, 95% CI=[-101.439149, -101.439146], covered=False
# [attempt=17] pdl_no: SUCCESS pe=0.477516 ape=0.477516
# [attempt=17] est=-69.541382, SE=1.733338, 95% CI=[-72.938663, -66.144100], covered=True
# [attempt=17] pdl_user: SUCCESS pe=0.012908 ape=0.012908
# [attempt=17] est=-67.227798, SE=0.000000, 95% CI=[-67.227798, -67.227798], covered=False
# [attempt=17] pdl_product: SUCCESS pe=-0.020791 ape=0.020791
# [attempt=17] est=-90.565094, SE=1.264370, 95% CI=[-93.043215, -88.086973], covered=False
# [attempt=17] pdl_all: SUCCESS pe=0.319130 ape=0.319130
#
# === Bootstrap attempt 18 === pdl_no:18/100 | pdl_user:17/100 | pdl_product:16/100 | pdl_all:17/100
# [attempt=18] est=-55.394833, SE=0.000000, 95% CI=[-55.394833, -55.394832], covered=False
# [attempt=18] pdl_no: SUCCESS pe=-0.193144 ape=0.193144
# [attempt=18] est=-72.063354, SE=2.138806, 95% CI=[-76.255339, -67.871370], covered=True
# [attempt=18] pdl_user: SUCCESS pe=0.049642 ape=0.049642
# [attempt=18] est=-54.528748, SE=0.000000, 95% CI=[-54.528748, -54.528748], covered=False
# [attempt=18] pdl_product: SUCCESS pe=-0.205759 ape=0.205759
# [attempt=18] est=-78.679688, SE=2.584425, 95% CI=[-83.745069, -73.614306], covered=False
# [attempt=18] pdl_all: SUCCESS pe=0.146012 ape=0.146012
#
# === Bootstrap attempt 19 === pdl_no:19/100 | pdl_user:18/100 | pdl_product:17/100 | pdl_all:18/100
# [attempt=19] est=-54.048866, SE=0.000001, 95% CI=[-54.048868, -54.048865], covered=False
# [attempt=19] pdl_no: SUCCESS pe=-0.212749 ape=0.212749
# [attempt=19] est=-66.432877, SE=1.497787, 95% CI=[-69.368486, -63.497267], covered=True
# [attempt=19] pdl_user: SUCCESS pe=-0.032369 ape=0.032369
# [attempt=19] est=-58.239773, SE=0.000000, 95% CI=[-58.239773, -58.239773], covered=False
# [attempt=19] pdl_product: SUCCESS pe=-0.151706 ape=0.151706
# [attempt=19] est=-73.615318, SE=1.402390, 95% CI=[-76.363952, -70.866684], covered=False
# [attempt=19] pdl_all: SUCCESS pe=0.072247 ape=0.072247
#
# === Bootstrap attempt 20 === pdl_no:20/100 | pdl_user:19/100 | pdl_product:18/100 | pdl_all:19/100
# [attempt=20] est=-34.688042, SE=0.000000, 95% CI=[-34.688042, -34.688041], covered=False
# [attempt=20] pdl_no: SUCCESS pe=-0.494750 ape=0.494750
# [attempt=20] est=-19.351015, SE=0.908475, 95% CI=[-21.131593, -17.570438], covered=False
# [attempt=20] pdl_user: SUCCESS pe=-0.718142 ape=0.718142
# [attempt=20] est=-34.724232, SE=0.000000, 95% CI=[-34.724232, -34.724231], covered=False
# [attempt=20] pdl_product: SUCCESS pe=-0.494223 ape=0.494223
# [attempt=20] est=-53.868671, SE=1.533231, 95% CI=[-56.873750, -50.863593], covered=False
# [attempt=20] pdl_all: SUCCESS pe=-0.215374 ape=0.215374
#
# === Bootstrap attempt 21 === pdl_no:21/100 | pdl_user:20/100 | pdl_product:19/100 | pdl_all:20/100
# [attempt=21] est=-129.495132, SE=0.000001, 95% CI=[-129.495134, -129.495131], covered=False
# [attempt=21] pdl_no: SUCCESS pe=0.886167 ape=0.886167
# [attempt=21] est=-97.103920, SE=2.054037, 95% CI=[-101.129758, -93.078082], covered=False
# [attempt=21] pdl_user: SUCCESS pe=0.414371 ape=0.414371
# [attempt=21] pdl_product: EXCEPTION -> skipped | ValueError('not enough values to unpack (expected 5, got 3)')
# [attempt=21] est=-79.297615, SE=1.676471, 95% CI=[-82.583439, -76.011791], covered=False
# [attempt=21] pdl_all: SUCCESS pe=0.155013 ape=0.155013
#
# === Bootstrap attempt 22 === pdl_no:22/100 | pdl_user:21/100 | pdl_product:19/100 | pdl_all:21/100
# [attempt=22] est=-62.062237, SE=0.000001, 95% CI=[-62.062238, -62.062235], covered=False
# [attempt=22] pdl_no: SUCCESS pe=-0.096030 ape=0.096030
# [attempt=22] est=-59.154591, SE=3.214538, 95% CI=[-65.454970, -52.854211], covered=False
# [attempt=22] pdl_user: SUCCESS pe=-0.138381 ape=0.138381
# [attempt=22] est=-109.635818, SE=0.000001, 95% CI=[-109.635820, -109.635817], covered=False
# [attempt=22] pdl_product: SUCCESS pe=0.596905 ape=0.596905
# [attempt=22] est=-62.152588, SE=1.908052, 95% CI=[-65.892303, -58.412873], covered=False
# [attempt=22] pdl_all: SUCCESS pe=-0.094714 ape=0.094714
#
# === Bootstrap attempt 23 === pdl_no:23/100 | pdl_user:22/100 | pdl_product:20/100 | pdl_all:22/100
# [attempt=23] est=-76.566299, SE=0.000001, 95% CI=[-76.566301, -76.566298], covered=False
# [attempt=23] pdl_no: SUCCESS pe=0.115230 ape=0.115230
# [attempt=23] est=-68.095406, SE=7.952261, 95% CI=[-83.681554, -52.509257], covered=True
# [attempt=23] pdl_user: SUCCESS pe=-0.008153 ape=0.008153
# [attempt=23] est=-78.130379, SE=0.000001, 95% CI=[-78.130380, -78.130377], covered=False
# [attempt=23] pdl_product: SUCCESS pe=0.138011 ape=0.138011
# [attempt=23] est=-82.249359, SE=2.338976, 95% CI=[-86.833668, -77.665050], covered=False
# [attempt=23] pdl_all: SUCCESS pe=0.198007 ape=0.198007
#
# === Bootstrap attempt 24 === pdl_no:24/100 | pdl_user:23/100 | pdl_product:21/100 | pdl_all:23/100
# [attempt=24] est=-89.954063, SE=0.000002, 95% CI=[-89.954066, -89.954060], covered=False
# [attempt=24] pdl_no: SUCCESS pe=0.310230 ape=0.310230
# [attempt=24] est=-40.005310, SE=5.107397, 95% CI=[-50.015626, -29.994994], covered=False
# [attempt=24] pdl_user: SUCCESS pe=-0.417301 ape=0.417301
# [attempt=24] pdl_product: EXCEPTION -> skipped | ValueError('not enough values to unpack (expected 5, got 3)')
# [attempt=24] est=-91.393806, SE=1.339235, 95% CI=[-94.018658, -88.768955], covered=False
# [attempt=24] pdl_all: SUCCESS pe=0.331200 ape=0.331200
#
# === Bootstrap attempt 25 === pdl_no:25/100 | pdl_user:24/100 | pdl_product:21/100 | pdl_all:24/100
# [attempt=25] est=-75.473495, SE=0.000001, 95% CI=[-75.473497, -75.473494], covered=False
# [attempt=25] pdl_no: SUCCESS pe=0.099312 ape=0.099312
# [attempt=25] est=-56.939903, SE=2.658790, 95% CI=[-62.151036, -51.728771], covered=False
# [attempt=25] pdl_user: SUCCESS pe=-0.170639 ape=0.170639
# [attempt=25] est=-54.301640, SE=0.000000, 95% CI=[-54.301640, -54.301639], covered=False
# [attempt=25] pdl_product: SUCCESS pe=-0.209067 ape=0.209067
# [attempt=25] est=-63.791931, SE=2.083830, 95% CI=[-67.876164, -59.707698], covered=False
# [attempt=25] pdl_all: SUCCESS pe=-0.070836 ape=0.070836
#
# === Bootstrap attempt 26 === pdl_no:26/100 | pdl_user:25/100 | pdl_product:22/100 | pdl_all:25/100
# [attempt=26] est=-45.828522, SE=0.000000, 95% CI=[-45.828522, -45.828522], covered=False
# [attempt=26] pdl_no: SUCCESS pe=-0.332483 ape=0.332483
# [attempt=26] est=-65.796761, SE=1.537251, 95% CI=[-68.809717, -62.783804], covered=True
# [attempt=26] pdl_user: SUCCESS pe=-0.041634 ape=0.041634
# [attempt=26] pdl_product: EXCEPTION -> skipped | ValueError('not enough values to unpack (expected 5, got 3)')
# [attempt=26] pdl_all: EXCEPTION -> skipped | ValueError('not enough values to unpack (expected 5, got 3)')
#
# === Bootstrap attempt 27 === pdl_no:27/100 | pdl_user:26/100 | pdl_product:22/100 | pdl_all:25/100
# [attempt=27] est=-87.686134, SE=0.000001, 95% CI=[-87.686136, -87.686133], covered=False
# [attempt=27] pdl_no: SUCCESS pe=0.277196 ape=0.277196
# [attempt=27] est=-68.267708, SE=2.213565, 95% CI=[-72.606216, -63.929200], covered=True
# [attempt=27] pdl_user: SUCCESS pe=-0.005644 ape=0.005644
# [attempt=27] est=-70.391121, SE=0.000000, 95% CI=[-70.391121, -70.391121], covered=False
# [attempt=27] pdl_product: SUCCESS pe=0.025285 ape=0.025285
# [attempt=27] est=-78.191505, SE=2.214818, 95% CI=[-82.532471, -73.850540], covered=False
# [attempt=27] pdl_all: SUCCESS pe=0.138902 ape=0.138902
#
# === Bootstrap attempt 28 === pdl_no:28/100 | pdl_user:27/100 | pdl_product:23/100 | pdl_all:26/100
# [attempt=28] est=-56.353695, SE=0.000000, 95% CI=[-56.353695, -56.353695], covered=False
# [attempt=28] pdl_no: SUCCESS pe=-0.179178 ape=0.179178
# [attempt=28] est=-105.768005, SE=3.687542, 95% CI=[-112.995456, -98.540555], covered=False
# [attempt=28] pdl_user: SUCCESS pe=0.540568 ape=0.540568
# [attempt=28] est=-83.793457, SE=0.000001, 95% CI=[-83.793459, -83.793456], covered=False
# [attempt=28] pdl_product: SUCCESS pe=0.220497 ape=0.220497
# [attempt=28] est=-59.147526, SE=1.819273, 95% CI=[-62.713235, -55.581816], covered=False
# [attempt=28] pdl_all: SUCCESS pe=-0.138484 ape=0.138484
#
# === Bootstrap attempt 29 === pdl_no:29/100 | pdl_user:28/100 | pdl_product:24/100 | pdl_all:27/100
# [attempt=29] est=-59.910431, SE=0.000000, 95% CI=[-59.910432, -59.910430], covered=False
# [attempt=29] pdl_no: SUCCESS pe=-0.127372 ape=0.127372
# [attempt=29] est=-89.832436, SE=2.580917, 95% CI=[-94.890941, -84.773930], covered=False
# [attempt=29] pdl_user: SUCCESS pe=0.308458 ape=0.308458
# [attempt=29] est=-63.923508, SE=0.000000, 95% CI=[-63.923508, -63.923508], covered=False
# [attempt=29] pdl_product: SUCCESS pe=-0.068919 ape=0.068919
# [attempt=29] est=-77.263657, SE=1.056510, 95% CI=[-79.334379, -75.192935], covered=False
# [attempt=29] pdl_all: SUCCESS pe=0.125387 ape=0.125387
#
# === Bootstrap attempt 30 === pdl_no:30/100 | pdl_user:29/100 | pdl_product:25/100 | pdl_all:28/100
# [attempt=30] est=-46.963978, SE=0.000000, 95% CI=[-46.963978, -46.963978], covered=False
# [attempt=30] pdl_no: SUCCESS pe=-0.315944 ape=0.315944
# [attempt=30] est=-42.038048, SE=3.351067, 95% CI=[-48.606020, -35.470076], covered=False
# [attempt=30] pdl_user: SUCCESS pe=-0.387693 ape=0.387693
# [attempt=30] est=-49.194073, SE=0.000001, 95% CI=[-49.194074, -49.194071], covered=False
# [attempt=30] pdl_product: SUCCESS pe=-0.283462 ape=0.283462
# [attempt=30] est=-55.331593, SE=2.115807, 95% CI=[-59.478498, -51.184687], covered=False
# [attempt=30] pdl_all: SUCCESS pe=-0.194065 ape=0.194065
#
# === Bootstrap attempt 31 === pdl_no:31/100 | pdl_user:30/100 | pdl_product:26/100 | pdl_all:29/100
# [attempt=31] est=-97.437363, SE=0.000000, 95% CI=[-97.437363, -97.437363], covered=False
# [attempt=31] pdl_no: SUCCESS pe=0.419228 ape=0.419228
# [attempt=31] est=-83.944305, SE=1.954801, 95% CI=[-87.775645, -80.112966], covered=False
# [attempt=31] pdl_user: SUCCESS pe=0.222694 ape=0.222694
# [attempt=31] pdl_product: EXCEPTION -> skipped | ValueError('not enough values to unpack (expected 5, got 3)')
# [attempt=31] est=-76.871979, SE=2.357199, 95% CI=[-81.492004, -72.251953], covered=False
# [attempt=31] pdl_all: SUCCESS pe=0.119682 ape=0.119682
#
# === Bootstrap attempt 32 === pdl_no:32/100 | pdl_user:31/100 | pdl_product:26/100 | pdl_all:30/100
# [attempt=32] est=-99.051903, SE=0.000002, 95% CI=[-99.051906, -99.051900], covered=False
# [attempt=32] pdl_no: SUCCESS pe=0.442745 ape=0.442745
# [attempt=32] est=-94.536232, SE=2.172690, 95% CI=[-98.794626, -90.277838], covered=False
# [attempt=32] pdl_user: SUCCESS pe=0.376972 ape=0.376972
# [attempt=32] est=-89.687241, SE=0.000000, 95% CI=[-89.687241, -89.687241], covered=False
# [attempt=32] pdl_product: SUCCESS pe=0.306343 ape=0.306343
# [attempt=32] est=-92.023453, SE=1.481264, 95% CI=[-94.926678, -89.120227], covered=False
# [attempt=32] pdl_all: SUCCESS pe=0.340372 ape=0.340372
#
# === Bootstrap attempt 33 === pdl_no:33/100 | pdl_user:32/100 | pdl_product:27/100 | pdl_all:31/100
# [attempt=33] est=-45.793282, SE=0.000000, 95% CI=[-45.793282, -45.793281], covered=False
# [attempt=33] pdl_no: SUCCESS pe=-0.332996 ape=0.332996
# [attempt=33] est=-59.941154, SE=2.897616, 95% CI=[-65.620378, -54.261931], covered=False
# [attempt=33] pdl_user: SUCCESS pe=-0.126925 ape=0.126925
# [attempt=33] est=-78.964783, SE=0.000001, 95% CI=[-78.964784, -78.964781], covered=False
# [attempt=33] pdl_product: SUCCESS pe=0.150165 ape=0.150165
# [attempt=33] est=-74.558861, SE=2.111864, 95% CI=[-78.698039, -70.419682], covered=False
# [attempt=33] pdl_all: SUCCESS pe=0.085990 ape=0.085990
#
# === Bootstrap attempt 34 === pdl_no:34/100 | pdl_user:33/100 | pdl_product:28/100 | pdl_all:32/100
# [attempt=34] est=-102.857460, SE=0.000000, 95% CI=[-102.857460, -102.857460], covered=False
# [attempt=34] pdl_no: SUCCESS pe=0.498175 ape=0.498175
# [attempt=34] est=-83.919922, SE=1.978307, 95% CI=[-87.797332, -80.042512], covered=False
# [attempt=34] pdl_user: SUCCESS pe=0.222339 ape=0.222339
# [attempt=34] est=-78.615784, SE=0.000001, 95% CI=[-78.615785, -78.615782], covered=False
# [attempt=34] pdl_product: SUCCESS pe=0.145082 ape=0.145082
# [attempt=34] pdl_all: EXCEPTION -> skipped | ValueError('not enough values to unpack (expected 5, got 3)')
#
# === Bootstrap attempt 35 === pdl_no:35/100 | pdl_user:34/100 | pdl_product:29/100 | pdl_all:32/100
# [attempt=35] est=-90.926636, SE=0.000001, 95% CI=[-90.926637, -90.926634], covered=False
# [attempt=35] pdl_no: SUCCESS pe=0.324396 ape=0.324396
# [attempt=35] est=-87.998367, SE=8.121260, 95% CI=[-103.915746, -72.080988], covered=False
# [attempt=35] pdl_user: SUCCESS pe=0.281744 ape=0.281744
# [attempt=35] est=-79.060921, SE=0.000001, 95% CI=[-79.060922, -79.060919], covered=False
# [attempt=35] pdl_product: SUCCESS pe=0.151565 ape=0.151565
# [attempt=35] est=-78.741844, SE=3.383890, 95% CI=[-85.374148, -72.109540], covered=False
# [attempt=35] pdl_all: SUCCESS pe=0.146918 ape=0.146918
#
# === Bootstrap attempt 36 === pdl_no:36/100 | pdl_user:35/100 | pdl_product:30/100 | pdl_all:33/100
# [attempt=36] est=-81.746727, SE=0.000001, 95% CI=[-81.746729, -81.746725], covered=False
# [attempt=36] pdl_no: SUCCESS pe=0.190686 ape=0.190686
# [attempt=36] est=-110.292824, SE=3.224167, 95% CI=[-116.612077, -103.973571], covered=False
# [attempt=36] pdl_user: SUCCESS pe=0.606475 ape=0.606475
# [attempt=36] est=-51.550591, SE=0.000001, 95% CI=[-51.550592, -51.550589], covered=False
# [attempt=36] pdl_product: SUCCESS pe=-0.249138 ape=0.249138
# [attempt=36] est=-119.413727, SE=0.674275, 95% CI=[-120.735281, -118.092172], covered=False
# [attempt=36] pdl_all: SUCCESS pe=0.739326 ape=0.739326
#
# === Bootstrap attempt 37 === pdl_no:37/100 | pdl_user:36/100 | pdl_product:31/100 | pdl_all:34/100
# [attempt=37] est=-103.522224, SE=0.000001, 95% CI=[-103.522226, -103.522223], covered=False
# [attempt=37] pdl_no: SUCCESS pe=0.507857 ape=0.507857
# [attempt=37] pdl_user: EXCEPTION -> skipped | ValueError('not enough values to unpack (expected 5, got 3)')
# [attempt=37] est=-142.039856, SE=0.000002, 95% CI=[-142.039859, -142.039853], covered=False
# [attempt=37] pdl_product: SUCCESS pe=1.068888 ape=1.068888
# [attempt=37] pdl_all: EXCEPTION -> skipped | ValueError('not enough values to unpack (expected 5, got 3)')
#
# === Bootstrap attempt 38 === pdl_no:38/100 | pdl_user:36/100 | pdl_product:32/100 | pdl_all:34/100
# [attempt=38] est=-83.810013, SE=0.000001, 95% CI=[-83.810014, -83.810011], covered=False
# [attempt=38] pdl_no: SUCCESS pe=0.220738 ape=0.220738
# [attempt=38] est=-70.700592, SE=1.989340, 95% CI=[-74.599628, -66.801556], covered=True
# [attempt=38] pdl_user: SUCCESS pe=0.029793 ape=0.029793
# [attempt=38] est=-55.108921, SE=0.000001, 95% CI=[-55.108923, -55.108920], covered=False
# [attempt=38] pdl_product: SUCCESS pe=-0.197309 ape=0.197309
# [attempt=38] est=-73.568253, SE=1.553275, 95% CI=[-76.612615, -70.523890], covered=False
# [attempt=38] pdl_all: SUCCESS pe=0.071562 ape=0.071562
#
# === Bootstrap attempt 39 === pdl_no:39/100 | pdl_user:37/100 | pdl_product:33/100 | pdl_all:35/100
# [attempt=39] est=-97.081558, SE=0.000001, 95% CI=[-97.081560, -97.081557], covered=False
# [attempt=39] pdl_no: SUCCESS pe=0.414046 ape=0.414046
# [attempt=39] est=-86.912575, SE=1.427135, 95% CI=[-89.709709, -84.115441], covered=False
# [attempt=39] pdl_user: SUCCESS pe=0.265929 ape=0.265929
# [attempt=39] est=-49.924473, SE=0.000000, 95% CI=[-49.924474, -49.924472], covered=False
# [attempt=39] pdl_product: SUCCESS pe=-0.272823 ape=0.272823
# [attempt=39] est=-83.419853, SE=2.218352, 95% CI=[-87.767745, -79.071962], covered=False
# [attempt=39] pdl_all: SUCCESS pe=0.215056 ape=0.215056
#
# === Bootstrap attempt 40 === pdl_no:40/100 | pdl_user:38/100 | pdl_product:34/100 | pdl_all:36/100
# [attempt=40] est=-97.167633, SE=0.000000, 95% CI=[-97.167633, -97.167633], covered=False
# [attempt=40] pdl_no: SUCCESS pe=0.415299 ape=0.415299
# [attempt=40] est=-82.273125, SE=3.351717, 95% CI=[-88.842369, -75.703880], covered=False
# [attempt=40] pdl_user: SUCCESS pe=0.198353 ape=0.198353
# [attempt=40] est=-58.329777, SE=0.000000, 95% CI=[-58.329778, -58.329776], covered=False
# [attempt=40] pdl_product: SUCCESS pe=-0.150395 ape=0.150395
# [attempt=40] est=-85.676247, SE=3.304408, 95% CI=[-92.152768, -79.199725], covered=False
# [attempt=40] pdl_all: SUCCESS pe=0.247921 ape=0.247921
#
# === Bootstrap attempt 41 === pdl_no:41/100 | pdl_user:39/100 | pdl_product:35/100 | pdl_all:37/100
# [attempt=41] est=-80.894562, SE=0.000001, 95% CI=[-80.894563, -80.894560], covered=False
# [attempt=41] pdl_no: SUCCESS pe=0.178273 ape=0.178273
# [attempt=41] pdl_user: EXCEPTION -> skipped | ValueError('not enough values to unpack (expected 5, got 3)')
# [attempt=41] est=-55.495731, SE=0.000000, 95% CI=[-55.495732, -55.495731], covered=False
# [attempt=41] pdl_product: SUCCESS pe=-0.191675 ape=0.191675
# [attempt=41] est=-83.931473, SE=2.050282, 95% CI=[-87.949951, -79.912994], covered=False
# [attempt=41] pdl_all: SUCCESS pe=0.222508 ape=0.222508
#
# === Bootstrap attempt 42 === pdl_no:42/100 | pdl_user:39/100 | pdl_product:36/100 | pdl_all:38/100
# [attempt=42] est=-73.205925, SE=0.000001, 95% CI=[-73.205927, -73.205923], covered=False
# [attempt=42] pdl_no: SUCCESS pe=0.066284 ape=0.066284
# [attempt=42] est=-81.825035, SE=1.692055, 95% CI=[-85.141403, -78.508667], covered=False
# [attempt=42] pdl_user: SUCCESS pe=0.191826 ape=0.191826
# [attempt=42] est=-65.178825, SE=0.000001, 95% CI=[-65.178827, -65.178824], covered=False
# [attempt=42] pdl_product: SUCCESS pe=-0.050635 ape=0.050635
# [attempt=42] est=-77.886192, SE=2.221343, 95% CI=[-82.239946, -73.532439], covered=False
# [attempt=42] pdl_all: SUCCESS pe=0.134455 ape=0.134455
#
# === Bootstrap attempt 43 === pdl_no:43/100 | pdl_user:40/100 | pdl_product:37/100 | pdl_all:39/100
# [attempt=43] est=-85.159058, SE=0.000001, 95% CI=[-85.159059, -85.159056], covered=False
# [attempt=43] pdl_no: SUCCESS pe=0.240388 ape=0.240388
# [attempt=43] est=-70.826935, SE=1.580279, 95% CI=[-73.924225, -67.729644], covered=True
# [attempt=43] pdl_user: SUCCESS pe=0.031633 ape=0.031633
# [attempt=43] est=-80.768822, SE=0.000002, 95% CI=[-80.768825, -80.768819], covered=False
# [attempt=43] pdl_product: SUCCESS pe=0.176442 ape=0.176442
# [attempt=43] est=-82.871140, SE=1.482806, 95% CI=[-85.777386, -79.964893], covered=False
# [attempt=43] pdl_all: SUCCESS pe=0.207063 ape=0.207063
#
# === Bootstrap attempt 44 === pdl_no:44/100 | pdl_user:41/100 | pdl_product:38/100 | pdl_all:40/100
# [attempt=44] est=-51.215744, SE=0.000000, 95% CI=[-51.215744, -51.215744], covered=False
# [attempt=44] pdl_no: SUCCESS pe=-0.254015 ape=0.254015
# [attempt=44] est=-74.656967, SE=2.559600, 95% CI=[-79.673692, -69.640242], covered=False
# [attempt=44] pdl_user: SUCCESS pe=0.087419 ape=0.087419
# [attempt=44] est=-83.113220, SE=0.000001, 95% CI=[-83.113222, -83.113219], covered=False
# [attempt=44] pdl_product: SUCCESS pe=0.210589 ape=0.210589
# [attempt=44] est=-59.511429, SE=1.674636, 95% CI=[-62.793656, -56.229201], covered=False
# [attempt=44] pdl_all: SUCCESS pe=-0.133184 ape=0.133184
#
# === Bootstrap attempt 45 === pdl_no:45/100 | pdl_user:42/100 | pdl_product:39/100 | pdl_all:41/100
# [attempt=45] est=-129.501999, SE=0.000001, 95% CI=[-129.502000, -129.501997], covered=False
# [attempt=45] pdl_no: SUCCESS pe=0.886267 ape=0.886267
# [attempt=45] est=-124.300438, SE=2.627218, 95% CI=[-129.449690, -119.151185], covered=False
# [attempt=45] pdl_user: SUCCESS pe=0.810503 ape=0.810503
# [attempt=45] pdl_product: EXCEPTION -> skipped | ValueError('not enough values to unpack (expected 5, got 3)')
# [attempt=45] est=-88.307671, SE=1.767689, 95% CI=[-91.772277, -84.843064], covered=False
# [attempt=45] pdl_all: SUCCESS pe=0.286249 ape=0.286249
#
# === Bootstrap attempt 46 === pdl_no:46/100 | pdl_user:43/100 | pdl_product:39/100 | pdl_all:42/100
# [attempt=46] est=-80.273041, SE=0.000001, 95% CI=[-80.273042, -80.273039], covered=False
# [attempt=46] pdl_no: SUCCESS pe=0.169220 ape=0.169220
# [attempt=46] est=-54.266315, SE=1.683028, 95% CI=[-57.564991, -50.967640], covered=False
# [attempt=46] pdl_user: SUCCESS pe=-0.209582 ape=0.209582
# [attempt=46] est=-36.270866, SE=0.000000, 95% CI=[-36.270867, -36.270866], covered=False
# [attempt=46] pdl_product: SUCCESS pe=-0.471695 ape=0.471695
# [attempt=46] est=-59.104862, SE=0.670654, 95% CI=[-60.419321, -57.790404], covered=False
# [attempt=46] pdl_all: SUCCESS pe=-0.139106 ape=0.139106
#
# === Bootstrap attempt 47 === pdl_no:47/100 | pdl_user:44/100 | pdl_product:40/100 | pdl_all:43/100
# [attempt=47] est=-56.107300, SE=0.000000, 95% CI=[-56.107301, -56.107299], covered=False
# [attempt=47] pdl_no: SUCCESS pe=-0.182767 ape=0.182767
# [attempt=47] pdl_user: EXCEPTION -> skipped | ValueError('not enough values to unpack (expected 5, got 3)')
# [attempt=47] est=-73.897278, SE=0.000001, 95% CI=[-73.897279, -73.897276], covered=False
# [attempt=47] pdl_product: SUCCESS pe=0.076354 ape=0.076354
# [attempt=47] est=-101.210007, SE=1.456799, 95% CI=[-104.065280, -98.354733], covered=False
# [attempt=47] pdl_all: SUCCESS pe=0.474179 ape=0.474179
#
# === Bootstrap attempt 48 === pdl_no:48/100 | pdl_user:44/100 | pdl_product:41/100 | pdl_all:44/100
# [attempt=48] est=-44.547806, SE=0.000000, 95% CI=[-44.547807, -44.547805], covered=False
# [attempt=48] pdl_no: SUCCESS pe=-0.351137 ape=0.351137
# [attempt=48] est=-64.187042, SE=3.031892, 95% CI=[-70.129443, -58.244642], covered=True
# [attempt=48] pdl_user: SUCCESS pe=-0.065081 ape=0.065081
# [attempt=48] est=-66.778839, SE=0.000000, 95% CI=[-66.778840, -66.778838], covered=False
# [attempt=48] pdl_product: SUCCESS pe=-0.027330 ape=0.027330
# [attempt=48] est=-67.294075, SE=0.860795, 95% CI=[-68.981202, -65.606948], covered=True
# [attempt=48] pdl_all: SUCCESS pe=-0.019825 ape=0.019825
#
# === Bootstrap attempt 49 === pdl_no:49/100 | pdl_user:45/100 | pdl_product:42/100 | pdl_all:45/100
# [attempt=49] est=-63.327202, SE=0.000000, 95% CI=[-63.327203, -63.327201], covered=False
# [attempt=49] pdl_no: SUCCESS pe=-0.077605 ape=0.077605
# [attempt=49] est=-43.550823, SE=1.945130, 95% CI=[-47.363209, -39.738437], covered=False
# [attempt=49] pdl_user: SUCCESS pe=-0.365659 ape=0.365659
# [attempt=49] est=-46.892128, SE=0.000000, 95% CI=[-46.892129, -46.892127], covered=False
# [attempt=49] pdl_product: SUCCESS pe=-0.316991 ape=0.316991
# [attempt=49] est=-52.382877, SE=1.062153, 95% CI=[-54.464659, -50.301095], covered=False
# [attempt=49] pdl_all: SUCCESS pe=-0.237015 ape=0.237015
#
# === Bootstrap attempt 50 === pdl_no:50/100 | pdl_user:46/100 | pdl_product:43/100 | pdl_all:46/100
# [attempt=50] est=-35.515324, SE=0.000000, 95% CI=[-35.515324, -35.515323], covered=False
# [attempt=50] pdl_no: SUCCESS pe=-0.482700 ape=0.482700
# [attempt=50] est=-78.696304, SE=3.300866, 95% CI=[-85.165884, -72.226725], covered=False
# [attempt=50] pdl_user: SUCCESS pe=0.146254 ape=0.146254
# [attempt=50] est=-45.893887, SE=0.000000, 95% CI=[-45.893887, -45.893886], covered=False
# [attempt=50] pdl_product: SUCCESS pe=-0.331531 ape=0.331531
# [attempt=50] est=-63.451733, SE=2.159332, 95% CI=[-67.683946, -59.219519], covered=False
# [attempt=50] pdl_all: SUCCESS pe=-0.075791 ape=0.075791
#
# === Bootstrap attempt 51 === pdl_no:51/100 | pdl_user:47/100 | pdl_product:44/100 | pdl_all:47/100
# [attempt=51] est=-62.734074, SE=0.000001, 95% CI=[-62.734076, -62.734071], covered=False
# [attempt=51] pdl_no: SUCCESS pe=-0.086244 ape=0.086244
# [attempt=51] est=-55.390049, SE=1.451717, 95% CI=[-58.235363, -52.544735], covered=False
# [attempt=51] pdl_user: SUCCESS pe=-0.193214 ape=0.193214
# [attempt=51] est=-56.003792, SE=0.000000, 95% CI=[-56.003792, -56.003792], covered=False
# [attempt=51] pdl_product: SUCCESS pe=-0.184274 ape=0.184274
# [attempt=51] est=-72.760040, SE=1.251445, 95% CI=[-75.212829, -70.307252], covered=False
# [attempt=51] pdl_all: SUCCESS pe=0.059790 ape=0.059790
#
# === Bootstrap attempt 52 === pdl_no:52/100 | pdl_user:48/100 | pdl_product:45/100 | pdl_all:48/100
# [attempt=52] est=-92.689270, SE=0.000001, 95% CI=[-92.689272, -92.689268], covered=False
# [attempt=52] pdl_no: SUCCESS pe=0.350070 ape=0.350070
# [attempt=52] est=-67.949272, SE=4.625704, 95% CI=[-77.015486, -58.883058], covered=True
# [attempt=52] pdl_user: SUCCESS pe=-0.010282 ape=0.010282
# [attempt=52] est=-86.498848, SE=0.000001, 95% CI=[-86.498849, -86.498846], covered=False
# [attempt=52] pdl_product: SUCCESS pe=0.259903 ape=0.259903
# [attempt=52] est=-93.538109, SE=1.965928, 95% CI=[-97.391257, -89.684960], covered=False
# [attempt=52] pdl_all: SUCCESS pe=0.362433 ape=0.362433
#
# === Bootstrap attempt 53 === pdl_no:53/100 | pdl_user:49/100 | pdl_product:46/100 | pdl_all:49/100
# [attempt=53] est=-70.840958, SE=0.000000, 95% CI=[-70.840958, -70.840958], covered=False
# [attempt=53] pdl_no: SUCCESS pe=0.031837 ape=0.031837
# [attempt=53] pdl_user: EXCEPTION -> skipped | ValueError('not enough values to unpack (expected 5, got 3)')
# [attempt=53] est=-82.206902, SE=0.000000, 95% CI=[-82.206902, -82.206902], covered=False
# [attempt=53] pdl_product: SUCCESS pe=0.197388 ape=0.197388
# [attempt=53] est=-81.457428, SE=1.966855, 95% CI=[-85.312393, -77.602463], covered=False
# [attempt=53] pdl_all: SUCCESS pe=0.186472 ape=0.186472
#
# === Bootstrap attempt 54 === pdl_no:54/100 | pdl_user:49/100 | pdl_product:47/100 | pdl_all:50/100
# [attempt=54] est=-53.623924, SE=0.000000, 95% CI=[-53.623925, -53.623923], covered=False
# [attempt=54] pdl_no: SUCCESS pe=-0.218938 ape=0.218938
# [attempt=54] est=-116.432304, SE=1.952857, 95% CI=[-120.259835, -112.604774], covered=False
# [attempt=54] pdl_user: SUCCESS pe=0.695900 ape=0.695900
# [attempt=54] est=-104.902840, SE=0.000000, 95% CI=[-104.902840, -104.902840], covered=False
# [attempt=54] pdl_product: SUCCESS pe=0.527967 ape=0.527967
# [attempt=54] pdl_all: EXCEPTION -> skipped | ValueError('not enough values to unpack (expected 5, got 3)')
#
# === Bootstrap attempt 55 === pdl_no:55/100 | pdl_user:50/100 | pdl_product:48/100 | pdl_all:50/100
# [attempt=55] est=-64.912453, SE=0.000000, 95% CI=[-64.912453, -64.912453], covered=False
# [attempt=55] pdl_no: SUCCESS pe=-0.054515 ape=0.054515
# [attempt=55] est=-69.100739, SE=4.078249, 95% CI=[-77.093962, -61.107515], covered=True
# [attempt=55] pdl_user: SUCCESS pe=0.006490 ape=0.006490
# [attempt=55] est=-70.810135, SE=0.000001, 95% CI=[-70.810136, -70.810133], covered=False
# [attempt=55] pdl_product: SUCCESS pe=0.031388 ape=0.031388
# [attempt=55] est=-75.307701, SE=2.565351, 95% CI=[-80.335698, -70.279704], covered=False
# [attempt=55] pdl_all: SUCCESS pe=0.096898 ape=0.096898
#
# === Bootstrap attempt 56 === pdl_no:56/100 | pdl_user:51/100 | pdl_product:49/100 | pdl_all:51/100
# [attempt=56] est=-65.341507, SE=0.000000, 95% CI=[-65.341508, -65.341506], covered=False
# [attempt=56] pdl_no: SUCCESS pe=-0.048265 ape=0.048265
# [attempt=56] est=-48.480286, SE=1.979320, 95% CI=[-52.359682, -44.600889], covered=False
# [attempt=56] pdl_user: SUCCESS pe=-0.293858 ape=0.293858
# [attempt=56] est=-65.482887, SE=0.000001, 95% CI=[-65.482889, -65.482886], covered=False
# [attempt=56] pdl_product: SUCCESS pe=-0.046206 ape=0.046206
# [attempt=56] est=-64.185020, SE=1.984964, 95% CI=[-68.075479, -60.294562], covered=False
# [attempt=56] pdl_all: SUCCESS pe=-0.065110 ape=0.065110
#
# === Bootstrap attempt 57 === pdl_no:57/100 | pdl_user:52/100 | pdl_product:50/100 | pdl_all:52/100
# [attempt=57] est=-59.043159, SE=0.000000, 95% CI=[-59.043159, -59.043159], covered=False
# [attempt=57] pdl_no: SUCCESS pe=-0.140004 ape=0.140004
# [attempt=57] pdl_user: EXCEPTION -> skipped | ValueError('not enough values to unpack (expected 5, got 3)')
# [attempt=57] est=-43.118008, SE=0.000000, 95% CI=[-43.118008, -43.118008], covered=False
# [attempt=57] pdl_product: SUCCESS pe=-0.371963 ape=0.371963
# [attempt=57] est=-64.724785, SE=0.960092, 95% CI=[-66.606531, -62.843039], covered=False
# [attempt=57] pdl_all: SUCCESS pe=-0.057248 ape=0.057248
#
# === Bootstrap attempt 58 === pdl_no:58/100 | pdl_user:52/100 | pdl_product:51/100 | pdl_all:53/100
# [attempt=58] est=-11.734485, SE=0.000000, 95% CI=[-11.734485, -11.734484], covered=False
# [attempt=58] pdl_no: SUCCESS pe=-0.829081 ape=0.829081
# [attempt=58] est=-16.461395, SE=1.042035, 95% CI=[-18.503747, -14.419044], covered=False
# [attempt=58] pdl_user: SUCCESS pe=-0.760231 ape=0.760231
# [attempt=58] est=-23.679775, SE=0.000000, 95% CI=[-23.679776, -23.679774], covered=False
# [attempt=58] pdl_product: SUCCESS pe=-0.655091 ape=0.655091
# [attempt=58] est=-39.217865, SE=1.434675, 95% CI=[-42.029777, -36.405953], covered=False
# [attempt=58] pdl_all: SUCCESS pe=-0.428770 ape=0.428770
#
# === Bootstrap attempt 59 === pdl_no:59/100 | pdl_user:53/100 | pdl_product:52/100 | pdl_all:54/100
# [attempt=59] est=-113.032356, SE=0.000002, 95% CI=[-113.032359, -113.032353], covered=False
# [attempt=59] pdl_no: SUCCESS pe=0.646378 ape=0.646378
# [attempt=59] est=-112.463745, SE=2.211052, 95% CI=[-116.797327, -108.130163], covered=False
# [attempt=59] pdl_user: SUCCESS pe=0.638096 ape=0.638096
# [attempt=59] pdl_product: EXCEPTION -> skipped | ValueError('not enough values to unpack (expected 5, got 3)')
# [attempt=59] pdl_all: EXCEPTION -> skipped | ValueError('not enough values to unpack (expected 5, got 3)')
#
# === Bootstrap attempt 60 === pdl_no:60/100 | pdl_user:54/100 | pdl_product:52/100 | pdl_all:54/100
# [attempt=60] est=-92.668282, SE=0.000000, 95% CI=[-92.668282, -92.668282], covered=False
# [attempt=60] pdl_no: SUCCESS pe=0.349764 ape=0.349764
# [attempt=60] est=-71.469322, SE=2.136688, 95% CI=[-75.657155, -67.281490], covered=True
# [attempt=60] pdl_user: SUCCESS pe=0.040990 ape=0.040990
# [attempt=60] est=-79.106308, SE=0.000000, 95% CI=[-79.106308, -79.106308], covered=False
# [attempt=60] pdl_product: SUCCESS pe=0.152226 ape=0.152226
# [attempt=60] est=-87.954300, SE=1.926570, 95% CI=[-91.730309, -84.178291], covered=False
# [attempt=60] pdl_all: SUCCESS pe=0.281102 ape=0.281102
#
# === Bootstrap attempt 61 === pdl_no:61/100 | pdl_user:55/100 | pdl_product:53/100 | pdl_all:55/100
# [attempt=61] est=-58.911427, SE=0.000001, 95% CI=[-58.911428, -58.911425], covered=False
# [attempt=61] pdl_no: SUCCESS pe=-0.141923 ape=0.141923
# [attempt=61] est=-73.991898, SE=1.593457, 95% CI=[-77.115017, -70.868779], covered=False
# [attempt=61] pdl_user: SUCCESS pe=0.077732 ape=0.077732
# [attempt=61] est=-70.270546, SE=0.000000, 95% CI=[-70.270547, -70.270545], covered=False
# [attempt=61] pdl_product: SUCCESS pe=0.023529 ape=0.023529
# [attempt=61] est=-76.719368, SE=2.842044, 95% CI=[-82.289672, -71.149064], covered=False
# [attempt=61] pdl_all: SUCCESS pe=0.117459 ape=0.117459
#
# === Bootstrap attempt 62 === pdl_no:62/100 | pdl_user:56/100 | pdl_product:54/100 | pdl_all:56/100
# [attempt=62] est=-76.437447, SE=0.000000, 95% CI=[-76.437447, -76.437447], covered=False
# [attempt=62] pdl_no: SUCCESS pe=0.113353 ape=0.113353
# [attempt=62] pdl_user: EXCEPTION -> skipped | ValueError('not enough values to unpack (expected 5, got 3)')
# [attempt=62] est=-65.846870, SE=0.000001, 95% CI=[-65.846873, -65.846868], covered=False
# [attempt=62] pdl_product: SUCCESS pe=-0.040905 ape=0.040905
# [attempt=62] est=-69.674339, SE=0.996341, 95% CI=[-71.627132, -67.721546], covered=True
# [attempt=62] pdl_all: SUCCESS pe=0.014845 ape=0.014845
#
# === Bootstrap attempt 63 === pdl_no:63/100 | pdl_user:56/100 | pdl_product:55/100 | pdl_all:57/100
# [attempt=63] est=-62.443325, SE=0.000001, 95% CI=[-62.443327, -62.443324], covered=False
# [attempt=63] pdl_no: SUCCESS pe=-0.090479 ape=0.090479
# [attempt=63] est=-69.026840, SE=1.530036, 95% CI=[-72.025656, -66.028025], covered=True
# [attempt=63] pdl_user: SUCCESS pe=0.005413 ape=0.005413
# [attempt=63] est=-96.447166, SE=0.000001, 95% CI=[-96.447168, -96.447165], covered=False
# [attempt=63] pdl_product: SUCCESS pe=0.404805 ape=0.404805
# [attempt=63] est=-86.152626, SE=0.416092, 95% CI=[-86.968152, -85.337101], covered=False
# [attempt=63] pdl_all: SUCCESS pe=0.254860 ape=0.254860
#
# === Bootstrap attempt 64 === pdl_no:64/100 | pdl_user:57/100 | pdl_product:56/100 | pdl_all:58/100
# [attempt=64] est=-44.279373, SE=0.000001, 95% CI=[-44.279375, -44.279372], covered=False
# [attempt=64] pdl_no: SUCCESS pe=-0.355047 ape=0.355047
# [attempt=64] est=-76.999001, SE=1.992039, 95% CI=[-80.903326, -73.094675], covered=False
# [attempt=64] pdl_user: SUCCESS pe=0.121532 ape=0.121532
# [attempt=64] est=-69.654678, SE=0.000000, 95% CI=[-69.654678, -69.654678], covered=False
# [attempt=64] pdl_product: SUCCESS pe=0.014558 ape=0.014558
# [attempt=64] est=-64.276695, SE=0.846568, 95% CI=[-65.935938, -62.617452], covered=False
# [attempt=64] pdl_all: SUCCESS pe=-0.063775 ape=0.063775
#
# === Bootstrap attempt 65 === pdl_no:65/100 | pdl_user:58/100 | pdl_product:57/100 | pdl_all:59/100
# [attempt=65] est=-94.407288, SE=0.000000, 95% CI=[-94.407288, -94.407288], covered=False
# [attempt=65] pdl_no: SUCCESS pe=0.375093 ape=0.375093
# [attempt=65] est=-81.568100, SE=3.524006, 95% CI=[-88.475026, -74.661174], covered=False
# [attempt=65] pdl_user: SUCCESS pe=0.188084 ape=0.188084
# [attempt=65] est=-63.747459, SE=0.000001, 95% CI=[-63.747462, -63.747457], covered=False
# [attempt=65] pdl_product: SUCCESS pe=-0.071484 ape=0.071484
# [attempt=65] est=-51.706604, SE=2.750715, 95% CI=[-57.097906, -46.315302], covered=False
# [attempt=65] pdl_all: SUCCESS pe=-0.246865 ape=0.246865
#
# === Bootstrap attempt 66 === pdl_no:66/100 | pdl_user:59/100 | pdl_product:58/100 | pdl_all:60/100
# [attempt=66] est=-70.765182, SE=0.000001, 95% CI=[-70.765184, -70.765181], covered=False
# [attempt=66] pdl_no: SUCCESS pe=0.030733 ape=0.030733
# [attempt=66] est=-62.739532, SE=1.954945, 95% CI=[-66.571155, -58.907910], covered=False
# [attempt=66] pdl_user: SUCCESS pe=-0.086165 ape=0.086165
# [attempt=66] pdl_product: EXCEPTION -> skipped | ValueError('not enough values to unpack (expected 5, got 3)')
# [attempt=66] est=-115.932381, SE=0.930696, 95% CI=[-117.756511, -114.108250], covered=False
# [attempt=66] pdl_all: SUCCESS pe=0.688618 ape=0.688618
#
# === Bootstrap attempt 67 === pdl_no:67/100 | pdl_user:60/100 | pdl_product:58/100 | pdl_all:61/100
# [attempt=67] est=-57.564892, SE=0.000001, 95% CI=[-57.564893, -57.564890], covered=False
# [attempt=67] pdl_no: SUCCESS pe=-0.161536 ape=0.161536
# [attempt=67] pdl_user: EXCEPTION -> skipped | ValueError('not enough values to unpack (expected 5, got 3)')
# [attempt=67] est=-72.589012, SE=0.000001, 95% CI=[-72.589014, -72.589011], covered=False
# [attempt=67] pdl_product: SUCCESS pe=0.057298 ape=0.057298
# [attempt=67] est=-60.584290, SE=0.963597, 95% CI=[-62.472905, -58.695674], covered=False
# [attempt=67] pdl_all: SUCCESS pe=-0.117557 ape=0.117557
#
# === Bootstrap attempt 68 === pdl_no:68/100 | pdl_user:60/100 | pdl_product:59/100 | pdl_all:62/100
# [attempt=68] est=-51.733749, SE=0.000000, 95% CI=[-51.733749, -51.733749], covered=False
# [attempt=68] pdl_no: SUCCESS pe=-0.246470 ape=0.246470
# [attempt=68] est=-106.304329, SE=2.270938, 95% CI=[-110.755286, -101.853372], covered=False
# [attempt=68] pdl_user: SUCCESS pe=0.548380 ape=0.548380
# [attempt=68] est=-89.354828, SE=0.000001, 95% CI=[-89.354829, -89.354826], covered=False
# [attempt=68] pdl_product: SUCCESS pe=0.301502 ape=0.301502
# [attempt=68] est=-73.108879, SE=1.234931, 95% CI=[-75.529299, -70.688459], covered=False
# [attempt=68] pdl_all: SUCCESS pe=0.064871 ape=0.064871
#
# === Bootstrap attempt 69 === pdl_no:69/100 | pdl_user:61/100 | pdl_product:60/100 | pdl_all:63/100
# [attempt=69] pdl_no: EXCEPTION -> skipped | ValueError('not enough values to unpack (expected 5, got 3)')
# [attempt=69] est=-129.206604, SE=1.238788, 95% CI=[-131.634584, -126.778624], covered=False
# [attempt=69] pdl_user: SUCCESS pe=0.881964 ape=0.881964
# [attempt=69] est=-97.905647, SE=0.000000, 95% CI=[-97.905647, -97.905647], covered=False
# [attempt=69] pdl_product: SUCCESS pe=0.426049 ape=0.426049
# [attempt=69] est=-93.494743, SE=1.249859, 95% CI=[-95.944423, -91.045064], covered=False
# [attempt=69] pdl_all: SUCCESS pe=0.361802 ape=0.361802
#
# === Bootstrap attempt 70 === pdl_no:69/100 | pdl_user:62/100 | pdl_product:61/100 | pdl_all:64/100
# [attempt=70] est=-41.262657, SE=0.000000, 95% CI=[-41.262657, -41.262657], covered=False
# [attempt=70] pdl_no: SUCCESS pe=-0.398987 ape=0.398987
# [attempt=70] est=-56.823956, SE=1.588171, 95% CI=[-59.936714, -53.711197], covered=False
# [attempt=70] pdl_user: SUCCESS pe=-0.172328 ape=0.172328
# [attempt=70] est=-60.807884, SE=0.000000, 95% CI=[-60.807885, -60.807883], covered=False
# [attempt=70] pdl_product: SUCCESS pe=-0.114300 ape=0.114300
# [attempt=70] est=-79.349304, SE=0.867466, 95% CI=[-81.049507, -77.649101], covered=False
# [attempt=70] pdl_all: SUCCESS pe=0.155766 ape=0.155766
#
# === Bootstrap attempt 71 === pdl_no:70/100 | pdl_user:63/100 | pdl_product:62/100 | pdl_all:65/100
# [attempt=71] est=-74.272049, SE=0.000000, 95% CI=[-74.272050, -74.272048], covered=False
# [attempt=71] pdl_no: SUCCESS pe=0.081813 ape=0.081813
# [attempt=71] pdl_user: EXCEPTION -> skipped | ValueError('not enough values to unpack (expected 5, got 3)')
# [attempt=71] est=-90.924599, SE=0.000001, 95% CI=[-90.924600, -90.924597], covered=False
# [attempt=71] pdl_product: SUCCESS pe=0.324366 ape=0.324366
# ...
#
# === Bootstrap attempt 88 === pdl_no:87/100 | pdl_user:78/100 | pdl_product:76/100 | pdl_all:79/100
# [attempt=88] est=-43.646477, SE=0.000000, 95% CI=[-43.646477, -43.646477], covered=False
# [attempt=88] pdl_no: SUCCESS pe=-0.364265 ape=0.364265
# [attempt=88] est=-62.263783, SE=1.462569, 95% CI=[-65.130365, -59.397200], covered=False
# [attempt=88] pdl_user: SUCCESS pe=-0.093094 ape=0.093094
# [attempt=88] est=-59.030663, SE=0.000000, 95% CI=[-59.030663, -59.030662], covered=False
# [attempt=88] pdl_product: SUCCESS pe=-0.140186 ape=0.140186
# [attempt=88] est=-68.865608, SE=1.099079, 95% CI=[-71.019765, -66.711452], covered=True
# [attempt=88] pdl_all: SUCCESS pe=0.003065 ape=0.003065
#
# === Bootstrap attempt 89 === pdl_no:88/100 | pdl_user:79/100 | pdl_product:77/100 | pdl_all:80/100
# [attempt=89] est=-113.338715, SE=0.000001, 95% CI=[-113.338716, -113.338713], covered=False
# [attempt=89] pdl_no: SUCCESS pe=0.650840 ape=0.650840
# [attempt=89] est=-65.355209, SE=3.832617, 95% CI=[-72.867002, -57.843417], covered=True
# [attempt=89] pdl_user: SUCCESS pe=-0.048066 ape=0.048066
# [attempt=89] est=-74.149910, SE=0.000000, 95% CI=[-74.149910, -74.149910], covered=False
# [attempt=89] pdl_product: SUCCESS pe=0.080034 ape=0.080034
# [attempt=89] est=-103.106758, SE=1.750264, 95% CI=[-106.537212, -99.676304], covered=False
# [attempt=89] pdl_all: SUCCESS pe=0.501806 ape=0.501806
#
# === Bootstrap attempt 90 === pdl_no:89/100 | pdl_user:80/100 | pdl_product:78/100 | pdl_all:81/100
# [attempt=90] est=-60.351555, SE=0.000001, 95% CI=[-60.351556, -60.351553], covered=False
# [attempt=90] pdl_no: SUCCESS pe=-0.120947 ape=0.120947
# [attempt=90] est=-60.569313, SE=2.617451, 95% CI=[-65.699424, -55.439202], covered=False
# [attempt=90] pdl_user: SUCCESS pe=-0.117775 ape=0.117775
# [attempt=90] est=-59.727379, SE=0.000000, 95% CI=[-59.727379, -59.727379], covered=False
# [attempt=90] pdl_product: SUCCESS pe=-0.130038 ape=0.130038
# [attempt=90] est=-76.199326, SE=1.988901, 95% CI=[-80.097500, -72.301152], covered=False
# [attempt=90] pdl_all: SUCCESS pe=0.109885 ape=0.109885
#
# === Bootstrap attempt 91 === pdl_no:90/100 | pdl_user:81/100 | pdl_product:79/100 | pdl_all:82/100
# [attempt=91] est=-85.668190, SE=0.000001, 95% CI=[-85.668192, -85.668188], covered=False
# [attempt=91] pdl_no: SUCCESS pe=0.247804 ape=0.247804
# [attempt=91] est=-52.461010, SE=3.240057, 95% CI=[-58.811405, -46.110615], covered=False
# [attempt=91] pdl_user: SUCCESS pe=-0.235877 ape=0.235877
# [attempt=91] est=-88.450493, SE=0.000000, 95% CI=[-88.450493, -88.450493], covered=False
# [attempt=91] pdl_product: SUCCESS pe=0.288330 ape=0.288330
# [attempt=91] pdl_all: EXCEPTION -> skipped | ValueError('not enough values to unpack (expected 5, got 3)')
#
# === Bootstrap attempt 92 === pdl_no:91/100 | pdl_user:82/100 | pdl_product:80/100 | pdl_all:82/100
# [attempt=92] est=-84.798820, SE=0.000000, 95% CI=[-84.798820, -84.798820], covered=False
# [attempt=92] pdl_no: SUCCESS pe=0.235141 ape=0.235141
# [attempt=92] pdl_user: EXCEPTION -> skipped | ValueError('not enough values to unpack (expected 5, got 3)')
# [attempt=92] est=-113.529099, SE=0.000002, 95% CI=[-113.529102, -113.529095], covered=False
# [attempt=92] pdl_product: SUCCESS pe=0.653613 ape=0.653613
# [attempt=92] est=-115.566895, SE=1.234393, 95% CI=[-117.986261, -113.147528], covered=False
# [attempt=92] pdl_all: SUCCESS pe=0.683295 ape=0.683295
#
# === Bootstrap attempt 93 === pdl_no:92/100 | pdl_user:82/100 | pdl_product:81/100 | pdl_all:83/100
# [attempt=93] est=-63.914646, SE=0.000000, 95% CI=[-63.914647, -63.914645], covered=False
# [attempt=93] pdl_no: SUCCESS pe=-0.069048 ape=0.069048
# [attempt=93] est=-58.146553, SE=4.791581, 95% CI=[-67.537880, -48.755226], covered=False
# [attempt=93] pdl_user: SUCCESS pe=-0.153064 ape=0.153064
# [attempt=93] pdl_product: EXCEPTION -> skipped | ValueError('not enough values to unpack (expected 5, got 3)')
# [attempt=93] est=-70.788483, SE=1.462696, 95% CI=[-73.655315, -67.921651], covered=True
# [attempt=93] pdl_all: SUCCESS pe=0.031073 ape=0.031073
#
# === Bootstrap attempt 94 === pdl_no:93/100 | pdl_user:83/100 | pdl_product:81/100 | pdl_all:84/100
# [attempt=94] est=-62.759476, SE=0.000001, 95% CI=[-62.759477, -62.759474], covered=False
# [attempt=94] pdl_no: SUCCESS pe=-0.085874 ape=0.085874
# [attempt=94] pdl_user: EXCEPTION -> skipped | ValueError('not enough values to unpack (expected 5, got 3)')
# [attempt=94] est=-61.065319, SE=0.000000, 95% CI=[-61.065320, -61.065318], covered=False
# [attempt=94] pdl_product: SUCCESS pe=-0.110550 ape=0.110550
# [attempt=94] est=-90.760941, SE=1.612517, 95% CI=[-93.921416, -87.600465], covered=False
# [attempt=94] pdl_all: SUCCESS pe=0.321982 ape=0.321982
#
# === Bootstrap attempt 95 === pdl_no:94/100 | pdl_user:83/100 | pdl_product:82/100 | pdl_all:85/100
# [attempt=95] est=-51.875931, SE=0.000001, 95% CI=[-51.875932, -51.875929], covered=False
# [attempt=95] pdl_no: SUCCESS pe=-0.244399 ape=0.244399
# [attempt=95] est=-64.644760, SE=1.470976, 95% CI=[-67.527821, -61.761699], covered=False
# [attempt=95] pdl_user: SUCCESS pe=-0.058414 ape=0.058414
# [attempt=95] est=-51.582973, SE=0.000000, 95% CI=[-51.582973, -51.582973], covered=False
# [attempt=95] pdl_product: SUCCESS pe=-0.248666 ape=0.248666
# [attempt=95] est=-68.822342, SE=1.384386, 95% CI=[-71.535688, -66.108996], covered=True
# [attempt=95] pdl_all: SUCCESS pe=0.002435 ape=0.002435
#
# === Bootstrap attempt 96 === pdl_no:95/100 | pdl_user:84/100 | pdl_product:83/100 | pdl_all:86/100
# [attempt=96] est=-68.447647, SE=0.000000, 95% CI=[-68.447647, -68.447647], covered=False
# [attempt=96] pdl_no: SUCCESS pe=-0.003023 ape=0.003023
# [attempt=96] pdl_user: EXCEPTION -> skipped | ValueError('not enough values to unpack (expected 5, got 3)')
# [attempt=96] est=-94.421227, SE=0.000001, 95% CI=[-94.421228, -94.421225], covered=False
# [attempt=96] pdl_product: SUCCESS pe=0.375296 ape=0.375296
# [attempt=96] est=-88.765778, SE=1.573726, 95% CI=[-91.850225, -85.681331], covered=False
# [attempt=96] pdl_all: SUCCESS pe=0.292922 ape=0.292922
#
# === Bootstrap attempt 97 === pdl_no:96/100 | pdl_user:84/100 | pdl_product:84/100 | pdl_all:87/100
# [attempt=97] est=-102.481697, SE=0.000002, 95% CI=[-102.481700, -102.481694], covered=False
# [attempt=97] pdl_no: SUCCESS pe=0.492702 ape=0.492702
# [attempt=97] est=-93.949745, SE=2.404817, 95% CI=[-98.663100, -89.236390], covered=False
# [attempt=97] pdl_user: SUCCESS pe=0.368429 ape=0.368429
# [attempt=97] est=-103.420670, SE=0.000001, 95% CI=[-103.420671, -103.420668], covered=False
# [attempt=97] pdl_product: SUCCESS pe=0.506378 ape=0.506378
# [attempt=97] est=-86.073563, SE=1.642830, 95% CI=[-89.293451, -82.853674], covered=False
# [attempt=97] pdl_all: SUCCESS pe=0.253708 ape=0.253708
#
# === Bootstrap attempt 98 === pdl_no:97/100 | pdl_user:85/100 | pdl_product:85/100 | pdl_all:88/100
# [attempt=98] est=-44.178684, SE=0.000000, 95% CI=[-44.178685, -44.178683], covered=False
# [attempt=98] pdl_no: SUCCESS pe=-0.356513 ape=0.356513
# [attempt=98] est=-48.156651, SE=1.694744, 95% CI=[-51.478289, -44.835012], covered=False
# [attempt=98] pdl_user: SUCCESS pe=-0.298572 ape=0.298572
# [attempt=98] est=-47.088036, SE=0.000000, 95% CI=[-47.088036, -47.088035], covered=False
# [attempt=98] pdl_product: SUCCESS pe=-0.314137 ape=0.314137
# [attempt=98] est=-30.980503, SE=2.228399, 95% CI=[-35.348085, -26.612922], covered=False
# [attempt=98] pdl_all: SUCCESS pe=-0.548752 ape=0.548752
#
# === Bootstrap attempt 99 === pdl_no:98/100 | pdl_user:86/100 | pdl_product:86/100 | pdl_all:89/100
# [attempt=99] est=-87.906212, SE=0.000000, 95% CI=[-87.906212, -87.906212], covered=False
# [attempt=99] pdl_no: SUCCESS pe=0.280402 ape=0.280402
# [attempt=99] est=-80.499268, SE=1.682711, 95% CI=[-83.797321, -77.201214], covered=False
# [attempt=99] pdl_user: SUCCESS pe=0.172516 ape=0.172516
# [attempt=99] est=-59.865051, SE=0.000001, 95% CI=[-59.865053, -59.865050], covered=False
# [attempt=99] pdl_product: SUCCESS pe=-0.128033 ape=0.128033
# [attempt=99] est=-75.281647, SE=2.777397, 95% CI=[-80.725245, -69.838048], covered=False
# [attempt=99] pdl_all: SUCCESS pe=0.096518 ape=0.096518
#
# === Bootstrap attempt 100 === pdl_no:99/100 | pdl_user:87/100 | pdl_product:87/100 | pdl_all:90/100
# [attempt=100] est=-91.508759, SE=0.000001, 95% CI=[-91.508760, -91.508757], covered=False
# [attempt=100] pdl_no: SUCCESS pe=0.332875 ape=0.332875
# [attempt=100] est=-118.557472, SE=1.420661, 95% CI=[-121.341918, -115.773027], covered=False
# [attempt=100] pdl_user: SUCCESS pe=0.726854 ape=0.726854
# [attempt=100] est=-94.954926, SE=0.000001, 95% CI=[-94.954927, -94.954924], covered=False
# [attempt=100] pdl_product: SUCCESS pe=0.383070 ape=0.383070
# [attempt=100] pdl_all: EXCEPTION -> skipped | ValueError('not enough values to unpack (expected 5, got 3)')
#
# === Bootstrap attempt 101 === pdl_no:100/100 | pdl_user:88/100 | pdl_product:88/100 | pdl_all:90/100
# [attempt=101] est=-77.491867, SE=2.632582, 95% CI=[-82.651633, -72.332101], covered=False
# [attempt=101] pdl_user: SUCCESS pe=0.128711 ape=0.128711
# [attempt=101] est=-66.791946, SE=0.000000, 95% CI=[-66.791947, -66.791946], covered=False
# [attempt=101] pdl_product: SUCCESS pe=-0.027139 ape=0.027139
# [attempt=101] est=-81.639450, SE=1.998326, 95% CI=[-85.556098, -77.722802], covered=False
# [attempt=101] pdl_all: SUCCESS pe=0.189123 ape=0.189123
#
# === Bootstrap attempt 102 === pdl_no:100/100 | pdl_user:89/100 | pdl_product:89/100 | pdl_all:91/100
# [attempt=102] est=-85.176781, SE=2.807103, 95% CI=[-90.678602, -79.674959], covered=False
# [attempt=102] pdl_user: SUCCESS pe=0.240646 ape=0.240646
# [attempt=102] est=-133.144928, SE=0.000001, 95% CI=[-133.144930, -133.144926], covered=False
# [attempt=102] pdl_product: SUCCESS pe=0.939328 ape=0.939328
# [attempt=102] est=-77.368683, SE=2.493515, 95% CI=[-82.255883, -72.481483], covered=False
# [attempt=102] pdl_all: SUCCESS pe=0.126917 ape=0.126917
#
# === Bootstrap attempt 103 === pdl_no:100/100 | pdl_user:90/100 | pdl_product:90/100 | pdl_all:92/100
# [attempt=103] est=-38.996994, SE=2.420721, 95% CI=[-43.741520, -34.252468], covered=False
# [attempt=103] pdl_user: SUCCESS pe=-0.431988 ape=0.431988
# [attempt=103] est=-56.595615, SE=0.000000, 95% CI=[-56.595616, -56.595615], covered=False
# [attempt=103] pdl_product: SUCCESS pe=-0.175654 ape=0.175654
# [attempt=103] est=-59.968700, SE=2.028268, 95% CI=[-63.944034, -55.993367], covered=False
# [attempt=103] pdl_all: SUCCESS pe=-0.126523 ape=0.126523
#
# === Bootstrap attempt 104 === pdl_no:100/100 | pdl_user:91/100 | pdl_product:91/100 | pdl_all:93/100
# [attempt=104] est=-115.555443, SE=2.155897, 95% CI=[-119.780924, -111.329961], covered=False
# [attempt=104] pdl_user: SUCCESS pe=0.683128 ape=0.683128
# [attempt=104] est=-101.133659, SE=0.000000, 95% CI=[-101.133659, -101.133659], covered=False
# [attempt=104] pdl_product: SUCCESS pe=0.473067 ape=0.473067
# [attempt=104] est=-99.639366, SE=1.416516, 95% CI=[-102.415687, -96.863045], covered=False
# [attempt=104] pdl_all: SUCCESS pe=0.451302 ape=0.451302
#
# === Bootstrap attempt 105 === pdl_no:100/100 | pdl_user:92/100 | pdl_product:92/100 | pdl_all:94/100
# [attempt=105] est=-71.472527, SE=2.510177, 95% CI=[-76.392383, -66.552670], covered=True
# [attempt=105] pdl_user: SUCCESS pe=0.041036 ape=0.041036
# [attempt=105] est=-66.367043, SE=0.000000, 95% CI=[-66.367043, -66.367043], covered=False
# [attempt=105] pdl_product: SUCCESS pe=-0.033328 ape=0.033328
# [attempt=105] est=-74.804131, SE=0.833117, 95% CI=[-76.437010, -73.171251], covered=False
# [attempt=105] pdl_all: SUCCESS pe=0.089563 ape=0.089563
#
# === Bootstrap attempt 106 === pdl_no:100/100 | pdl_user:93/100 | pdl_product:93/100 | pdl_all:95/100
# [attempt=106] est=-44.475407, SE=2.001530, 95% CI=[-48.398334, -40.552479], covered=False
# [attempt=106] pdl_user: SUCCESS pe=-0.352192 ape=0.352192
# [attempt=106] est=-53.299679, SE=0.000000, 95% CI=[-53.299680, -53.299678], covered=False
# [attempt=106] pdl_product: SUCCESS pe=-0.223661 ape=0.223661
# [attempt=106] est=-36.364548, SE=1.118403, 95% CI=[-38.556577, -34.172518], covered=False
# [attempt=106] pdl_all: SUCCESS pe=-0.470331 ape=0.470331
#
# === Bootstrap attempt 107 === pdl_no:100/100 | pdl_user:94/100 | pdl_product:94/100 | pdl_all:96/100
# [attempt=107] est=-120.364410, SE=2.102904, 95% CI=[-124.486028, -116.242793], covered=False
# [attempt=107] pdl_user: SUCCESS pe=0.753173 ape=0.753173
# [attempt=107] pdl_product: EXCEPTION -> skipped | ValueError('not enough values to unpack (expected 5, got 3)')
# [attempt=107] est=-125.098274, SE=2.023690, 95% CI=[-129.064633, -121.131915], covered=False
# [attempt=107] pdl_all: SUCCESS pe=0.822124 ape=0.822124
#
# === Bootstrap attempt 108 === pdl_no:100/100 | pdl_user:95/100 | pdl_product:94/100 | pdl_all:97/100
# [attempt=108] est=-47.201019, SE=1.405536, 95% CI=[-49.955820, -44.446219], covered=False
# [attempt=108] pdl_user: SUCCESS pe=-0.312491 ape=0.312491
# [attempt=108] est=-62.985352, SE=0.000000, 95% CI=[-62.985352, -62.985351], covered=False
# [attempt=108] pdl_product: SUCCESS pe=-0.082584 ape=0.082584
# [attempt=108] est=-67.728142, SE=1.679333, 95% CI=[-71.019575, -64.436708], covered=True
# [attempt=108] pdl_all: SUCCESS pe=-0.013503 ape=0.013503
#
# === Bootstrap attempt 109 === pdl_no:100/100 | pdl_user:96/100 | pdl_product:95/100 | pdl_all:98/100
# [attempt=109] est=-66.331650, SE=2.013043, 95% CI=[-70.277142, -62.386157], covered=True
# [attempt=109] pdl_user: SUCCESS pe=-0.033843 ape=0.033843
# [attempt=109] est=-53.207806, SE=0.000000, 95% CI=[-53.207806, -53.207806], covered=False
# [attempt=109] pdl_product: SUCCESS pe=-0.224999 ape=0.224999
# [attempt=109] est=-54.019306, SE=1.875611, 95% CI=[-57.695437, -50.343175], covered=False
# [attempt=109] pdl_all: SUCCESS pe=-0.213179 ape=0.213179
#
# === Bootstrap attempt 110 === pdl_no:100/100 | pdl_user:97/100 | pdl_product:96/100 | pdl_all:99/100
# [attempt=110] pdl_user: EXCEPTION -> skipped | ValueError('not enough values to unpack (expected 5, got 3)')
# [attempt=110] est=-59.185726, SE=0.000000, 95% CI=[-59.185727, -59.185725], covered=False
# [attempt=110] pdl_product: SUCCESS pe=-0.137928 ape=0.137928
# [attempt=110] est=-124.864006, SE=1.326939, 95% CI=[-127.464760, -122.263252], covered=False
# [attempt=110] pdl_all: SUCCESS pe=0.818712 ape=0.818712
#
# === Bootstrap attempt 111 === pdl_no:100/100 | pdl_user:97/100 | pdl_product:97/100 | pdl_all:100/100
# [attempt=111] est=-60.972759, SE=3.496238, 95% CI=[-67.825261, -54.120257], covered=False
# [attempt=111] pdl_user: SUCCESS pe=-0.111899 ape=0.111899
# [attempt=111] est=-77.817184, SE=0.000001, 95% CI=[-77.817186, -77.817183], covered=False
# [attempt=111] pdl_product: SUCCESS pe=0.133450 ape=0.133450
#
# === Bootstrap attempt 112 === pdl_no:100/100 | pdl_user:98/100 | pdl_product:98/100 | pdl_all:100/100
# [attempt=112] est=-46.985462, SE=4.599853, 95% CI=[-56.001010, -37.969915], covered=False
# [attempt=112] pdl_user: SUCCESS pe=-0.315631 ape=0.315631
# [attempt=112] est=-39.502541, SE=0.000000, 95% CI=[-39.502541, -39.502541], covered=False
# [attempt=112] pdl_product: SUCCESS pe=-0.424624 ape=0.424624
#
# === Bootstrap attempt 113 === pdl_no:100/100 | pdl_user:99/100 | pdl_product:99/100 | pdl_all:100/100
# [attempt=113] est=-93.313400, SE=1.516714, 95% CI=[-96.286105, -90.340696], covered=False
# [attempt=113] pdl_user: SUCCESS pe=0.359160 ape=0.359160
# [attempt=113] est=-91.070648, SE=0.000000, 95% CI=[-91.070648, -91.070648], covered=False
# [attempt=113] pdl_product: SUCCESS pe=0.326493 ape=0.326493
#
# ================= BOOTSTRAP SUMMARY =================
# pdl_no: n_ok=100/100 | PE mean=0.060482, PE median=0.032225, std=0.328486 | APE mean=0.261757, APE median=0.206002, std=0.205886 | covered mean=0.000000
# pdl_user: n_ok=100/100 | PE mean=0.062477, PE median=0.027665, std=0.332797 | APE mean=0.250201, APE median=0.180300, std=0.226856 | covered mean=0.260000
# pdl_product: n_ok=100/100 | PE mean=0.022048, PE median=-0.026266, std=0.289260 | APE mean=0.217639, APE median=0.173871, std=0.190571 | covered mean=0.000000
# pdl_all: n_ok=100/100 | PE mean=0.119465, PE median=0.109591, std=0.261961 | APE mean=0.211596, APE median=0.139004, std=0.194460 | covered mean=0.110000
#
# All methods reached 100 successful bootstrap runs.

# %%
num_bootstrap = 100
bootstrap_pe = []
bootstrap_ape = []

for b in range(num_bootstrap):
    seed = 34 + b
    set_seed(seed)

    # Bootstrap resample merged_half with replacement
    boot_df = merged_half.sample(frac=1, replace=True, random_state=seed)

    revenue_control, revenue_treated = calculate_total_revenue(boot_df)

    dim = (revenue_treated - revenue_control) * 600 / 266
    dim_pe = (dim - true) / true
    dim_ape = abs(dim_pe)

    bootstrap_pe.append(dim_pe)
    bootstrap_ape.append(dim_ape)

    if (b + 1) % 10 == 0:
        print(f"Bootstrap iteration {b+1}/{num_bootstrap} complete.")

bootstrap_pe = np.array(bootstrap_pe, dtype=float)
bootstrap_ape = np.array(bootstrap_ape, dtype=float)

mask = np.isfinite(bootstrap_pe) & np.isfinite(bootstrap_ape)
bootstrap_pe = bootstrap_pe[mask]
bootstrap_ape = bootstrap_ape[mask]

mean_pe_dim = np.mean(bootstrap_pe)
median_pe_dim = np.median(bootstrap_pe)
std_pe_dim = np.std(bootstrap_pe, ddof=1)

mean_ape_dim = np.mean(bootstrap_ape)
median_ape_dim = np.median(bootstrap_ape)
std_ape_dim = np.std(bootstrap_ape, ddof=1)

print("\nBootstrap Results (DIM):")
print(f"n = {len(bootstrap_pe)}")
print(f"Mean percentage error: {mean_pe_dim:.5f}")
print(f"Std of PE: {std_pe_dim:.5f}")
print(f"Median percentage error: {median_pe_dim:.5f}")
print(f"\nMean absolute percentage error: {mean_ape_dim:.5f}")
print(f"Std of APE: {std_ape_dim:.5f}")
print(f"Median absolute percentage error: {median_ape_dim:.5f}")
# Out:
# Bootstrap iteration 10/100 complete.
# Bootstrap iteration 20/100 complete.
# Bootstrap iteration 30/100 complete.
# Bootstrap iteration 40/100 complete.
# Bootstrap iteration 50/100 complete.
# Bootstrap iteration 60/100 complete.
# Bootstrap iteration 70/100 complete.
# Bootstrap iteration 80/100 complete.
# Bootstrap iteration 90/100 complete.
# Bootstrap iteration 100/100 complete.
#
# Bootstrap Results (DIM):
# n = 100
# Mean percentage error: -0.11342
# Std of PE: 0.18540
# Median percentage error: -0.15405
#
# Mean absolute percentage error: 0.18721
# Std of APE: 0.10939
# Median absolute percentage error: 0.17024
